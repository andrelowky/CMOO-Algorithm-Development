# %%
# basic dependencies

import numpy as np
from numpy import loadtxt
from numpy import savetxt

import pandas as pd
import math
import time

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

###########

# torch dependencies
import torch

tkwargs = {"dtype": torch.double, # set as double to minimize zero error for cholesky decomposition error
           "device": torch.device("cuda:0" if torch.cuda.is_available() else "cpu")} # set tensors to GPU, if multiple GPUs please set cuda:x properly

torch.set_printoptions(precision=3)

###########

# botorch dependencies
import botorch

# data related
from botorch.utils.sampling import draw_sobol_samples
from botorch.utils.transforms import unnormalize, normalize

# surrogate model specific
from botorch.models.gp_regression import SingleTaskGP
from botorch.models.model_list_gp_regression import ModelListGP
from botorch.models.transforms.outcome import Standardize
from gpytorch.mlls.sum_marginal_log_likelihood import SumMarginalLogLikelihood
from botorch import fit_gpytorch_model

# qNEHVI specific
from botorch.acquisition.multi_objective.objective import IdentityMCMultiOutputObjective
from botorch.acquisition.multi_objective.monte_carlo import qNoisyExpectedHypervolumeImprovement

# utilities
from botorch.optim.optimize import optimize_acqf
from botorch.sampling.samplers import SobolQMCNormalSampler
from botorch.utils.multi_objective.pareto import is_non_dominated
from botorch.utils.multi_objective.hypervolume import Hypervolume
from typing import Optional
from torch import Tensor
from botorch.exceptions import BadInitialCandidatesWarning

import warnings

warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

###########

# pymoo dependencies
import pymoo

from pymoo.problems import get_problem
from pymoo.core.problem import ElementwiseProblem

from pymoo.algorithms.moo.unsga3 import UNSGA3
from pymoo.util.ref_dirs import get_reference_directions
from pymoo.optimize import minimize

from pymoo.core.problem import Problem as PymooProblem
from pymoo.core.termination import NoTermination

###########

# jmetalpy dependencies
from jmetal.core.problem import FloatProblem
from jmetal.core.solution import FloatSolution
from jmetal.util.termination_criterion import StoppingByEvaluations, TerminationCriterion
from jmetal.util.aggregative_function import Tschebycheff
from jmetal.operator import PolynomialMutation, DifferentialEvolutionCrossover
from jmetal.algorithm.multiobjective.moead import Permutation
from jmetal.algorithm.multiobjective import MOEADIEpsilon


###########

from scipy.stats import qmc
from scipy.stats import gaussian_kde # for density plot

###########

# plotting dependencies
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# this is for the colorbar, you can change the cmap if you prefer other colour schemes
from matplotlib.cm import ScalarMappable
cm = plt.cm.get_cmap('viridis')

# function to return the std dev across runs
def ci(y, N_TRIALS):
    return 1.96 * y.std(axis=0) / np.sqrt(N_TRIALS)

SMALL_SIZE = 14
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def optimize_qnehvi(problem, ref_point, initial_x, # must haves
                    N_BATCH, BATCH_SIZE, 
                    random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with Pure qNEHVI")

    t0 = time.time()

    # some initializing 
    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj, train_con = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    train_con_noisy = train_con + noise*torch.randn_like(train_con)
    
    ##########
    
    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, problem.bounds)
    
    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
        
    ##########    
    
    def create_idxr(i):
        def idxr(Z):
            return Z[..., i]

        return idxr

    def create_idxrs():
        return [create_idxr(i=i) for i in range(problem.n_obj, problem.n_obj+problem.n_constr)]
    
    # original location for an extra HV check wrt to initial samples
    
    ########## ########## ########## start of iteration loop


    # training loop for N_BATCH iterations
    for iteration in range(1, N_BATCH + 1):    

        t3 = time.time()
                
        # fit the surrogate model
        fit_gpytorch_model(mll)    
                
        ##########
            
        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x_gp, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            constraints=create_idxrs(), # constraint on last n_constr col
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on
        
        ##########
        
        # propose candidates given defined qNEHVI acq func given model and latest observed training data
        new_x, _ = optimize_acqf(
                        acq_function=acq_func,
                        bounds=standard_bounds, # since train_x was normalized
                        q=BATCH_SIZE, # no of candidates to propose in parallel
                        num_restarts=2, # no of restarts of raw_samples
                        raw_samples=256,  # pool of samples to choose the starting points from
                        options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                        )

        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj, new_con = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)
        new_con_noisy = new_con + noise*torch.randn_like(new_con)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        train_con_noisy = torch.cat([train_con_noisy, new_con_noisy])
        
        ##########
        
        # computing HV of current candidate list
        is_feas = (train_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = train_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0
        
        hvs.append(volume)
        
        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, problem.bounds) # dont forget to renormalize!
        train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)
        
        ##########
        
        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")
            
        del new_x, new_obj, new_con, new_obj_noisy, new_con_noisy, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial     
        
        ########## ########## ########## end of iteration loop

    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")       
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

# %%
def optimize_hybrid_nsga(problem, ref_point, initial_x, # must haves
                         N_BATCH, BATCH_SIZE, 
                         random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with Hybrid qNEHVI + U-NSGA-III")

    t0 = time.time()

    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    pymooproblem = PymooProblem(n_var=problem.n_var, n_obj=problem.n_obj, n_constr=problem.n_constr, 
                  xl=np.zeros(problem.n_var), xu=np.ones(problem.n_var))

    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj, train_con = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    train_con_noisy = train_con + noise*torch.randn_like(train_con)

    ##########

    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, problem.bounds)

    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
    
    ##########    
    
    def create_idxr(i):
        def idxr(Z):
            return Z[..., i]

        return idxr

    def create_idxrs():
        return [create_idxr(i=i) for i in range(problem.n_obj, problem.n_obj+problem.n_constr)]
    
    ########## ########## ########## start of iteration loop

    for iteration in range(1, N_BATCH + 1):   

        t3 = time.time()

        ##########

        fit_gpytorch_model(mll)  

        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x_gp, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            constraints=create_idxrs(), # constraint on last n_constr col
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on

        # propose best candidates given QMC and qNEHVI
        qnehvi_x, _ = optimize_acqf(acq_function=acq_func,
                                    bounds=standard_bounds, # since train_x was normalized
                                    q=BATCH_SIZE, # no of candidates to propose in parallel, 12 is the max for a GTX1065
                                    num_restarts=1, # no of restarts if q candidates fail to show improvement
                                    raw_samples=256,  # pool of samples to choose the starting points from
                                    options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                                 )

        ##########
       
        algorithm = UNSGA3(pop_size=256,
                           ref_dirs=get_reference_directions("energy", problem.n_obj, 256, seed=random_state),
                           sampling=train_x_gp.cpu().numpy(),
                          )

        algorithm.setup(pymooproblem, termination=NoTermination())

        # set the 1st population to the current evaluated population
        pop = algorithm.ask()
        pop.set("F", train_obj_noisy.cpu().numpy())
        pop.set("G", train_con_noisy.cpu().numpy())
        algorithm.tell(infills=pop)

        # propose children based on tournament selection -> crossover/mutation
        newpop = algorithm.ask()
        nsga3_x = torch.tensor(newpop.get("X"), **tkwargs)
        
        ##########

        candidates = torch.cat([qnehvi_x, nsga3_x])

        acq_value_list = []

        for i in range(0, candidates.shape[0]):
            with torch.no_grad():
                acq_value = acq_func(candidates[i].unsqueeze(dim=0))
                acq_value_list.append(acq_value.item())

        pred_hv_list = []
        model.eval();

        for i in range(0, candidates.shape[0]):
            with torch.no_grad():
                posterior = model.posterior(candidates[i].unsqueeze(0))
                pred_y = posterior.mean
                pred_hv = hv.compute(pred_y[:,:problem.n_obj])
                pred_hv_list.append(pred_hv)

        sorted_x = candidates.cpu().numpy()[np.lexsort((pred_hv_list, acq_value_list))]

        ##########
        
        new_x = torch.tensor(sorted_x[-BATCH_SIZE:], **tkwargs) # take best BATCH_SIZE samples
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)
        new_obj, new_con = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)
        new_con_noisy = new_con + noise*torch.randn_like(new_con)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        train_con_noisy = torch.cat([train_con_noisy, new_con_noisy])

        # computing HV of current candidate list
        is_feas = (train_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = train_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0

        hvs.append(volume)

        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, problem.bounds) # dont forget to renormalize!
        train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)

        ##########

        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")

        del new_x, new_obj, new_con, qnehvi_x, nsga3_x, new_obj_noisy, new_con_noisy, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial    
        
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")   
    
    del models, model, mll
    torch.cuda.empty_cache() # clear some memory here between each run/trial  
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

# %%
def optimize_hybrid_moead(problem, ref_point, initial_x, # must haves
                         N_BATCH, BATCH_SIZE, 
                         random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with Hybrid qNEHVI + MOEAD")

    t0 = time.time()

    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    # define jmetal class
    class jmetalproblem(FloatProblem):

        def __init__(self):
            super(jmetalproblem, self).__init__()
            self.number_of_variables = problem.n_var
            self.number_of_objectives = problem.n_obj
            self.number_of_constraints = problem.n_constr

            obj_directions = []
            obj_labels = []

            for i in range(1,problem.n_obj+1):
                obj_directions.append(self.MINIMIZE)
                obj_labels.append(f'f{i}')

            self.obj_directions = obj_directions
            self.obj_labels = obj_labels

            self.lower_bound = [0.0] * problem.n_var
            self.upper_bound = [1.0] * problem.n_var

        def evaluate(self, solution: FloatSolution) -> FloatSolution:
            pass

        def get_name(self):
            return 'jmetalproblem'

    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj, train_con = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    train_con_noisy = train_con + noise*torch.randn_like(train_con)

    ##########

    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, problem.bounds)

    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
    
    ##########    
    
    def create_idxr(i):
        def idxr(Z):
            return Z[..., i]

        return idxr

    def create_idxrs():
        return [create_idxr(i=i) for i in range(problem.n_obj, problem.n_obj+problem.n_constr)]
    
    ########## ########## ########## start of iteration loop

    for iteration in range(1, N_BATCH + 1):   

        t3 = time.time()

        ##########

        fit_gpytorch_model(mll)  

        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x_gp, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            constraints=create_idxrs(), # constraint on last n_constr col
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on

        # propose best candidates given QMC and qNEHVI
        qnehvi_x, _ = optimize_acqf(acq_function=acq_func,
                                    bounds=standard_bounds, # since train_x was normalized
                                    q=BATCH_SIZE, # no of candidates to propose in parallel, 12 is the max for a GTX1065
                                    num_restarts=1, # no of restarts if q candidates fail to show improvement
                                    raw_samples=256,  # pool of samples to choose the starting points from
                                    options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                                 )

        ##########
        
        max_pop = train_x_gp.shape[0]
        
        # redefine a new algo at each iteration
        MOEAD_algo = MOEADIEpsilon(problem=jmetalproblem(),
                          population_size=max_pop,
                          crossover=DifferentialEvolutionCrossover(CR=1.0, F=0.5, K=0.5),
                          mutation=PolynomialMutation(probability=1.0 / jmetalproblem().number_of_variables, distribution_index=20),
                          aggregative_function=Tschebycheff(dimension=jmetalproblem().number_of_objectives),
                          neighbor_size=int(max_pop/2),
                          neighbourhood_selection_probability=0.9,
                          max_number_of_replaced_solutions=2,
                          weight_files_path='weights',
                          #termination_criterion=StoppingByEvaluations(BATCH_SIZE),
                         )
        
        
        # initialize population
        initial_solutions = []

        for i in range(0, max_pop):
            solution1 = FloatSolution(lower_bound=[0.0] * problem.n_var,
                                      upper_bound=[1.0] * problem.n_var,
                                      number_of_objectives=problem.n_obj,
                                      number_of_constraints=problem.n_constr,
                                     )
            solution1.variables = train_x_gp[i].cpu().tolist()
            solution1.objectives = train_obj_noisy[i].cpu().tolist()
            solution1.constraints = train_con_noisy[i].cpu().tolist()
            
            initial_solutions.append(solution1)

        MOEAD_algo.solutions = initial_solutions

        # perform selection, crossover and mutation to form our offspring population
        MOEAD_algo.permutation = Permutation(max_pop)
        offspring_population = []

        for q in range(256):
            mating_population = MOEAD_algo.selection(MOEAD_algo.solutions)
            offspring = MOEAD_algo.reproduction(mating_population)
            offspring_population.append(offspring[0].variables)
            
        moead_x = torch.tensor(offspring_population, **tkwargs)
        
        ##########

        candidates = torch.cat([qnehvi_x, moead_x])

        acq_value_list = []

        for i in range(0, candidates.shape[0]):
            with torch.no_grad():
                acq_value = acq_func(candidates[i].unsqueeze(dim=0))
                acq_value_list.append(acq_value.item())

        pred_hv_list = []
        model.eval();

        for i in range(0, candidates.shape[0]):
            with torch.no_grad():
                posterior = model.posterior(candidates[i].unsqueeze(0))
                pred_y = posterior.mean
                pred_hv = hv.compute(pred_y[:,:problem.n_obj])
                pred_hv_list.append(pred_hv)

        sorted_x = candidates.cpu().numpy()[np.lexsort((pred_hv_list, acq_value_list))]

        ##########
        
        new_x = torch.tensor(sorted_x[-BATCH_SIZE:], **tkwargs) # take best BATCH_SIZE samples
        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj, new_con = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)
        new_con_noisy = new_con + noise*torch.randn_like(new_con)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        train_con_noisy = torch.cat([train_con_noisy, new_con_noisy])

        # computing HV of current candidate list
        is_feas = (train_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = train_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0

        hvs.append(volume)

        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, problem.bounds) # dont forget to renormalize!
        train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)

        ##########

        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")

        del new_x, new_obj, new_con, qnehvi_x, moead_x, new_obj_noisy, new_con_noisy, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial    
        
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")   
    
    del models, model, mll
    torch.cuda.empty_cache() # clear some memory here between each run/trial  
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

# %%
'''dimensions = 8
    
from botorch.test_functions.multi_objective import MW7

MW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)

class Problem_MW7(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 2
    
    ref_point = torch.tensor([1.2,1.2], **tkwargs)
    
    bounds = MW7base.bounds    
    
    def evaluate(X):       
        output = MW7base(X)
        slack = -MW7base.evaluate_slack(X)
       
        return output, slack

from botorch.test_functions.multi_objective import WeldedBeam

WeldedBeambase = WeldedBeam(negate=True).to(**tkwargs)

class Problem_WeldedBeam(torch.nn.Module):
    n_var = WeldedBeambase.dim
    n_obj = WeldedBeambase.num_objectives
    n_constr = WeldedBeambase.num_constraints
    
    ref_point = torch.tensor([40,0.015], **tkwargs)
    
    bounds = WeldedBeambase.bounds    
    
    def evaluate(X):       
        output = WeldedBeambase(X)
        slack = -WeldedBeambase.evaluate_slack(X)
       
        return output, slack
    
# this is equivalent to difficulty triplet no4 in pymoo's API
diff1 = 0.25
diff2 = 0.25
diff3 = 0.25

class Problem_DAS1(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 11
    bounds = torch.stack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    # this will change depending on difficulty triplet
    # check the actual PF from pymoo to find
    ref_point = torch.tensor([1.6,1.6], **tkwargs)
    
    def evaluate(X):
        g = torch.zeros(X.shape[0], **tkwargs)
        for i in range(X.shape[1]):
            g += torch.pow(X[...,i] - torch.sin(0.5 * np.pi * X[...,0]), 2)

        f1 = X[...,0] + g
        f2 = 1.0 - torch.pow(X[...,0], 2) + g
        
        #################
        
        a = 20
        b = 2 * diff1 - 1.
        d = 0.5 if diff2 != 0 else 0
        if diff2 > 0:
            e = d - torch.log(torch.tensor(diff2, **tkwargs))
        else:
            e = 1e30
        r = 0.5 * diff3

        p_k = [0., 1.0, 0., 1.0, 2.0, 0., 1.0, 2.0, 3.0]
        q_k = [1.5, 0.5, 2.5, 1.5, 0.5, 3.5, 2.5, 1.5, 0.5]

        a_k2 = 0.3
        b_k2 = 1.2
        theta_k = torch.tensor(-0.25 * torch.pi, **tkwargs)

        c = torch.zeros((X.shape[0], 11), **tkwargs)

        c[...,0] = torch.sin(a * torch.pi * X[...,0]) - b

        if diff2 == 1:
            c[...,1] = 1e-4 - torch.abs(e - g, **tkwargs)
        else:
            c[...,1] = (e - g) * (g - d)

        for i in range(2, 11):
            c[...,i] = ((f1 - p_k[i-2]) * torch.cos(theta_k) - (f2 - q_k[i-2]) * torch.sin(theta_k)) ** 2 / a_k2 + ((f1 - p_k[i-2]) * torch.sin(theta_k) + (f2 - q_k[i-2]) * torch.cos(theta_k)) ** 2 / b_k2 - r


        ####################
        
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        output = torch.stack([-f1, -f2], dim=-1)
        
        # constraint equations should take the form of c(n)<=0
        # should return <=0 values when constraints are active,
        # and >0 values when constraints are violated
        slack = -c    
        
        return output, slack
    
class MWBase(torch.nn.Module):   
    def g1(X, n_obj):
        d = dimensions
        n = d - n_obj

        z = torch.pow(X[..., n_obj - 1:], n)
        i = torch.arange(n_obj - 1, d, **tkwargs)

        exp = 1 - torch.exp(-10.0 * (z - 0.5 - i / (2 * d)) * (z - 0.5 - i / (2 * d)))
        distance = 1 + exp.sum(axis=1)
        return distance
    
    def g3(X, n_obj):
        contrib = 2.0 * torch.pow(
            X[..., n_obj - 1:] + (X[..., n_obj - 2:-1] - 0.5) * (X[..., n_obj - 2:-1] - 0.5) - 1.0, 2.0)
        
        distance = 1 + contrib.sum(axis=1)
        return distance
    
    def LA1(A, B, C, D, theta):
        return A * torch.pow(torch.sin(B * np.pi * torch.pow(theta, C)), D)

    def LA2(A, B, C, D, theta):
        return A * torch.pow(torch.sin(B * torch.pow(theta, C)), D)
    
class Problem_MW3(torch.nn.Module):
    # must define these!
    n_var = dimensions
    n_obj = 2
    n_constr = 2 # inequality constraints only!
    
    ref_point = torch.tensor([1.1,1.1], **tkwargs)
        
    # input bounds, don't forget to change according to n_var!  
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):
        
        # objectives are defined by f1, f2....
        # if you have complex equations, you can break it up and place them in ProblemBase for convenience, not compulsory
        # otherwise, you could place an oracle here that outputs the objective
        g = MWBase.g3(X, n_obj=2)
        f1 = X[:, 0]
        f2 = g * (1.0 - f1 / g)
        
        # inequality constraints should take the form of c(n)<=0
        # for equality constraints, either use the equality constr argument, or rewrite into inequality form (preferred)
        # if no constraints, write as c1 = 0 * X[..., 0], and set n_constr=1     
        c1 = f1 + f2 - 1.05 - MWBase.LA1(0.45, 0.75, 1.0, 6.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)
        c2 = 0.85 - f1 - f2 + MWBase.LA1(0.3, 0.75, 1.0, 2.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)
        
        # botorch assumes maximisation
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        output = torch.stack([-f1, -f2], dim=-1)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        slack = torch.stack([c1, c2], dim=-1)
        
        return output, slack
    
class Problem_MW5(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 3
    
    ref_point = torch.tensor([1.2,1.2], **tkwargs)

    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        
        g1 = MWBase.g3(X, n_obj=2)
        f1 = g1 * X[:, 0]
        f2 = g1 * torch.sqrt(1.0 - torch.pow(f1 / g1, 2.0))
                
        # constraint equations should take the form of c(n)<=0
        # should return <=0 values when constraints are active,
        # and >0 values when constraints are violated
        # take care if constraints are too restrictive, will cause early flatlining if all samples are rejected
        atan = torch.arctan(f2 / f1)
        c1 =  (f1 ** 2) + (f2 ** 2) - torch.pow(1.7 - MWBase.LA2(0.2, 2.0, 1.0, 1.0, atan), 2.0) 

        t = 0.5 * np.pi - 2 * torch.abs(atan - 0.25 * np.pi)
        c2 = torch.pow(1 + MWBase.LA2(0.5, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)
        c3 = torch.pow(1 - MWBase.LA2(0.45, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)
        
        output = torch.stack([-f1, -f2], dim=-1)
        slack = torch.stack([c1, c2, c3], dim=-1)
        
        return output, slack

class Problem_MW12(torch.nn.Module):
    # must define these!
    n_var = dimensions
    n_obj = 2
    n_constr = 2 # inequality constraints only!
    
    ref_point = torch.tensor([1.5,1.5], **tkwargs)
        
    # input bounds, don't forget to change according to n_var!  
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):
        
        # objectives are defined by f1, f2....
        # if you have complex equations, you can break it up and place them in ProblemBase for convenience, not compulsory
        # otherwise, you could place an oracle here that outputs the objective
        g = MWBase.g1(X, n_obj=2)
        f1 = g * X[:, 0]
        f2 = g * (0.85 - 0.8 * (f1 / g) - 0.08 *torch.abs(torch.sin(3.2 * torch.pi * (f1 / g))))
        
        # inequality constraints should take the form of c(n)<=0
        # for equality constraints, either use the equality constr argument, or rewrite into inequality form (preferred)
        # if no constraints, write as c1 = 0 * X[..., 0], and set n_constr=1     
        c1 = -1.0 * (1 - 0.625 * f1 - f2 + 0.08 * torch.sin(2 * torch.pi * (f2 - f1 / 1.6))) * (1.4 - 0.875 * f1 - f2 + 0.08 * torch.sin(2 * torch.pi * (f2 / 1.4 - f1 / 1.6)))
        c2 = (1 - 0.8 * f1 - f2 + 0.08 * torch.sin(2 * torch.pi * (f2 - f1 / 1.5))) * (1.8 - 1.125 * f1 - f2 + 0.08 * torch.sin(2 * torch.pi * (f2 / 1.8 - f1 / 1.6)))
        
        # botorch assumes maximisation
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        output = torch.stack([-f1, -f2], dim=-1)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        slack = torch.stack([c1, c2], dim=-1)
        
        return output, slack
    
initial_x_array = loadtxt("initial_x_10trials8dim_01bounds.csv", delimiter=',')
initial_x_array = initial_x_array.reshape(10, 18, 8)'''
# Out:
# 'dimensions = 8\n    \nfrom botorch.test_functions.multi_objective import MW7\n\nMW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)\n\nclass Problem_MW7(torch.nn.Module):\n    n_var = dimensions\n    n_obj = 2\n    n_constr = 2\n    \n    ref_point = torch.tensor([1.2,1.2], **tkwargs)\n    \n    bounds = MW7base.bounds    \n    \n    def evaluate(X):       \n        output = MW7base(X)\n        slack = -MW7base.evaluate_slack(X)\n       \n        return output, slack\n\nfrom botorch.test_functions.multi_objective import WeldedBeam\n\nWeldedBeambase = WeldedBeam(negate=True).to(**tkwargs)\n\nclass Problem_WeldedBeam(torch.nn.Module):\n    n_var = WeldedBeambase.dim\n    n_obj = WeldedBeambase.num_objectives\n    n_constr = WeldedBeambase.num_constraints\n    \n    ref_point = torch.tensor([40,0.015], **tkwargs)\n    \n    bounds = WeldedBeambase.bounds    \n    \n    def evaluate(X):       \n        output = WeldedBeambase(X)\n        slack = -WeldedBeambase.evaluate_slack(X)\n       \n        return output, slack\n    \n# this is equivalent to difficulty triplet no4 in pymoo\'s API\ndiff1 = 0.25\ndiff2 = 0.25\ndiff3 = 0.25\n\nclass Problem_DAS1(torch.nn.Module):\n    n_var = dimensions\n    n_obj = 2\n    n_constr = 11\n    bounds = torch.stack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])\n    \n    # this will change depending on difficulty triplet\n    # check the actual PF from pymoo to find\n    ref_point = torch.tensor([1.6,1.6], **tkwargs)\n    \n    def evaluate(X):\n        g = torch.zeros(X.shape[0], **tkwargs)\n        for i in range(X.shape[1]):\n            g += torch.pow(X[...,i] - torch.sin(0.5 * np.pi * X[...,0]), 2)\n\n        f1 = X[...,0] + g\n        f2 = 1.0 - torch.pow(X[...,0], 2) + g\n        \n        #################\n        \n        a = 20\n        b = 2 * diff1 - 1.\n        d = 0.5 if diff2 != 0 else 0\n        if diff2 > 0:\n            e = d - torch.log(torch.tensor(diff2, **tkwargs))\n        else:\n            e = 1e30\n        r = 0.5 * diff3\n\n        p_k = [0., 1.0, 0., 1.0, 2.0, 0., 1.0, 2.0, 3.0]\n        q_k = [1.5, 0.5, 2.5, 1.5, 0.5, 3.5, 2.5, 1.5, 0.5]\n\n        a_k2 = 0.3\n        b_k2 = 1.2\n        theta_k = torch.tensor(-0.25 * torch.pi, **tkwargs)\n\n        c = torch.zeros((X.shape[0], 11), **tkwargs)\n\n        c[...,0] = torch.sin(a * torch.pi * X[...,0]) - b\n\n        if diff2 == 1:\n            c[...,1] = 1e-4 - torch.abs(e - g, **tkwargs)\n        else:\n            c[...,1] = (e - g) * (g - d)\n\n        for i in range(2, 11):\n            c[...,i] = ((f1 - p_k[i-2]) * torch.cos(theta_k) - (f2 - q_k[i-2]) * torch.sin(theta_k)) ** 2 / a_k2 + ((f1 - p_k[i-2]) * torch.sin(theta_k) + (f2 - q_k[i-2]) * torch.cos(theta_k)) ** 2 / b_k2 - r\n\n\n        ####################\n        \n        # to maximise a postive output, stay positive\n        # to minimise a positive output, force negative\n        # to maximise a negative output (away from zero), force positive\n        # to minimise a negative output (towards zero), stay negative\n        output = torch.stack([-f1, -f2], dim=-1)\n        \n        # constraint equations should take the form of c(n)<=0\n        # should return <=0 values when constraints are active,\n        # and >0 values when constraints are violated\n        slack = -c    \n        \n        return output, slack\n    \nclass MWBase(torch.nn.Module):   \n    def g1(X, n_obj):\n        d = dimensions\n        n = d - n_obj\n\n        z = torch.pow(X[..., n_obj - 1:], n)\n        i = torch.arange(n_obj - 1, d, **tkwargs)\n\n        exp = 1 - torch.exp(-10.0 * (z - 0.5 - i / (2 * d)) * (z - 0.5 - i / (2 * d)))\n        distance = 1 + exp.sum(axis=1)\n        return distance\n    \n    def g3(X, n_obj):\n        contrib = 2.0 * torch.pow(\n            X[..., n_obj - 1:] + (X[..., n_obj - 2:-1] - 0.5) * (X[..., n_obj - 2:-1] - 0.5) - 1.0, 2.0)\n        \n        distance = 1 + contrib.sum(axis=1)\n        return distance\n   ...

# %%
import joblib

initial_x_dict = joblib.load('initial_x_dict')

# %%
problemname = 'MW5'

N_TRIALS = 5
verbose = True
noise = 0.00

N_BATCH = 24
BATCH_SIZE = 8

for dimensions in range(8, 12+ 1):
    
    class MWBase(torch.nn.Module):   
        def g1(X, n_obj):
            d = dimensions
            n = d - n_obj

            z = torch.pow(X[..., n_obj - 1:], n)
            i = torch.arange(n_obj - 1, d, **tkwargs)

            exp = 1 - torch.exp(-10.0 * (z - 0.5 - i / (2 * d)) * (z - 0.5 - i / (2 * d)))
            distance = 1 + exp.sum(axis=1)
            return distance

        def g3(X, n_obj):
            contrib = 2.0 * torch.pow(
                X[..., n_obj - 1:] + (X[..., n_obj - 2:-1] - 0.5) * (X[..., n_obj - 2:-1] - 0.5) - 1.0, 2.0)

            distance = 1 + contrib.sum(axis=1)
            return distance

        def LA1(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * np.pi * torch.pow(theta, C)), D)

        def LA2(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * torch.pow(theta, C)), D)

    class problem(torch.nn.Module):
        n_var = dimensions
        n_obj = 2
        n_constr = 3

        ref_point = torch.tensor([1.2,1.2], **tkwargs)

        bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])

        def evaluate(X):
            # to maximise a postive output, stay positive
            # to minimise a positive output, force negative
            # to maximise a negative output (away from zero), force positive
            # to minimise a negative output (towards zero), stay negative

            g1 = MWBase.g3(X, n_obj=2)
            f1 = g1 * X[:, 0]
            f2 = g1 * torch.sqrt(1.0 - torch.pow(f1 / g1, 2.0))

            # constraint equations should take the form of c(n)<=0
            # should return <=0 values when constraints are active,
            # and >0 values when constraints are violated
            # take care if constraints are too restrictive, will cause early flatlining if all samples are rejected
            atan = torch.arctan(f2 / f1)
            c1 =  (f1 ** 2) + (f2 ** 2) - torch.pow(1.7 - MWBase.LA2(0.2, 2.0, 1.0, 1.0, atan), 2.0) 

            t = 0.5 * np.pi - 2 * torch.abs(atan - 0.25 * np.pi)
            c2 = torch.pow(1 + MWBase.LA2(0.5, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)
            c3 = torch.pow(1 - MWBase.LA2(0.45, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)

            output = torch.stack([-f1, -f2], dim=-1)
            slack = torch.stack([c1, c2, c3], dim=-1)

            return output, slack
        
    hv_list = []
    train_list = []

    # main loop for each trial/run, random_state will be trial number
    for trial in range(0, N_TRIALS):
        print(f"\nTrial {trial+1:>2} of {N_TRIALS} for problem {problemname} with d = {dimensions}\n", end="")

        # initialize with a 2*(d+1) sample set
        initial_x = torch.tensor(initial_x_dict[dimensions][trial], **tkwargs)

        hv, train = optimize_qnehvi(problem, problem.ref_point, initial_x,
                         N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                         random_state=trial, noise=noise, verbose=verbose)
        hv_list.append(hv)
        train_list.append(train)

    savetxt(f"{problemname}_{dimensions}dim_hvs_qnehvi_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", hv_list, delimiter=',')    
    savetxt(f"{problemname}_{dimensions}dim_train_qnehvi_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", np.array(train_list).reshape(-1), delimiter=',')
        
print("All done!")
# Out:
# Trial  1 of 5 for problem MW5 with d = 8
# Optimizing with Pure qNEHVI
# C:\Users\lowki\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2189.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 24: Hypervolume = 0.00, time = 6.30s.
# Batch  2 of 24: Hypervolume = 0.00, time = 28.76s.
# Batch  3 of 24: Hypervolume = 0.00, time = 49.15s.
# Batch  4 of 24: Hypervolume = 0.14, time = 41.50s.
# Batch  5 of 24: Hypervolume = 0.20, time = 44.65s.
# Batch  6 of 24: Hypervolume = 0.20, time = 20.49s.
# Batch  7 of 24: Hypervolume = 0.20, time = 23.00s.
# Batch  8 of 24: Hypervolume = 0.20, time = 36.46s.
# Batch  9 of 24: Hypervolume = 0.20, time = 12.83s.
# Batch 10 of 24: Hypervolume = 0.20, time = 9.41s.
# Batch 11 of 24: Hypervolume = 0.20, time = 35.71s.
# Batch 12 of 24: Hypervolume = 0.20, time = 6.35s.
# Batch 13 of 24: Hypervolume = 0.20, time = 39.08s.
# Batch 14 of 24: Hypervolume = 0.20, time = 30.46s.
# Batch 15 of 24: Hypervolume = 0.20, time = 17.23s.
# Batch 16 of 24: Hypervolume = 0.24, time = 37.33s.
# Batch 17 of 24: Hypervolume = 0.24, time = 6.10s.
# Batch 18 of 24: Hypervolume = 0.24, time = 27.50s.
# Batch 19 of 24: Hypervolume = 0.24, time = 31.35s.
# Batch 20 of 24: Hypervolume = 0.24, time = 6.79s.
# Batch 21 of 24: Hypervolume = 0.24, time = 31.56s.
# Batch 22 of 24: Hypervolume = 0.24, time = 35.56s.
# Batch 23 of 24: Hypervolume = 0.24, time = 29.49s.
# Batch 24 of 24: Hypervolume = 0.24, time = 35.71s.
# Time taken in total: 642.87s.
#
# Trial  2 of 5 for problem MW5 with d = 8
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 25.65s.
# Batch  2 of 24: Hypervolume = 0.13, time = 25.71s.
# Batch  3 of 24: Hypervolume = 0.13, time = 8.66s.
# Batch  4 of 24: Hypervolume = 0.13, time = 43.03s.
# Batch  5 of 24: Hypervolume = 0.13, time = 6.56s.
# Batch  6 of 24: Hypervolume = 0.13, time = 12.74s.
# Batch  7 of 24: Hypervolume = 0.13, time = 11.55s.
# Batch  8 of 24: Hypervolume = 0.13, time = 39.34s.
# Batch  9 of 24: Hypervolume = 0.13, time = 15.11s.
# Batch 10 of 24: Hypervolume = 0.13, time = 25.76s.
# Batch 11 of 24: Hypervolume = 0.14, time = 22.38s.
# Batch 12 of 24: Hypervolume = 0.14, time = 11.06s.
# Batch 13 of 24: Hypervolume = 0.14, time = 35.87s.
# Batch 14 of 24: Hypervolume = 0.14, time = 6.52s.
# Batch 15 of 24: Hypervolume = 0.14, time = 33.81s.
# Batch 16 of 24: Hypervolume = 0.14, time = 23.36s.
# Batch 17 of 24: Hypervolume = 0.14, time = 35.02s.
# Batch 18 of 24: Hypervolume = 0.14, time = 28.16s.
# Batch 19 of 24: Hypervolume = 0.14, time = 12.10s.
# Batch 20 of 24: Hypervolume = 0.14, time = 32.49s.
# Batch 21 of 24: Hypervolume = 0.14, time = 16.42s.
# Batch 22 of 24: Hypervolume = 0.18, time = 37.29s.
# Batch 23 of 24: Hypervolume = 0.18, time = 11.70s.
# Batch 24 of 24: Hypervolume = 0.18, time = 26.78s.
# Time taken in total: 547.06s.
#
# Trial  3 of 5 for problem MW5 with d = 8
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 42.29s.
# Batch  2 of 24: Hypervolume = 0.00, time = 57.12s.
# Batch  3 of 24: Hypervolume = 0.00, time = 7.29s.
# Batch  4 of 24: Hypervolume = 0.00, time = 6.55s.
# Batch  5 of 24: Hypervolume = 0.00, time = 41.35s.
# Batch  6 of 24: Hypervolume = 0.00, time = 34.30s.
# Batch  7 of 24: Hypervolume = 0.00, time = 9.23s.
# Batch  8 of 24: Hypervolume = 0.00, time = 10.95s.
# Batch  9 of 24: Hypervolume = 0.00, time = 23.18s.
# Batch 10 of 24: Hypervolume = 0.00, time = 30.95s.
# Batch 11 of 24: Hypervolume = 0.00, time = 20.74s.
# Batch 12 of 24: Hypervolume = 0.00, time = 11.38s.
# Batch 13 of 24: Hypervolume = 0.15, time = 12.30s.
# Batch 14 of 24: Hypervolume = 0.15, time = 32.18s.
# Batch 15 of 24: Hypervolume = 0.15, time = 6.33s.
# Batch 16 of 24: Hypervolume = 0.19, time = 8.29s.
# Batch 17 of 24: Hypervolume = 0.19, time = 34.03s.
# Batch 18 of 24: Hypervolume = 0.19, time = 8.18s.
# Batch 19 of 24: Hypervolume = 0.19, time = 15.78s.
# Batch 20 of 24: Hypervolume = 0.19, time = 8.50s.
# Batch 21 of 24: Hypervolume = 0.19, time = 4.49s.
# Batch 22 of 24: Hypervolume = 0.19, time = 4.14s.
# Batch 23 of 24: Hypervolume = 0.19, time = 23.91s.
# Batch 24 of 24: Hypervolume = 0.19, time = 36.77s.
# Time taken in total: 490.29s.
#
# Trial  4 of 5 for problem MW5 with d = 8
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 25.77s.
# Batch  2 of 24: Hypervolume = 0.00, time = 13.47s.
# Batch  3 of 24: Hypervolume = 0.00, time = 25.66s.
# Batch  4 of 24: Hypervolume = 0.17, time = 26.00s.
# Batch  5 of 24: Hypervolume = 0.17, time = 23.69s.
# Batch  6 of 24: Hypervolume = 0.17, time = 22.42s.
# Batch  7 of 24: Hypervolume = 0.17, time = 36.67s.
# Batch  8 of 24: Hypervolume = 0.17, time = 16.45s.
# Batch  9 of 24: Hypervolume = 0.17, time = 32.83s.
# Batch 10 of 24: Hypervolume = 0.24, time = 6.20s.
# Batch 11 of 24: Hypervolume = 0.24, time = 32.21s.
# Batch 12 of 24: Hypervolume = 0.24, time = 34.06s.
# Batch 13 of 24: Hypervolume = 0.28, time = 38.08s.
# Batch 14 of 24: Hypervolume = 0.28, time = 23.03s.
# Batch 15 of 24: Hypervolume = 0.28, time = 9.18s.
# Batch 16 of 24: Hypervolume = 0.28, time = 33.00s.
# Batch 17 of 24: Hypervolume = 0.28, time = 25.75s.
# Batch 18 of 24: Hypervolume = 0.28, time = 18.35s.
# Batch 19 of 24: Hypervolume = 0.28, time = 21.03s.
# Batch 20 of 24: Hypervolume = 0.28, time = 5.26s.
# Batch 21 of 24: Hypervolume = 0.30, time = 40.52s.
# Batch 22 of 24: Hypervolume = 0.30, time = 32.20s.
# Batch 23 of 24: Hypervolume = 0.30, time = 34.24s.
# Batch 24 of 24: Hypervolume = 0.30, time = 20.00s.
# Time taken in total: 596.13s.
#
# Trial  5 of 5 for problem MW5 with d = 8
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 42.12s.
# Batch  2 of 24: Hypervolume = 0.00, time = 16.74s.
# Batch  3 of 24: Hypervolume = 0.08, time = 18.82s.
# Batch  4 of 24: Hypervolume = 0.09, time = 36.68s.
# Batch  5 of 24: Hypervolume = 0.09, time = 11.43s.
# Batch  6 of 24: Hypervolume = 0.09, time = 18.22s.
# Batch  7 of 24: Hypervolume = 0.09, time = 33.04s.
# Batch  8 of 24: Hypervolume = 0.19, time = 31.77s.
# Batch  9 of 24: Hypervolume = 0.19, time = 7.14s.
# Batch 10 of 24: Hypervolume = 0.26, time = 16.96s.
# Batch 11 of 24: Hypervolume = 0.26, time = 34.47s.
# Batch 12 of 24: Hypervolume = 0.26, time = 14.19s.
# Batch 13 of 24: Hypervolume = 0.26, time = 32.69s.
# Batch 14 of 24: Hypervolume = 0.26, time = 32.37s.
# Batch 15 of 24: Hypervolume = 0.26, time = 35.43s.
# Batch 16 of 24: Hypervolume = 0.26, time = 32.19s.
# Batch 17 of 24: Hypervolume = 0.27, time = 31.50s.
# Batch 18 of 24: Hypervolume = 0.27, time = 12.30s.
# Batch 19 of 24: Hypervolume = 0.27, time = 13.29s.
# Batch 20 of 24: Hypervolume = 0.27, time = 6.60s.
# Batch 21 of 24: Hypervolume = 0.27, time = 36.28s.
# Batch 22 of 24: Hypervolume = 0.27, time = 9.80s.
# Batch 23 of 24: Hypervolume = 0.27, time = 27.88s.
# Batch 24 of 24: Hypervolume = 0.27, time = 12.60s.
# Time taken in total: 564.58s.
#
# Trial  1 of 5 for problem MW5 with d = 9
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 2.05s.
# Batch  2 of 24: Hypervolume = 0.00, time = 5.12s.
# Batch  3 of 24: Hypervolume = 0.00, time = 39.50s.
# Batch  4 of 24: Hypervolume = 0.00, time = 16.99s.
# Batch  5 of 24: Hypervolume = 0.00, time = 4.45s.
# Batch  6 of 24: Hypervolume = 0.00, time = 9.83s.
# Batch  7 of 24: Hypervolume = 0.00, time = 5.65s.
# Batch  8 of 24: Hypervolume = 0.00, time = 31.19s.
# Batch  9 of 24: Hypervolume = 0.00, time = 13.40s.
# Batch 10 of 24: Hypervolume = 0.06, time = 5.24s.
# Batch 11 of 24: Hypervolume = 0.06, time = 25.89s.
# Batch 12 of 24: Hypervolume = 0.06, time = 32.67s.
# Batch 13 of 24: Hypervolume = 0.06, time = 18.69s.
# Batch 14 of 24: Hypervolume = 0.06, time = 4.09s.
# Batch 15 of 24: Hypervolume = 0.12, time = 4.60s.
# Batch 16 of 24: Hypervolume = 0.12, time = 17.31s.
# Batch 17 of 24: Hypervolume = 0.12, time = 24.95s.
# Batch 18 of 24: Hypervolume = 0.12, time = 32.68s.
# Batch 19 of 24: Hypervolume = 0.12, time = 8.25s.
# Batch 20 of 24: Hypervolume = 0.18, time = 29.52s.
# Batch 21 of 24: Hypervolume = 0.18, time = 14.67s.
# Batch 22 of 24: Hypervolume = 0.18, time = 6.98s.
# Batch 23 of 24: Hypervolume = 0.18, time = 4.20s.
# Batch 24 of 24: Hypervolume = 0.18, time = 13.12s.
# Time taken in total: 371.11s.
#
# Trial  2 of 5 for problem MW5 with d = 9
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 17.54s.
# Batch  2 of 24: Hypervolume = 0.00, time = 52.47s.
# Batch  3 of 24: Hypervolume = 0.00, time = 43.26s.
# Batch  4 of 24: Hypervolume = 0.00, time = 24.51s.
# Batch  5 of 24: Hypervolume = 0.00, time = 38.40s.
# Batch  6 of 24: Hypervolume = 0.00, time = 17.21s.
# Batch  7 of 24: Hypervolume = 0.00, time = 12.15s.
# Batch  8 of 24: Hypervolume = 0.00, time = 6.36s.
# Batch  9 of 24: Hypervolume = 0.07, time = 7.22s.
# Batch 10 of 24: Hypervolume = 0.07, time = 16.06s.
# Batch 11 of 24: Hypervolume = 0.07, time = 11.34s.
# Batch 12 of 24: Hypervolume = 0.07, time = 32.62s.
# Batch 13 of 24: Hypervolume = 0.09, time = 6.32s.
# Batch 14 of 24: Hypervolume = 0.09, time = 14.51s.
# Batch 15 of 24: Hypervolume = 0.09, time = 5.50s.
# Batch 16 of 24: Hypervolume = 0.12, time = 10.26s.
# Batch 17 of 24: Hypervolume = 0.12, time = 5.15s.
# Batch 18 of 24: Hypervolume = 0.12, time = 28.70s.
# Batch 19 of 24: Hypervolume = 0.12, time = 11.68s.
# Batch 20 of 24: Hypervolume = 0.12, time = 3.98s.
# Batch 21 of 24: Hypervolume = 0.12, time = 17.13s.
# Batch 22 of 24: Hypervolume = 0.12, time = 16.88s.
# Batch 23 of 24: Hypervolume = 0.12, time = 12.31s.
# Batch 24 of 24: Hypervolume = 0.12, time = 10.22s.
# Time taken in total: 421.81s.
#
# Trial  3 of 5 for problem MW5 with d = 9
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 54.86s.
# Batch  2 of 24: Hypervolume = 0.00, time = 40.47s.
# Batch  3 of 24: Hypervolume = 0.00, time = 35.76s.
# Batch  4 of 24: Hypervolume = 0.03, time = 20.03s.
# Batch  5 of 24: Hypervolume = 0.03, time = 45.63s.
# Batch  6 of 24: Hypervolume = 0.03, time = 12.25s.
# Batch  7 of 24: Hypervolume = 0.05, time = 38.25s.
# Batch  8 of 24: Hypervolume = 0.05, time = 19.56s.
# Batch  9 of 24: Hypervolume = 0.05, time = 20.29s.
# Batch 10 of 24: Hypervolume = 0.05, time = 10.06s.
# Batch 11 of 24: Hypervolume = 0.05, time = 5.08s.
# Batch 12 of 24: Hypervolume = 0.09, time = 32.01s.
# Batch 13 of 24: Hypervolume = 0.09, time = 40.26s.
# Batch 14 of 24: Hypervolume = 0.09, time = 6.35s.
# Batch 15 of 24: Hypervolume = 0.09, time = 7.61s.
# Batch 16 of 24: Hypervolume = 0.09, time = 12.79s.
# Batch 17 of 24: Hypervolume = 0.09, time = 17.85s.
# Batch 18 of 24: Hypervolume = 0.09, time = 9.96s.
# Batch 19 of 24: Hypervolume = 0.09, time = 33.79s.
# Batch 20 of 24: Hypervolume = 0.09, time = 9.49s.
# Batch 21 of 24: Hypervolume = 0.09, time = 28.98s.
# Batch 22 of 24: Hypervolume = 0.09, time = 8.54s.
# Batch 23 of 24: Hypervolume = 0.17, time = 28.61s.
# Batch 24 of 24: Hypervolume = 0.17, time = 6.04s.
# Time taken in total: 544.58s.
#
# Trial  4 of 5 for problem MW5 with d = 9
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 53.71s.
# Batch  2 of 24: Hypervolume = 0.00, time = 37.19s.
# Batch  3 of 24: Hypervolume = 0.00, time = 27.12s.
# Batch  4 of 24: Hypervolume = 0.00, time = 37.23s.
# Batch  5 of 24: Hypervolume = 0.12, time = 37.06s.
# Batch  6 of 24: Hypervolume = 0.12, time = 43.69s.
# Batch  7 of 24: Hypervolume = 0.12, time = 35.96s.
# Batch  8 of 24: Hypervolume = 0.12, time = 10.35s.
# Batch  9 of 24: Hypervolume = 0.12, time = 25.14s.
# Batch 10 of 24: Hypervolume = 0.12, time = 28.49s.
# Batch 11 of 24: Hypervolume = 0.12, time = 30.67s.
# Batch 12 of 24: Hypervolume = 0.12, time = 7.24s.
# Batch 13 of 24: Hypervolume = 0.14, time = 14.34s.
# Batch 14 of 24: Hypervolume = 0.14, time = 35.30s.
# Batch 15 of 24: Hypervolume = 0.14, time = 36.92s.
# Batch 16 of 24: Hypervolume = 0.19, time = 33.30s.
# Batch 17 of 24: Hypervolume = 0.19, time = 23.79s.
# Batch 18 of 24: Hypervolume = 0.19, time = 34.56s.
# Batch 19 of 24: Hypervolume = 0.19, time = 26.90s.
# Batch 20 of 24: Hypervolume = 0.26, time = 16.38s.
# Batch 21 of 24: Hypervolume = 0.26, time = 32.94s.
# Batch 22 of 24: Hypervolume = 0.26, time = 24.31s.
# Batch 23 of 24: Hypervolume = 0.28, time = 5.04s.
# Batch 24 of 24: Hypervolume = 0.28, time = 34.20s.
# Time taken in total: 691.86s.
#
# Trial  5 of 5 for problem MW5 with d = 9
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.55s.
# Batch  2 of 24: Hypervolume = 0.00, time = 1.86s.
# Batch  3 of 24: Hypervolume = 0.00, time = 8.77s.
# Batch  4 of 24: Hypervolume = 0.00, time = 27.23s.
# Batch  5 of 24: Hypervolume = 0.00, time = 26.22s.
# Batch  6 of 24: Hypervolume = 0.00, time = 4.37s.
# Batch  7 of 24: Hypervolume = 0.00, time = 38.89s.
# Batch  8 of 24: Hypervolume = 0.18, time = 34.30s.
# Batch  9 of 24: Hypervolume = 0.18, time = 15.75s.
# Batch 10 of 24: Hypervolume = 0.21, time = 18.36s.
# Batch 11 of 24: Hypervolume = 0.21, time = 13.96s.
# Batch 12 of 24: Hypervolume = 0.21, time = 36.75s.
# Batch 13 of 24: Hypervolume = 0.21, time = 12.46s.
# Batch 14 of 24: Hypervolume = 0.21, time = 36.82s.
# Batch 15 of 24: Hypervolume = 0.21, time = 37.02s.
# Batch 16 of 24: Hypervolume = 0.21, time = 8.79s.
# Batch 17 of 24: Hypervolume = 0.21, time = 27.21s.
# Batch 18 of 24: Hypervolume = 0.21, time = 17.86s.
# Batch 19 of 24: Hypervolume = 0.21, time = 11.90s.
# Batch 20 of 24: Hypervolume = 0.21, time = 18.83s.
# Batch 21 of 24: Hypervolume = 0.21, time = 11.80s.
# Batch 22 of 24: Hypervolume = 0.28, time = 10.33s.
# Batch 23 of 24: Hypervolume = 0.28, time = 14.66s.
# Batch 24 of 24: Hypervolume = 0.28, time = 4.06s.
# Time taken in total: 439.79s.
#
# Trial  1 of 5 for problem MW5 with d = 10
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.70s.
# Batch  2 of 24: Hypervolume = 0.00, time = 43.95s.
# Batch  3 of 24: Hypervolume = 0.00, time = 21.21s.
# Batch  4 of 24: Hypervolume = 0.00, time = 12.90s.
# Batch  5 of 24: Hypervolume = 0.01, time = 16.24s.
# Batch  6 of 24: Hypervolume = 0.01, time = 21.29s.
# Batch  7 of 24: Hypervolume = 0.01, time = 20.95s.
# Batch  8 of 24: Hypervolume = 0.01, time = 21.55s.
# Batch  9 of 24: Hypervolume = 0.01, time = 12.86s.
# Batch 10 of 24: Hypervolume = 0.01, time = 7.19s.
# Batch 11 of 24: Hypervolume = 0.01, time = 3.95s.
# Batch 12 of 24: Hypervolume = 0.01, time = 8.99s.
# Batch 13 of 24: Hypervolume = 0.01, time = 3.52s.
# Batch 14 of 24: Hypervolume = 0.01, time = 23.30s.
# Batch 15 of 24: Hypervolume = 0.01, time = 5.66s.
# Batch 16 of 24: Hypervolume = 0.01, time = 29.38s.
# Batch 17 of 24: Hypervolume = 0.01, time = 3.21s.
# Batch 18 of 24: Hypervolume = 0.01, time = 3.62s.
# Batch 19 of 24: Hypervolume = 0.01, time = 21.13s.
# Batch 20 of 24: Hypervolume = 0.01, time = 3.66s.
# Batch 21 of 24: Hypervolume = 0.01, time = 3.76s.
# Batch 22 of 24: Hypervolume = 0.01, time = 3.38s.
# Batch 23 of 24: Hypervolume = 0.01, time = 32.07s.
# Batch 24 of 24: Hypervolume = 0.14, time = 12.32s.
# Time taken in total: 337.81s.
#
# Trial  2 of 5 for problem MW5 with d = 10
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.59s.
# Batch  2 of 24: Hypervolume = 0.00, time = 6.96s.
# Batch  3 of 24: Hypervolume = 0.00, time = 2.84s.
# Batch  4 of 24: Hypervolume = 0.00, time = 10.24s.
# Batch  5 of 24: Hypervolume = 0.00, time = 20.90s.
# Batch  6 of 24: Hypervolume = 0.00, time = 22.64s.
# Batch  7 of 24: Hypervolume = 0.00, time = 21.21s.
# Batch  8 of 24: Hypervolume = 0.00, time = 41.65s.
# Batch  9 of 24: Hypervolume = 0.07, time = 12.44s.
# Batch 10 of 24: Hypervolume = 0.07, time = 40.30s.
# Batch 11 of 24: Hypervolume = 0.07, time = 4.36s.
# Batch 12 of 24: Hypervolume = 0.07, time = 14.96s.
# Batch 13 of 24: Hypervolume = 0.07, time = 8.40s.
# Batch 14 of 24: Hypervolume = 0.07, time = 25.03s.
# Batch 15 of 24: Hypervolume = 0.07, time = 40.85s.
# Batch 16 of 24: Hypervolume = 0.07, time = 36.28s.
# Batch 17 of 24: Hypervolume = 0.07, time = 3.28s.
# Batch 18 of 24: Hypervolume = 0.07, time = 12.59s.
# Batch 19 of 24: Hypervolume = 0.07, time = 15.17s.
# Batch 20 of 24: Hypervolume = 0.15, time = 6.36s.
# Batch 21 of 24: Hypervolume = 0.15, time = 9.49s.
# Batch 22 of 24: Hypervolume = 0.15, time = 11.49s.
# Batch 23 of 24: Hypervolume = 0.15, time = 6.46s.
# Batch 24 of 24: Hypervolume = 0.15, time = 35.54s.
# Time taken in total: 411.04s.
#
# Trial  3 of 5 for problem MW5 with d = 10
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 9.97s.
# Batch  2 of 24: Hypervolume = 0.00, time = 46.22s.
# Batch  3 of 24: Hypervolume = 0.04, time = 58.15s.
# Batch  4 of 24: Hypervolume = 0.04, time = 43.32s.
# Batch  5 of 24: Hypervolume = 0.05, time = 16.45s.
# Batch  6 of 24: Hypervolume = 0.05, time = 30.49s.
# Batch  7 of 24: Hypervolume = 0.05, time = 19.75s.
# Batch  8 of 24: Hypervolume = 0.05, time = 32.09s.
# Batch  9 of 24: Hypervolume = 0.05, time = 15.61s.
# Batch 10 of 24: Hypervolume = 0.05, time = 42.97s.
# Batch 11 of 24: Hypervolume = 0.05, time = 5.62s.
# Batch 12 of 24: Hypervolume = 0.05, time = 17.05s.
# Batch 13 of 24: Hypervolume = 0.05, time = 25.72s.
# Batch 14 of 24: Hypervolume = 0.05, time = 18.11s.
# Batch 15 of 24: Hypervolume = 0.05, time = 6.57s.
# Batch 16 of 24: Hypervolume = 0.05, time = 4.71s.
# Batch 17 of 24: Hypervolume = 0.05, time = 30.23s.
# Batch 18 of 24: Hypervolume = 0.05, time = 26.50s.
# Batch 19 of 24: Hypervolume = 0.05, time = 32.79s.
# Batch 20 of 24: Hypervolume = 0.05, time = 35.08s.
# Batch 21 of 24: Hypervolume = 0.05, time = 7.79s.
# Batch 22 of 24: Hypervolume = 0.05, time = 29.62s.
# Batch 23 of 24: Hypervolume = 0.07, time = 5.40s.
# Batch 24 of 24: Hypervolume = 0.07, time = 36.94s.
# Time taken in total: 597.20s.
#
# Trial  4 of 5 for problem MW5 with d = 10
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 19.13s.
# Batch  2 of 24: Hypervolume = 0.00, time = 31.86s.
# Batch  3 of 24: Hypervolume = 0.00, time = 32.79s.
# Batch  4 of 24: Hypervolume = 0.00, time = 5.93s.
# Batch  5 of 24: Hypervolume = 0.00, time = 4.46s.
# Batch  6 of 24: Hypervolume = 0.00, time = 28.38s.
# Batch  7 of 24: Hypervolume = 0.00, time = 9.31s.
# Batch  8 of 24: Hypervolume = 0.00, time = 36.62s.
# Batch  9 of 24: Hypervolume = 0.00, time = 9.90s.
# Batch 10 of 24: Hypervolume = 0.12, time = 7.36s.
# Batch 11 of 24: Hypervolume = 0.12, time = 3.18s.
# Batch 12 of 24: Hypervolume = 0.12, time = 19.41s.
# Batch 13 of 24: Hypervolume = 0.12, time = 3.05s.
# Batch 14 of 24: Hypervolume = 0.12, time = 16.22s.
# Batch 15 of 24: Hypervolume = 0.12, time = 22.32s.
# Batch 16 of 24: Hypervolume = 0.12, time = 6.69s.
# Batch 17 of 24: Hypervolume = 0.12, time = 4.73s.
# Batch 18 of 24: Hypervolume = 0.12, time = 3.05s.
# Batch 19 of 24: Hypervolume = 0.12, time = 22.15s.
# Batch 20 of 24: Hypervolume = 0.12, time = 3.28s.
# Batch 21 of 24: Hypervolume = 0.12, time = 28.95s.
# Batch 22 of 24: Hypervolume = 0.12, time = 34.48s.
# Batch 23 of 24: Hypervolume = 0.12, time = 3.79s.
# Batch 24 of 24: Hypervolume = 0.12, time = 20.89s.
# Time taken in total: 377.96s.
#
# Trial  5 of 5 for problem MW5 with d = 10
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 25.98s.
# Batch  2 of 24: Hypervolume = 0.08, time = 27.24s.
# Batch  3 of 24: Hypervolume = 0.08, time = 6.09s.
# Batch  4 of 24: Hypervolume = 0.08, time = 10.60s.
# Batch  5 of 24: Hypervolume = 0.08, time = 10.15s.
# Batch  6 of 24: Hypervolume = 0.08, time = 11.23s.
# Batch  7 of 24: Hypervolume = 0.08, time = 8.37s.
# Batch  8 of 24: Hypervolume = 0.08, time = 8.22s.
# Batch  9 of 24: Hypervolume = 0.08, time = 33.00s.
# Batch 10 of 24: Hypervolume = 0.08, time = 4.60s.
# Batch 11 of 24: Hypervolume = 0.08, time = 18.27s.
# Batch 12 of 24: Hypervolume = 0.08, time = 16.61s.
# Batch 13 of 24: Hypervolume = 0.08, time = 2.34s.
# Batch 14 of 24: Hypervolume = 0.08, time = 22.75s.
# Batch 15 of 24: Hypervolume = 0.08, time = 35.64s.
# Batch 16 of 24: Hypervolume = 0.08, time = 37.32s.
# Batch 17 of 24: Hypervolume = 0.08, time = 12.46s.
# Batch 18 of 24: Hypervolume = 0.08, time = 34.34s.
# Batch 19 of 24: Hypervolume = 0.08, time = 32.66s.
# Batch 20 of 24: Hypervolume = 0.08, time = 2.71s.
# Batch 21 of 24: Hypervolume = 0.08, time = 21.00s.
# Batch 22 of 24: Hypervolume = 0.19, time = 10.99s.
# Batch 23 of 24: Hypervolume = 0.19, time = 34.51s.
# Batch 24 of 24: Hypervolume = 0.19, time = 3.20s.
# Time taken in total: 430.27s.
#
# Trial  1 of 5 for problem MW5 with d = 11
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 49.27s.
# Batch  2 of 24: Hypervolume = 0.00, time = 35.28s.
# Batch  3 of 24: Hypervolume = 0.00, time = 4.93s.
# Batch  4 of 24: Hypervolume = 0.00, time = 60.49s.
# Batch  5 of 24: Hypervolume = 0.00, time = 16.50s.
# Batch  6 of 24: Hypervolume = 0.00, time = 15.70s.
# Batch  7 of 24: Hypervolume = 0.00, time = 18.64s.
# Batch  8 of 24: Hypervolume = 0.00, time = 19.79s.
# Batch  9 of 24: Hypervolume = 0.10, time = 31.80s.
# Batch 10 of 24: Hypervolume = 0.10, time = 6.71s.
# Batch 11 of 24: Hypervolume = 0.10, time = 9.70s.
# Batch 12 of 24: Hypervolume = 0.10, time = 9.91s.
# Batch 13 of 24: Hypervolume = 0.10, time = 3.76s.
# Batch 14 of 24: Hypervolume = 0.10, time = 4.21s.
# Batch 15 of 24: Hypervolume = 0.10, time = 3.62s.
# Batch 16 of 24: Hypervolume = 0.10, time = 3.55s.
# Batch 17 of 24: Hypervolume = 0.10, time = 3.92s.
# Batch 18 of 24: Hypervolume = 0.10, time = 19.55s.
# Batch 19 of 24: Hypervolume = 0.10, time = 16.69s.
# Batch 20 of 24: Hypervolume = 0.12, time = 28.43s.
# Batch 21 of 24: Hypervolume = 0.12, time = 9.23s.
# Batch 22 of 24: Hypervolume = 0.12, time = 15.45s.
# Batch 23 of 24: Hypervolume = 0.12, time = 3.56s.
# Batch 24 of 24: Hypervolume = 0.12, time = 3.89s.
# Time taken in total: 394.60s.
#
# Trial  2 of 5 for problem MW5 with d = 11
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.59s.
# Batch  2 of 24: Hypervolume = 0.00, time = 18.03s.
# Batch  3 of 24: Hypervolume = 0.00, time = 28.57s.
# Batch  4 of 24: Hypervolume = 0.00, time = 19.46s.
# Batch  5 of 24: Hypervolume = 0.00, time = 20.60s.
# Batch  6 of 24: Hypervolume = 0.00, time = 16.06s.
# Batch  7 of 24: Hypervolume = 0.00, time = 39.86s.
# Batch  8 of 24: Hypervolume = 0.00, time = 24.57s.
# Batch  9 of 24: Hypervolume = 0.00, time = 28.56s.
# Batch 10 of 24: Hypervolume = 0.00, time = 39.77s.
# Batch 11 of 24: Hypervolume = 0.00, time = 23.64s.
# Batch 12 of 24: Hypervolume = 0.00, time = 35.48s.
# Batch 13 of 24: Hypervolume = 0.16, time = 17.45s.
# Batch 14 of 24: Hypervolume = 0.16, time = 6.73s.
# Batch 15 of 24: Hypervolume = 0.16, time = 29.56s.
# Batch 16 of 24: Hypervolume = 0.16, time = 38.66s.
# Batch 17 of 24: Hypervolume = 0.16, time = 19.54s.
# Batch 18 of 24: Hypervolume = 0.16, time = 39.10s.
# Batch 19 of 24: Hypervolume = 0.16, time = 21.20s.
# Batch 20 of 24: Hypervolume = 0.16, time = 3.67s.
# Batch 21 of 24: Hypervolume = 0.21, time = 14.63s.
# Batch 22 of 24: Hypervolume = 0.21, time = 3.62s.
# Batch 23 of 24: Hypervolume = 0.21, time = 9.19s.
# Batch 24 of 24: Hypervolume = 0.21, time = 21.04s.
# Time taken in total: 520.60s.
#
# Trial  3 of 5 for problem MW5 with d = 11
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 2.17s.
# Batch  2 of 24: Hypervolume = 0.01, time = 34.74s.
# Batch  3 of 24: Hypervolume = 0.01, time = 48.68s.
# Batch  4 of 24: Hypervolume = 0.01, time = 13.54s.
# Batch  5 of 24: Hypervolume = 0.01, time = 7.30s.
# Batch  6 of 24: Hypervolume = 0.01, time = 32.46s.
# Batch  7 of 24: Hypervolume = 0.01, time = 48.18s.
# Batch  8 of 24: Hypervolume = 0.01, time = 5.70s.
# Batch  9 of 24: Hypervolume = 0.19, time = 38.30s.
# Batch 10 of 24: Hypervolume = 0.19, time = 28.42s.
# Batch 11 of 24: Hypervolume = 0.19, time = 12.81s.
# Batch 12 of 24: Hypervolume = 0.19, time = 3.12s.
# Batch 13 of 24: Hypervolume = 0.19, time = 19.09s.
# Batch 14 of 24: Hypervolume = 0.19, time = 18.45s.
# Batch 15 of 24: Hypervolume = 0.19, time = 3.00s.
# Batch 16 of 24: Hypervolume = 0.19, time = 3.17s.
# Batch 17 of 24: Hypervolume = 0.19, time = 3.23s.
# Batch 18 of 24: Hypervolume = 0.19, time = 3.22s.
# Batch 19 of 24: Hypervolume = 0.19, time = 3.44s.
# Batch 20 of 24: Hypervolume = 0.19, time = 31.91s.
# Batch 21 of 24: Hypervolume = 0.19, time = 3.26s.
# Batch 22 of 24: Hypervolume = 0.19, time = 21.23s.
# Batch 23 of 24: Hypervolume = 0.19, time = 3.59s.
# Batch 24 of 24: Hypervolume = 0.19, time = 16.86s.
# Time taken in total: 405.92s.
#
# Trial  4 of 5 for problem MW5 with d = 11
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.81s.
# Batch  2 of 24: Hypervolume = 0.00, time = 10.93s.
# Batch  3 of 24: Hypervolume = 0.00, time = 47.11s.
# Batch  4 of 24: Hypervolume = 0.00, time = 8.89s.
# Batch  5 of 24: Hypervolume = 0.00, time = 9.81s.
# Batch  6 of 24: Hypervolume = 0.00, time = 37.04s.
# Batch  7 of 24: Hypervolume = 0.00, time = 39.20s.
# Batch  8 of 24: Hypervolume = 0.00, time = 13.84s.
# Batch  9 of 24: Hypervolume = 0.00, time = 35.27s.
# Batch 10 of 24: Hypervolume = 0.00, time = 4.17s.
# Batch 11 of 24: Hypervolume = 0.00, time = 9.00s.
# Batch 12 of 24: Hypervolume = 0.00, time = 12.92s.
# Batch 13 of 24: Hypervolume = 0.00, time = 34.29s.
# Batch 14 of 24: Hypervolume = 0.00, time = 9.12s.
# Batch 15 of 24: Hypervolume = 0.00, time = 16.06s.
# Batch 16 of 24: Hypervolume = 0.00, time = 3.36s.
# Batch 17 of 24: Hypervolume = 0.00, time = 32.63s.
# Batch 18 of 24: Hypervolume = 0.00, time = 5.05s.
# Batch 19 of 24: Hypervolume = 0.00, time = 12.06s.
# Batch 20 of 24: Hypervolume = 0.00, time = 5.45s.
# Batch 21 of 24: Hypervolume = 0.00, time = 37.88s.
# Batch 22 of 24: Hypervolume = 0.00, time = 5.26s.
# Batch 23 of 24: Hypervolume = 0.00, time = 3.73s.
# Batch 24 of 24: Hypervolume = 0.00, time = 3.56s.
# Time taken in total: 398.49s.
#
# Trial  5 of 5 for problem MW5 with d = 11
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 26.21s.
# Batch  2 of 24: Hypervolume = 0.00, time = 8.54s.
# Batch  3 of 24: Hypervolume = 0.00, time = 45.58s.
# Batch  4 of 24: Hypervolume = 0.00, time = 8.14s.
# Batch  5 of 24: Hypervolume = 0.00, time = 12.11s.
# Batch  6 of 24: Hypervolume = 0.00, time = 3.95s.
# Batch  7 of 24: Hypervolume = 0.00, time = 16.98s.
# Batch  8 of 24: Hypervolume = 0.00, time = 8.28s.
# Batch  9 of 24: Hypervolume = 0.00, time = 33.30s.
# Batch 10 of 24: Hypervolume = 0.00, time = 28.65s.
# Batch 11 of 24: Hypervolume = 0.00, time = 3.80s.
# Batch 12 of 24: Hypervolume = 0.00, time = 3.19s.
# Batch 13 of 24: Hypervolume = 0.00, time = 3.75s.
# Batch 14 of 24: Hypervolume = 0.00, time = 26.90s.
# Batch 15 of 24: Hypervolume = 0.00, time = 17.07s.
# Batch 16 of 24: Hypervolume = 0.00, time = 29.74s.
# Batch 17 of 24: Hypervolume = 0.00, time = 34.43s.
# Batch 18 of 24: Hypervolume = 0.00, time = 25.49s.
# Batch 19 of 24: Hypervolume = 0.00, time = 17.19s.
# Batch 20 of 24: Hypervolume = 0.00, time = 17.76s.
# Batch 21 of 24: Hypervolume = 0.00, time = 31.63s.
# Batch 22 of 24: Hypervolume = 0.00, time = 3.51s.
# Batch 23 of 24: Hypervolume = 0.00, time = 14.40s.
# Batch 24 of 24: Hypervolume = 0.00, time = 3.62s.
# Time taken in total: 424.28s.
#
# Trial  1 of 5 for problem MW5 with d = 12
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.69s.
# Batch  2 of 24: Hypervolume = 0.00, time = 2.06s.
# Batch  3 of 24: Hypervolume = 0.00, time = 17.56s.
# Batch  4 of 24: Hypervolume = 0.00, time = 37.66s.
# Batch  5 of 24: Hypervolume = 0.09, time = 22.29s.
# Batch  6 of 24: Hypervolume = 0.09, time = 17.45s.
# Batch  7 of 24: Hypervolume = 0.15, time = 7.03s.
# Batch  8 of 24: Hypervolume = 0.15, time = 11.89s.
# Batch  9 of 24: Hypervolume = 0.15, time = 26.85s.
# Batch 10 of 24: Hypervolume = 0.15, time = 8.40s.
# Batch 11 of 24: Hypervolume = 0.15, time = 8.11s.
# Batch 12 of 24: Hypervolume = 0.15, time = 3.86s.
# Batch 13 of 24: Hypervolume = 0.15, time = 3.48s.
# Batch 14 of 24: Hypervolume = 0.15, time = 21.32s.
# Batch 15 of 24: Hypervolume = 0.15, time = 21.81s.
# Batch 16 of 24: Hypervolume = 0.15, time = 4.17s.
# Batch 17 of 24: Hypervolume = 0.16, time = 8.38s.
# Batch 18 of 24: Hypervolume = 0.16, time = 12.92s.
# Batch 19 of 24: Hypervolume = 0.16, time = 18.76s.
# Batch 20 of 24: Hypervolume = 0.16, time = 4.81s.
# Batch 21 of 24: Hypervolume = 0.16, time = 4.16s.
# Batch 22 of 24: Hypervolume = 0.16, time = 12.17s.
# Batch 23 of 24: Hypervolume = 0.16, time = 4.45s.
# Batch 24 of 24: Hypervolume = 0.16, time = 4.03s.
# Time taken in total: 285.35s.
#
# Trial  2 of 5 for problem MW5 with d = 12
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.59s.
# Batch  2 of 24: Hypervolume = 0.00, time = 1.84s.
# Batch  3 of 24: Hypervolume = 0.00, time = 11.54s.
# Batch  4 of 24: Hypervolume = 0.00, time = 1.81s.
# Batch  5 of 24: Hypervolume = 0.00, time = 1.86s.
# Batch  6 of 24: Hypervolume = 0.00, time = 6.23s.
# Batch  7 of 24: Hypervolume = 0.00, time = 2.06s.
# Batch  8 of 24: Hypervolume = 0.13, time = 6.56s.
# Batch  9 of 24: Hypervolume = 0.13, time = 48.35s.
# Batch 10 of 24: Hypervolume = 0.13, time = 13.57s.
# Batch 11 of 24: Hypervolume = 0.13, time = 2.33s.
# Batch 12 of 24: Hypervolume = 0.13, time = 43.40s.
# Batch 13 of 24: Hypervolume = 0.13, time = 2.59s.
# Batch 14 of 24: Hypervolume = 0.13, time = 21.20s.
# Batch 15 of 24: Hypervolume = 0.13, time = 18.31s.
# Batch 16 of 24: Hypervolume = 0.13, time = 2.55s.
# Batch 17 of 24: Hypervolume = 0.13, time = 2.47s.
# Batch 18 of 24: Hypervolume = 0.13, time = 2.41s.
# Batch 19 of 24: Hypervolume = 0.13, time = 4.81s.
# Batch 20 of 24: Hypervolume = 0.13, time = 18.28s.
# Batch 21 of 24: Hypervolume = 0.13, time = 2.84s.
# Batch 22 of 24: Hypervolume = 0.13, time = 3.06s.
# Batch 23 of 24: Hypervolume = 0.13, time = 3.20s.
# Batch 24 of 24: Hypervolume = 0.13, time = 3.25s.
# Time taken in total: 226.16s.
#
# Trial  3 of 5 for problem MW5 with d = 12
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.61s.
# Batch  2 of 24: Hypervolume = 0.00, time = 39.91s.
# Batch  3 of 24: Hypervolume = 0.00, time = 48.44s.
# Batch  4 of 24: Hypervolume = 0.00, time = 47.18s.
# Batch  5 of 24: Hypervolume = 0.00, time = 44.22s.
# Batch  6 of 24: Hypervolume = 0.00, time = 4.26s.
# Batch  7 of 24: Hypervolume = 0.00, time = 7.19s.
# Batch  8 of 24: Hypervolume = 0.00, time = 43.19s.
# Batch  9 of 24: Hypervolume = 0.00, time = 19.51s.
# Batch 10 of 24: Hypervolume = 0.13, time = 16.20s.
# Batch 11 of 24: Hypervolume = 0.13, time = 26.34s.
# Batch 12 of 24: Hypervolume = 0.13, time = 3.70s.
# Batch 13 of 24: Hypervolume = 0.13, time = 3.95s.
# Batch 14 of 24: Hypervolume = 0.13, time = 3.89s.
# Batch 15 of 24: Hypervolume = 0.13, time = 13.28s.
# Batch 16 of 24: Hypervolume = 0.13, time = 3.92s.
# Batch 17 of 24: Hypervolume = 0.13, time = 3.58s.
# Batch 18 of 24: Hypervolume = 0.13, time = 3.81s.
# Batch 19 of 24: Hypervolume = 0.13, time = 3.37s.
# Batch 20 of 24: Hypervolume = 0.13, time = 3.86s.
# Batch 21 of 24: Hypervolume = 0.13, time = 32.32s.
# Batch 22 of 24: Hypervolume = 0.13, time = 3.73s.
# Batch 23 of 24: Hypervolume = 0.13, time = 4.05s.
# Batch 24 of 24: Hypervolume = 0.13, time = 3.87s.
# Time taken in total: 385.43s.
#
# Trial  4 of 5 for problem MW5 with d = 12
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.67s.
# Batch  2 of 24: Hypervolume = 0.00, time = 2.08s.
# Batch  3 of 24: Hypervolume = 0.00, time = 2.64s.
# Batch  4 of 24: Hypervolume = 0.01, time = 5.01s.
# Batch  5 of 24: Hypervolume = 0.02, time = 47.83s.
# Batch  6 of 24: Hypervolume = 0.13, time = 14.11s.
# Batch  7 of 24: Hypervolume = 0.13, time = 14.86s.
# Batch  8 of 24: Hypervolume = 0.13, time = 4.00s.
# Batch  9 of 24: Hypervolume = 0.13, time = 10.70s.
# Batch 10 of 24: Hypervolume = 0.13, time = 19.64s.
# Batch 11 of 24: Hypervolume = 0.13, time = 10.61s.
# Batch 12 of 24: Hypervolume = 0.13, time = 3.55s.
# Batch 13 of 24: Hypervolume = 0.18, time = 7.39s.
# Batch 14 of 24: Hypervolume = 0.18, time = 3.36s.
# Batch 15 of 24: Hypervolume = 0.18, time = 3.41s.
# Batch 16 of 24: Hypervolume = 0.18, time = 3.20s.
# Batch 17 of 24: Hypervolume = 0.18, time = 3.08s.
# Batch 18 of 24: Hypervolume = 0.18, time = 17.71s.
# Batch 19 of 24: Hypervolume = 0.18, time = 3.16s.
# Batch 20 of 24: Hypervolume = 0.18, time = 3.62s.
# Batch 21 of 24: Hypervolume = 0.18, time = 3.97s.
# Batch 22 of 24: Hypervolume = 0.18, time = 3.80s.
# Batch 23 of 24: Hypervolume = 0.18, time = 4.45s.
# Batch 24 of 24: Hypervolume = 0.18, time = 3.72s.
# Time taken in total: 197.56s.
#
# Trial  5 of 5 for problem MW5 with d = 12
# Optimizing with Pure qNEHVI
# Batch  1 of 24: Hypervolume = 0.00, time = 1.61s.
# Batch  2 of 24: Hypervolume = 0.00, time = 27.59s.
# Batch  3 of 24: Hypervolume = 0.00, time = 11.56s.
# Batch  4 of 24: Hypervolume = 0.00, time = 2.81s.
# Batch  5 of 24: Hypervolume = 0.02, time = 9.64s.
# Batch  6 of 24: Hypervolume = 0.02, time = 42.69s.
# Batch  7 of 24: Hypervolume = 0.02, time = 4.12s.
# Batch  8 of 24: Hypervolume = 0.02, time = 5.23s.
# Batch  9 of 24: Hypervolume = 0.02, time = 41.57s.
# Batch 10 of 24: Hypervolume = 0.02, time = 15.04s.
# Batch 11 of 24: Hypervolume = 0.04, time = 13.09s.
# Batch 12 of 24: Hypervolume = 0.04, time = 36.55s.
# Batch 13 of 24: Hypervolume = 0.04, time = 28.52s.
# Batch 14 of 24: Hypervolume = 0.04, time = 14.34s.
# Batch 15 of 24: Hypervolume = 0.04, time = 5.03s.
# Batch 16 of 24: Hypervolume = 0.04, time = 2.87s.
# Batch 17 of 24: Hypervolume = 0.04, time = 15.70s.
# Batch 18 of 24: Hypervolume = 0.04, time = 8.00s.
# Batch 19 of 24: Hypervolume = 0.04, time = 2.73s.
# Batch 20 of 24: Hypervolume = 0.04, time = 2.91s.
# Batch 21 of 24: Hypervolume = 0.04, time = 14.54s.
# Batch 22 of 24: Hypervolume = 0.04, time = 3.12s.
# Batch 23 of 24: Hypervolume = 0.04, time = 29.24s.
# Batch 24 of 24: Hypervolume = 0.04, time = 3.22s.
# Time taken in total: 341.76s.
# All done!

# %%
problemname = 'MW5'

N_TRIALS = 5
verbose = True
noise = 0.00

N_BATCH = 24
BATCH_SIZE = 8

for dimensions in range(10, 12+ 1):

    class MWBase(torch.nn.Module):   
        def g1(X, n_obj):
            d = dimensions
            n = d - n_obj

            z = torch.pow(X[..., n_obj - 1:], n)
            i = torch.arange(n_obj - 1, d, **tkwargs)

            exp = 1 - torch.exp(-10.0 * (z - 0.5 - i / (2 * d)) * (z - 0.5 - i / (2 * d)))
            distance = 1 + exp.sum(axis=1)
            return distance

        def g3(X, n_obj):
            contrib = 2.0 * torch.pow(
                X[..., n_obj - 1:] + (X[..., n_obj - 2:-1] - 0.5) * (X[..., n_obj - 2:-1] - 0.5) - 1.0, 2.0)

            distance = 1 + contrib.sum(axis=1)
            return distance

        def LA1(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * np.pi * torch.pow(theta, C)), D)

        def LA2(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * torch.pow(theta, C)), D)

    class problem(torch.nn.Module):
        n_var = dimensions
        n_obj = 2
        n_constr = 3

        ref_point = torch.tensor([1.2,1.2], **tkwargs)

        bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])

        def evaluate(X):
            # to maximise a postive output, stay positive
            # to minimise a positive output, force negative
            # to maximise a negative output (away from zero), force positive
            # to minimise a negative output (towards zero), stay negative

            g1 = MWBase.g3(X, n_obj=2)
            f1 = g1 * X[:, 0]
            f2 = g1 * torch.sqrt(1.0 - torch.pow(f1 / g1, 2.0))

            # constraint equations should take the form of c(n)<=0
            # should return <=0 values when constraints are active,
            # and >0 values when constraints are violated
            # take care if constraints are too restrictive, will cause early flatlining if all samples are rejected
            atan = torch.arctan(f2 / f1)
            c1 =  (f1 ** 2) + (f2 ** 2) - torch.pow(1.7 - MWBase.LA2(0.2, 2.0, 1.0, 1.0, atan), 2.0) 

            t = 0.5 * np.pi - 2 * torch.abs(atan - 0.25 * np.pi)
            c2 = torch.pow(1 + MWBase.LA2(0.5, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)
            c3 = torch.pow(1 - MWBase.LA2(0.45, 6.0, 3.0, 1.0, t), 2.0) - (f1 ** 2) - (f2 ** 2)

            output = torch.stack([-f1, -f2], dim=-1)
            slack = torch.stack([c1, c2, c3], dim=-1)

            return output, slack
        
    hv_list = []
    train_list = []

    # main loop for each trial/run, random_state will be trial number
    for trial in range(0, N_TRIALS):
        print(f"\nTrial {trial+1:>2} of {N_TRIALS} for problem {problemname} with d = {dimensions}\n", end="")

        # initialize with a 2*(d+1) sample set
        initial_x = torch.tensor(initial_x_dict[dimensions][trial], **tkwargs)

        hv, train = optimize_hybrid_nsga(problem, problem.ref_point, initial_x,
                         N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                         random_state=trial, noise=noise, verbose=verbose)
        hv_list.append(hv)
        train_list.append(train)

    savetxt(f"{problemname}_{dimensions}dim_hvs_hybrid_nsga_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", hv_list, delimiter=',')    
    savetxt(f"{problemname}_{dimensions}dim_train_hybrid_nsga_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", np.array(train_list).reshape(-1), delimiter=',')
        
print("All done!")
# Out:
# Trial  1 of 5 for problem MW5 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# C:\Users\lowki\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2189.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 24: Hypervolume = 0.00, time = 14.28s.
# Batch  2 of 24: Hypervolume = 0.00, time = 15.19s.
# Batch  3 of 24: Hypervolume = 0.15, time = 29.20s.
# Batch  4 of 24: Hypervolume = 0.15, time = 53.47s.
# Batch  5 of 24: Hypervolume = 0.15, time = 15.92s.
# Batch  6 of 24: Hypervolume = 0.15, time = 24.56s.
# Batch  7 of 24: Hypervolume = 0.15, time = 13.88s.
# Batch  8 of 24: Hypervolume = 0.24, time = 37.93s.
# Batch  9 of 24: Hypervolume = 0.26, time = 30.60s.
# Batch 10 of 24: Hypervolume = 0.26, time = 16.80s.
# Batch 11 of 24: Hypervolume = 0.26, time = 20.47s.
# Batch 12 of 24: Hypervolume = 0.26, time = 21.61s.
# Batch 13 of 24: Hypervolume = 0.32, time = 14.15s.
# Batch 14 of 24: Hypervolume = 0.32, time = 13.00s.
# Batch 15 of 24: Hypervolume = 0.32, time = 27.78s.
# Batch 16 of 24: Hypervolume = 0.32, time = 13.07s.
# Batch 17 of 24: Hypervolume = 0.32, time = 12.56s.
# Batch 18 of 24: Hypervolume = 0.33, time = 28.27s.
# Batch 19 of 24: Hypervolume = 0.34, time = 13.22s.
# Batch 20 of 24: Hypervolume = 0.35, time = 14.32s.
# Batch 21 of 24: Hypervolume = 0.35, time = 15.05s.
# Batch 22 of 24: Hypervolume = 0.35, time = 13.51s.
# Batch 23 of 24: Hypervolume = 0.35, time = 13.42s.
# Batch 24 of 24: Hypervolume = 0.37, time = 28.60s.
# Time taken in total: 500.94s.
#
# Trial  2 of 5 for problem MW5 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.17s.
# Batch  2 of 24: Hypervolume = 0.00, time = 25.21s.
# Batch  3 of 24: Hypervolume = 0.08, time = 13.48s.
# Batch  4 of 24: Hypervolume = 0.09, time = 31.02s.
# Batch  5 of 24: Hypervolume = 0.09, time = 28.57s.
# Batch  6 of 24: Hypervolume = 0.09, time = 32.77s.
# Batch  7 of 24: Hypervolume = 0.16, time = 15.02s.
# Batch  8 of 24: Hypervolume = 0.19, time = 11.33s.
# Batch  9 of 24: Hypervolume = 0.20, time = 19.50s.
# Batch 10 of 24: Hypervolume = 0.20, time = 11.08s.
# Batch 11 of 24: Hypervolume = 0.21, time = 22.21s.
# Batch 12 of 24: Hypervolume = 0.21, time = 11.40s.
# Batch 13 of 24: Hypervolume = 0.22, time = 20.07s.
# Batch 14 of 24: Hypervolume = 0.22, time = 11.70s.
# Batch 15 of 24: Hypervolume = 0.28, time = 18.88s.
# Batch 16 of 24: Hypervolume = 0.29, time = 10.90s.
# Batch 17 of 24: Hypervolume = 0.29, time = 11.22s.
# Batch 18 of 24: Hypervolume = 0.29, time = 12.00s.
# Batch 19 of 24: Hypervolume = 0.30, time = 12.20s.
# Batch 20 of 24: Hypervolume = 0.31, time = 11.00s.
# Batch 21 of 24: Hypervolume = 0.32, time = 27.67s.
# Batch 22 of 24: Hypervolume = 0.33, time = 12.03s.
# Batch 23 of 24: Hypervolume = 0.35, time = 11.66s.
# Batch 24 of 24: Hypervolume = 0.37, time = 11.75s.
# Time taken in total: 401.86s.
#
# Trial  3 of 5 for problem MW5 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 15.83s.
# Batch  2 of 24: Hypervolume = 0.03, time = 56.90s.
# Batch  3 of 24: Hypervolume = 0.03, time = 42.77s.
# Batch  4 of 24: Hypervolume = 0.11, time = 29.03s.
# Batch  5 of 24: Hypervolume = 0.11, time = 38.68s.
# Batch  6 of 24: Hypervolume = 0.11, time = 14.76s.
# Batch  7 of 24: Hypervolume = 0.14, time = 31.72s.
# Batch  8 of 24: Hypervolume = 0.17, time = 16.64s.
# Batch  9 of 24: Hypervolume = 0.24, time = 13.10s.
# Batch 10 of 24: Hypervolume = 0.34, time = 21.59s.
# Batch 11 of 24: Hypervolume = 0.38, time = 43.21s.
# Batch 12 of 24: Hypervolume = 0.40, time = 24.39s.
# Batch 13 of 24: Hypervolume = 0.40, time = 14.40s.
# Batch 14 of 24: Hypervolume = 0.42, time = 10.69s.
# Batch 15 of 24: Hypervolume = 0.43, time = 10.36s.
# Batch 16 of 24: Hypervolume = 0.43, time = 11.02s.
# Batch 17 of 24: Hypervolume = 0.44, time = 10.29s.
# Batch 18 of 24: Hypervolume = 0.46, time = 10.83s.
# Batch 19 of 24: Hypervolume = 0.46, time = 10.53s.
# Batch 20 of 24: Hypervolume = 0.46, time = 11.11s.
# Batch 21 of 24: Hypervolume = 0.46, time = 20.02s.
# Batch 22 of 24: Hypervolume = 0.46, time = 10.48s.
# Batch 23 of 24: Hypervolume = 0.48, time = 10.56s.
# Batch 24 of 24: Hypervolume = 0.48, time = 11.58s.
# Time taken in total: 490.51s.
#
# Trial  4 of 5 for problem MW5 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 19.55s.
# Batch  2 of 24: Hypervolume = 0.00, time = 22.56s.
# Batch  3 of 24: Hypervolume = 0.01, time = 9.32s.
# Batch  4 of 24: Hypervolume = 0.16, time = 11.86s.
# Batch  5 of 24: Hypervolume = 0.16, time = 39.44s.
# Batch  6 of 24: Hypervolume = 0.22, time = 34.84s.
# Batch  7 of 24: Hypervolume = 0.22, time = 18.32s.
# Batch  8 of 24: Hypervolume = 0.23, time = 10.21s.
# Batch  9 of 24: Hypervolume = 0.23, time = 16.58s.
# Batch 10 of 24: Hypervolume = 0.23, time = 26.25s.
# Batch 11 of 24: Hypervolume = 0.24, time = 9.69s.
# Batch 12 of 24: Hypervolume = 0.25, time = 22.92s.
# Batch 13 of 24: Hypervolume = 0.28, time = 10.00s.
# Batch 14 of 24: Hypervolume = 0.28, time = 10.65s.
# Batch 15 of 24: Hypervolume = 0.28, time = 9.49s.
# Batch 16 of 24: Hypervolume = 0.29, time = 15.07s.
# Batch 17 of 24: Hypervolume = 0.35, time = 20.15s.
# Batch 18 of 24: Hypervolume = 0.37, time = 20.03s.
# Batch 19 of 24: Hypervolume = 0.40, time = 13.70s.
# Batch 20 of 24: Hypervolume = 0.40, time = 10.19s.
# Batch 21 of 24: Hypervolume = 0.42, time = 10.93s.
# Batch 22 of 24: Hypervolume = 0.43, time = 10.69s.
# Batch 23 of 24: Hypervolume = 0.44, time = 11.58s.
# Batch 24 of 24: Hypervolume = 0.44, time = 11.72s.
# Time taken in total: 395.83s.
#
# Trial  5 of 5 for problem MW5 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 31.48s.
# Batch  2 of 24: Hypervolume = 0.00, time = 34.52s.
# Batch  3 of 24: Hypervolume = 0.00, time = 12.86s.
# Batch  4 of 24: Hypervolume = 0.07, time = 11.82s.
# Batch  5 of 24: Hypervolume = 0.13, time = 16.89s.
# Batch  6 of 24: Hypervolume = 0.18, time = 12.33s.
# Batch  7 of 24: Hypervolume = 0.19, time = 11.28s.
# Batch  8 of 24: Hypervolume = 0.20, time = 12.04s.
# Batch  9 of 24: Hypervolume = 0.21, time = 11.45s.
# Batch 10 of 24: Hypervolume = 0.21, time = 11.78s.
# Batch 11 of 24: Hypervolume = 0.23, time = 27.07s.
# Batch 12 of 24: Hypervolume = 0.23, time = 11.80s.
# Batch 13 of 24: Hypervolume = 0.23, time = 12.00s.
# Batch 14 of 24: Hypervolume = 0.30, time = 12.50s.
# Batch 15 of 24: Hypervolume = 0.31, time = 12.54s.
# Batch 16 of 24: Hypervolume = 0.31, time = 25.17s.
# Batch 17 of 24: Hypervolume = 0.31, time = 11.63s.
# Batch 18 of 24: Hypervolume = 0.36, time = 12.27s.
# Batch 19 of 24: Hypervolume = 0.36, time = 13.22s.
# Batch 20 of 24: Hypervolume = 0.36, time = 12.25s.
# Batch 21 of 24: Hypervolume = 0.36, time = 11.70s.
# Batch 22 of 24: Hypervolume = 0.36, time = 13.33s.
# Batch 23 of 24: Hypervolume = 0.38, time = 28.43s.
# Batch 24 of 24: Hypervolume = 0.39, time = 16.79s.
# Time taken in total: 387.22s.
#
# Trial  1 of 5 for problem MW5 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 16.89s.
# Batch  2 of 24: Hypervolume = 0.00, time = 20.03s.
# Batch  3 of 24: Hypervolume = 0.06, time = 40.76s.
# Batch  4 of 24: Hypervolume = 0.12, time = 44.69s.
# Batch  5 of 24: Hypervolume = 0.14, time = 26.26s.
# Batch  6 of 24: Hypervolume = 0.15, time = 47.51s.
# Batch  7 of 24: Hypervolume = 0.17, time = 12.46s.
# Batch  8 of 24: Hypervolume = 0.18, time = 12.15s.
# Batch  9 of 24: Hypervolume = 0.18, time = 15.88s.
# Batch 10 of 24: Hypervolume = 0.19, time = 12.49s.
# Batch 11 of 24: Hypervolume = 0.21, time = 11.82s.
# Batch 12 of 24: Hypervolume = 0.21, time = 11.63s.
# Batch 13 of 24: Hypervolume = 0.22, time = 12.19s.
# Batch 14 of 24: Hypervolume = 0.22, time = 12.09s.
# Batch 15 of 24: Hypervolume = 0.22, time = 12.39s.
# Batch 16 of 24: Hypervolume = 0.22, time = 12.35s.
# Batch 17 of 24: Hypervolume = 0.22, time = 31.00s.
# Batch 18 of 24: Hypervolume = 0.22, time = 11.83s.
# Batch 19 of 24: Hypervolume = 0.23, time = 11.94s.
# Batch 20 of 24: Hypervolume = 0.23, time = 12.19s.
# Batch 21 of 24: Hypervolume = 0.23, time = 12.51s.
# Batch 22 of 24: Hypervolume = 0.23, time = 13.28s.
# Batch 23 of 24: Hypervolume = 0.23, time = 12.69s.
# Batch 24 of 24: Hypervolume = 0.23, time = 12.36s.
# Time taken in total: 439.40s.
#
# Trial  2 of 5 for problem MW5 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.15s.
# Batch  2 of 24: Hypervolume = 0.00, time = 37.98s.
# Batch  3 of 24: Hypervolume = 0.10, time = 14.32s.
# Batch  4 of 24: Hypervolume = 0.17, time = 33.72s.
# Batch  5 of 24: Hypervolume = 0.18, time = 14.20s.
# Batch  6 of 24: Hypervolume = 0.18, time = 11.68s.
# Batch  7 of 24: Hypervolume = 0.18, time = 11.39s.
# Batch  8 of 24: Hypervolume = 0.22, time = 20.71s.
# Batch  9 of 24: Hypervolume = 0.26, time = 11.26s.
# Batch 10 of 24: Hypervolume = 0.31, time = 17.60s.
# Batch 11 of 24: Hypervolume = 0.31, time = 11.51s.
# Batch 12 of 24: Hypervolume = 0.31, time = 11.56s.
# Batch 13 of 24: Hypervolume = 0.31, time = 11.93s.
# Batch 14 of 24: Hypervolume = 0.32, time = 11.39s.
# Batch 15 of 24: Hypervolume = 0.32, time = 11.82s.
# Batch 16 of 24: Hypervolume = 0.35, time = 11.90s.
# Batch 17 of 24: Hypervolume = 0.37, time = 11.73s.
# Batch 18 of 24: Hypervolume = 0.37, time = 11.31s.
# Batch 19 of 24: Hypervolume = 0.38, time = 12.01s.
# Batch 20 of 24: Hypervolume = 0.39, time = 12.29s.
# Batch 21 of 24: Hypervolume = 0.39, time = 12.76s.
# Batch 22 of 24: Hypervolume = 0.39, time = 12.42s.
# Batch 23 of 24: Hypervolume = 0.39, time = 12.98s.
# Batch 24 of 24: Hypervolume = 0.39, time = 12.28s.
# Time taken in total: 349.91s.
#
# Trial  3 of 5 for problem MW5 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.65s.
# Batch  2 of 24: Hypervolume = 0.00, time = 14.15s.
# Batch  3 of 24: Hypervolume = 0.02, time = 20.54s.
# Batch  4 of 24: Hypervolume = 0.02, time = 27.90s.
# Batch  5 of 24: Hypervolume = 0.09, time = 44.81s.
# Batch  6 of 24: Hypervolume = 0.09, time = 36.66s.
# Batch  7 of 24: Hypervolume = 0.18, time = 29.33s.
# Batch  8 of 24: Hypervolume = 0.25, time = 10.25s.
# Batch  9 of 24: Hypervolume = 0.25, time = 10.92s.
# Batch 10 of 24: Hypervolume = 0.25, time = 9.28s.
# Batch 11 of 24: Hypervolume = 0.27, time = 37.06s.
# Batch 12 of 24: Hypervolume = 0.27, time = 10.06s.
# Batch 13 of 24: Hypervolume = 0.27, time = 10.51s.
# Batch 14 of 24: Hypervolume = 0.30, time = 10.14s.
# Batch 15 of 24: Hypervolume = 0.30, time = 24.09s.
# Batch 16 of 24: Hypervolume = 0.30, time = 10.48s.
# Batch 17 of 24: Hypervolume = 0.30, time = 25.15s.
# Batch 18 of 24: Hypervolume = 0.33, time = 10.36s.
# Batch 19 of 24: Hypervolume = 0.33, time = 24.16s.
# Batch 20 of 24: Hypervolume = 0.33, time = 11.05s.
# Batch 21 of 24: Hypervolume = 0.33, time = 10.99s.
# Batch 22 of 24: Hypervolume = 0.33, time = 11.91s.
# Batch 23 of 24: Hypervolume = 0.33, time = 11.01s.
# Batch 24 of 24: Hypervolume = 0.36, time = 10.47s.
# Time taken in total: 429.99s.
#
# Trial  4 of 5 for problem MW5 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.26s.
# Batch  2 of 24: Hypervolume = 0.00, time = 12.81s.
# Batch  3 of 24: Hypervolume = 0.00, time = 44.15s.
# Batch  4 of 24: Hypervolume = 0.00, time = 27.16s.
# Batch  5 of 24: Hypervolume = 0.13, time = 28.18s.
# Batch  6 of 24: Hypervolume = 0.18, time = 13.17s.
# Batch  7 of 24: Hypervolume = 0.22, time = 10.14s.
# Batch  8 of 24: Hypervolume = 0.23, time = 26.40s.
# Batch  9 of 24: Hypervolume = 0.26, time = 24.66s.
# Batch 10 of 24: Hypervolume = 0.27, time = 11.71s.
# Batch 11 of 24: Hypervolume = 0.30, time = 9.92s.
# Batch 12 of 24: Hypervolume = 0.30, time = 39.34s.
# Batch 13 of 24: Hypervolume = 0.31, time = 34.95s.
# Batch 14 of 24: Hypervolume = 0.33, time = 9.82s.
# Batch 15 of 24: Hypervolume = 0.37, time = 10.05s.
# Batch 16 of 24: Hypervolume = 0.39, time = 13.44s.
# Batch 17 of 24: Hypervolume = 0.39, time = 10.14s.
# Batch 18 of 24: Hypervolume = 0.41, time = 25.67s.
# Batch 19 of 24: Hypervolume = 0.43, time = 12.62s.
# Batch 20 of 24: Hypervolume = 0.44, time = 23.86s.
# Batch 21 of 24: Hypervolume = 0.44, time = 10.73s.
# Batch 22 of 24: Hypervolume = 0.44, time = 22.67s.
# Batch 23 of 24: Hypervolume = 0.45, time = 10.20s.
# Batch 24 of 24: Hypervolume = 0.46, time = 10.94s.
# Time taken in total: 451.01s.
#
# Trial  5 of 5 for problem MW5 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 35.52s.
# Batch  2 of 24: Hypervolume = 0.00, time = 11.66s.
# Batch  3 of 24: Hypervolume = 0.01, time = 11.87s.
# Batch  4 of 24: Hypervolume = 0.08, time = 18.85s.
# Batch  5 of 24: Hypervolume = 0.08, time = 11.57s.
# Batch  6 of 24: Hypervolume = 0.21, time = 24.33s.
# Batch  7 of 24: Hypervolume = 0.21, time = 26.95s.
# Batch  8 of 24: Hypervolume = 0.21, time = 16.39s.
# Batch  9 of 24: Hypervolume = 0.28, time = 11.29s.
# Batch 10 of 24: Hypervolume = 0.29, time = 11.94s.
# Batch 11 of 24: Hypervolume = 0.29, time = 11.55s.
# Batch 12 of 24: Hypervolume = 0.29, time = 11.37s.
# Batch 13 of 24: Hypervolume = 0.30, time = 23.74s.
# Batch 14 of 24: Hypervolume = 0.30, time = 11.35s.
# Batch 15 of 24: Hypervolume = 0.34, time = 11.54s.
# Batch 16 of 24: Hypervolume = 0.35, time = 11.42s.
# Batch 17 of 24: Hypervolume = 0.36, time = 11.69s.
# Batch 18 of 24: Hypervolume = 0.38, time = 12.03s.
# Batch 19 of 24: Hypervolume = 0.38, time = 11.93s.
# Batch 20 of 24: Hypervolume = 0.39, time = 11.88s.
# Batch 21 of 24: Hypervolume = 0.39, time = 11.83s.
# Batch 22 of 24: Hypervolume = 0.39, time = 11.97s.
# Batch 23 of 24: Hypervolume = 0.39, time = 12.20s.
# Batch 24 of 24: Hypervolume = 0.39, time = 11.45s.
# Time taken in total: 356.35s.
#
# Trial  1 of 5 for problem MW5 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.78s.
# Batch  2 of 24: Hypervolume = 0.00, time = 10.83s.
# Batch  3 of 24: Hypervolume = 0.00, time = 13.16s.
# Batch  4 of 24: Hypervolume = 0.16, time = 18.10s.
# Batch  5 of 24: Hypervolume = 0.17, time = 12.05s.
# Batch  6 of 24: Hypervolume = 0.17, time = 12.95s.
# Batch  7 of 24: Hypervolume = 0.19, time = 12.57s.
# Batch  8 of 24: Hypervolume = 0.20, time = 12.58s.
# Batch  9 of 24: Hypervolume = 0.20, time = 12.80s.
# Batch 10 of 24: Hypervolume = 0.20, time = 12.52s.
# Batch 11 of 24: Hypervolume = 0.21, time = 12.13s.
# Batch 12 of 24: Hypervolume = 0.21, time = 12.60s.
# Batch 13 of 24: Hypervolume = 0.24, time = 12.46s.
# Batch 14 of 24: Hypervolume = 0.27, time = 11.79s.
# Batch 15 of 24: Hypervolume = 0.28, time = 12.48s.
# Batch 16 of 24: Hypervolume = 0.30, time = 12.60s.
# Batch 17 of 24: Hypervolume = 0.30, time = 12.85s.
# Batch 18 of 24: Hypervolume = 0.31, time = 12.52s.
# Batch 19 of 24: Hypervolume = 0.32, time = 12.32s.
# Batch 20 of 24: Hypervolume = 0.33, time = 12.25s.
# Batch 21 of 24: Hypervolume = 0.34, time = 12.66s.
# Batch 22 of 24: Hypervolume = 0.34, time = 12.66s.
# Batch 23 of 24: Hypervolume = 0.34, time = 13.52s.
# Batch 24 of 24: Hypervolume = 0.35, time = 13.44s.
# Time taken in total: 303.64s.
#
# Trial  2 of 5 for problem MW5 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.32s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.96s.
# Batch  3 of 24: Hypervolume = 0.00, time = 23.24s.
# Batch  4 of 24: Hypervolume = 0.03, time = 41.54s.
# Batch  5 of 24: Hypervolume = 0.10, time = 13.43s.
# Batch  6 of 24: Hypervolume = 0.12, time = 26.32s.
# Batch  7 of 24: Hypervolume = 0.13, time = 13.29s.
# Batch  8 of 24: Hypervolume = 0.14, time = 11.80s.
# Batch  9 of 24: Hypervolume = 0.14, time = 11.49s.
# Batch 10 of 24: Hypervolume = 0.18, time = 11.27s.
# Batch 11 of 24: Hypervolume = 0.21, time = 17.85s.
# Batch 12 of 24: Hypervolume = 0.24, time = 26.69s.
# Batch 13 of 24: Hypervolume = 0.25, time = 17.40s.
# Batch 14 of 24: Hypervolume = 0.31, time = 11.68s.
# Batch 15 of 24: Hypervolume = 0.33, time = 11.63s.
# Batch 16 of 24: Hypervolume = 0.33, time = 11.91s.
# Batch 17 of 24: Hypervolume = 0.35, time = 12.08s.
# Batch 18 of 24: Hypervolume = 0.37, time = 11.89s.
# Batch 19 of 24: Hypervolume = 0.38, time = 11.18s.
# Batch 20 of 24: Hypervolume = 0.38, time = 12.08s.
# Batch 21 of 24: Hypervolume = 0.39, time = 11.83s.
# Batch 22 of 24: Hypervolume = 0.39, time = 11.94s.
# Batch 23 of 24: Hypervolume = 0.40, time = 12.05s.
# Batch 24 of 24: Hypervolume = 0.41, time = 12.04s.
# Time taken in total: 363.99s.
#
# Trial  3 of 5 for problem MW5 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.20s.
# Batch  2 of 24: Hypervolume = 0.00, time = 34.14s.
# Batch  3 of 24: Hypervolume = 0.03, time = 32.83s.
# Batch  4 of 24: Hypervolume = 0.04, time = 13.27s.
# Batch  5 of 24: Hypervolume = 0.15, time = 27.02s.
# Batch  6 of 24: Hypervolume = 0.15, time = 10.28s.
# Batch  7 of 24: Hypervolume = 0.16, time = 24.11s.
# Batch  8 of 24: Hypervolume = 0.19, time = 10.43s.
# Batch  9 of 24: Hypervolume = 0.21, time = 10.46s.
# Batch 10 of 24: Hypervolume = 0.22, time = 10.15s.
# Batch 11 of 24: Hypervolume = 0.22, time = 9.94s.
# Batch 12 of 24: Hypervolume = 0.23, time = 10.40s.
# Batch 13 of 24: Hypervolume = 0.26, time = 18.27s.
# Batch 14 of 24: Hypervolume = 0.26, time = 10.39s.
# Batch 15 of 24: Hypervolume = 0.28, time = 10.20s.
# Batch 16 of 24: Hypervolume = 0.28, time = 10.07s.
# Batch 17 of 24: Hypervolume = 0.28, time = 10.38s.
# Batch 18 of 24: Hypervolume = 0.28, time = 10.01s.
# Batch 19 of 24: Hypervolume = 0.29, time = 10.13s.
# Batch 20 of 24: Hypervolume = 0.29, time = 10.89s.
# Batch 21 of 24: Hypervolume = 0.32, time = 10.53s.
# Batch 22 of 24: Hypervolume = 0.32, time = 10.78s.
# Batch 23 of 24: Hypervolume = 0.32, time = 10.45s.
# Batch 24 of 24: Hypervolume = 0.32, time = 12.26s.
# Time taken in total: 335.63s.
#
# Trial  4 of 5 for problem MW5 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.04s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.72s.
# Batch  3 of 24: Hypervolume = 0.00, time = 10.17s.
# Batch  4 of 24: Hypervolume = 0.00, time = 21.75s.
# Batch  5 of 24: Hypervolume = 0.03, time = 52.61s.
# Batch  6 of 24: Hypervolume = 0.03, time = 14.96s.
# Batch  7 of 24: Hypervolume = 0.08, time = 11.26s.
# Batch  8 of 24: Hypervolume = 0.11, time = 10.75s.
# Batch  9 of 24: Hypervolume = 0.14, time = 10.89s.
# Batch 10 of 24: Hypervolume = 0.14, time = 10.20s.
# Batch 11 of 24: Hypervolume = 0.15, time = 10.56s.
# Batch 12 of 24: Hypervolume = 0.20, time = 11.54s.
# Batch 13 of 24: Hypervolume = 0.20, time = 10.87s.
# Batch 14 of 24: Hypervolume = 0.20, time = 10.65s.
# Batch 15 of 24: Hypervolume = 0.20, time = 10.59s.
# Batch 16 of 24: Hypervolume = 0.21, time = 10.75s.
# Batch 17 of 24: Hypervolume = 0.21, time = 26.84s.
# Batch 18 of 24: Hypervolume = 0.27, time = 11.09s.
# Batch 19 of 24: Hypervolume = 0.29, time = 10.76s.
# Batch 20 of 24: Hypervolume = 0.29, time = 10.72s.
# Batch 21 of 24: Hypervolume = 0.31, time = 10.82s.
# Batch 22 of 24: Hypervolume = 0.31, time = 11.22s.
# Batch 23 of 24: Hypervolume = 0.34, time = 11.20s.
# Batch 24 of 24: Hypervolume = 0.34, time = 15.81s.
# Time taken in total: 333.79s.
#
# Trial  5 of 5 for problem MW5 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.03s.
# Batch  2 of 24: Hypervolume = 0.00, time = 18.73s.
# Batch  3 of 24: Hypervolume = 0.00, time = 14.72s.
# Batch  4 of 24: Hypervolume = 0.08, time = 14.96s.
# Batch  5 of 24: Hypervolume = 0.13, time = 25.52s.
# Batch  6 of 24: Hypervolume = 0.15, time = 31.07s.
# Batch  7 of 24: Hypervolume = 0.15, time = 11.43s.
# Batch  8 of 24: Hypervolume = 0.15, time = 11.06s.
# Batch  9 of 24: Hypervolume = 0.15, time = 11.67s.
# Batch 10 of 24: Hypervolume = 0.26, time = 11.23s.
# Batch 11 of 24: Hypervolume = 0.27, time = 11.81s.
# Batch 12 of 24: Hypervolume = 0.27, time = 18.51s.
# Batch 13 of 24: Hypervolume = 0.31, time = 11.76s.
# Batch 14 of 24: Hypervolume = 0.31, time = 11.97s.
# Batch 15 of 24: Hypervolume = 0.31, time = 11.78s.
# Batch 16 of 24: Hypervolume = 0.32, time = 11.67s.
# Batch 17 of 24: Hypervolume = 0.35, time = 12.07s.
# Batch 18 of 24: Hypervolume = 0.38, time = 12.17s.
# Batch 19 of 24: Hypervolume = 0.38, time = 12.07s.
# Batch 20 of 24: Hypervolume = 0.39, time = 12.20s.
# Batch 21 of 24: Hypervolume = 0.40, time = 12.32s.
# Batch 22 of 24: Hypervolume = 0.40, time = 12.17s.
# Batch 23 of 24: Hypervolume = 0.40, time = 12.65s.
# Batch 24 of 24: Hypervolume = 0.41, time = 12.12s.
# Time taken in total: 334.74s.
# All done!

# %%
problemname = 'MW3'

N_TRIALS = 5
verbose = True
noise = 0.00

N_BATCH = 24
BATCH_SIZE = 8

for dimensions in range(7, 12+ 1):

    class MWBase(torch.nn.Module):   
        def g1(X, n_obj):
            d = dimensions
            n = d - n_obj

            z = torch.pow(X[..., n_obj - 1:], n)
            i = torch.arange(n_obj - 1, d, **tkwargs)

            exp = 1 - torch.exp(-10.0 * (z - 0.5 - i / (2 * d)) * (z - 0.5 - i / (2 * d)))
            distance = 1 + exp.sum(axis=1)
            return distance

        def g3(X, n_obj):
            contrib = 2.0 * torch.pow(
                X[..., n_obj - 1:] + (X[..., n_obj - 2:-1] - 0.5) * (X[..., n_obj - 2:-1] - 0.5) - 1.0, 2.0)

            distance = 1 + contrib.sum(axis=1)
            return distance

        def LA1(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * np.pi * torch.pow(theta, C)), D)

        def LA2(A, B, C, D, theta):
            return A * torch.pow(torch.sin(B * torch.pow(theta, C)), D)

    class problem(torch.nn.Module):
        # must define these!
        n_var = dimensions
        n_obj = 2
        n_constr = 2 # inequality constraints only!

        ref_point = torch.tensor([1.1,1.1], **tkwargs)

        # input bounds, don't forget to change according to n_var!  
        bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])

        def evaluate(X):

            # objectives are defined by f1, f2....
            # if you have complex equations, you can break it up and place them in ProblemBase for convenience, not compulsory
            # otherwise, you could place an oracle here that outputs the objective
            g = MWBase.g3(X, n_obj=2)
            f1 = X[:, 0]
            f2 = g * (1.0 - f1 / g)

            # inequality constraints should take the form of c(n)<=0
            # for equality constraints, either use the equality constr argument, or rewrite into inequality form (preferred)
            # if no constraints, write as c1 = 0 * X[..., 0], and set n_constr=1     
            c1 = f1 + f2 - 1.05 - MWBase.LA1(0.45, 0.75, 1.0, 6.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)
            c2 = 0.85 - f1 - f2 + MWBase.LA1(0.3, 0.75, 1.0, 2.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)

            # botorch assumes maximisation
            # to maximise a postive output, stay positive
            # to minimise a positive output, force negative
            # to maximise a negative output (away from zero), force positive
            # to minimise a negative output (towards zero), stay negative
            output = torch.stack([-f1, -f2], dim=-1)

            # for 1 constraint, take c1.unsqueeze(dim=-1)
            # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
            slack = torch.stack([c1, c2], dim=-1)

            return output, slack
        
    hv_list = []
    train_list = []

    # main loop for each trial/run, random_state will be trial number
    for trial in range(0, N_TRIALS):
        print(f"\nTrial {trial+1:>2} of {N_TRIALS} for problem {problemname} with d = {dimensions}\n", end="")

        # initialize with a 2*(d+1) sample set
        initial_x = torch.tensor(initial_x_dict[dimensions][trial], **tkwargs)

        hv, train = optimize_hybrid_nsga(problem, problem.ref_point, initial_x,
                         N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                         random_state=trial, noise=noise, verbose=verbose)
        hv_list.append(hv)
        train_list.append(train)

    savetxt(f"{problemname}_{dimensions}dim_hvs_hybrid_nsga_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", hv_list, delimiter=',')    
    savetxt(f"{problemname}_{dimensions}dim_train_hybrid_nsga_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", np.array(train_list).reshape(-1), delimiter=',')
        
print("All done!")
# Out:
# Trial  1 of 5 for problem MW3 with d = 7
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# C:\Users\lowki\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2189.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 24: Hypervolume = 0.00, time = 12.96s.
# Batch  2 of 24: Hypervolume = 0.00, time = 15.62s.
# Batch  3 of 24: Hypervolume = 0.14, time = 14.40s.
# Batch  4 of 24: Hypervolume = 0.19, time = 33.53s.
# Batch  5 of 24: Hypervolume = 0.35, time = 22.66s.
# Batch  6 of 24: Hypervolume = 0.38, time = 12.45s.
# Batch  7 of 24: Hypervolume = 0.49, time = 29.86s.
# Batch  8 of 24: Hypervolume = 0.56, time = 17.46s.
# Batch  9 of 24: Hypervolume = 0.57, time = 12.83s.
# Batch 10 of 24: Hypervolume = 0.57, time = 18.53s.
# Batch 11 of 24: Hypervolume = 0.59, time = 19.86s.
# Batch 12 of 24: Hypervolume = 0.61, time = 15.97s.
# Batch 13 of 24: Hypervolume = 0.61, time = 15.65s.
# Batch 14 of 24: Hypervolume = 0.62, time = 11.04s.
# Batch 15 of 24: Hypervolume = 0.62, time = 15.48s.
# Batch 16 of 24: Hypervolume = 0.62, time = 15.59s.
# Batch 17 of 24: Hypervolume = 0.63, time = 30.69s.
# Batch 18 of 24: Hypervolume = 0.63, time = 14.37s.
# Batch 19 of 24: Hypervolume = 0.63, time = 18.26s.
# Batch 20 of 24: Hypervolume = 0.63, time = 14.14s.
# Batch 21 of 24: Hypervolume = 0.63, time = 13.20s.
# Batch 22 of 24: Hypervolume = 0.63, time = 13.68s.
# Batch 23 of 24: Hypervolume = 0.63, time = 16.85s.
# Batch 24 of 24: Hypervolume = 0.64, time = 33.99s.
# Time taken in total: 439.18s.
#
# Trial  2 of 5 for problem MW3 with d = 7
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 30.20s.
# Batch  2 of 24: Hypervolume = 0.14, time = 10.05s.
# Batch  3 of 24: Hypervolume = 0.30, time = 22.03s.
# Batch  4 of 24: Hypervolume = 0.30, time = 28.90s.
# Batch  5 of 24: Hypervolume = 0.40, time = 11.97s.
# Batch  6 of 24: Hypervolume = 0.51, time = 27.22s.
# Batch  7 of 24: Hypervolume = 0.54, time = 11.96s.
# Batch  8 of 24: Hypervolume = 0.55, time = 11.81s.
# Batch  9 of 24: Hypervolume = 0.58, time = 32.16s.
# Batch 10 of 24: Hypervolume = 0.59, time = 15.32s.
# Batch 11 of 24: Hypervolume = 0.60, time = 11.79s.
# Batch 12 of 24: Hypervolume = 0.60, time = 13.50s.
# Batch 13 of 24: Hypervolume = 0.61, time = 29.41s.
# Batch 14 of 24: Hypervolume = 0.61, time = 17.04s.
# Batch 15 of 24: Hypervolume = 0.61, time = 26.65s.
# Batch 16 of 24: Hypervolume = 0.62, time = 13.73s.
# Batch 17 of 24: Hypervolume = 0.62, time = 11.33s.
# Batch 18 of 24: Hypervolume = 0.62, time = 20.83s.
# Batch 19 of 24: Hypervolume = 0.62, time = 28.10s.
# Batch 20 of 24: Hypervolume = 0.62, time = 16.69s.
# Batch 21 of 24: Hypervolume = 0.62, time = 15.25s.
# Batch 22 of 24: Hypervolume = 0.63, time = 13.42s.
# Batch 23 of 24: Hypervolume = 0.63, time = 20.99s.
# Batch 24 of 24: Hypervolume = 0.63, time = 21.45s.
# Time taken in total: 461.82s.
#
# Trial  3 of 5 for problem MW3 with d = 7
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 11.92s.
# Batch  2 of 24: Hypervolume = 0.00, time = 28.43s.
# Batch  3 of 24: Hypervolume = 0.24, time = 30.87s.
# Batch  4 of 24: Hypervolume = 0.35, time = 24.52s.
# Batch  5 of 24: Hypervolume = 0.41, time = 22.89s.
# Batch  6 of 24: Hypervolume = 0.41, time = 17.04s.
# Batch  7 of 24: Hypervolume = 0.44, time = 23.42s.
# Batch  8 of 24: Hypervolume = 0.51, time = 12.79s.
# Batch  9 of 24: Hypervolume = 0.52, time = 13.19s.
# Batch 10 of 24: Hypervolume = 0.56, time = 13.59s.
# Batch 11 of 24: Hypervolume = 0.59, time = 11.12s.
# Batch 12 of 24: Hypervolume = 0.59, time = 11.66s.
# Batch 13 of 24: Hypervolume = 0.60, time = 10.85s.
# Batch 14 of 24: Hypervolume = 0.61, time = 10.55s.
# Batch 15 of 24: Hypervolume = 0.61, time = 11.43s.
# Batch 16 of 24: Hypervolume = 0.61, time = 12.11s.
# Batch 17 of 24: Hypervolume = 0.61, time = 13.79s.
# Batch 18 of 24: Hypervolume = 0.62, time = 15.64s.
# Batch 19 of 24: Hypervolume = 0.62, time = 12.62s.
# Batch 20 of 24: Hypervolume = 0.63, time = 14.93s.
# Batch 21 of 24: Hypervolume = 0.63, time = 15.62s.
# Batch 22 of 24: Hypervolume = 0.63, time = 13.18s.
# Batch 23 of 24: Hypervolume = 0.63, time = 17.04s.
# Batch 24 of 24: Hypervolume = 0.63, time = 15.53s.
# Time taken in total: 384.78s.
#
# Trial  4 of 5 for problem MW3 with d = 7
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.21, time = 36.36s.
# Batch  2 of 24: Hypervolume = 0.29, time = 30.46s.
# Batch  3 of 24: Hypervolume = 0.44, time = 28.00s.
# Batch  4 of 24: Hypervolume = 0.49, time = 13.68s.
# Batch  5 of 24: Hypervolume = 0.53, time = 33.03s.
# Batch  6 of 24: Hypervolume = 0.54, time = 9.12s.
# Batch  7 of 24: Hypervolume = 0.55, time = 22.07s.
# Batch  8 of 24: Hypervolume = 0.56, time = 11.85s.
# Batch  9 of 24: Hypervolume = 0.59, time = 16.54s.
# Batch 10 of 24: Hypervolume = 0.60, time = 14.57s.
# Batch 11 of 24: Hypervolume = 0.60, time = 16.55s.
# Batch 12 of 24: Hypervolume = 0.60, time = 11.68s.
# Batch 13 of 24: Hypervolume = 0.60, time = 11.00s.
# Batch 14 of 24: Hypervolume = 0.61, time = 13.73s.
# Batch 15 of 24: Hypervolume = 0.61, time = 16.03s.
# Batch 16 of 24: Hypervolume = 0.61, time = 16.53s.
# Batch 17 of 24: Hypervolume = 0.61, time = 13.63s.
# Batch 18 of 24: Hypervolume = 0.61, time = 19.22s.
# Batch 19 of 24: Hypervolume = 0.61, time = 14.03s.
# Batch 20 of 24: Hypervolume = 0.62, time = 21.97s.
# Batch 21 of 24: Hypervolume = 0.62, time = 27.80s.
# Batch 22 of 24: Hypervolume = 0.62, time = 28.94s.
# Batch 23 of 24: Hypervolume = 0.63, time = 12.09s.
# Batch 24 of 24: Hypervolume = 0.63, time = 11.76s.
# Time taken in total: 450.67s.
#
# Trial  5 of 5 for problem MW3 with d = 7
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.23s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.17s.
# Batch  3 of 24: Hypervolume = 0.38, time = 26.96s.
# Batch  4 of 24: Hypervolume = 0.44, time = 18.86s.
# Batch  5 of 24: Hypervolume = 0.45, time = 16.55s.
# Batch  6 of 24: Hypervolume = 0.54, time = 13.82s.
# Batch  7 of 24: Hypervolume = 0.55, time = 12.06s.
# Batch  8 of 24: Hypervolume = 0.56, time = 13.66s.
# Batch  9 of 24: Hypervolume = 0.57, time = 32.65s.
# Batch 10 of 24: Hypervolume = 0.57, time = 22.40s.
# Batch 11 of 24: Hypervolume = 0.57, time = 9.96s.
# Batch 12 of 24: Hypervolume = 0.58, time = 21.65s.
# Batch 13 of 24: Hypervolume = 0.58, time = 16.65s.
# Batch 14 of 24: Hypervolume = 0.58, time = 14.24s.
# Batch 15 of 24: Hypervolume = 0.59, time = 15.29s.
# Batch 16 of 24: Hypervolume = 0.59, time = 12.71s.
# Batch 17 of 24: Hypervolume = 0.59, time = 10.69s.
# Batch 18 of 24: Hypervolume = 0.59, time = 26.80s.
# Batch 19 of 24: Hypervolume = 0.59, time = 15.10s.
# Batch 20 of 24: Hypervolume = 0.59, time = 16.16s.
# Batch 21 of 24: Hypervolume = 0.61, time = 23.41s.
# Batch 22 of 24: Hypervolume = 0.61, time = 15.08s.
# Batch 23 of 24: Hypervolume = 0.61, time = 19.60s.
# Batch 24 of 24: Hypervolume = 0.61, time = 14.04s.
# Time taken in total: 405.77s.
#
# Trial  1 of 5 for problem MW3 with d = 8
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.13s.
# Batch  2 of 24: Hypervolume = 0.12, time = 29.42s.
# Batch  3 of 24: Hypervolume = 0.22, time = 29.10s.
# Batch  4 of 24: Hypervolume = 0.31, time = 19.22s.
# Batch  5 of 24: Hypervolume = 0.34, time = 14.62s.
# Batch  6 of 24: Hypervolume = 0.37, time = 17.26s.
# Batch  7 of 24: Hypervolume = 0.43, time = 14.88s.
# Batch  8 of 24: Hypervolume = 0.45, time = 31.72s.
# Batch  9 of 24: Hypervolume = 0.51, time = 18.04s.
# Batch 10 of 24: Hypervolume = 0.52, time = 11.05s.
# Batch 11 of 24: Hypervolume = 0.55, time = 20.24s.
# Batch 12 of 24: Hypervolume = 0.57, time = 12.48s.
# Batch 13 of 24: Hypervolume = 0.58, time = 23.24s.
# Batch 14 of 24: Hypervolume = 0.58, time = 18.43s.
# Batch 15 of 24: Hypervolume = 0.59, time = 25.41s.
# Batch 16 of 24: Hypervolume = 0.59, time = 14.73s.
# Batch 17 of 24: Hypervolume = 0.60, time = 24.07s.
# Batch 18 of 24: Hypervolume = 0.60, time = 15.05s.
# Batch 19 of 24: Hypervolume = 0.61, time = 17.08s.
# Batch 20 of 24: Hypervolume = 0.61, time = 23.50s.
# Batch 21 of 24: Hypervolume = 0.62, time = 12.51s.
# Batch 22 of 24: Hypervolume = 0.62, time = 22.38s.
# Batch 23 of 24: Hypervolume = 0.62, time = 12.87s.
# Batch 24 of 24: Hypervolume = 0.62, time = 32.86s.
# Time taken in total: 469.35s.
#
# Trial  2 of 5 for problem MW3 with d = 8
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 14.27s.
# Batch  2 of 24: Hypervolume = 0.11, time = 9.84s.
# Batch  3 of 24: Hypervolume = 0.25, time = 30.06s.
# Batch  4 of 24: Hypervolume = 0.25, time = 12.58s.
# Batch  5 of 24: Hypervolume = 0.36, time = 12.20s.
# Batch  6 of 24: Hypervolume = 0.49, time = 12.39s.
# Batch  7 of 24: Hypervolume = 0.52, time = 24.44s.
# Batch  8 of 24: Hypervolume = 0.55, time = 11.58s.
# Batch  9 of 24: Hypervolume = 0.57, time = 23.10s.
# Batch 10 of 24: Hypervolume = 0.59, time = 13.40s.
# Batch 11 of 24: Hypervolume = 0.59, time = 13.01s.
# Batch 12 of 24: Hypervolume = 0.60, time = 16.67s.
# Batch 13 of 24: Hypervolume = 0.61, time = 10.44s.
# Batch 14 of 24: Hypervolume = 0.61, time = 15.50s.
# Batch 15 of 24: Hypervolume = 0.62, time = 25.59s.
# Batch 16 of 24: Hypervolume = 0.62, time = 10.67s.
# Batch 17 of 24: Hypervolume = 0.62, time = 26.67s.
# Batch 18 of 24: Hypervolume = 0.63, time = 12.11s.
# Batch 19 of 24: Hypervolume = 0.63, time = 16.48s.
# Batch 20 of 24: Hypervolume = 0.63, time = 20.63s.
# Batch 21 of 24: Hypervolume = 0.63, time = 15.09s.
# Batch 22 of 24: Hypervolume = 0.63, time = 12.12s.
# Batch 23 of 24: Hypervolume = 0.63, time = 16.61s.
# Batch 24 of 24: Hypervolume = 0.63, time = 15.90s.
# Time taken in total: 391.39s.
#
# Trial  3 of 5 for problem MW3 with d = 8
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 30.85s.
# Batch  2 of 24: Hypervolume = 0.13, time = 36.40s.
# Batch  3 of 24: Hypervolume = 0.16, time = 22.74s.
# Batch  4 of 24: Hypervolume = 0.25, time = 30.21s.
# Batch  5 of 24: Hypervolume = 0.46, time = 17.47s.
# Batch  6 of 24: Hypervolume = 0.49, time = 32.05s.
# Batch  7 of 24: Hypervolume = 0.51, time = 25.18s.
# Batch  8 of 24: Hypervolume = 0.51, time = 8.34s.
# Batch  9 of 24: Hypervolume = 0.56, time = 28.63s.
# Batch 10 of 24: Hypervolume = 0.56, time = 17.59s.
# Batch 11 of 24: Hypervolume = 0.57, time = 15.39s.
# Batch 12 of 24: Hypervolume = 0.58, time = 17.90s.
# Batch 13 of 24: Hypervolume = 0.58, time = 9.51s.
# Batch 14 of 24: Hypervolume = 0.59, time = 11.62s.
# Batch 15 of 24: Hypervolume = 0.60, time = 11.06s.
# Batch 16 of 24: Hypervolume = 0.61, time = 9.34s.
# Batch 17 of 24: Hypervolume = 0.61, time = 13.34s.
# Batch 18 of 24: Hypervolume = 0.62, time = 24.31s.
# Batch 19 of 24: Hypervolume = 0.62, time = 10.01s.
# Batch 20 of 24: Hypervolume = 0.62, time = 20.07s.
# Batch 21 of 24: Hypervolume = 0.62, time = 36.52s.
# Batch 22 of 24: Hypervolume = 0.63, time = 11.83s.
# Batch 23 of 24: Hypervolume = 0.63, time = 26.28s.
# Batch 24 of 24: Hypervolume = 0.63, time = 19.75s.
# Time taken in total: 486.43s.
#
# Trial  4 of 5 for problem MW3 with d = 8
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.21, time = 26.78s.
# Batch  2 of 24: Hypervolume = 0.21, time = 11.58s.
# Batch  3 of 24: Hypervolume = 0.37, time = 26.05s.
# Batch  4 of 24: Hypervolume = 0.42, time = 27.04s.
# Batch  5 of 24: Hypervolume = 0.43, time = 10.59s.
# Batch  6 of 24: Hypervolume = 0.46, time = 23.60s.
# Batch  7 of 24: Hypervolume = 0.50, time = 14.15s.
# Batch  8 of 24: Hypervolume = 0.51, time = 12.20s.
# Batch  9 of 24: Hypervolume = 0.56, time = 25.51s.
# Batch 10 of 24: Hypervolume = 0.57, time = 11.38s.
# Batch 11 of 24: Hypervolume = 0.58, time = 8.87s.
# Batch 12 of 24: Hypervolume = 0.59, time = 8.81s.
# Batch 13 of 24: Hypervolume = 0.60, time = 8.94s.
# Batch 14 of 24: Hypervolume = 0.60, time = 15.96s.
# Batch 15 of 24: Hypervolume = 0.60, time = 17.03s.
# Batch 16 of 24: Hypervolume = 0.61, time = 8.56s.
# Batch 17 of 24: Hypervolume = 0.61, time = 15.25s.
# Batch 18 of 24: Hypervolume = 0.62, time = 9.47s.
# Batch 19 of 24: Hypervolume = 0.62, time = 14.68s.
# Batch 20 of 24: Hypervolume = 0.62, time = 13.98s.
# Batch 21 of 24: Hypervolume = 0.62, time = 14.43s.
# Batch 22 of 24: Hypervolume = 0.62, time = 10.75s.
# Batch 23 of 24: Hypervolume = 0.63, time = 11.39s.
# Batch 24 of 24: Hypervolume = 0.63, time = 29.43s.
# Time taken in total: 376.51s.
#
# Trial  5 of 5 for problem MW3 with d = 8
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 19.95s.
# Batch  2 of 24: Hypervolume = 0.19, time = 22.64s.
# Batch  3 of 24: Hypervolume = 0.19, time = 33.80s.
# Batch  4 of 24: Hypervolume = 0.33, time = 31.27s.
# Batch  5 of 24: Hypervolume = 0.45, time = 31.73s.
# Batch  6 of 24: Hypervolume = 0.51, time = 13.42s.
# Batch  7 of 24: Hypervolume = 0.55, time = 28.98s.
# Batch  8 of 24: Hypervolume = 0.56, time = 29.56s.
# Batch  9 of 24: Hypervolume = 0.57, time = 22.50s.
# Batch 10 of 24: Hypervolume = 0.58, time = 30.26s.
# Batch 11 of 24: Hypervolume = 0.58, time = 16.34s.
# Batch 12 of 24: Hypervolume = 0.58, time = 11.73s.
# Batch 13 of 24: Hypervolume = 0.59, time = 10.11s.
# Batch 14 of 24: Hypervolume = 0.59, time = 21.87s.
# Batch 15 of 24: Hypervolume = 0.60, time = 15.18s.
# Batch 16 of 24: Hypervolume = 0.61, time = 14.61s.
# Batch 17 of 24: Hypervolume = 0.61, time = 19.42s.
# Batch 18 of 24: Hypervolume = 0.61, time = 10.42s.
# Batch 19 of 24: Hypervolume = 0.61, time = 17.48s.
# Batch 20 of 24: Hypervolume = 0.62, time = 30.13s.
# Batch 21 of 24: Hypervolume = 0.63, time = 16.04s.
# Batch 22 of 24: Hypervolume = 0.63, time = 11.58s.
# Batch 23 of 24: Hypervolume = 0.63, time = 15.37s.
# Batch 24 of 24: Hypervolume = 0.63, time = 17.40s.
# Time taken in total: 491.85s.
#
# Trial  1 of 5 for problem MW3 with d = 9
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.09s.
# Batch  2 of 24: Hypervolume = 0.00, time = 10.14s.
# Batch  3 of 24: Hypervolume = 0.00, time = 17.07s.
# Batch  4 of 24: Hypervolume = 0.21, time = 28.26s.
# Batch  5 of 24: Hypervolume = 0.48, time = 25.80s.
# Batch  6 of 24: Hypervolume = 0.52, time = 25.32s.
# Batch  7 of 24: Hypervolume = 0.52, time = 11.72s.
# Batch  8 of 24: Hypervolume = 0.52, time = 16.70s.
# Batch  9 of 24: Hypervolume = 0.56, time = 10.83s.
# Batch 10 of 24: Hypervolume = 0.57, time = 10.81s.
# Batch 11 of 24: Hypervolume = 0.58, time = 22.99s.
# Batch 12 of 24: Hypervolume = 0.59, time = 23.65s.
# Batch 13 of 24: Hypervolume = 0.60, time = 17.04s.
# Batch 14 of 24: Hypervolume = 0.60, time = 11.73s.
# Batch 15 of 24: Hypervolume = 0.61, time = 11.09s.
# Batch 16 of 24: Hypervolume = 0.61, time = 24.29s.
# Batch 17 of 24: Hypervolume = 0.62, time = 11.62s.
# Batch 18 of 24: Hypervolume = 0.62, time = 12.12s.
# Batch 19 of 24: Hypervolume = 0.62, time = 11.83s.
# Batch 20 of 24: Hypervolume = 0.62, time = 11.62s.
# Batch 21 of 24: Hypervolume = 0.63, time = 12.20s.
# Batch 22 of 24: Hypervolume = 0.63, time = 13.15s.
# Batch 23 of 24: Hypervolume = 0.63, time = 12.56s.
# Batch 24 of 24: Hypervolume = 0.63, time = 12.86s.
# Time taken in total: 374.58s.
#
# Trial  2 of 5 for problem MW3 with d = 9
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.22s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.30s.
# Batch  3 of 24: Hypervolume = 0.37, time = 28.06s.
# Batch  4 of 24: Hypervolume = 0.39, time = 31.10s.
# Batch  5 of 24: Hypervolume = 0.42, time = 14.45s.
# Batch  6 of 24: Hypervolume = 0.48, time = 21.87s.
# Batch  7 of 24: Hypervolume = 0.48, time = 14.29s.
# Batch  8 of 24: Hypervolume = 0.48, time = 32.91s.
# Batch  9 of 24: Hypervolume = 0.56, time = 32.29s.
# Batch 10 of 24: Hypervolume = 0.57, time = 12.12s.
# Batch 11 of 24: Hypervolume = 0.57, time = 9.69s.
# Batch 12 of 24: Hypervolume = 0.58, time = 21.60s.
# Batch 13 of 24: Hypervolume = 0.59, time = 23.60s.
# Batch 14 of 24: Hypervolume = 0.60, time = 10.29s.
# Batch 15 of 24: Hypervolume = 0.60, time = 9.83s.
# Batch 16 of 24: Hypervolume = 0.60, time = 17.92s.
# Batch 17 of 24: Hypervolume = 0.61, time = 21.14s.
# Batch 18 of 24: Hypervolume = 0.61, time = 10.36s.
# Batch 19 of 24: Hypervolume = 0.61, time = 10.03s.
# Batch 20 of 24: Hypervolume = 0.62, time = 10.64s.
# Batch 21 of 24: Hypervolume = 0.62, time = 10.61s.
# Batch 22 of 24: Hypervolume = 0.62, time = 10.78s.
# Batch 23 of 24: Hypervolume = 0.62, time = 11.01s.
# Batch 24 of 24: Hypervolume = 0.62, time = 11.54s.
# Time taken in total: 393.68s.
#
# Trial  3 of 5 for problem MW3 with d = 9
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 34.79s.
# Batch  2 of 24: Hypervolume = 0.00, time = 8.42s.
# Batch  3 of 24: Hypervolume = 0.19, time = 10.66s.
# Batch  4 of 24: Hypervolume = 0.21, time = 28.73s.
# Batch  5 of 24: Hypervolume = 0.43, time = 27.53s.
# Batch  6 of 24: Hypervolume = 0.45, time = 26.31s.
# Batch  7 of 24: Hypervolume = 0.45, time = 16.27s.
# Batch  8 of 24: Hypervolume = 0.51, time = 9.95s.
# Batch  9 of 24: Hypervolume = 0.57, time = 14.95s.
# Batch 10 of 24: Hypervolume = 0.58, time = 15.73s.
# Batch 11 of 24: Hypervolume = 0.58, time = 8.53s.
# Batch 12 of 24: Hypervolume = 0.58, time = 12.53s.
# Batch 13 of 24: Hypervolume = 0.59, time = 9.26s.
# Batch 14 of 24: Hypervolume = 0.60, time = 9.67s.
# Batch 15 of 24: Hypervolume = 0.60, time = 22.66s.
# Batch 16 of 24: Hypervolume = 0.61, time = 9.44s.
# Batch 17 of 24: Hypervolume = 0.61, time = 31.40s.
# Batch 18 of 24: Hypervolume = 0.62, time = 15.82s.
# Batch 19 of 24: Hypervolume = 0.62, time = 10.36s.
# Batch 20 of 24: Hypervolume = 0.62, time = 9.73s.
# Batch 21 of 24: Hypervolume = 0.62, time = 9.53s.
# Batch 22 of 24: Hypervolume = 0.62, time = 9.67s.
# Batch 23 of 24: Hypervolume = 0.63, time = 21.04s.
# Batch 24 of 24: Hypervolume = 0.63, time = 10.61s.
# Time taken in total: 383.69s.
#
# Trial  4 of 5 for problem MW3 with d = 9
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 19.10s.
# Batch  2 of 24: Hypervolume = 0.00, time = 26.45s.
# Batch  3 of 24: Hypervolume = 0.25, time = 27.38s.
# Batch  4 of 24: Hypervolume = 0.41, time = 17.21s.
# Batch  5 of 24: Hypervolume = 0.43, time = 19.80s.
# Batch  6 of 24: Hypervolume = 0.45, time = 19.45s.
# Batch  7 of 24: Hypervolume = 0.48, time = 27.81s.
# Batch  8 of 24: Hypervolume = 0.49, time = 17.68s.
# Batch  9 of 24: Hypervolume = 0.51, time = 11.83s.
# Batch 10 of 24: Hypervolume = 0.53, time = 29.60s.
# Batch 11 of 24: Hypervolume = 0.53, time = 19.57s.
# Batch 12 of 24: Hypervolume = 0.55, time = 9.23s.
# Batch 13 of 24: Hypervolume = 0.56, time = 12.26s.
# Batch 14 of 24: Hypervolume = 0.58, time = 8.79s.
# Batch 15 of 24: Hypervolume = 0.58, time = 8.81s.
# Batch 16 of 24: Hypervolume = 0.59, time = 9.39s.
# Batch 17 of 24: Hypervolume = 0.59, time = 9.17s.
# Batch 18 of 24: Hypervolume = 0.59, time = 11.20s.
# Batch 19 of 24: Hypervolume = 0.59, time = 9.29s.
# Batch 20 of 24: Hypervolume = 0.59, time = 9.81s.
# Batch 21 of 24: Hypervolume = 0.60, time = 9.92s.
# Batch 22 of 24: Hypervolume = 0.60, time = 10.25s.
# Batch 23 of 24: Hypervolume = 0.60, time = 10.93s.
# Batch 24 of 24: Hypervolume = 0.60, time = 10.58s.
# Time taken in total: 365.59s.
#
# Trial  5 of 5 for problem MW3 with d = 9
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.14s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.04s.
# Batch  3 of 24: Hypervolume = 0.23, time = 20.67s.
# Batch  4 of 24: Hypervolume = 0.24, time = 16.57s.
# Batch  5 of 24: Hypervolume = 0.38, time = 16.92s.
# Batch  6 of 24: Hypervolume = 0.40, time = 13.47s.
# Batch  7 of 24: Hypervolume = 0.41, time = 27.68s.
# Batch  8 of 24: Hypervolume = 0.45, time = 9.94s.
# Batch  9 of 24: Hypervolume = 0.51, time = 13.93s.
# Batch 10 of 24: Hypervolume = 0.52, time = 12.76s.
# Batch 11 of 24: Hypervolume = 0.52, time = 12.22s.
# Batch 12 of 24: Hypervolume = 0.56, time = 22.79s.
# Batch 13 of 24: Hypervolume = 0.56, time = 26.69s.
# Batch 14 of 24: Hypervolume = 0.56, time = 10.48s.
# Batch 15 of 24: Hypervolume = 0.57, time = 10.07s.
# Batch 16 of 24: Hypervolume = 0.57, time = 10.20s.
# Batch 17 of 24: Hypervolume = 0.60, time = 10.25s.
# Batch 18 of 24: Hypervolume = 0.60, time = 15.22s.
# Batch 19 of 24: Hypervolume = 0.60, time = 10.58s.
# Batch 20 of 24: Hypervolume = 0.60, time = 10.37s.
# Batch 21 of 24: Hypervolume = 0.60, time = 13.11s.
# Batch 22 of 24: Hypervolume = 0.61, time = 11.33s.
# Batch 23 of 24: Hypervolume = 0.61, time = 11.48s.
# Batch 24 of 24: Hypervolume = 0.61, time = 12.56s.
# Time taken in total: 336.49s.
#
# Trial  1 of 5 for problem MW3 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.08s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.65s.
# Batch  3 of 24: Hypervolume = 0.00, time = 11.75s.
# Batch  4 of 24: Hypervolume = 0.17, time = 24.30s.
# Batch  5 of 24: Hypervolume = 0.18, time = 12.34s.
# Batch  6 of 24: Hypervolume = 0.31, time = 28.49s.
# Batch  7 of 24: Hypervolume = 0.45, time = 27.84s.
# Batch  8 of 24: Hypervolume = 0.45, time = 27.12s.
# Batch  9 of 24: Hypervolume = 0.46, time = 20.01s.
# Batch 10 of 24: Hypervolume = 0.47, time = 12.01s.
# Batch 11 of 24: Hypervolume = 0.51, time = 32.65s.
# Batch 12 of 24: Hypervolume = 0.52, time = 11.59s.
# Batch 13 of 24: Hypervolume = 0.52, time = 11.48s.
# Batch 14 of 24: Hypervolume = 0.56, time = 12.00s.
# Batch 15 of 24: Hypervolume = 0.56, time = 11.64s.
# Batch 16 of 24: Hypervolume = 0.57, time = 10.93s.
# Batch 17 of 24: Hypervolume = 0.57, time = 10.83s.
# Batch 18 of 24: Hypervolume = 0.58, time = 11.09s.
# Batch 19 of 24: Hypervolume = 0.58, time = 11.37s.
# Batch 20 of 24: Hypervolume = 0.58, time = 11.18s.
# Batch 21 of 24: Hypervolume = 0.59, time = 19.23s.
# Batch 22 of 24: Hypervolume = 0.60, time = 11.39s.
# Batch 23 of 24: Hypervolume = 0.60, time = 12.12s.
# Batch 24 of 24: Hypervolume = 0.60, time = 11.45s.
# Time taken in total: 371.58s.
#
# Trial  2 of 5 for problem MW3 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.33s.
# Batch  2 of 24: Hypervolume = 0.00, time = 26.98s.
# Batch  3 of 24: Hypervolume = 0.11, time = 15.15s.
# Batch  4 of 24: Hypervolume = 0.18, time = 21.57s.
# Batch  5 of 24: Hypervolume = 0.32, time = 12.97s.
# Batch  6 of 24: Hypervolume = 0.37, time = 9.84s.
# Batch  7 of 24: Hypervolume = 0.37, time = 9.54s.
# Batch  8 of 24: Hypervolume = 0.40, time = 12.64s.
# Batch  9 of 24: Hypervolume = 0.40, time = 10.22s.
# Batch 10 of 24: Hypervolume = 0.43, time = 10.00s.
# Batch 11 of 24: Hypervolume = 0.43, time = 10.39s.
# Batch 12 of 24: Hypervolume = 0.43, time = 9.90s.
# Batch 13 of 24: Hypervolume = 0.51, time = 9.92s.
# Batch 14 of 24: Hypervolume = 0.51, time = 10.75s.
# Batch 15 of 24: Hypervolume = 0.51, time = 10.14s.
# Batch 16 of 24: Hypervolume = 0.52, time = 10.20s.
# Batch 17 of 24: Hypervolume = 0.53, time = 10.33s.
# Batch 18 of 24: Hypervolume = 0.53, time = 10.04s.
# Batch 19 of 24: Hypervolume = 0.55, time = 11.83s.
# Batch 20 of 24: Hypervolume = 0.59, time = 10.54s.
# Batch 21 of 24: Hypervolume = 0.59, time = 10.45s.
# Batch 22 of 24: Hypervolume = 0.60, time = 10.81s.
# Batch 23 of 24: Hypervolume = 0.60, time = 11.10s.
# Batch 24 of 24: Hypervolume = 0.60, time = 10.86s.
# Time taken in total: 284.52s.
#
# Trial  3 of 5 for problem MW3 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 13.39s.
# Batch  2 of 24: Hypervolume = 0.00, time = 27.99s.
# Batch  3 of 24: Hypervolume = 0.00, time = 10.08s.
# Batch  4 of 24: Hypervolume = 0.17, time = 23.31s.
# Batch  5 of 24: Hypervolume = 0.33, time = 20.32s.
# Batch  6 of 24: Hypervolume = 0.33, time = 28.29s.
# Batch  7 of 24: Hypervolume = 0.40, time = 10.61s.
# Batch  8 of 24: Hypervolume = 0.40, time = 8.98s.
# Batch  9 of 24: Hypervolume = 0.40, time = 10.44s.
# Batch 10 of 24: Hypervolume = 0.48, time = 8.62s.
# Batch 11 of 24: Hypervolume = 0.48, time = 8.92s.
# Batch 12 of 24: Hypervolume = 0.50, time = 8.45s.
# Batch 13 of 24: Hypervolume = 0.53, time = 8.64s.
# Batch 14 of 24: Hypervolume = 0.54, time = 9.04s.
# Batch 15 of 24: Hypervolume = 0.54, time = 8.58s.
# Batch 16 of 24: Hypervolume = 0.59, time = 17.93s.
# Batch 17 of 24: Hypervolume = 0.59, time = 8.75s.
# Batch 18 of 24: Hypervolume = 0.59, time = 9.34s.
# Batch 19 of 24: Hypervolume = 0.59, time = 9.06s.
# Batch 20 of 24: Hypervolume = 0.59, time = 9.08s.
# Batch 21 of 24: Hypervolume = 0.60, time = 9.37s.
# Batch 22 of 24: Hypervolume = 0.61, time = 9.95s.
# Batch 23 of 24: Hypervolume = 0.61, time = 9.40s.
# Batch 24 of 24: Hypervolume = 0.62, time = 10.36s.
# Time taken in total: 298.92s.
#
# Trial  4 of 5 for problem MW3 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 7.17s.
# Batch  2 of 24: Hypervolume = 0.00, time = 27.18s.
# Batch  3 of 24: Hypervolume = 0.11, time = 28.87s.
# Batch  4 of 24: Hypervolume = 0.13, time = 8.62s.
# Batch  5 of 24: Hypervolume = 0.30, time = 20.90s.
# Batch  6 of 24: Hypervolume = 0.37, time = 19.96s.
# Batch  7 of 24: Hypervolume = 0.37, time = 8.56s.
# Batch  8 of 24: Hypervolume = 0.43, time = 11.62s.
# Batch  9 of 24: Hypervolume = 0.43, time = 18.39s.
# Batch 10 of 24: Hypervolume = 0.50, time = 8.97s.
# Batch 11 of 24: Hypervolume = 0.51, time = 19.64s.
# Batch 12 of 24: Hypervolume = 0.52, time = 8.69s.
# Batch 13 of 24: Hypervolume = 0.55, time = 10.11s.
# Batch 14 of 24: Hypervolume = 0.56, time = 19.93s.
# Batch 15 of 24: Hypervolume = 0.57, time = 34.74s.
# Batch 16 of 24: Hypervolume = 0.58, time = 11.56s.
# Batch 17 of 24: Hypervolume = 0.58, time = 9.14s.
# Batch 18 of 24: Hypervolume = 0.59, time = 9.35s.
# Batch 19 of 24: Hypervolume = 0.59, time = 9.25s.
# Batch 20 of 24: Hypervolume = 0.60, time = 9.25s.
# Batch 21 of 24: Hypervolume = 0.60, time = 10.72s.
# Batch 22 of 24: Hypervolume = 0.60, time = 19.56s.
# Batch 23 of 24: Hypervolume = 0.61, time = 13.29s.
# Batch 24 of 24: Hypervolume = 0.61, time = 10.61s.
# Time taken in total: 356.07s.
#
# Trial  5 of 5 for problem MW3 with d = 10
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.37s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.23s.
# Batch  3 of 24: Hypervolume = 0.00, time = 9.92s.
# Batch  4 of 24: Hypervolume = 0.20, time = 17.98s.
# Batch  5 of 24: Hypervolume = 0.30, time = 14.92s.
# Batch  6 of 24: Hypervolume = 0.33, time = 10.34s.
# Batch  7 of 24: Hypervolume = 0.33, time = 9.61s.
# Batch  8 of 24: Hypervolume = 0.34, time = 9.95s.
# Batch  9 of 24: Hypervolume = 0.34, time = 10.06s.
# Batch 10 of 24: Hypervolume = 0.35, time = 21.20s.
# Batch 11 of 24: Hypervolume = 0.35, time = 10.28s.
# Batch 12 of 24: Hypervolume = 0.36, time = 10.36s.
# Batch 13 of 24: Hypervolume = 0.36, time = 10.20s.
# Batch 14 of 24: Hypervolume = 0.36, time = 10.87s.
# Batch 15 of 24: Hypervolume = 0.38, time = 10.23s.
# Batch 16 of 24: Hypervolume = 0.38, time = 10.14s.
# Batch 17 of 24: Hypervolume = 0.38, time = 10.78s.
# Batch 18 of 24: Hypervolume = 0.38, time = 31.12s.
# Batch 19 of 24: Hypervolume = 0.45, time = 10.34s.
# Batch 20 of 24: Hypervolume = 0.45, time = 17.26s.
# Batch 21 of 24: Hypervolume = 0.45, time = 24.06s.
# Batch 22 of 24: Hypervolume = 0.53, time = 11.49s.
# Batch 23 of 24: Hypervolume = 0.54, time = 10.75s.
# Batch 24 of 24: Hypervolume = 0.55, time = 12.00s.
# Time taken in total: 311.50s.
#
# Trial  1 of 5 for problem MW3 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.08s.
# Batch  2 of 24: Hypervolume = 0.00, time = 19.45s.
# Batch  3 of 24: Hypervolume = 0.27, time = 29.35s.
# Batch  4 of 24: Hypervolume = 0.30, time = 29.26s.
# Batch  5 of 24: Hypervolume = 0.32, time = 18.49s.
# Batch  6 of 24: Hypervolume = 0.32, time = 11.01s.
# Batch  7 of 24: Hypervolume = 0.41, time = 32.70s.
# Batch  8 of 24: Hypervolume = 0.44, time = 10.67s.
# Batch  9 of 24: Hypervolume = 0.44, time = 10.86s.
# Batch 10 of 24: Hypervolume = 0.52, time = 11.15s.
# Batch 11 of 24: Hypervolume = 0.52, time = 10.93s.
# Batch 12 of 24: Hypervolume = 0.53, time = 11.06s.
# Batch 13 of 24: Hypervolume = 0.57, time = 11.26s.
# Batch 14 of 24: Hypervolume = 0.57, time = 11.26s.
# Batch 15 of 24: Hypervolume = 0.57, time = 11.11s.
# Batch 16 of 24: Hypervolume = 0.57, time = 11.36s.
# Batch 17 of 24: Hypervolume = 0.58, time = 11.18s.
# Batch 18 of 24: Hypervolume = 0.59, time = 11.61s.
# Batch 19 of 24: Hypervolume = 0.59, time = 12.29s.
# Batch 20 of 24: Hypervolume = 0.60, time = 11.33s.
# Batch 21 of 24: Hypervolume = 0.60, time = 11.20s.
# Batch 22 of 24: Hypervolume = 0.60, time = 12.00s.
# Batch 23 of 24: Hypervolume = 0.61, time = 11.79s.
# Batch 24 of 24: Hypervolume = 0.61, time = 11.54s.
# Time taken in total: 341.99s.
#
# Trial  2 of 5 for problem MW3 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.20s.
# Batch  2 of 24: Hypervolume = 0.00, time = 11.15s.
# Batch  3 of 24: Hypervolume = 0.17, time = 21.84s.
# Batch  4 of 24: Hypervolume = 0.19, time = 10.47s.
# Batch  5 of 24: Hypervolume = 0.19, time = 20.06s.
# Batch  6 of 24: Hypervolume = 0.35, time = 9.89s.
# Batch  7 of 24: Hypervolume = 0.42, time = 10.78s.
# Batch  8 of 24: Hypervolume = 0.45, time = 10.22s.
# Batch  9 of 24: Hypervolume = 0.46, time = 10.68s.
# Batch 10 of 24: Hypervolume = 0.47, time = 10.78s.
# Batch 11 of 24: Hypervolume = 0.48, time = 10.44s.
# Batch 12 of 24: Hypervolume = 0.49, time = 10.17s.
# Batch 13 of 24: Hypervolume = 0.50, time = 18.18s.
# Batch 14 of 24: Hypervolume = 0.52, time = 11.19s.
# Batch 15 of 24: Hypervolume = 0.53, time = 11.04s.
# Batch 16 of 24: Hypervolume = 0.54, time = 10.79s.
# Batch 17 of 24: Hypervolume = 0.54, time = 10.73s.
# Batch 18 of 24: Hypervolume = 0.56, time = 11.61s.
# Batch 19 of 24: Hypervolume = 0.56, time = 10.81s.
# Batch 20 of 24: Hypervolume = 0.56, time = 10.92s.
# Batch 21 of 24: Hypervolume = 0.56, time = 10.62s.
# Batch 22 of 24: Hypervolume = 0.56, time = 11.48s.
# Batch 23 of 24: Hypervolume = 0.57, time = 10.48s.
# Batch 24 of 24: Hypervolume = 0.57, time = 11.14s.
# Time taken in total: 283.73s.
#
# Trial  3 of 5 for problem MW3 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 13.62s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.50s.
# Batch  3 of 24: Hypervolume = 0.00, time = 26.53s.
# Batch  4 of 24: Hypervolume = 0.14, time = 8.22s.
# Batch  5 of 24: Hypervolume = 0.17, time = 19.07s.
# Batch  6 of 24: Hypervolume = 0.22, time = 26.81s.
# Batch  7 of 24: Hypervolume = 0.26, time = 8.64s.
# Batch  8 of 24: Hypervolume = 0.31, time = 21.29s.
# Batch  9 of 24: Hypervolume = 0.41, time = 8.40s.
# Batch 10 of 24: Hypervolume = 0.44, time = 8.70s.
# Batch 11 of 24: Hypervolume = 0.46, time = 9.23s.
# Batch 12 of 24: Hypervolume = 0.49, time = 8.75s.
# Batch 13 of 24: Hypervolume = 0.50, time = 8.86s.
# Batch 14 of 24: Hypervolume = 0.51, time = 8.70s.
# Batch 15 of 24: Hypervolume = 0.53, time = 8.76s.
# Batch 16 of 24: Hypervolume = 0.53, time = 8.86s.
# Batch 17 of 24: Hypervolume = 0.55, time = 8.51s.
# Batch 18 of 24: Hypervolume = 0.57, time = 9.53s.
# Batch 19 of 24: Hypervolume = 0.57, time = 9.03s.
# Batch 20 of 24: Hypervolume = 0.57, time = 9.15s.
# Batch 21 of 24: Hypervolume = 0.57, time = 9.45s.
# Batch 22 of 24: Hypervolume = 0.57, time = 9.11s.
# Batch 23 of 24: Hypervolume = 0.58, time = 9.51s.
# Batch 24 of 24: Hypervolume = 0.59, time = 9.59s.
# Time taken in total: 277.85s.
#
# Trial  4 of 5 for problem MW3 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 7.22s.
# Batch  2 of 24: Hypervolume = 0.00, time = 7.83s.
# Batch  3 of 24: Hypervolume = 0.00, time = 8.42s.
# Batch  4 of 24: Hypervolume = 0.00, time = 8.26s.
# Batch  5 of 24: Hypervolume = 0.14, time = 8.54s.
# Batch  6 of 24: Hypervolume = 0.29, time = 8.79s.
# Batch  7 of 24: Hypervolume = 0.31, time = 9.70s.
# Batch  8 of 24: Hypervolume = 0.35, time = 17.56s.
# Batch  9 of 24: Hypervolume = 0.35, time = 10.01s.
# Batch 10 of 24: Hypervolume = 0.35, time = 9.84s.
# Batch 11 of 24: Hypervolume = 0.40, time = 9.51s.
# Batch 12 of 24: Hypervolume = 0.41, time = 9.87s.
# Batch 13 of 24: Hypervolume = 0.45, time = 9.15s.
# Batch 14 of 24: Hypervolume = 0.49, time = 9.25s.
# Batch 15 of 24: Hypervolume = 0.52, time = 8.92s.
# Batch 16 of 24: Hypervolume = 0.54, time = 13.12s.
# Batch 17 of 24: Hypervolume = 0.54, time = 9.28s.
# Batch 18 of 24: Hypervolume = 0.55, time = 9.37s.
# Batch 19 of 24: Hypervolume = 0.55, time = 9.62s.
# Batch 20 of 24: Hypervolume = 0.56, time = 8.92s.
# Batch 21 of 24: Hypervolume = 0.57, time = 9.29s.
# Batch 22 of 24: Hypervolume = 0.58, time = 9.75s.
# Batch 23 of 24: Hypervolume = 0.58, time = 9.65s.
# Batch 24 of 24: Hypervolume = 0.59, time = 9.59s.
# Time taken in total: 231.53s.
#
# Trial  5 of 5 for problem MW3 with d = 11
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 7.95s.
# Batch  2 of 24: Hypervolume = 0.16, time = 9.54s.
# Batch  3 of 24: Hypervolume = 0.20, time = 9.87s.
# Batch  4 of 24: Hypervolume = 0.20, time = 9.45s.
# Batch  5 of 24: Hypervolume = 0.20, time = 10.32s.
# Batch  6 of 24: Hypervolume = 0.22, time = 23.29s.
# Batch  7 of 24: Hypervolume = 0.34, time = 13.57s.
# Batch  8 of 24: Hypervolume = 0.37, time = 10.12s.
# Batch  9 of 24: Hypervolume = 0.37, time = 9.86s.
# Batch 10 of 24: Hypervolume = 0.37, time = 10.64s.
# Batch 11 of 24: Hypervolume = 0.38, time = 21.74s.
# Batch 12 of 24: Hypervolume = 0.38, time = 9.98s.
# Batch 13 of 24: Hypervolume = 0.38, time = 10.65s.
# Batch 14 of 24: Hypervolume = 0.38, time = 10.15s.
# Batch 15 of 24: Hypervolume = 0.45, time = 10.25s.
# Batch 16 of 24: Hypervolume = 0.45, time = 10.51s.
# Batch 17 of 24: Hypervolume = 0.46, time = 10.90s.
# Batch 18 of 24: Hypervolume = 0.46, time = 11.12s.
# Batch 19 of 24: Hypervolume = 0.46, time = 10.48s.
# Batch 20 of 24: Hypervolume = 0.49, time = 10.76s.
# Batch 21 of 24: Hypervolume = 0.51, time = 10.37s.
# Batch 22 of 24: Hypervolume = 0.51, time = 10.31s.
# Batch 23 of 24: Hypervolume = 0.52, time = 11.43s.
# Batch 24 of 24: Hypervolume = 0.54, time = 10.79s.
# Time taken in total: 274.15s.
#
# Trial  1 of 5 for problem MW3 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 9.09s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.76s.
# Batch  3 of 24: Hypervolume = 0.00, time = 10.69s.
# Batch  4 of 24: Hypervolume = 0.00, time = 20.64s.
# Batch  5 of 24: Hypervolume = 0.21, time = 10.76s.
# Batch  6 of 24: Hypervolume = 0.25, time = 21.28s.
# Batch  7 of 24: Hypervolume = 0.25, time = 11.14s.
# Batch  8 of 24: Hypervolume = 0.27, time = 11.04s.
# Batch  9 of 24: Hypervolume = 0.33, time = 12.29s.
# Batch 10 of 24: Hypervolume = 0.34, time = 16.56s.
# Batch 11 of 24: Hypervolume = 0.34, time = 22.17s.
# Batch 12 of 24: Hypervolume = 0.37, time = 11.09s.
# Batch 13 of 24: Hypervolume = 0.37, time = 11.58s.
# Batch 14 of 24: Hypervolume = 0.38, time = 11.65s.
# Batch 15 of 24: Hypervolume = 0.38, time = 11.17s.
# Batch 16 of 24: Hypervolume = 0.47, time = 11.73s.
# Batch 17 of 24: Hypervolume = 0.47, time = 11.50s.
# Batch 18 of 24: Hypervolume = 0.50, time = 11.03s.
# Batch 19 of 24: Hypervolume = 0.51, time = 11.32s.
# Batch 20 of 24: Hypervolume = 0.51, time = 11.33s.
# Batch 21 of 24: Hypervolume = 0.52, time = 11.76s.
# Batch 22 of 24: Hypervolume = 0.54, time = 12.09s.
# Batch 23 of 24: Hypervolume = 0.54, time = 11.58s.
# Batch 24 of 24: Hypervolume = 0.55, time = 11.87s.
# Time taken in total: 305.21s.
#
# Trial  2 of 5 for problem MW3 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.15s.
# Batch  2 of 24: Hypervolume = 0.00, time = 8.61s.
# Batch  3 of 24: Hypervolume = 0.00, time = 9.20s.
# Batch  4 of 24: Hypervolume = 0.00, time = 9.31s.
# Batch  5 of 24: Hypervolume = 0.16, time = 28.90s.
# Batch  6 of 24: Hypervolume = 0.27, time = 11.43s.
# Batch  7 of 24: Hypervolume = 0.27, time = 10.34s.
# Batch  8 of 24: Hypervolume = 0.39, time = 16.71s.
# Batch  9 of 24: Hypervolume = 0.41, time = 20.26s.
# Batch 10 of 24: Hypervolume = 0.42, time = 13.92s.
# Batch 11 of 24: Hypervolume = 0.46, time = 10.78s.
# Batch 12 of 24: Hypervolume = 0.50, time = 10.98s.
# Batch 13 of 24: Hypervolume = 0.51, time = 11.08s.
# Batch 14 of 24: Hypervolume = 0.54, time = 10.58s.
# Batch 15 of 24: Hypervolume = 0.55, time = 10.45s.
# Batch 16 of 24: Hypervolume = 0.55, time = 10.75s.
# Batch 17 of 24: Hypervolume = 0.56, time = 10.78s.
# Batch 18 of 24: Hypervolume = 0.57, time = 10.81s.
# Batch 19 of 24: Hypervolume = 0.57, time = 10.47s.
# Batch 20 of 24: Hypervolume = 0.57, time = 11.14s.
# Batch 21 of 24: Hypervolume = 0.58, time = 12.06s.
# Batch 22 of 24: Hypervolume = 0.58, time = 11.50s.
# Batch 23 of 24: Hypervolume = 0.58, time = 10.44s.
# Batch 24 of 24: Hypervolume = 0.58, time = 11.31s.
# Time taken in total: 289.97s.
#
# Trial  3 of 5 for problem MW3 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 12.29s.
# Batch  2 of 24: Hypervolume = 0.00, time = 8.31s.
# Batch  3 of 24: Hypervolume = 0.00, time = 11.70s.
# Batch  4 of 24: Hypervolume = 0.00, time = 9.01s.
# Batch  5 of 24: Hypervolume = 0.19, time = 9.19s.
# Batch  6 of 24: Hypervolume = 0.20, time = 29.66s.
# Batch  7 of 24: Hypervolume = 0.27, time = 28.74s.
# Batch  8 of 24: Hypervolume = 0.29, time = 10.06s.
# Batch  9 of 24: Hypervolume = 0.29, time = 8.65s.
# Batch 10 of 24: Hypervolume = 0.33, time = 8.90s.
# Batch 11 of 24: Hypervolume = 0.33, time = 9.33s.
# Batch 12 of 24: Hypervolume = 0.37, time = 13.28s.
# Batch 13 of 24: Hypervolume = 0.37, time = 8.62s.
# Batch 14 of 24: Hypervolume = 0.38, time = 8.92s.
# Batch 15 of 24: Hypervolume = 0.47, time = 8.70s.
# Batch 16 of 24: Hypervolume = 0.47, time = 9.11s.
# Batch 17 of 24: Hypervolume = 0.47, time = 8.98s.
# Batch 18 of 24: Hypervolume = 0.48, time = 9.26s.
# Batch 19 of 24: Hypervolume = 0.50, time = 10.17s.
# Batch 20 of 24: Hypervolume = 0.51, time = 9.34s.
# Batch 21 of 24: Hypervolume = 0.53, time = 9.45s.
# Batch 22 of 24: Hypervolume = 0.54, time = 10.26s.
# Batch 23 of 24: Hypervolume = 0.55, time = 9.79s.
# Batch 24 of 24: Hypervolume = 0.57, time = 10.37s.
# Time taken in total: 272.16s.
#
# Trial  4 of 5 for problem MW3 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 7.58s.
# Batch  2 of 24: Hypervolume = 0.00, time = 8.69s.
# Batch  3 of 24: Hypervolume = 0.00, time = 8.29s.
# Batch  4 of 24: Hypervolume = 0.00, time = 19.45s.
# Batch  5 of 24: Hypervolume = 0.27, time = 9.89s.
# Batch  6 of 24: Hypervolume = 0.30, time = 18.45s.
# Batch  7 of 24: Hypervolume = 0.34, time = 9.28s.
# Batch  8 of 24: Hypervolume = 0.36, time = 9.69s.
# Batch  9 of 24: Hypervolume = 0.46, time = 9.26s.
# Batch 10 of 24: Hypervolume = 0.46, time = 10.15s.
# Batch 11 of 24: Hypervolume = 0.50, time = 9.62s.
# Batch 12 of 24: Hypervolume = 0.53, time = 17.61s.
# Batch 13 of 24: Hypervolume = 0.54, time = 20.20s.
# Batch 14 of 24: Hypervolume = 0.56, time = 9.54s.
# Batch 15 of 24: Hypervolume = 0.56, time = 9.94s.
# Batch 16 of 24: Hypervolume = 0.57, time = 9.44s.
# Batch 17 of 24: Hypervolume = 0.57, time = 9.61s.
# Batch 18 of 24: Hypervolume = 0.58, time = 9.54s.
# Batch 19 of 24: Hypervolume = 0.58, time = 9.47s.
# Batch 20 of 24: Hypervolume = 0.59, time = 9.48s.
# Batch 21 of 24: Hypervolume = 0.59, time = 9.48s.
# Batch 22 of 24: Hypervolume = 0.60, time = 10.17s.
# Batch 23 of 24: Hypervolume = 0.60, time = 10.36s.
# Batch 24 of 24: Hypervolume = 0.60, time = 10.29s.
# Time taken in total: 265.48s.
#
# Trial  5 of 5 for problem MW3 with d = 12
# Optimizing with Hybrid qNEHVI + U-NSGA-III
# Batch  1 of 24: Hypervolume = 0.00, time = 8.34s.
# Batch  2 of 24: Hypervolume = 0.00, time = 9.39s.
# Batch  3 of 24: Hypervolume = 0.00, time = 29.66s.
# Batch  4 of 24: Hypervolume = 0.21, time = 16.37s.
# Batch  5 of 24: Hypervolume = 0.28, time = 12.31s.
# Batch  6 of 24: Hypervolume = 0.29, time = 10.75s.
# Batch  7 of 24: Hypervolume = 0.33, time = 10.54s.
# Batch  8 of 24: Hypervolume = 0.34, time = 10.31s.
# Batch  9 of 24: Hypervolume = 0.35, time = 10.76s.
# Batch 10 of 24: Hypervolume = 0.36, time = 11.28s.
# Batch 11 of 24: Hypervolume = 0.36, time = 21.10s.
# Batch 12 of 24: Hypervolume = 0.36, time = 10.48s.
# Batch 13 of 24: Hypervolume = 0.37, time = 10.50s.
# Batch 14 of 24: Hypervolume = 0.37, time = 10.45s.
# Batch 15 of 24: Hypervolume = 0.37, time = 10.39s.
# Batch 16 of 24: Hypervolume = 0.37, time = 10.31s.
# Batch 17 of 24: Hypervolume = 0.38, time = 10.61s.
# Batch 18 of 24: Hypervolume = 0.38, time = 10.26s.
# Batch 19 of 24: Hypervolume = 0.38, time = 11.18s.
# Batch 20 of 24: Hypervolume = 0.39, time = 11.75s.
# Batch 21 of 24: Hypervolume = 0.40, time = 10.17s.
# Batch 22 of 24: Hypervolume = 0.48, time = 11.08s.
# Batch 23 of 24: Hypervolume = 0.48, time = 11.01s.
# Batch 24 of 24: Hypervolume = 0.50, time = 10.70s.
# Time taken in total: 289.73s.
# All done!

# %%
from botorch.test_functions.multi_objective import MW7

problemname = 'MW7'

N_TRIALS = 5
verbose = True
noise = 0.00

N_BATCH = 24
BATCH_SIZE = 8

for dimensions in range(2, 6+ 1):

    MW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)

    class problem(torch.nn.Module):
        n_var = dimensions
        n_obj = 2
        n_constr = 2

        ref_point = torch.tensor([1.2,1.2], **tkwargs)

        bounds = MW7base.bounds    

        def evaluate(X):       
            output = MW7base(X)
            slack = -MW7base.evaluate_slack(X)

            return output, slack
        
    hv_list = []
    train_list = []

    # main loop for each trial/run, random_state will be trial number
    for trial in range(0, N_TRIALS):
        print(f"\nTrial {trial+1:>2} of {N_TRIALS} for problem {problemname} with d = {dimensions}\n", end="")

        # initialize with a 2*(d+1) sample set
        initial_x = torch.tensor(initial_x_dict[dimensions][trial], **tkwargs)

        hv, train = optimize_hybrid_moead(problem, problem.ref_point, initial_x,
                         N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                         random_state=trial, noise=noise, verbose=verbose)
        hv_list.append(hv)
        train_list.append(train)

    savetxt(f"{problemname}_{dimensions}dim_hvs_hybrid_moead_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", hv_list, delimiter=',')    
    savetxt(f"{problemname}_{dimensions}dim_train_hybrid_moead_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", np.array(train_list).reshape(-1), delimiter=',')
        
print("All done!")
# Out:
# Trial  1 of 5 for problem MW7 with d = 2
# Optimizing with Hybrid qNEHVI + MOEAD
# C:\Users\user\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2189.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 24: Hypervolume = 0.15, time = 27.79s.
# Batch  2 of 24: Hypervolume = 0.15, time = 24.85s.
# Batch  3 of 24: Hypervolume = 0.24, time = 11.95s.
# Batch  4 of 24: Hypervolume = 0.24, time = 14.35s.
# Batch  5 of 24: Hypervolume = 0.36, time = 13.70s.
# Batch  6 of 24: Hypervolume = 0.41, time = 8.18s.
# Batch  7 of 24: Hypervolume = 0.43, time = 9.74s.
# Batch  8 of 24: Hypervolume = 0.45, time = 9.29s.
# Batch  9 of 24: Hypervolume = 0.46, time = 13.08s.
# Batch 10 of 24: Hypervolume = 0.47, time = 10.18s.
# Batch 11 of 24: Hypervolume = 0.48, time = 8.25s.
# Batch 12 of 24: Hypervolume = 0.48, time = 9.54s.
# Batch 13 of 24: Hypervolume = 0.48, time = 13.29s.
# Batch 14 of 24: Hypervolume = 0.49, time = 8.36s.
# Batch 15 of 24: Hypervolume = 0.49, time = 8.42s.
# Batch 16 of 24: Hypervolume = 0.49, time = 11.64s.
# Batch 17 of 24: Hypervolume = 0.49, time = 10.41s.
# Batch 18 of 24: Hypervolume = 0.49, time = 10.62s.
# Batch 19 of 24: Hypervolume = 0.49, time = 11.29s.
# Batch 20 of 24: Hypervolume = 0.49, time = 8.77s.
# Batch 21 of 24: Hypervolume = 0.49, time = 10.74s.
# Batch 22 of 24: Hypervolume = 0.49, time = 9.46s.
# Batch 23 of 24: Hypervolume = 0.50, time = 9.31s.
# Batch 24 of 24: Hypervolume = 0.50, time = 10.08s.
# Time taken in total: 283.49s.
#
# Trial  2 of 5 for problem MW7 with d = 2
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 30.73s.
# Batch  2 of 24: Hypervolume = 0.24, time = 26.61s.
# Batch  3 of 24: Hypervolume = 0.24, time = 30.60s.
# Batch  4 of 24: Hypervolume = 0.24, time = 16.44s.
# Batch  5 of 24: Hypervolume = 0.25, time = 27.54s.
# Batch  6 of 24: Hypervolume = 0.38, time = 23.15s.
# Batch  7 of 24: Hypervolume = 0.42, time = 9.79s.
# Batch  8 of 24: Hypervolume = 0.43, time = 13.45s.
# Batch  9 of 24: Hypervolume = 0.45, time = 9.97s.
# Batch 10 of 24: Hypervolume = 0.46, time = 10.33s.
# Batch 11 of 24: Hypervolume = 0.46, time = 8.35s.
# Batch 12 of 24: Hypervolume = 0.47, time = 8.94s.
# Batch 13 of 24: Hypervolume = 0.48, time = 10.02s.
# Batch 14 of 24: Hypervolume = 0.48, time = 11.20s.
# Batch 15 of 24: Hypervolume = 0.48, time = 11.70s.
# Batch 16 of 24: Hypervolume = 0.49, time = 8.57s.
# Batch 17 of 24: Hypervolume = 0.49, time = 9.59s.
# Batch 18 of 24: Hypervolume = 0.49, time = 8.87s.
# Batch 19 of 24: Hypervolume = 0.49, time = 9.18s.
# Batch 20 of 24: Hypervolume = 0.49, time = 8.68s.
# Batch 21 of 24: Hypervolume = 0.49, time = 8.66s.
# Batch 22 of 24: Hypervolume = 0.49, time = 9.24s.
# Batch 23 of 24: Hypervolume = 0.49, time = 9.79s.
# Batch 24 of 24: Hypervolume = 0.49, time = 10.71s.
# Time taken in total: 332.18s.
#
# Trial  3 of 5 for problem MW7 with d = 2
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.10, time = 30.30s.
# Batch  2 of 24: Hypervolume = 0.10, time = 12.47s.
# Batch  3 of 24: Hypervolume = 0.20, time = 14.51s.
# Batch  4 of 24: Hypervolume = 0.24, time = 22.70s.
# Batch  5 of 24: Hypervolume = 0.36, time = 14.71s.
# Batch  6 of 24: Hypervolume = 0.40, time = 9.85s.
# Batch  7 of 24: Hypervolume = 0.43, time = 11.59s.
# Batch  8 of 24: Hypervolume = 0.45, time = 12.16s.
# Batch  9 of 24: Hypervolume = 0.46, time = 10.84s.
# Batch 10 of 24: Hypervolume = 0.47, time = 8.31s.
# Batch 11 of 24: Hypervolume = 0.48, time = 8.15s.
# Batch 12 of 24: Hypervolume = 0.48, time = 8.40s.
# Batch 13 of 24: Hypervolume = 0.48, time = 8.74s.
# Batch 14 of 24: Hypervolume = 0.48, time = 9.24s.
# Batch 15 of 24: Hypervolume = 0.49, time = 8.02s.
# Batch 16 of 24: Hypervolume = 0.49, time = 8.44s.
# Batch 17 of 24: Hypervolume = 0.49, time = 11.64s.
# Batch 18 of 24: Hypervolume = 0.49, time = 9.51s.
# Batch 19 of 24: Hypervolume = 0.49, time = 9.51s.
# Batch 20 of 24: Hypervolume = 0.49, time = 9.64s.
# Batch 21 of 24: Hypervolume = 0.49, time = 9.48s.
# Batch 22 of 24: Hypervolume = 0.49, time = 9.13s.
# Batch 23 of 24: Hypervolume = 0.49, time = 9.69s.
# Batch 24 of 24: Hypervolume = 0.49, time = 10.14s.
# Time taken in total: 277.23s.
#
# Trial  4 of 5 for problem MW7 with d = 2
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.22, time = 14.11s.
# Batch  2 of 24: Hypervolume = 0.22, time = 13.76s.
# Batch  3 of 24: Hypervolume = 0.36, time = 11.75s.
# Batch  4 of 24: Hypervolume = 0.39, time = 12.55s.
# Batch  5 of 24: Hypervolume = 0.39, time = 15.49s.
# Batch  6 of 24: Hypervolume = 0.42, time = 10.65s.
# Batch  7 of 24: Hypervolume = 0.43, time = 26.20s.
# Batch  8 of 24: Hypervolume = 0.43, time = 14.50s.
# Batch  9 of 24: Hypervolume = 0.45, time = 18.11s.
# Batch 10 of 24: Hypervolume = 0.47, time = 11.63s.
# Batch 11 of 24: Hypervolume = 0.48, time = 9.03s.
# Batch 12 of 24: Hypervolume = 0.48, time = 11.03s.
# Batch 13 of 24: Hypervolume = 0.49, time = 9.56s.
# Batch 14 of 24: Hypervolume = 0.49, time = 9.74s.
# Batch 15 of 24: Hypervolume = 0.49, time = 8.99s.
# Batch 16 of 24: Hypervolume = 0.49, time = 9.36s.
# Batch 17 of 24: Hypervolume = 0.49, time = 9.15s.
# Batch 18 of 24: Hypervolume = 0.49, time = 9.74s.
# Batch 19 of 24: Hypervolume = 0.49, time = 8.87s.
# Batch 20 of 24: Hypervolume = 0.49, time = 9.89s.
# Batch 21 of 24: Hypervolume = 0.49, time = 9.49s.
# Batch 22 of 24: Hypervolume = 0.49, time = 13.37s.
# Batch 23 of 24: Hypervolume = 0.49, time = 9.62s.
# Batch 24 of 24: Hypervolume = 0.49, time = 9.58s.
# Time taken in total: 286.24s.
#
# Trial  5 of 5 for problem MW7 with d = 2
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.22, time = 11.16s.
# Batch  2 of 24: Hypervolume = 0.37, time = 24.00s.
# Batch  3 of 24: Hypervolume = 0.37, time = 22.76s.
# Batch  4 of 24: Hypervolume = 0.40, time = 28.15s.
# Batch  5 of 24: Hypervolume = 0.43, time = 13.17s.
# Batch  6 of 24: Hypervolume = 0.46, time = 11.99s.
# Batch  7 of 24: Hypervolume = 0.47, time = 21.94s.
# Batch  8 of 24: Hypervolume = 0.47, time = 8.10s.
# Batch  9 of 24: Hypervolume = 0.47, time = 11.63s.
# Batch 10 of 24: Hypervolume = 0.48, time = 9.33s.
# Batch 11 of 24: Hypervolume = 0.48, time = 7.68s.
# Batch 12 of 24: Hypervolume = 0.48, time = 9.50s.
# Batch 13 of 24: Hypervolume = 0.49, time = 9.64s.
# Batch 14 of 24: Hypervolume = 0.49, time = 8.98s.
# Batch 15 of 24: Hypervolume = 0.49, time = 8.24s.
# Batch 16 of 24: Hypervolume = 0.49, time = 10.41s.
# Batch 17 of 24: Hypervolume = 0.49, time = 8.64s.
# Batch 18 of 24: Hypervolume = 0.49, time = 9.97s.
# Batch 19 of 24: Hypervolume = 0.49, time = 9.50s.
# Batch 20 of 24: Hypervolume = 0.49, time = 10.40s.
# Batch 21 of 24: Hypervolume = 0.49, time = 9.56s.
# Batch 22 of 24: Hypervolume = 0.49, time = 9.63s.
# Batch 23 of 24: Hypervolume = 0.49, time = 9.36s.
# Batch 24 of 24: Hypervolume = 0.49, time = 10.80s.
# Time taken in total: 294.62s.
#
# Trial  1 of 5 for problem MW7 with d = 3
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.16, time = 33.47s.
# Batch  2 of 24: Hypervolume = 0.30, time = 27.17s.
# Batch  3 of 24: Hypervolume = 0.35, time = 29.77s.
# Batch  4 of 24: Hypervolume = 0.37, time = 10.15s.
# Batch  5 of 24: Hypervolume = 0.38, time = 21.18s.
# Batch  6 of 24: Hypervolume = 0.39, time = 24.42s.
# Batch  7 of 24: Hypervolume = 0.41, time = 19.42s.
# Batch  8 of 24: Hypervolume = 0.44, time = 8.83s.
# Batch  9 of 24: Hypervolume = 0.44, time = 24.82s.
# Batch 10 of 24: Hypervolume = 0.46, time = 26.44s.
# Batch 11 of 24: Hypervolume = 0.47, time = 14.07s.
# Batch 12 of 24: Hypervolume = 0.47, time = 15.81s.
# Batch 13 of 24: Hypervolume = 0.47, time = 12.00s.
# Batch 14 of 24: Hypervolume = 0.48, time = 19.84s.
# Batch 15 of 24: Hypervolume = 0.48, time = 9.15s.
# Batch 16 of 24: Hypervolume = 0.48, time = 10.48s.
# Batch 17 of 24: Hypervolume = 0.48, time = 10.96s.
# Batch 18 of 24: Hypervolume = 0.48, time = 10.76s.
# Batch 19 of 24: Hypervolume = 0.49, time = 18.47s.
# Batch 20 of 24: Hypervolume = 0.49, time = 9.45s.
# Batch 21 of 24: Hypervolume = 0.49, time = 13.15s.
# Batch 22 of 24: Hypervolume = 0.49, time = 8.93s.
# Batch 23 of 24: Hypervolume = 0.49, time = 11.95s.
# Batch 24 of 24: Hypervolume = 0.49, time = 12.15s.
# Time taken in total: 402.93s.
#
# Trial  2 of 5 for problem MW7 with d = 3
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.11, time = 28.59s.
# Batch  2 of 24: Hypervolume = 0.19, time = 13.64s.
# Batch  3 of 24: Hypervolume = 0.25, time = 23.41s.
# Batch  4 of 24: Hypervolume = 0.32, time = 24.95s.
# Batch  5 of 24: Hypervolume = 0.39, time = 26.67s.
# Batch  6 of 24: Hypervolume = 0.40, time = 8.50s.
# Batch  7 of 24: Hypervolume = 0.40, time = 8.54s.
# Batch  8 of 24: Hypervolume = 0.42, time = 33.14s.
# Batch  9 of 24: Hypervolume = 0.44, time = 23.80s.
# Batch 10 of 24: Hypervolume = 0.45, time = 11.98s.
# Batch 11 of 24: Hypervolume = 0.45, time = 28.16s.
# Batch 12 of 24: Hypervolume = 0.46, time = 11.32s.
# Batch 13 of 24: Hypervolume = 0.47, time = 12.34s.
# Batch 14 of 24: Hypervolume = 0.47, time = 8.21s.
# Batch 15 of 24: Hypervolume = 0.48, time = 17.37s.
# Batch 16 of 24: Hypervolume = 0.48, time = 8.58s.
# Batch 17 of 24: Hypervolume = 0.48, time = 9.45s.
# Batch 18 of 24: Hypervolume = 0.48, time = 8.54s.
# Batch 19 of 24: Hypervolume = 0.49, time = 10.96s.
# Batch 20 of 24: Hypervolume = 0.49, time = 11.47s.
# Batch 21 of 24: Hypervolume = 0.49, time = 10.56s.
# Batch 22 of 24: Hypervolume = 0.49, time = 10.93s.
# Batch 23 of 24: Hypervolume = 0.49, time = 14.94s.
# Batch 24 of 24: Hypervolume = 0.49, time = 10.47s.
# Time taken in total: 376.57s.
#
# Trial  3 of 5 for problem MW7 with d = 3
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.10, time = 34.71s.
# Batch  2 of 24: Hypervolume = 0.22, time = 20.52s.
# Batch  3 of 24: Hypervolume = 0.22, time = 23.67s.
# Batch  4 of 24: Hypervolume = 0.25, time = 23.96s.
# Batch  5 of 24: Hypervolume = 0.38, time = 24.73s.
# Batch  6 of 24: Hypervolume = 0.39, time = 19.39s.
# Batch  7 of 24: Hypervolume = 0.41, time = 14.24s.
# Batch  8 of 24: Hypervolume = 0.41, time = 13.48s.
# Batch  9 of 24: Hypervolume = 0.43, time = 20.38s.
# Batch 10 of 24: Hypervolume = 0.45, time = 13.19s.
# Batch 11 of 24: Hypervolume = 0.45, time = 22.09s.
# Batch 12 of 24: Hypervolume = 0.46, time = 12.99s.
# Batch 13 of 24: Hypervolume = 0.47, time = 8.61s.
# Batch 14 of 24: Hypervolume = 0.47, time = 20.06s.
# Batch 15 of 24: Hypervolume = 0.48, time = 25.77s.
# Batch 16 of 24: Hypervolume = 0.48, time = 14.83s.
# Batch 17 of 24: Hypervolume = 0.48, time = 10.91s.
# Batch 18 of 24: Hypervolume = 0.48, time = 11.49s.
# Batch 19 of 24: Hypervolume = 0.49, time = 13.44s.
# Batch 20 of 24: Hypervolume = 0.49, time = 11.16s.
# Batch 21 of 24: Hypervolume = 0.49, time = 11.17s.
# Batch 22 of 24: Hypervolume = 0.49, time = 15.19s.
# Batch 23 of 24: Hypervolume = 0.49, time = 9.76s.
# Batch 24 of 24: Hypervolume = 0.49, time = 10.86s.
# Time taken in total: 406.64s.
#
# Trial  4 of 5 for problem MW7 with d = 3
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.32, time = 27.77s.
# Batch  2 of 24: Hypervolume = 0.32, time = 18.42s.
# Batch  3 of 24: Hypervolume = 0.35, time = 21.74s.
# Batch  4 of 24: Hypervolume = 0.39, time = 27.77s.
# Batch  5 of 24: Hypervolume = 0.39, time = 26.89s.
# Batch  6 of 24: Hypervolume = 0.41, time = 29.21s.
# Batch  7 of 24: Hypervolume = 0.43, time = 25.40s.
# Batch  8 of 24: Hypervolume = 0.44, time = 20.54s.
# Batch  9 of 24: Hypervolume = 0.44, time = 12.31s.
# Batch 10 of 24: Hypervolume = 0.45, time = 25.09s.
# Batch 11 of 24: Hypervolume = 0.45, time = 16.35s.
# Batch 12 of 24: Hypervolume = 0.45, time = 20.13s.
# Batch 13 of 24: Hypervolume = 0.45, time = 21.38s.
# Batch 14 of 24: Hypervolume = 0.46, time = 17.49s.
# Batch 15 of 24: Hypervolume = 0.47, time = 10.24s.
# Batch 16 of 24: Hypervolume = 0.48, time = 8.96s.
# Batch 17 of 24: Hypervolume = 0.48, time = 10.92s.
# Batch 18 of 24: Hypervolume = 0.48, time = 13.20s.
# Batch 19 of 24: Hypervolume = 0.48, time = 10.38s.
# Batch 20 of 24: Hypervolume = 0.48, time = 14.31s.
# Batch 21 of 24: Hypervolume = 0.48, time = 14.71s.
# Batch 22 of 24: Hypervolume = 0.49, time = 15.87s.
# Batch 23 of 24: Hypervolume = 0.49, time = 12.78s.
# Batch 24 of 24: Hypervolume = 0.49, time = 11.64s.
# Time taken in total: 433.55s.
#
# Trial  5 of 5 for problem MW7 with d = 3
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.23, time = 36.86s.
# Batch  2 of 24: Hypervolume = 0.26, time = 30.85s.
# Batch  3 of 24: Hypervolume = 0.26, time = 32.86s.
# Batch  4 of 24: Hypervolume = 0.38, time = 9.66s.
# Batch  5 of 24: Hypervolume = 0.42, time = 25.83s.
# Batch  6 of 24: Hypervolume = 0.43, time = 10.86s.
# Batch  7 of 24: Hypervolume = 0.43, time = 33.87s.
# Batch  8 of 24: Hypervolume = 0.44, time = 25.90s.
# Batch  9 of 24: Hypervolume = 0.45, time = 26.85s.
# Batch 10 of 24: Hypervolume = 0.46, time = 16.00s.
# Batch 11 of 24: Hypervolume = 0.46, time = 15.76s.
# Batch 12 of 24: Hypervolume = 0.46, time = 10.92s.
# Batch 13 of 24: Hypervolume = 0.47, time = 13.34s.
# Batch 14 of 24: Hypervolume = 0.48, time = 8.94s.
# Batch 15 of 24: Hypervolume = 0.48, time = 14.08s.
# Batch 16 of 24: Hypervolume = 0.48, time = 10.25s.
# Batch 17 of 24: Hypervolume = 0.48, time = 12.23s.
# Batch 18 of 24: Hypervolume = 0.48, time = 9.26s.
# Batch 19 of 24: Hypervolume = 0.49, time = 14.66s.
# Batch 20 of 24: Hypervolume = 0.49, time = 9.47s.
# Batch 21 of 24: Hypervolume = 0.49, time = 20.69s.
# Batch 22 of 24: Hypervolume = 0.49, time = 10.88s.
# Batch 23 of 24: Hypervolume = 0.49, time = 13.42s.
# Batch 24 of 24: Hypervolume = 0.49, time = 13.45s.
# Time taken in total: 426.96s.
#
# Trial  1 of 5 for problem MW7 with d = 4
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.19, time = 35.96s.
# Batch  2 of 24: Hypervolume = 0.22, time = 31.66s.
# Batch  3 of 24: Hypervolume = 0.25, time = 16.50s.
# Batch  4 of 24: Hypervolume = 0.25, time = 9.91s.
# Batch  5 of 24: Hypervolume = 0.34, time = 24.41s.
# Batch  6 of 24: Hypervolume = 0.40, time = 10.04s.
# Batch  7 of 24: Hypervolume = 0.40, time = 33.95s.
# Batch  8 of 24: Hypervolume = 0.43, time = 11.57s.
# Batch  9 of 24: Hypervolume = 0.43, time = 34.78s.
# Batch 10 of 24: Hypervolume = 0.44, time = 14.20s.
# Batch 11 of 24: Hypervolume = 0.44, time = 19.05s.
# Batch 12 of 24: Hypervolume = 0.45, time = 32.70s.
# Batch 13 of 24: Hypervolume = 0.45, time = 10.79s.
# Batch 14 of 24: Hypervolume = 0.45, time = 24.67s.
# Batch 15 of 24: Hypervolume = 0.45, time = 23.83s.
# Batch 16 of 24: Hypervolume = 0.45, time = 13.36s.
# Batch 17 of 24: Hypervolume = 0.47, time = 10.08s.
# Batch 18 of 24: Hypervolume = 0.47, time = 12.00s.
# Batch 19 of 24: Hypervolume = 0.47, time = 12.42s.
# Batch 20 of 24: Hypervolume = 0.47, time = 11.15s.
# Batch 21 of 24: Hypervolume = 0.47, time = 23.50s.
# Batch 22 of 24: Hypervolume = 0.47, time = 14.76s.
# Batch 23 of 24: Hypervolume = 0.48, time = 11.41s.
# Batch 24 of 24: Hypervolume = 0.48, time = 13.40s.
# Time taken in total: 456.14s.
#
# Trial  2 of 5 for problem MW7 with d = 4
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 34.40s.
# Batch  2 of 24: Hypervolume = 0.21, time = 7.60s.
# Batch  3 of 24: Hypervolume = 0.22, time = 21.77s.
# Batch  4 of 24: Hypervolume = 0.38, time = 28.31s.
# Batch  5 of 24: Hypervolume = 0.38, time = 30.87s.
# Batch  6 of 24: Hypervolume = 0.41, time = 29.75s.
# Batch  7 of 24: Hypervolume = 0.43, time = 24.95s.
# Batch  8 of 24: Hypervolume = 0.44, time = 34.47s.
# Batch  9 of 24: Hypervolume = 0.44, time = 25.68s.
# Batch 10 of 24: Hypervolume = 0.44, time = 25.70s.
# Batch 11 of 24: Hypervolume = 0.44, time = 28.66s.
# Batch 12 of 24: Hypervolume = 0.45, time = 10.72s.
# Batch 13 of 24: Hypervolume = 0.45, time = 12.05s.
# Batch 14 of 24: Hypervolume = 0.46, time = 11.08s.
# Batch 15 of 24: Hypervolume = 0.46, time = 16.48s.
# Batch 16 of 24: Hypervolume = 0.46, time = 10.14s.
# Batch 17 of 24: Hypervolume = 0.47, time = 9.81s.
# Batch 18 of 24: Hypervolume = 0.47, time = 30.46s.
# Batch 19 of 24: Hypervolume = 0.47, time = 16.11s.
# Batch 20 of 24: Hypervolume = 0.47, time = 11.81s.
# Batch 21 of 24: Hypervolume = 0.47, time = 14.98s.
# Batch 22 of 24: Hypervolume = 0.47, time = 10.15s.
# Batch 23 of 24: Hypervolume = 0.48, time = 15.76s.
# Batch 24 of 24: Hypervolume = 0.48, time = 13.80s.
# Time taken in total: 475.55s.
#
# Trial  3 of 5 for problem MW7 with d = 4
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 12.10s.
# Batch  2 of 24: Hypervolume = 0.23, time = 31.17s.
# Batch  3 of 24: Hypervolume = 0.24, time = 11.63s.
# Batch  4 of 24: Hypervolume = 0.24, time = 27.34s.
# Batch  5 of 24: Hypervolume = 0.38, time = 10.79s.
# Batch  6 of 24: Hypervolume = 0.38, time = 26.59s.
# Batch  7 of 24: Hypervolume = 0.39, time = 9.69s.
# Batch  8 of 24: Hypervolume = 0.40, time = 32.39s.
# Batch  9 of 24: Hypervolume = 0.42, time = 13.14s.
# Batch 10 of 24: Hypervolume = 0.42, time = 17.47s.
# Batch 11 of 24: Hypervolume = 0.43, time = 32.93s.
# Batch 12 of 24: Hypervolume = 0.45, time = 25.96s.
# Batch 13 of 24: Hypervolume = 0.45, time = 33.26s.
# Batch 14 of 24: Hypervolume = 0.46, time = 9.41s.
# Batch 15 of 24: Hypervolume = 0.46, time = 30.77s.
# Batch 16 of 24: Hypervolume = 0.46, time = 9.38s.
# Batch 17 of 24: Hypervolume = 0.46, time = 10.43s.
# Batch 18 of 24: Hypervolume = 0.47, time = 10.59s.
# Batch 19 of 24: Hypervolume = 0.47, time = 10.00s.
# Batch 20 of 24: Hypervolume = 0.47, time = 16.85s.
# Batch 21 of 24: Hypervolume = 0.47, time = 33.46s.
# Batch 22 of 24: Hypervolume = 0.47, time = 14.26s.
# Batch 23 of 24: Hypervolume = 0.47, time = 25.49s.
# Batch 24 of 24: Hypervolume = 0.47, time = 12.15s.
# Time taken in total: 467.31s.
#
# Trial  4 of 5 for problem MW7 with d = 4
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.29, time = 15.20s.
# Batch  2 of 24: Hypervolume = 0.30, time = 30.23s.
# Batch  3 of 24: Hypervolume = 0.30, time = 27.98s.
# Batch  4 of 24: Hypervolume = 0.30, time = 26.22s.
# Batch  5 of 24: Hypervolume = 0.33, time = 27.45s.
# Batch  6 of 24: Hypervolume = 0.39, time = 14.19s.
# Batch  7 of 24: Hypervolume = 0.41, time = 19.89s.
# Batch  8 of 24: Hypervolume = 0.41, time = 18.47s.
# Batch  9 of 24: Hypervolume = 0.41, time = 23.31s.
# Batch 10 of 24: Hypervolume = 0.44, time = 16.98s.
# Batch 11 of 24: Hypervolume = 0.44, time = 17.81s.
# Batch 12 of 24: Hypervolume = 0.45, time = 14.17s.
# Batch 13 of 24: Hypervolume = 0.45, time = 12.96s.
# Batch 14 of 24: Hypervolume = 0.46, time = 31.20s.
# Batch 15 of 24: Hypervolume = 0.46, time = 29.85s.
# Batch 16 of 24: Hypervolume = 0.46, time = 25.42s.
# Batch 17 of 24: Hypervolume = 0.47, time = 14.92s.
# Batch 18 of 24: Hypervolume = 0.47, time = 11.80s.
# Batch 19 of 24: Hypervolume = 0.47, time = 10.10s.
# Batch 20 of 24: Hypervolume = 0.47, time = 12.22s.
# Batch 21 of 24: Hypervolume = 0.47, time = 14.21s.
# Batch 22 of 24: Hypervolume = 0.48, time = 12.27s.
# Batch 23 of 24: Hypervolume = 0.48, time = 15.75s.
# Batch 24 of 24: Hypervolume = 0.48, time = 13.57s.
# Time taken in total: 456.20s.
#
# Trial  5 of 5 for problem MW7 with d = 4
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.20, time = 46.14s.
# Batch  2 of 24: Hypervolume = 0.20, time = 21.50s.
# Batch  3 of 24: Hypervolume = 0.24, time = 10.19s.
# Batch  4 of 24: Hypervolume = 0.30, time = 23.81s.
# Batch  5 of 24: Hypervolume = 0.39, time = 31.21s.
# Batch  6 of 24: Hypervolume = 0.39, time = 28.87s.
# Batch  7 of 24: Hypervolume = 0.41, time = 40.11s.
# Batch  8 of 24: Hypervolume = 0.42, time = 31.53s.
# Batch  9 of 24: Hypervolume = 0.43, time = 20.28s.
# Batch 10 of 24: Hypervolume = 0.43, time = 29.44s.
# Batch 11 of 24: Hypervolume = 0.44, time = 22.34s.
# Batch 12 of 24: Hypervolume = 0.45, time = 17.53s.
# Batch 13 of 24: Hypervolume = 0.45, time = 14.16s.
# Batch 14 of 24: Hypervolume = 0.45, time = 34.61s.
# Batch 15 of 24: Hypervolume = 0.47, time = 30.84s.
# Batch 16 of 24: Hypervolume = 0.47, time = 10.86s.
# Batch 17 of 24: Hypervolume = 0.47, time = 23.50s.
# Batch 18 of 24: Hypervolume = 0.48, time = 13.82s.
# Batch 19 of 24: Hypervolume = 0.48, time = 10.64s.
# Batch 20 of 24: Hypervolume = 0.48, time = 12.80s.
# Batch 21 of 24: Hypervolume = 0.48, time = 17.86s.
# Batch 22 of 24: Hypervolume = 0.48, time = 13.17s.
# Batch 23 of 24: Hypervolume = 0.48, time = 15.96s.
# Batch 24 of 24: Hypervolume = 0.48, time = 14.33s.
# Time taken in total: 535.55s.
#
# Trial  1 of 5 for problem MW7 with d = 5
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.19, time = 11.44s.
# Batch  2 of 24: Hypervolume = 0.20, time = 36.73s.
# Batch  3 of 24: Hypervolume = 0.30, time = 15.72s.
# Batch  4 of 24: Hypervolume = 0.34, time = 10.37s.
# Batch  5 of 24: Hypervolume = 0.36, time = 23.29s.
# Batch  6 of 24: Hypervolume = 0.37, time = 15.40s.
# Batch  7 of 24: Hypervolume = 0.39, time = 13.22s.
# Batch  8 of 24: Hypervolume = 0.40, time = 38.17s.
# Batch  9 of 24: Hypervolume = 0.43, time = 27.62s.
# Batch 10 of 24: Hypervolume = 0.44, time = 9.53s.
# Batch 11 of 24: Hypervolume = 0.44, time = 31.61s.
# Batch 12 of 24: Hypervolume = 0.44, time = 10.83s.
# Batch 13 of 24: Hypervolume = 0.44, time = 10.84s.
# Batch 14 of 24: Hypervolume = 0.45, time = 20.36s.
# Batch 15 of 24: Hypervolume = 0.46, time = 12.58s.
# Batch 16 of 24: Hypervolume = 0.46, time = 17.99s.
# Batch 17 of 24: Hypervolume = 0.46, time = 12.30s.
# Batch 18 of 24: Hypervolume = 0.46, time = 20.85s.
# Batch 19 of 24: Hypervolume = 0.46, time = 11.75s.
# Batch 20 of 24: Hypervolume = 0.46, time = 11.37s.
# Batch 21 of 24: Hypervolume = 0.46, time = 25.13s.
# Batch 22 of 24: Hypervolume = 0.46, time = 15.00s.
# Batch 23 of 24: Hypervolume = 0.46, time = 35.61s.
# Batch 24 of 24: Hypervolume = 0.46, time = 23.84s.
# Time taken in total: 461.64s.
#
# Trial  2 of 5 for problem MW7 with d = 5
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.16, time = 12.97s.
# Batch  2 of 24: Hypervolume = 0.20, time = 13.67s.
# Batch  3 of 24: Hypervolume = 0.25, time = 20.06s.
# Batch  4 of 24: Hypervolume = 0.31, time = 21.48s.
# Batch  5 of 24: Hypervolume = 0.36, time = 9.44s.
# Batch  6 of 24: Hypervolume = 0.37, time = 10.73s.
# Batch  7 of 24: Hypervolume = 0.38, time = 17.26s.
# Batch  8 of 24: Hypervolume = 0.40, time = 12.00s.
# Batch  9 of 24: Hypervolume = 0.41, time = 15.24s.
# Batch 10 of 24: Hypervolume = 0.42, time = 17.32s.
# Batch 11 of 24: Hypervolume = 0.42, time = 10.47s.
# Batch 12 of 24: Hypervolume = 0.44, time = 13.96s.
# Batch 13 of 24: Hypervolume = 0.44, time = 12.64s.
# Batch 14 of 24: Hypervolume = 0.44, time = 24.27s.
# Batch 15 of 24: Hypervolume = 0.45, time = 22.44s.
# Batch 16 of 24: Hypervolume = 0.45, time = 16.50s.
# Batch 17 of 24: Hypervolume = 0.46, time = 11.60s.
# Batch 18 of 24: Hypervolume = 0.46, time = 17.55s.
# Batch 19 of 24: Hypervolume = 0.46, time = 28.23s.
# Batch 20 of 24: Hypervolume = 0.46, time = 11.96s.
# Batch 21 of 24: Hypervolume = 0.46, time = 11.08s.
# Batch 22 of 24: Hypervolume = 0.47, time = 15.57s.
# Batch 23 of 24: Hypervolume = 0.47, time = 11.91s.
# Batch 24 of 24: Hypervolume = 0.47, time = 11.02s.
# Time taken in total: 369.42s.
#
# Trial  3 of 5 for problem MW7 with d = 5
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 22.83s.
# Batch  2 of 24: Hypervolume = 0.19, time = 44.36s.
# Batch  3 of 24: Hypervolume = 0.21, time = 33.64s.
# Batch  4 of 24: Hypervolume = 0.21, time = 26.05s.
# Batch  5 of 24: Hypervolume = 0.26, time = 9.59s.
# Batch  6 of 24: Hypervolume = 0.26, time = 34.54s.
# Batch  7 of 24: Hypervolume = 0.26, time = 19.45s.
# Batch  8 of 24: Hypervolume = 0.27, time = 17.82s.
# Batch  9 of 24: Hypervolume = 0.27, time = 11.33s.
# Batch 10 of 24: Hypervolume = 0.27, time = 18.28s.
# Batch 11 of 24: Hypervolume = 0.37, time = 28.04s.
# Batch 12 of 24: Hypervolume = 0.42, time = 22.39s.
# Batch 13 of 24: Hypervolume = 0.43, time = 12.36s.
# Batch 14 of 24: Hypervolume = 0.44, time = 12.82s.
# Batch 15 of 24: Hypervolume = 0.44, time = 10.99s.
# Batch 16 of 24: Hypervolume = 0.44, time = 25.29s.
# Batch 17 of 24: Hypervolume = 0.44, time = 13.62s.
# Batch 18 of 24: Hypervolume = 0.45, time = 11.48s.
# Batch 19 of 24: Hypervolume = 0.45, time = 10.80s.
# Batch 20 of 24: Hypervolume = 0.46, time = 11.99s.
# Batch 21 of 24: Hypervolume = 0.46, time = 10.63s.
# Batch 22 of 24: Hypervolume = 0.47, time = 11.21s.
# Batch 23 of 24: Hypervolume = 0.47, time = 24.26s.
# Batch 24 of 24: Hypervolume = 0.47, time = 13.60s.
# Time taken in total: 457.42s.
#
# Trial  4 of 5 for problem MW7 with d = 5
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.05, time = 39.80s.
# Batch  2 of 24: Hypervolume = 0.17, time = 34.58s.
# Batch  3 of 24: Hypervolume = 0.20, time = 26.71s.
# Batch  4 of 24: Hypervolume = 0.26, time = 28.84s.
# Batch  5 of 24: Hypervolume = 0.37, time = 10.96s.
# Batch  6 of 24: Hypervolume = 0.40, time = 9.43s.
# Batch  7 of 24: Hypervolume = 0.41, time = 11.84s.
# Batch  8 of 24: Hypervolume = 0.42, time = 10.46s.
# Batch  9 of 24: Hypervolume = 0.43, time = 33.41s.
# Batch 10 of 24: Hypervolume = 0.43, time = 27.64s.
# Batch 11 of 24: Hypervolume = 0.43, time = 13.60s.
# Batch 12 of 24: Hypervolume = 0.44, time = 9.79s.
# Batch 13 of 24: Hypervolume = 0.44, time = 12.65s.
# Batch 14 of 24: Hypervolume = 0.44, time = 20.86s.
# Batch 15 of 24: Hypervolume = 0.44, time = 30.95s.
# Batch 16 of 24: Hypervolume = 0.45, time = 22.33s.
# Batch 17 of 24: Hypervolume = 0.45, time = 14.62s.
# Batch 18 of 24: Hypervolume = 0.45, time = 20.60s.
# Batch 19 of 24: Hypervolume = 0.45, time = 41.60s.
# Batch 20 of 24: Hypervolume = 0.46, time = 28.03s.
# Batch 21 of 24: Hypervolume = 0.46, time = 28.90s.
# Batch 22 of 24: Hypervolume = 0.46, time = 12.65s.
# Batch 23 of 24: Hypervolume = 0.46, time = 13.59s.
# Batch 24 of 24: Hypervolume = 0.46, time = 27.14s.
# Time taken in total: 531.02s.
#
# Trial  5 of 5 for problem MW7 with d = 5
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.06, time = 38.61s.
# Batch  2 of 24: Hypervolume = 0.06, time = 31.57s.
# Batch  3 of 24: Hypervolume = 0.06, time = 11.19s.
# Batch  4 of 24: Hypervolume = 0.23, time = 21.37s.
# Batch  5 of 24: Hypervolume = 0.25, time = 27.24s.
# Batch  6 of 24: Hypervolume = 0.26, time = 9.44s.
# Batch  7 of 24: Hypervolume = 0.26, time = 8.63s.
# Batch  8 of 24: Hypervolume = 0.26, time = 30.59s.
# Batch  9 of 24: Hypervolume = 0.26, time = 31.68s.
# Batch 10 of 24: Hypervolume = 0.26, time = 32.19s.
# Batch 11 of 24: Hypervolume = 0.26, time = 12.58s.
# Batch 12 of 24: Hypervolume = 0.35, time = 13.59s.
# Batch 13 of 24: Hypervolume = 0.39, time = 13.89s.
# Batch 14 of 24: Hypervolume = 0.42, time = 27.45s.
# Batch 15 of 24: Hypervolume = 0.42, time = 28.14s.
# Batch 16 of 24: Hypervolume = 0.43, time = 17.42s.
# Batch 17 of 24: Hypervolume = 0.43, time = 9.42s.
# Batch 18 of 24: Hypervolume = 0.43, time = 18.53s.
# Batch 19 of 24: Hypervolume = 0.44, time = 11.66s.
# Batch 20 of 24: Hypervolume = 0.45, time = 11.94s.
# Batch 21 of 24: Hypervolume = 0.45, time = 13.56s.
# Batch 22 of 24: Hypervolume = 0.45, time = 10.55s.
# Batch 23 of 24: Hypervolume = 0.45, time = 13.30s.
# Batch 24 of 24: Hypervolume = 0.45, time = 13.80s.
# Time taken in total: 458.43s.
#
# Trial  1 of 5 for problem MW7 with d = 6
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 10.64s.
# Batch  2 of 24: Hypervolume = 0.09, time = 9.56s.
# Batch  3 of 24: Hypervolume = 0.14, time = 29.99s.
# Batch  4 of 24: Hypervolume = 0.23, time = 10.98s.
# Batch  5 of 24: Hypervolume = 0.24, time = 22.01s.
# Batch  6 of 24: Hypervolume = 0.24, time = 7.79s.
# Batch  7 of 24: Hypervolume = 0.24, time = 21.57s.
# Batch  8 of 24: Hypervolume = 0.24, time = 23.90s.
# Batch  9 of 24: Hypervolume = 0.37, time = 10.57s.
# Batch 10 of 24: Hypervolume = 0.37, time = 27.58s.
# Batch 11 of 24: Hypervolume = 0.38, time = 15.27s.
# Batch 12 of 24: Hypervolume = 0.40, time = 15.28s.
# Batch 13 of 24: Hypervolume = 0.41, time = 28.15s.
# Batch 14 of 24: Hypervolume = 0.41, time = 12.90s.
# Batch 15 of 24: Hypervolume = 0.41, time = 23.26s.
# Batch 16 of 24: Hypervolume = 0.41, time = 16.69s.
# Batch 17 of 24: Hypervolume = 0.41, time = 10.83s.
# Batch 18 of 24: Hypervolume = 0.42, time = 18.95s.
# Batch 19 of 24: Hypervolume = 0.43, time = 15.06s.
# Batch 20 of 24: Hypervolume = 0.44, time = 23.13s.
# Batch 21 of 24: Hypervolume = 0.44, time = 20.42s.
# Batch 22 of 24: Hypervolume = 0.44, time = 32.08s.
# Batch 23 of 24: Hypervolume = 0.45, time = 11.10s.
# Batch 24 of 24: Hypervolume = 0.45, time = 20.48s.
# Time taken in total: 438.23s.
#
# Trial  2 of 5 for problem MW7 with d = 6
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.15, time = 42.74s.
# Batch  2 of 24: Hypervolume = 0.22, time = 11.42s.
# Batch  3 of 24: Hypervolume = 0.24, time = 30.26s.
# Batch  4 of 24: Hypervolume = 0.24, time = 21.53s.
# Batch  5 of 24: Hypervolume = 0.24, time = 9.30s.
# Batch  6 of 24: Hypervolume = 0.24, time = 10.29s.
# Batch  7 of 24: Hypervolume = 0.24, time = 10.22s.
# Batch  8 of 24: Hypervolume = 0.27, time = 23.66s.
# Batch  9 of 24: Hypervolume = 0.38, time = 7.85s.
# Batch 10 of 24: Hypervolume = 0.38, time = 8.96s.
# Batch 11 of 24: Hypervolume = 0.38, time = 9.83s.
# Batch 12 of 24: Hypervolume = 0.40, time = 23.90s.
# Batch 13 of 24: Hypervolume = 0.42, time = 26.86s.
# Batch 14 of 24: Hypervolume = 0.42, time = 14.06s.
# Batch 15 of 24: Hypervolume = 0.42, time = 10.47s.
# Batch 16 of 24: Hypervolume = 0.43, time = 34.69s.
# Batch 17 of 24: Hypervolume = 0.43, time = 12.57s.
# Batch 18 of 24: Hypervolume = 0.44, time = 12.21s.
# Batch 19 of 24: Hypervolume = 0.44, time = 19.69s.
# Batch 20 of 24: Hypervolume = 0.44, time = 13.76s.
# Batch 21 of 24: Hypervolume = 0.44, time = 12.69s.
# Batch 22 of 24: Hypervolume = 0.44, time = 10.33s.
# Batch 23 of 24: Hypervolume = 0.44, time = 12.34s.
# Batch 24 of 24: Hypervolume = 0.45, time = 28.24s.
# Time taken in total: 417.93s.
#
# Trial  3 of 5 for problem MW7 with d = 6
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 12.28s.
# Batch  2 of 24: Hypervolume = 0.11, time = 10.02s.
# Batch  3 of 24: Hypervolume = 0.18, time = 39.94s.
# Batch  4 of 24: Hypervolume = 0.19, time = 7.52s.
# Batch  5 of 24: Hypervolume = 0.19, time = 14.11s.
# Batch  6 of 24: Hypervolume = 0.19, time = 26.63s.
# Batch  7 of 24: Hypervolume = 0.26, time = 30.43s.
# Batch  8 of 24: Hypervolume = 0.34, time = 10.63s.
# Batch  9 of 24: Hypervolume = 0.34, time = 26.27s.
# Batch 10 of 24: Hypervolume = 0.35, time = 10.63s.
# Batch 11 of 24: Hypervolume = 0.37, time = 10.37s.
# Batch 12 of 24: Hypervolume = 0.39, time = 25.45s.
# Batch 13 of 24: Hypervolume = 0.40, time = 11.30s.
# Batch 14 of 24: Hypervolume = 0.41, time = 14.10s.
# Batch 15 of 24: Hypervolume = 0.42, time = 11.67s.
# Batch 16 of 24: Hypervolume = 0.42, time = 26.89s.
# Batch 17 of 24: Hypervolume = 0.42, time = 15.96s.
# Batch 18 of 24: Hypervolume = 0.42, time = 29.76s.
# Batch 19 of 24: Hypervolume = 0.42, time = 20.29s.
# Batch 20 of 24: Hypervolume = 0.43, time = 34.23s.
# Batch 21 of 24: Hypervolume = 0.45, time = 29.13s.
# Batch 22 of 24: Hypervolume = 0.45, time = 25.60s.
# Batch 23 of 24: Hypervolume = 0.45, time = 12.66s.
# Batch 24 of 24: Hypervolume = 0.45, time = 30.60s.
# Time taken in total: 486.48s.
#
# Trial  4 of 5 for problem MW7 with d = 6
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 52.30s.
# Batch  2 of 24: Hypervolume = 0.03, time = 31.69s.
# Batch  3 of 24: Hypervolume = 0.17, time = 27.27s.
# Batch  4 of 24: Hypervolume = 0.28, time = 11.16s.
# Batch  5 of 24: Hypervolume = 0.35, time = 23.07s.
# Batch  6 of 24: Hypervolume = 0.36, time = 14.88s.
# Batch  7 of 24: Hypervolume = 0.38, time = 9.18s.
# Batch  8 of 24: Hypervolume = 0.38, time = 39.01s.
# Batch  9 of 24: Hypervolume = 0.38, time = 13.48s.
# Batch 10 of 24: Hypervolume = 0.38, time = 11.31s.
# Batch 11 of 24: Hypervolume = 0.39, time = 23.50s.
# Batch 12 of 24: Hypervolume = 0.40, time = 18.36s.
# Batch 13 of 24: Hypervolume = 0.42, time = 12.58s.
# Batch 14 of 24: Hypervolume = 0.43, time = 30.74s.
# Batch 15 of 24: Hypervolume = 0.43, time = 13.03s.
# Batch 16 of 24: Hypervolume = 0.43, time = 14.37s.
# Batch 17 of 24: Hypervolume = 0.44, time = 26.59s.
# Batch 18 of 24: Hypervolume = 0.44, time = 25.97s.
# Batch 19 of 24: Hypervolume = 0.45, time = 16.77s.
# Batch 20 of 24: Hypervolume = 0.46, time = 27.01s.
# Batch 21 of 24: Hypervolume = 0.46, time = 16.06s.
# Batch 22 of 24: Hypervolume = 0.46, time = 11.58s.
# Batch 23 of 24: Hypervolume = 0.46, time = 13.45s.
# Batch 24 of 24: Hypervolume = 0.46, time = 27.63s.
# Time taken in total: 511.06s.
#
# Trial  5 of 5 for problem MW7 with d = 6
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.08, time = 49.10s.
# Batch  2 of 24: Hypervolume = 0.21, time = 36.99s.
# Batch  3 of 24: Hypervolume = 0.21, time = 11.13s.
# Batch  4 of 24: Hypervolume = 0.21, time = 11.84s.
# Batch  5 of 24: Hypervolume = 0.27, time = 27.19s.
# Batch  6 of 24: Hypervolume = 0.29, time = 29.18s.
# Batch  7 of 24: Hypervolume = 0.35, time = 26.03s.
# Batch  8 of 24: Hypervolume = 0.38, time = 10.64s.
# Batch  9 of 24: Hypervolume = 0.40, time = 12.93s.
# Batch 10 of 24: Hypervolume = 0.41, time = 37.56s.
# Batch 11 of 24: Hypervolume = 0.42, time = 11.85s.
# Batch 12 of 24: Hypervolume = 0.43, time = 13.29s.
# Batch 13 of 24: Hypervolume = 0.43, time = 10.08s.
# Batch 14 of 24: Hypervolume = 0.43, time = 18.92s.
# Batch 15 of 24: Hypervolume = 0.44, time = 33.80s.
# Batch 16 of 24: Hypervolume = 0.44, time = 27.39s.
# Batch 17 of 24: Hypervolume = 0.45, time = 30.89s.
# Batch 18 of 24: Hypervolume = 0.45, time = 37.24s.
# Batch 19 of 24: Hypervolume = 0.45, time = 27.39s.
# Batch 20 of 24: Hypervolume = 0.45, time = 33.40s.
# Batch 21 of 24: Hypervolume = 0.46, time = 9.70s.
# Batch 22 of 24: Hypervolume = 0.46, time = 28.19s.
# Batch 23 of 24: Hypervolume = 0.46, time = 17.29s.
# Batch 24 of 24: Hypervolume = 0.46, time = 18.03s.
# Time taken in total: 570.13s.
# All done!

# %%
from botorch.test_functions.multi_objective import MW7

problemname = 'MW7'

N_TRIALS = 5
verbose = True
noise = 0.00

N_BATCH = 24
BATCH_SIZE = 8

for dimensions in range(8, 9+ 1):

    MW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)

    class problem(torch.nn.Module):
        n_var = dimensions
        n_obj = 2
        n_constr = 2

        ref_point = torch.tensor([1.2,1.2], **tkwargs)

        bounds = MW7base.bounds    

        def evaluate(X):       
            output = MW7base(X)
            slack = -MW7base.evaluate_slack(X)

            return output, slack
        
    hv_list = []
    train_list = []

    # main loop for each trial/run, random_state will be trial number
    for trial in range(0, N_TRIALS):
        print(f"\nTrial {trial+1:>2} of {N_TRIALS} for problem {problemname} with d = {dimensions}\n", end="")

        # initialize with a 2*(d+1) sample set
        initial_x = torch.tensor(initial_x_dict[dimensions][trial], **tkwargs)

        hv, train = optimize_hybrid_moead(problem, problem.ref_point, initial_x,
                         N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                         random_state=trial, noise=noise, verbose=verbose)
        hv_list.append(hv)
        train_list.append(train)

    savetxt(f"{problemname}_{dimensions}dim_hvs_hybrid_moead_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", hv_list, delimiter=',')    
    savetxt(f"{problemname}_{dimensions}dim_train_hybrid_moead_{N_BATCH}by{BATCH_SIZE}_{N_TRIALS}trials.csv", np.array(train_list).reshape(-1), delimiter=',')
        
print("All done!")
# Out:
# Trial  1 of 5 for problem MW7 with d = 8
# Optimizing with Hybrid qNEHVI + MOEAD
# C:\Users\user\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:2189.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 24: Hypervolume = 0.00, time = 22.06s.
# Batch  2 of 24: Hypervolume = 0.00, time = 6.33s.
# Batch  3 of 24: Hypervolume = 0.00, time = 14.23s.
# Batch  4 of 24: Hypervolume = 0.05, time = 13.52s.
# Batch  5 of 24: Hypervolume = 0.05, time = 7.93s.
# Batch  6 of 24: Hypervolume = 0.06, time = 17.53s.
# Batch  7 of 24: Hypervolume = 0.15, time = 25.29s.
# Batch  8 of 24: Hypervolume = 0.16, time = 23.22s.
# Batch  9 of 24: Hypervolume = 0.16, time = 14.24s.
# Batch 10 of 24: Hypervolume = 0.24, time = 28.41s.
# Batch 11 of 24: Hypervolume = 0.30, time = 10.78s.
# Batch 12 of 24: Hypervolume = 0.33, time = 26.95s.
# Batch 13 of 24: Hypervolume = 0.34, time = 12.88s.
# Batch 14 of 24: Hypervolume = 0.37, time = 24.30s.
# Batch 15 of 24: Hypervolume = 0.38, time = 11.79s.
# Batch 16 of 24: Hypervolume = 0.39, time = 11.55s.
# Batch 17 of 24: Hypervolume = 0.42, time = 7.39s.
# Batch 18 of 24: Hypervolume = 0.42, time = 9.35s.
# Batch 19 of 24: Hypervolume = 0.43, time = 17.86s.
# Batch 20 of 24: Hypervolume = 0.43, time = 13.82s.
# Batch 21 of 24: Hypervolume = 0.43, time = 9.97s.
# Batch 22 of 24: Hypervolume = 0.43, time = 11.57s.
# Batch 23 of 24: Hypervolume = 0.43, time = 8.81s.
# Batch 24 of 24: Hypervolume = 0.44, time = 12.93s.
# Time taken in total: 362.81s.
#
# Trial  2 of 5 for problem MW7 with d = 8
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 5.10s.
# Batch  2 of 24: Hypervolume = 0.05, time = 19.85s.
# Batch  3 of 24: Hypervolume = 0.20, time = 10.77s.
# Batch  4 of 24: Hypervolume = 0.23, time = 31.38s.
# Batch  5 of 24: Hypervolume = 0.30, time = 32.59s.
# Batch  6 of 24: Hypervolume = 0.34, time = 19.01s.
# Batch  7 of 24: Hypervolume = 0.34, time = 34.16s.
# Batch  8 of 24: Hypervolume = 0.37, time = 9.22s.
# Batch  9 of 24: Hypervolume = 0.38, time = 9.85s.
# Batch 10 of 24: Hypervolume = 0.39, time = 30.79s.
# Batch 11 of 24: Hypervolume = 0.40, time = 23.63s.
# Batch 12 of 24: Hypervolume = 0.42, time = 15.86s.
# Batch 13 of 24: Hypervolume = 0.42, time = 9.99s.
# Batch 14 of 24: Hypervolume = 0.42, time = 10.87s.
# Batch 15 of 24: Hypervolume = 0.42, time = 30.71s.
# Batch 16 of 24: Hypervolume = 0.42, time = 10.07s.
# Batch 17 of 24: Hypervolume = 0.43, time = 7.54s.
# Batch 18 of 24: Hypervolume = 0.43, time = 28.34s.
# Batch 19 of 24: Hypervolume = 0.43, time = 7.67s.
# Batch 20 of 24: Hypervolume = 0.43, time = 32.37s.
# Batch 21 of 24: Hypervolume = 0.43, time = 7.71s.
# Batch 22 of 24: Hypervolume = 0.44, time = 8.57s.
# Batch 23 of 24: Hypervolume = 0.44, time = 22.50s.
# Batch 24 of 24: Hypervolume = 0.44, time = 8.65s.
# Time taken in total: 427.28s.
#
# Trial  3 of 5 for problem MW7 with d = 8
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 31.80s.
# Batch  2 of 24: Hypervolume = 0.21, time = 10.14s.
# Batch  3 of 24: Hypervolume = 0.25, time = 36.62s.
# Batch  4 of 24: Hypervolume = 0.29, time = 19.83s.
# Batch  5 of 24: Hypervolume = 0.33, time = 24.61s.
# Batch  6 of 24: Hypervolume = 0.36, time = 11.38s.
# Batch  7 of 24: Hypervolume = 0.37, time = 11.22s.
# Batch  8 of 24: Hypervolume = 0.37, time = 24.93s.
# Batch  9 of 24: Hypervolume = 0.38, time = 27.47s.
# Batch 10 of 24: Hypervolume = 0.38, time = 20.24s.
# Batch 11 of 24: Hypervolume = 0.39, time = 7.51s.
# Batch 12 of 24: Hypervolume = 0.40, time = 13.30s.
# Batch 13 of 24: Hypervolume = 0.40, time = 31.62s.
# Batch 14 of 24: Hypervolume = 0.41, time = 28.84s.
# Batch 15 of 24: Hypervolume = 0.41, time = 6.63s.
# Batch 16 of 24: Hypervolume = 0.41, time = 14.47s.
# Batch 17 of 24: Hypervolume = 0.42, time = 18.19s.
# Batch 18 of 24: Hypervolume = 0.42, time = 9.38s.
# Batch 19 of 24: Hypervolume = 0.43, time = 17.04s.
# Batch 20 of 24: Hypervolume = 0.43, time = 27.46s.
# Batch 21 of 24: Hypervolume = 0.43, time = 10.73s.
# Batch 22 of 24: Hypervolume = 0.43, time = 30.96s.
# Batch 23 of 24: Hypervolume = 0.43, time = 15.77s.
# Batch 24 of 24: Hypervolume = 0.43, time = 28.94s.
# Time taken in total: 479.14s.
#
# Trial  4 of 5 for problem MW7 with d = 8
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.16, time = 28.67s.
# Batch  2 of 24: Hypervolume = 0.19, time = 12.22s.
# Batch  3 of 24: Hypervolume = 0.20, time = 23.82s.
# Batch  4 of 24: Hypervolume = 0.20, time = 26.42s.
# Batch  5 of 24: Hypervolume = 0.21, time = 28.40s.
# Batch  6 of 24: Hypervolume = 0.33, time = 17.43s.
# Batch  7 of 24: Hypervolume = 0.36, time = 18.42s.
# Batch  8 of 24: Hypervolume = 0.38, time = 17.30s.
# Batch  9 of 24: Hypervolume = 0.39, time = 9.88s.
# Batch 10 of 24: Hypervolume = 0.40, time = 15.43s.
# Batch 11 of 24: Hypervolume = 0.40, time = 10.32s.
# Batch 12 of 24: Hypervolume = 0.40, time = 9.37s.
# Batch 13 of 24: Hypervolume = 0.40, time = 16.44s.
# Batch 14 of 24: Hypervolume = 0.41, time = 12.17s.
# Batch 15 of 24: Hypervolume = 0.42, time = 11.61s.
# Batch 16 of 24: Hypervolume = 0.43, time = 11.09s.
# Batch 17 of 24: Hypervolume = 0.43, time = 7.59s.
# Batch 18 of 24: Hypervolume = 0.43, time = 8.58s.
# Batch 19 of 24: Hypervolume = 0.43, time = 22.97s.
# Batch 20 of 24: Hypervolume = 0.44, time = 22.02s.
# Batch 21 of 24: Hypervolume = 0.44, time = 8.07s.
# Batch 22 of 24: Hypervolume = 0.44, time = 8.07s.
# Batch 23 of 24: Hypervolume = 0.44, time = 12.11s.
# Batch 24 of 24: Hypervolume = 0.44, time = 7.85s.
# Time taken in total: 366.29s.
#
# Trial  5 of 5 for problem MW7 with d = 8
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 18.59s.
# Batch  2 of 24: Hypervolume = 0.00, time = 28.27s.
# Batch  3 of 24: Hypervolume = 0.00, time = 21.03s.
# Batch  4 of 24: Hypervolume = 0.06, time = 33.26s.
# Batch  5 of 24: Hypervolume = 0.21, time = 29.15s.
# Batch  6 of 24: Hypervolume = 0.22, time = 23.20s.
# Batch  7 of 24: Hypervolume = 0.28, time = 10.44s.
# Batch  8 of 24: Hypervolume = 0.30, time = 37.69s.
# Batch  9 of 24: Hypervolume = 0.30, time = 23.98s.
# Batch 10 of 24: Hypervolume = 0.32, time = 25.82s.
# Batch 11 of 24: Hypervolume = 0.32, time = 21.68s.
# Batch 12 of 24: Hypervolume = 0.34, time = 6.87s.
# Batch 13 of 24: Hypervolume = 0.35, time = 27.89s.
# Batch 14 of 24: Hypervolume = 0.36, time = 9.53s.
# Batch 15 of 24: Hypervolume = 0.36, time = 13.43s.
# Batch 16 of 24: Hypervolume = 0.38, time = 24.59s.
# Batch 17 of 24: Hypervolume = 0.38, time = 9.23s.
# Batch 18 of 24: Hypervolume = 0.38, time = 10.56s.
# Batch 19 of 24: Hypervolume = 0.38, time = 8.61s.
# Batch 20 of 24: Hypervolume = 0.38, time = 24.23s.
# Batch 21 of 24: Hypervolume = 0.40, time = 7.37s.
# Batch 22 of 24: Hypervolume = 0.40, time = 18.19s.
# Batch 23 of 24: Hypervolume = 0.40, time = 16.50s.
# Batch 24 of 24: Hypervolume = 0.40, time = 10.48s.
# Time taken in total: 460.61s.
#
# Trial  1 of 5 for problem MW7 with d = 9
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 6.94s.
# Batch  2 of 24: Hypervolume = 0.00, time = 12.13s.
# Batch  3 of 24: Hypervolume = 0.00, time = 26.85s.
# Batch  4 of 24: Hypervolume = 0.12, time = 29.76s.
# Batch  5 of 24: Hypervolume = 0.13, time = 15.55s.
# Batch  6 of 24: Hypervolume = 0.15, time = 9.47s.
# Batch  7 of 24: Hypervolume = 0.21, time = 10.43s.
# Batch  8 of 24: Hypervolume = 0.23, time = 11.03s.
# Batch  9 of 24: Hypervolume = 0.23, time = 10.48s.
# Batch 10 of 24: Hypervolume = 0.27, time = 10.22s.
# Batch 11 of 24: Hypervolume = 0.31, time = 6.51s.
# Batch 12 of 24: Hypervolume = 0.33, time = 12.44s.
# Batch 13 of 24: Hypervolume = 0.33, time = 7.07s.
# Batch 14 of 24: Hypervolume = 0.36, time = 6.76s.
# Batch 15 of 24: Hypervolume = 0.36, time = 6.86s.
# Batch 16 of 24: Hypervolume = 0.38, time = 11.89s.
# Batch 17 of 24: Hypervolume = 0.38, time = 17.83s.
# Batch 18 of 24: Hypervolume = 0.40, time = 8.21s.
# Batch 19 of 24: Hypervolume = 0.41, time = 7.97s.
# Batch 20 of 24: Hypervolume = 0.41, time = 7.91s.
# Batch 21 of 24: Hypervolume = 0.41, time = 8.24s.
# Batch 22 of 24: Hypervolume = 0.42, time = 7.33s.
# Batch 23 of 24: Hypervolume = 0.42, time = 8.72s.
# Batch 24 of 24: Hypervolume = 0.42, time = 8.28s.
# Time taken in total: 268.94s.
#
# Trial  2 of 5 for problem MW7 with d = 9
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 5.07s.
# Batch  2 of 24: Hypervolume = 0.00, time = 12.49s.
# Batch  3 of 24: Hypervolume = 0.00, time = 22.92s.
# Batch  4 of 24: Hypervolume = 0.00, time = 10.93s.
# Batch  5 of 24: Hypervolume = 0.14, time = 17.98s.
# Batch  6 of 24: Hypervolume = 0.18, time = 19.97s.
# Batch  7 of 24: Hypervolume = 0.18, time = 30.23s.
# Batch  8 of 24: Hypervolume = 0.20, time = 23.92s.
# Batch  9 of 24: Hypervolume = 0.23, time = 13.33s.
# Batch 10 of 24: Hypervolume = 0.28, time = 22.58s.
# Batch 11 of 24: Hypervolume = 0.31, time = 13.74s.
# Batch 12 of 24: Hypervolume = 0.32, time = 8.07s.
# Batch 13 of 24: Hypervolume = 0.33, time = 15.58s.
# Batch 14 of 24: Hypervolume = 0.37, time = 8.42s.
# Batch 15 of 24: Hypervolume = 0.37, time = 16.70s.
# Batch 16 of 24: Hypervolume = 0.39, time = 20.02s.
# Batch 17 of 24: Hypervolume = 0.40, time = 7.94s.
# Batch 18 of 24: Hypervolume = 0.41, time = 7.59s.
# Batch 19 of 24: Hypervolume = 0.41, time = 16.45s.
# Batch 20 of 24: Hypervolume = 0.41, time = 11.37s.
# Batch 21 of 24: Hypervolume = 0.41, time = 7.78s.
# Batch 22 of 24: Hypervolume = 0.41, time = 7.91s.
# Batch 23 of 24: Hypervolume = 0.42, time = 12.22s.
# Batch 24 of 24: Hypervolume = 0.42, time = 13.80s.
# Time taken in total: 347.05s.
#
# Trial  3 of 5 for problem MW7 with d = 9
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 28.27s.
# Batch  2 of 24: Hypervolume = 0.00, time = 7.29s.
# Batch  3 of 24: Hypervolume = 0.06, time = 21.43s.
# Batch  4 of 24: Hypervolume = 0.06, time = 33.82s.
# Batch  5 of 24: Hypervolume = 0.12, time = 14.46s.
# Batch  6 of 24: Hypervolume = 0.15, time = 25.83s.
# Batch  7 of 24: Hypervolume = 0.19, time = 30.68s.
# Batch  8 of 24: Hypervolume = 0.22, time = 10.29s.
# Batch  9 of 24: Hypervolume = 0.23, time = 23.84s.
# Batch 10 of 24: Hypervolume = 0.24, time = 25.75s.
# Batch 11 of 24: Hypervolume = 0.28, time = 11.64s.
# Batch 12 of 24: Hypervolume = 0.30, time = 10.30s.
# Batch 13 of 24: Hypervolume = 0.36, time = 6.89s.
# Batch 14 of 24: Hypervolume = 0.36, time = 6.99s.
# Batch 15 of 24: Hypervolume = 0.39, time = 7.42s.
# Batch 16 of 24: Hypervolume = 0.40, time = 7.57s.
# Batch 17 of 24: Hypervolume = 0.40, time = 6.95s.
# Batch 18 of 24: Hypervolume = 0.40, time = 7.74s.
# Batch 19 of 24: Hypervolume = 0.41, time = 7.65s.
# Batch 20 of 24: Hypervolume = 0.41, time = 7.78s.
# Batch 21 of 24: Hypervolume = 0.41, time = 8.08s.
# Batch 22 of 24: Hypervolume = 0.41, time = 8.50s.
# Batch 23 of 24: Hypervolume = 0.41, time = 9.31s.
# Batch 24 of 24: Hypervolume = 0.41, time = 8.59s.
# Time taken in total: 337.10s.
#
# Trial  4 of 5 for problem MW7 with d = 9
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 23.28s.
# Batch  2 of 24: Hypervolume = 0.15, time = 9.41s.
# Batch  3 of 24: Hypervolume = 0.17, time = 11.70s.
# Batch  4 of 24: Hypervolume = 0.22, time = 28.88s.
# Batch  5 of 24: Hypervolume = 0.27, time = 11.44s.
# Batch  6 of 24: Hypervolume = 0.29, time = 8.78s.
# Batch  7 of 24: Hypervolume = 0.31, time = 11.05s.
# Batch  8 of 24: Hypervolume = 0.31, time = 20.03s.
# Batch  9 of 24: Hypervolume = 0.34, time = 25.70s.
# Batch 10 of 24: Hypervolume = 0.36, time = 18.80s.
# Batch 11 of 24: Hypervolume = 0.36, time = 7.10s.
# Batch 12 of 24: Hypervolume = 0.38, time = 10.52s.
# Batch 13 of 24: Hypervolume = 0.39, time = 40.02s.
# Batch 14 of 24: Hypervolume = 0.39, time = 24.58s.
# Batch 15 of 24: Hypervolume = 0.40, time = 34.48s.
# Batch 16 of 24: Hypervolume = 0.40, time = 8.31s.
# Batch 17 of 24: Hypervolume = 0.41, time = 31.39s.
# Batch 18 of 24: Hypervolume = 0.41, time = 8.07s.
# Batch 19 of 24: Hypervolume = 0.41, time = 32.36s.
# Batch 20 of 24: Hypervolume = 0.42, time = 8.90s.
# Batch 21 of 24: Hypervolume = 0.42, time = 10.31s.
# Batch 22 of 24: Hypervolume = 0.43, time = 26.05s.
# Batch 23 of 24: Hypervolume = 0.44, time = 9.39s.
# Batch 24 of 24: Hypervolume = 0.44, time = 8.60s.
# Time taken in total: 429.22s.
#
# Trial  5 of 5 for problem MW7 with d = 9
# Optimizing with Hybrid qNEHVI + MOEAD
# Batch  1 of 24: Hypervolume = 0.00, time = 45.58s.
# Batch  2 of 24: Hypervolume = 0.00, time = 5.85s.
# Batch  3 of 24: Hypervolume = 0.00, time = 6.04s.
# Batch  4 of 24: Hypervolume = 0.00, time = 6.71s.
# Batch  5 of 24: Hypervolume = 0.00, time = 34.69s.
# Batch  6 of 24: Hypervolume = 0.00, time = 7.10s.
# Batch  7 of 24: Hypervolume = 0.00, time = 29.68s.
# Batch  8 of 24: Hypervolume = 0.18, time = 35.19s.
# Batch  9 of 24: Hypervolume = 0.18, time = 29.35s.
# Batch 10 of 24: Hypervolume = 0.23, time = 12.35s.
# Batch 11 of 24: Hypervolume = 0.25, time = 25.53s.
# Batch 12 of 24: Hypervolume = 0.28, time = 27.25s.
# Batch 13 of 24: Hypervolume = 0.29, time = 28.90s.
# Batch 14 of 24: Hypervolume = 0.30, time = 9.41s.
# Batch 15 of 24: Hypervolume = 0.33, time = 33.54s.
# Batch 16 of 24: Hypervolume = 0.36, time = 10.11s.
# Batch 17 of 24: Hypervolume = 0.38, time = 6.96s.
# Batch 18 of 24: Hypervolume = 0.38, time = 26.13s.
# Batch 19 of 24: Hypervolume = 0.39, time = 18.34s.
# Batch 20 of 24: Hypervolume = 0.39, time = 13.24s.
# Batch 21 of 24: Hypervolume = 0.40, time = 7.72s.
# Batch 22 of 24: Hypervolume = 0.40, time = 25.25s.
# Batch 23 of 24: Hypervolume = 0.40, time = 27.47s.
# Batch 24 of 24: Hypervolume = 0.41, time = 11.27s.
# Time taken in total: 483.73s.
# All done!
