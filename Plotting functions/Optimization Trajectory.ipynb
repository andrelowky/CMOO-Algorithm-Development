# %%
# basic dependencies

import numpy as np
from numpy import loadtxt
from numpy import savetxt

import pandas as pd
import math
import time
import joblib


np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

###########

# torch dependencies
import torch

tkwargs = {"dtype": torch.double, # set as double to minimize zero error for cholesky decomposition error
           "device": torch.device("cuda:0" if torch.cuda.is_available() else "cpu")} # set tensors to GPU, if multiple GPUs please set cuda:x properly

torch.set_printoptions(precision=3)

###########

# botorch dependencies
import botorch

# data related
from botorch.utils.sampling import draw_sobol_samples
from botorch.utils.transforms import unnormalize, normalize

# surrogate model specific
from botorch.models.gp_regression import SingleTaskGP, FixedNoiseGP
from botorch.models.model_list_gp_regression import ModelListGP
from botorch.models.transforms.outcome import Standardize
from gpytorch.mlls.sum_marginal_log_likelihood import SumMarginalLogLikelihood
from botorch import fit_gpytorch_model

# qNEHVI specific
from botorch.optim.optimize import optimize_acqf
from botorch.acquisition.multi_objective.objective import IdentityMCMultiOutputObjective
from botorch.acquisition.multi_objective.monte_carlo import qNoisyExpectedHypervolumeImprovement

# utilities
from botorch.sampling.samplers import SobolQMCNormalSampler
from botorch.utils.multi_objective.pareto import is_non_dominated
from botorch.utils.multi_objective.hypervolume import Hypervolume
from botorch.utils.multi_objective.hypervolume import infer_reference_point
from typing import Optional
from torch import Tensor
from botorch.exceptions import BadInitialCandidatesWarning

import warnings

warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

###########

# pymoo dependencies
import pymoo

from pymoo.factory import get_problem
from pymoo.core.problem import ElementwiseProblem
from pymoo.core.problem import Problem

from pymoo.algorithms.moo.nsga3 import NSGA3
from pymoo.algorithms.moo.unsga3 import UNSGA3
from pymoo.algorithms.moo.ctaea import CTAEA

from pymoo.factory import get_sampling, get_crossover, get_mutation, get_reference_directions, get_termination
from pymoo.optimize import minimize

from pymoo.util.termination.no_termination import NoTermination
from pymoo.core.evaluator import set_cv

###########

# plotting dependencies
import matplotlib
from matplotlib import pyplot as plt

from scipy.stats import gaussian_kde # for density plot

# %matplotlib inline

# this is for the colorbar, you can change the cmap if you prefer other colour schemes
from matplotlib.cm import ScalarMappable

# function to return the std dev across runs
def ci(y, N_TRIALS):
    return 1.96 * y.std(axis=0) / np.sqrt(N_TRIALS)

SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def optimize_qnehvi(problem, ref_point, initial_x, # must haves
                    N_BATCH, BATCH_SIZE, 
                    random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with qNEHVI")

    t0 = time.time()

    # some initializing 
    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj, train_con = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    train_con_noisy = train_con + noise*torch.randn_like(train_con)
    
    ##########
    
    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, standard_bounds)
    
    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
        
    ##########    
    
    def create_idxr(i):
        def idxr(Z):
            return Z[..., i]

        return idxr

    def create_idxrs():
        return [create_idxr(i=i) for i in range(problem.n_obj, problem.n_obj+problem.n_constr)]
    
    # original location for an extra HV check wrt to initial samples
    
    ########## ########## ########## start of iteration loop


    # training loop for N_BATCH iterations
    for iteration in range(1, N_BATCH + 1):    

        t3 = time.time()
                
        # fit the surrogate model
        fit_gpytorch_model(mll)    
                
        ##########
            
        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            constraints=create_idxrs(), # constraint on last n_constr col
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on
        
        ##########
        
        # propose candidates given defined qNEHVI acq func given model and latest observed training data
        new_x, _ = optimize_acqf(
                        acq_function=acq_func,
                        bounds=standard_bounds, # since train_x was normalized
                        q=BATCH_SIZE, # no of candidates to propose in parallel
                        num_restarts=2, # no of restarts if q candidates fail to show improvement
                        raw_samples=128,  # pool of samples to choose the starting points from
                        options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                        )

        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj, new_con = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)
        new_con_noisy = new_con + noise*torch.randn_like(new_con)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        train_con_noisy = torch.cat([train_con_noisy, new_con_noisy])
        
        ##########
        
        # computing HV of current candidate list
        is_feas = (train_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = train_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0
        
        hvs.append(volume)
        
        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, standard_bounds) # dont forget to renormalize!
        train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)
        
        ##########
        
        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")
            
        del new_x, new_obj, new_con, new_obj_noisy, new_con_noisy, train_x_gp, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial     
        
        ########## ########## ########## end of iteration loop

    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")       
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

def optimize_nsga3(problem, ref_point, initial_x, # must haves
                   N_BATCH, pop_size,
                   ref_num=10, # as a rule of thumb, pop_size>ref_num,
                   noise=0, random_state=np.random.randint(0, 1000000, (1,)).item(), verbose=False):
    
    print("Optimizing with NSGA-III")
    
    t0 = time.time()    
    
    # some initializing
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    
    noise=noise

    # define a pymoo problem class based on the torch class
    class PymooProblem(ElementwiseProblem):

        def __init__(self):
            super().__init__(n_var=problem.n_var,
                             n_obj=problem.n_obj,
                             n_constr=problem.n_constr,
                             xl=problem.bounds[0].cpu().numpy(),
                             xu=problem.bounds[1].cpu().numpy())

        def _evaluate(self, X, out, *args, **kwargs):
            # base input/output from torch class
            train_x = torch.tensor(X.tolist(), **tkwargs).unsqueeze(dim=0)
            
            # take the noisy observations for algo
            train_obj, train_con = problem.evaluate(train_x)
            train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
            train_con_noisy = train_con + noise*torch.randn_like(train_con)

            # output the noisy observations instead
            out["F"] = -train_obj_noisy.cpu().numpy() # flip since botorch assumes maximisation vs pymoo minimization
            out["G"] = train_con_noisy.cpu().numpy()
            
    ##########        

    pymooproblem = PymooProblem()

    # create the reference directions to be used for the optimization
    ref_dirs = get_reference_directions("energy", problem.n_obj, ref_num, seed=random_state)
    
    # initial sampling
    sampling = initial_x.cpu().numpy()
    
    # create the algorithm object
    algorithm = UNSGA3(pop_size=pop_size,
                      ref_dirs=ref_dirs,
                      sampling=sampling
                     )

    # execute the optimization, take N_BATCH+1 since 1st iteration is just the initial sampling
    res = minimize(pymooproblem, algorithm, seed=random_state, termination=('n_gen', N_BATCH+1),
                   verbose=verbose, save_history=True)
    
    ##########
    
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")

    ##########
        
    # convert population data into tensor form
    # initial data
    train_x = torch.tensor(res.history[0].pop.get("X").tolist(), **tkwargs)
    train_obj, train_con = problem.evaluate(train_x) 
    # population at each iteration
    for i in range(1,N_BATCH+1): # don't forget we did +1 for total iterations
        new_x = torch.tensor(res.history[i].pop.get("X").tolist(), **tkwargs)
        new_obj, new_con = problem.evaluate(new_x)
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])

    ##########
        
    # calculate hypervolume based on checks, done on noiseless train_obj and train_con
    iterdict = {}
    a = 0
    b = initial_x.shape[0]
    for i in range(0, N_BATCH+1):

        iterdict[i] = (a, b)
        # a stays at zero
        b+=pop_size
    
    for i in range(0,N_BATCH):
        hvs_obj = train_obj[iterdict[i][0]:iterdict[i][1]]
        hvs_con = train_con[iterdict[i][0]:iterdict[i][1]]

        is_feas = (hvs_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = hvs_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0
        
        hvs.append(volume)
        
    print("DONE!\n")
        
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

def optimize_qnehvi_noconstr(problem, ref_point, initial_x, # must haves
                    N_BATCH, BATCH_SIZE, 
                    random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with qNEHVI")

    t0 = time.time()

    # some initializing 
    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    
    ##########
    
    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, standard_bounds)
    
    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = train_obj_noisy

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
        
    ##########    
    
    # original location for an extra HV check wrt to initial samples
    
    ########## ########## ########## start of iteration loop


    # training loop for N_BATCH iterations
    for iteration in range(1, N_BATCH + 1):    

        t3 = time.time()
                
        # fit the surrogate model
        fit_gpytorch_model(mll)    
                
        ##########
            
        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on
        
        ##########
        
        # propose candidates given defined qNEHVI acq func given model and latest observed training data
        new_x, _ = optimize_acqf(
                        acq_function=acq_func,
                        bounds=standard_bounds, # since train_x was normalized
                        q=BATCH_SIZE, # no of candidates to propose in parallel
                        num_restarts=2, # no of restarts if q candidates fail to show improvement
                        raw_samples=128,  # pool of samples to choose the starting points from
                        options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                        )

        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        
        ##########
        
        # computing HV of current candidate list
        pareto_mask = is_non_dominated(train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
        pareto_y = train_obj[pareto_mask] # take only points that fit the 2nd check
        volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        
        hvs.append(volume)
        
        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, standard_bounds) # dont forget to renormalize!
        train_y = train_obj_noisy

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)
        
        ##########
        
        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")
            
        del new_x, new_obj, new_obj_noisy, train_x_gp, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial     
        
        ########## ########## ########## end of iteration loop

    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")       
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj]).cpu().numpy()

def optimize_nsga3_noconstr(problem, ref_point,  initial_x, # must haves
                            N_BATCH, pop_size,
                            ref_num=10, # as a rule of thumb, pop_size>ref_num,
                            noise=0, random_state=np.random.randint(0, 1000000, (1,)).item(), verbose=False):
    
    print("Optimizing with NSGA-III")
    
    t0 = time.time()    
    
    # some initializing
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    
    noise=noise

    # define a pymoo problem class based on the torch class
    class PymooProblem(ElementwiseProblem):

        def __init__(self):
            super().__init__(n_var=problem.n_var,
                             n_obj=problem.n_obj,
                             xl=problem.bounds[0].cpu().numpy(),
                             xu=problem.bounds[1].cpu().numpy())

        def _evaluate(self, X, out, *args, **kwargs):
            # base input/output from torch class
            train_x = torch.tensor(X.tolist(), **tkwargs).unsqueeze(dim=0)
            
            # take the noisy observations for algo
            train_obj = problem.evaluate(train_x)
            train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)

            # output the noisy observations instead
            out["F"] = -train_obj_noisy.cpu().numpy() # flip since botorch assumes maximisation vs pymoo minimization
            
    ##########        

    pymooproblem = PymooProblem()

    # create the reference directions to be used for the optimization
    ref_dirs = get_reference_directions("energy", problem.n_obj, ref_num, seed=random_state)
    
    # initial sampling
    sampling = initial_x.cpu().numpy()
    
    # create the algorithm object
    algorithm = UNSGA3(pop_size=pop_size,
                      ref_dirs=ref_dirs,
                      sampling=sampling
                     )

    # execute the optimization, take N_BATCH+1 since 1st iteration is just the initial sampling
    res = minimize(pymooproblem, algorithm, seed=random_state, termination=('n_gen', N_BATCH+1),
                   verbose=verbose, save_history=True)
    
    ##########
    
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")
    
    ##########
    
    # convert population data into tensor form
    # initial data
    train_x = torch.tensor(res.history[0].pop.get("X").tolist(), **tkwargs)
    train_obj = problem.evaluate(train_x) 
    # population at each iteration
    for i in range(1,N_BATCH+1): # don't forget we did +1 for total iterations
        new_x = torch.tensor(res.history[i].pop.get("X").tolist(), **tkwargs)
        new_obj = problem.evaluate(new_x)
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        
    ##########
    
    # calculate hypervolume based on checks, done on noiseless train_obj and train_con
    iterdict = {}
    a = 0
    b = initial_x.shape[0]
    for i in range(0, N_BATCH+1):

        iterdict[i] = (a, b)
        # a stays at zero
        b+=pop_size
    
    for i in range(0,N_BATCH):
        hvs_obj = train_obj[iterdict[i][0]:iterdict[i][1]]

        # computing HV of current candidate list
        pareto_mask = is_non_dominated(hvs_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
        pareto_y = hvs_obj[pareto_mask] # take only points that fit the 2nd check
        volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
                
        hvs.append(volume)   
        
    ##########
     
    return hvs, torch.hstack([train_x, train_obj]).cpu().numpy()

# %%
dimensions = 8

from botorch.test_functions.multi_objective import ZDT1

ZDT1base = ZDT1(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT1(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT1base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import ZDT2

ZDT2base = ZDT2(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT2(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT2base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import ZDT3

ZDT3base = ZDT3(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT3(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT3base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import C2DTLZ2

LZ2base = C2DTLZ2(dim=dimensions, num_objectives=2, negate=True).to(**tkwargs)

class Problem_LZ2(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1
    
    bounds = LZ2base.bounds    
    
    def evaluate(X):       
        output = LZ2base(X)
        slack = -LZ2base.evaluate_slack(X)
       
        return output, slack
    
from botorch.test_functions.multi_objective import MW7

MW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)

class Problem_MW7(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1
    
    bounds = LZ2base.bounds    
    
    def evaluate(X):       
        output = MW7base(X)
        slack = -MW7base.evaluate_slack(X)
       
        return output, slack
    
class MWBase(torch.nn.Module):   
    def g3(X, n_obj):
        contrib = 2.0 * torch.pow(
            X[:, n_obj - 1:] + (X[:, n_obj - 2:-1] - 0.5) * (X[:, n_obj - 2:-1] - 0.5) - 1.0, 2.0)
        
        distance = 1 + contrib.sum(axis=1)
        return distance
    
    def LA1(A, B, C, D, theta):
        return A * torch.pow(torch.sin(B * np.pi * torch.pow(theta, C)), D)

    def LA2(A, B, C, D, theta):
        return A * torch.pow(torch.sin(B * torch.pow(theta, C)), D)

class Problem_MW3(torch.nn.Module):
    # must define these!
    n_var = dimensions
    n_obj = 2
    n_constr = 2 # inequality constraints only!
        
    # input bounds, don't forget to change according to n_var!  
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):
        
        # objectives are defined by f1, f2....
        # if you have complex equations, you can break it up and place them in ProblemBase for convenience, not compulsory
        # otherwise, you could place an oracle here that outputs the objective
        g = MWBase.g3(X, n_obj=2)
        f1 = X[:, 0]
        f2 = g * (1.0 - f1 / g)
        
        # inequality constraints should take the form of c(n)<=0
        # for equality constraints, either use the equality constr argument, or rewrite into inequality form (preferred)
        # if no constraints, write as c1 = 0 * X[..., 0], and set n_constr=1     
        c1 = f1 + f2 - 1.05 - MWBase.LA1(0.45, 0.75, 1.0, 6.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)
        c2 = 0.85 - f1 - f2 + MWBase.LA1(0.3, 0.75, 1.0, 2.0, np.sqrt(2.0) * f2 - np.sqrt(2.0) * f1)
        
        # botorch assumes maximisation
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        output = torch.stack([-f1, -f2], dim=-1)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        slack = torch.stack([c1, c2], dim=-1)
        
        return output, slack
    
diff1 = 0
diff2 = 0.5
diff3 = 0.5

class Problem_DAS1(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 11
    bounds = torch.stack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    #ref_point = LZ2.ref_point # make sure sign follows output
    
    def evaluate(X):
        g = torch.zeros(X.shape[0], **tkwargs)
        for i in range(X.shape[1]):
            g += torch.pow(X[...,i] - torch.sin(0.5 * np.pi * X[...,0]), 2)

        f1 = X[...,0] + g
        f2 = 1.0 - torch.pow(X[...,0], 2) + g
        
        #################
        
        a = 20
        b = 2 * diff1 - 1.
        d = 0.5 if diff2 != 0 else 0
        if diff2 > 0:
            e = d - torch.log(torch.tensor(diff2, **tkwargs))
        else:
            e = 1e30
        r = 0.5 * diff3

        p_k = [0., 1.0, 0., 1.0, 2.0, 0., 1.0, 2.0, 3.0]
        q_k = [1.5, 0.5, 2.5, 1.5, 0.5, 3.5, 2.5, 1.5, 0.5]

        a_k2 = 0.3
        b_k2 = 1.2
        theta_k = torch.tensor(-0.25 * np.pi, **tkwargs)

        c = torch.zeros((X.shape[0], 11), **tkwargs)

        c[...,0] = torch.sin(a * np.pi * X[...,0]) - b

        if diff2 == 1:
            c[...,1] = 1e-4 - torch.abs(e - g, **tkwargs)
        else:
            c[...,1] = (e - g) * (g - d)

        for i in range(2, 11):
            c[...,i] = ((f1 - p_k[i-2]) * torch.cos(theta_k) - (f2 - q_k[i-2]) * torch.sin(theta_k)) ** 2 / a_k2 + ((f1 - p_k[i-2]) * torch.sin(theta_k) + (f2 - q_k[i-2]) * torch.cos(theta_k)) ** 2 / b_k2 - r


        ####################
        
        # to maximise a postive output, stay positive
        # to minimise a positive output, force negative
        # to maximise a negative output (away from zero), force positive
        # to minimise a negative output (towards zero), stay negative
        output = torch.stack([-f1, -f2], dim=-1)
        
        # constraint equations should take the form of c(n)<=0
        # should return <=0 values when constraints are active,
        # and >0 values when constraints are violated
        slack = -c    
        
        return output, slack

#assert Problem.n_obj == Problem.ref_point.size(dim=-1) == Problem.evaluate(torch.ones(1, Problem.n_var, **tkwargs))[0].size(dim=-1),"Number of objectives, n_obj and reference point should match!"
#assert Problem.n_constr == Problem.evaluate(torch.ones(1, Problem.n_var, **tkwargs))[1].size(dim=-1), "Number of constraints and n_constr should match!"

# %%
ref_point = torch.tensor([11,11], **tkwargs)
verbose = True
noise = 0.00
problem = Problem_ZDT1

problem1 = get_problem("zdt1")
pareto = problem1.pareto_front()

trial = 1

N_BATCH = 100
BATCH_SIZE = 8

initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                    N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                    random_state=trial, noise=noise, verbose=verbose)

hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                 N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                 random_state=trial, noise=noise, verbose=False)


savetxt("ZDT1_hvs_nsga3_100by8.csv", hvs_nsga3, delimiter=',')
savetxt("ZDT1_hvs_qnehvi_100by8.csv", hvs_qnehvi, delimiter=',')

savetxt("ZDT1_train_qnehvi_100by8.csv", np.array(train_qnehvi).reshape(-1), delimiter=',')
savetxt("ZDT1_train_nsga3_100by8.csv", np.array(train_nsga3).reshape(-1), delimiter=',')
# Out:
# Optimizing with qNEHVI
# C:\Users\user\anaconda3\lib\site-packages\botorch\fit.py:143: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is C:\Users\user\AppData\Local\Temp/torch/kernels. This warning will appear only once per process. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cuda\jit_utils.cpp:860.)
#   warnings.warn(w.message, w.category)
# C:\Users\user\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:1672.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 100: Hypervolume = 93.51, time = 9.50s.
# Batch  2 of 100: Hypervolume = 101.39, time = 6.06s.
# Batch  3 of 100: Hypervolume = 108.71, time = 6.09s.
# Batch  4 of 100: Hypervolume = 116.61, time = 6.52s.
# Batch  5 of 100: Hypervolume = 117.26, time = 5.18s.
# Batch  6 of 100: Hypervolume = 117.81, time = 5.86s.
# Batch  7 of 100: Hypervolume = 117.81, time = 7.08s.
# Batch  8 of 100: Hypervolume = 117.81, time = 7.27s.
# Batch  9 of 100: Hypervolume = 117.81, time = 7.08s.
# Batch 10 of 100: Hypervolume = 117.81, time = 7.45s.
# Batch 11 of 100: Hypervolume = 117.81, time = 7.58s.
# Batch 12 of 100: Hypervolume = 117.81, time = 7.21s.
# Batch 13 of 100: Hypervolume = 117.81, time = 7.60s.
# Batch 14 of 100: Hypervolume = 117.81, time = 7.55s.
# Batch 15 of 100: Hypervolume = 117.81, time = 8.74s.
# Batch 16 of 100: Hypervolume = 117.81, time = 8.74s.
# Batch 17 of 100: Hypervolume = 117.81, time = 9.66s.
# Batch 18 of 100: Hypervolume = 117.81, time = 9.47s.
# Batch 19 of 100: Hypervolume = 117.81, time = 10.16s.
# Batch 20 of 100: Hypervolume = 117.81, time = 8.79s.
# Batch 21 of 100: Hypervolume = 117.81, time = 4.71s.
# Batch 22 of 100: Hypervolume = 117.81, time = 8.12s.
# Batch 23 of 100: Hypervolume = 117.81, time = 4.76s.
# Batch 24 of 100: Hypervolume = 117.81, time = 12.79s.
# Batch 25 of 100: Hypervolume = 117.81, time = 11.35s.
# Batch 26 of 100: Hypervolume = 117.81, time = 12.15s.
# Batch 27 of 100: Hypervolume = 117.81, time = 4.98s.
# Batch 28 of 100: Hypervolume = 117.81, time = 5.04s.
# Batch 29 of 100: Hypervolume = 117.81, time = 3.22s.
# Batch 30 of 100: Hypervolume = 117.81, time = 11.72s.
# Batch 31 of 100: Hypervolume = 117.81, time = 10.77s.
# Batch 32 of 100: Hypervolume = 117.81, time = 4.28s.
# Batch 33 of 100: Hypervolume = 117.85, time = 14.21s.
# Batch 34 of 100: Hypervolume = 117.85, time = 10.40s.
# Batch 35 of 100: Hypervolume = 117.85, time = 7.16s.
# Batch 36 of 100: Hypervolume = 117.85, time = 10.44s.
# Batch 37 of 100: Hypervolume = 117.85, time = 9.00s.
# Batch 38 of 100: Hypervolume = 117.85, time = 9.07s.
# Batch 39 of 100: Hypervolume = 117.85, time = 7.78s.
# Batch 40 of 100: Hypervolume = 117.85, time = 8.50s.
# Batch 41 of 100: Hypervolume = 117.85, time = 6.10s.
# Batch 42 of 100: Hypervolume = 117.85, time = 5.46s.
# Batch 43 of 100: Hypervolume = 117.85, time = 4.32s.
# Batch 44 of 100: Hypervolume = 117.85, time = 5.30s.
# Batch 45 of 100: Hypervolume = 117.85, time = 5.35s.
# Batch 46 of 100: Hypervolume = 117.85, time = 6.05s.
# Batch 47 of 100: Hypervolume = 117.85, time = 4.59s.
# Batch 48 of 100: Hypervolume = 117.85, time = 6.43s.
# Batch 49 of 100: Hypervolume = 117.85, time = 8.05s.
# Batch 50 of 100: Hypervolume = 117.85, time = 22.26s.
# Batch 51 of 100: Hypervolume = 117.85, time = 4.43s.
# Batch 52 of 100: Hypervolume = 117.85, time = 22.05s.
# Batch 53 of 100: Hypervolume = 117.85, time = 9.56s.
# Batch 54 of 100: Hypervolume = 117.85, time = 9.86s.
# Batch 55 of 100: Hypervolume = 117.85, time = 9.22s.
# Batch 56 of 100: Hypervolume = 117.85, time = 5.93s.
# Batch 57 of 100: Hypervolume = 117.85, time = 5.59s.
# Batch 58 of 100: Hypervolume = 117.85, time = 6.20s.
# Batch 59 of 100: Hypervolume = 117.85, time = 4.94s.
# Batch 60 of 100: Hypervolume = 117.85, time = 6.97s.
# Batch 61 of 100: Hypervolume = 117.85, time = 9.98s.
# Batch 62 of 100: Hypervolume = 117.85, time = 21.56s.
# Batch 63 of 100: Hypervolume = 117.85, time = 13.58s.
# Batch 64 of 100: Hypervolume = 117.85, time = 8.37s.
# Batch 65 of 100: Hypervolume = 117.85, time = 7.56s.
# Batch 66 of 100: Hypervolume = 117.85, time = 22.63s.
# Batch 67 of 100: Hypervolume = 117.85, time = 8.57s.
# Batch 68 of 100: Hypervolume = 117.85, time = 5.57s.
# Batch 69 of 100: Hypervolume = 117.85, time = 19.74s.
# Batch 70 of 100: Hypervolume = 117.85, time = 9.97s.
# Batch 71 of 100: Hypervolume = 117.85, time = 12.73s.
# Batch 72 of 100: Hypervolume = 117.85, time = 9.47s.
# Batch 73 of 100: Hypervolume = 117.85, time = 14.33s.
# Batch 74 of 100: Hypervolume = 117.85, time = 9.40s.
# Batch 75 of 100: Hypervolume = 117.85, time = 10.00s.
# Batch 76 of 100: Hypervolume = 117.85, time = 8.73s.
# Batch 77 of 100: Hypervolume = 117.85, time = 14.09s.
# Batch 78 of 100: Hypervolume = 117.85, time = 11.75s.
# Batch 79 of 100: Hypervolume = 117.85, time = 9.16s.
# Batch 80 of 100: Hypervolume = 117.85, time = 18.29s.
# Batch 81 of 100: Hypervolume = 117.85, time = 8.25s.
# Batch 82 of 100: Hypervolume = 117.85, time = 10.13s.
# Batch 83 of 100: Hypervolume = 117.85, time = 9.14s.
# Batch 84 of 100: Hypervolume = 117.85, time = 32.96s.
# Batch 85 of 100: Hypervolume = 117.85, time = 16.59s.
# Batch 86 of 100: Hypervolume = 117.85, time = 18.14s.
# Batch 87 of 100: Hypervolume = 117.85, time = 10.12s.
# Batch 88 of 100: Hypervolume = 117.85, time = 15.46s.
# Batch 89 of 100: Hypervolume = 117.85, time = 10.88s.
# Batch 90 of 100: Hypervolume = 117.85, time = 20.49s.
# Batch 91 of 100: Hypervolume = 117.85, time = 22.96s.
# Batch 92 of 100: Hypervolume = 117.85, time = 17.51s.
# Batch 93 of 100: Hypervolume = 117.85, time = 10.40s.
# Batch 94 of 100: Hypervolume = 117.85, time = 10.32s.
# Batch 95 of 100: Hypervolume = 117.85, time = 11.59s.
# Batch 96 of 100: Hypervolume = 117.85, time = 10.26s.
# Batch 97 of 100: Hypervolume = 117.85, time = 13.03s.
# Batch 98 of 100: Hypervolume = 117.85, time = 26.32s.
# Batch 99 of 100: Hypervolume = 117.85, time = 20.99s.
# Batch 100 of 100: Hypervolume = 117.85, time = 13.97s.
# Time taken in total: 1037.92s.
# Optimizing with NSGA-III
# Time taken in total: 1.08s.

# %%
N_BATCH = 100
BATCH_SIZE = 8

hvs_nsga3 = loadtxt("ZDT1_hvs_nsga3_100by8.csv", delimiter=',')
hvs_qnehvi = loadtxt("ZDT1_hvs_qnehvi_100by8.csv", delimiter=',')

train_qnehvi = loadtxt("ZDT1_train_qnehvi_100by8.csv", delimiter=',')
train_nsga3 = loadtxt("ZDT1_train_nsga3_100by8.csv",  delimiter=',')

train_qnehvi = np.array(train_qnehvi).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)    
train_nsga3 = np.array(train_nsga3).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)

cm = plt.cm.get_cmap('inferno')

fig, ax = plt.subplots(ncols = 2, figsize = (14,5))

algos = ['MOEA U-NSGA-III', 'MOBO qNEHVI']

batch_number = torch.cat([torch.zeros(2*(problem.n_var+1)),
                          torch.arange(1, N_BATCH+1).repeat(BATCH_SIZE, 1).t().reshape(-1)
                         ]).numpy()

for i, train in enumerate((train_nsga3, train_qnehvi)):

    ax[i].scatter(pareto[:,0],
                  pareto[:,1], 
                  c="r", s=3, marker=".", alpha=0.8)
    
    ax[i].scatter(-train[...,problem.n_var:problem.n_var+problem.n_obj][:,0],
                  -train[...,problem.n_var:problem.n_var+problem.n_obj][:,1],
                 c=batch_number, cmap=cm, s=3, alpha=0.8)

    ax[i].set_title(f"ZDT1 (d={dimensions}), {algos[i]} ({N_BATCH} x {BATCH_SIZE})", fontsize=14)
    ax[i].set_xlabel('f1')
    
    ax[i].set_xlim(-0.05, 1.05)
    ax[i].set_ylim(-0.2, 7.5)

ax[0].set_ylabel('f2')

ax[0].text(-0.025, 0.1, f"HV = {hvs_nsga3[-1]:.7f}", fontsize=14)
ax[1].text(-0.025, 0.1, f"HV = {hvs_qnehvi[-1]:.7f}", fontsize=14)


#plt.setp(ax, xlim=ax[1].get_xlim(), ylim=ax[1].get_ylim())

fig.tight_layout()

norm = plt.Normalize(batch_number.min(), batch_number.max())
sm =  ScalarMappable(norm=norm, cmap=cm)
sm.set_array([])
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.01, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.ax.set_title("Iteration", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Iteration')

# %%
fig.savefig('trajectory_ZDT1.pdf')

# %%
ref_point = torch.tensor([11,11], **tkwargs)
verbose = True
noise = 0.00
problem = Problem_ZDT2

problem1 = get_problem("zdt2")
pareto = problem1.pareto_front()

trial = 1

N_BATCH = 100
BATCH_SIZE = 8

initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                    N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                    random_state=trial, noise=noise, verbose=verbose)

hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                 N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                 random_state=trial, noise=noise, verbose=False)
# Out:
# Optimizing with qNEHVI
# Batch  1 of 100: Hypervolume = 76.22, time = 5.31s.
# Batch  2 of 100: Hypervolume = 86.23, time = 6.47s.
# Batch  3 of 100: Hypervolume = 97.66, time = 7.39s.
# Batch  4 of 100: Hypervolume = 107.70, time = 5.88s.
# Batch  5 of 100: Hypervolume = 108.48, time = 5.70s.
# Batch  6 of 100: Hypervolume = 119.85, time = 6.59s.
# Batch  7 of 100: Hypervolume = 120.00, time = 7.34s.
# Batch  8 of 100: Hypervolume = 120.00, time = 7.16s.
# Batch  9 of 100: Hypervolume = 120.00, time = 7.40s.
# Batch 10 of 100: Hypervolume = 120.00, time = 8.25s.
# Batch 11 of 100: Hypervolume = 120.00, time = 7.56s.
# Batch 12 of 100: Hypervolume = 120.00, time = 7.60s.
# Batch 13 of 100: Hypervolume = 120.00, time = 8.08s.
# Batch 14 of 100: Hypervolume = 120.00, time = 2.02s.
# Batch 15 of 100: Hypervolume = 120.00, time = 9.02s.
# Batch 16 of 100: Hypervolume = 120.00, time = 7.65s.
# Batch 17 of 100: Hypervolume = 120.00, time = 7.87s.
# Batch 18 of 100: Hypervolume = 120.00, time = 8.10s.
# Batch 19 of 100: Hypervolume = 120.00, time = 9.23s.
# Batch 20 of 100: Hypervolume = 120.00, time = 8.31s.
# Batch 21 of 100: Hypervolume = 120.00, time = 8.60s.
# Batch 22 of 100: Hypervolume = 120.00, time = 9.77s.
# Batch 23 of 100: Hypervolume = 120.00, time = 9.99s.
# Batch 24 of 100: Hypervolume = 120.00, time = 6.34s.
# Batch 25 of 100: Hypervolume = 120.00, time = 10.52s.
# Batch 26 of 100: Hypervolume = 120.00, time = 9.36s.
# Batch 27 of 100: Hypervolume = 120.00, time = 8.91s.
# Batch 28 of 100: Hypervolume = 120.00, time = 5.63s.
# Batch 29 of 100: Hypervolume = 120.00, time = 5.08s.
# Batch 30 of 100: Hypervolume = 120.00, time = 11.20s.
# Batch 31 of 100: Hypervolume = 120.00, time = 9.64s.
# Batch 32 of 100: Hypervolume = 120.00, time = 6.03s.
# Batch 33 of 100: Hypervolume = 120.00, time = 11.72s.
# Batch 34 of 100: Hypervolume = 120.00, time = 9.01s.
# Batch 35 of 100: Hypervolume = 120.00, time = 14.04s.
# Batch 36 of 100: Hypervolume = 120.00, time = 14.23s.
# Batch 37 of 100: Hypervolume = 120.00, time = 4.37s.
# Batch 38 of 100: Hypervolume = 120.00, time = 2.71s.
# Batch 39 of 100: Hypervolume = 120.00, time = 11.95s.
# Batch 40 of 100: Hypervolume = 120.00, time = 2.63s.
# Batch 41 of 100: Hypervolume = 120.00, time = 6.58s.
# Batch 42 of 100: Hypervolume = 120.00, time = 6.09s.
# Batch 43 of 100: Hypervolume = 120.00, time = 18.16s.
# Batch 44 of 100: Hypervolume = 120.00, time = 4.84s.
# Batch 45 of 100: Hypervolume = 120.00, time = 9.49s.
# Batch 46 of 100: Hypervolume = 120.00, time = 11.13s.
# Batch 47 of 100: Hypervolume = 120.00, time = 13.16s.
# Batch 48 of 100: Hypervolume = 120.00, time = 6.96s.
# Batch 49 of 100: Hypervolume = 120.00, time = 7.74s.
# Batch 50 of 100: Hypervolume = 120.00, time = 7.27s.
# Batch 51 of 100: Hypervolume = 120.00, time = 7.76s.
# Batch 52 of 100: Hypervolume = 120.00, time = 5.29s.
# Batch 53 of 100: Hypervolume = 120.00, time = 6.83s.
# Batch 54 of 100: Hypervolume = 120.00, time = 9.31s.
# Batch 55 of 100: Hypervolume = 120.00, time = 6.80s.
# Batch 56 of 100: Hypervolume = 120.00, time = 6.14s.
# Batch 57 of 100: Hypervolume = 120.00, time = 4.48s.
# Batch 58 of 100: Hypervolume = 120.00, time = 8.75s.
# Batch 59 of 100: Hypervolume = 120.00, time = 12.40s.
# Batch 60 of 100: Hypervolume = 120.00, time = 4.53s.
# Batch 61 of 100: Hypervolume = 120.00, time = 5.88s.
# Batch 62 of 100: Hypervolume = 120.00, time = 10.36s.
# Batch 63 of 100: Hypervolume = 120.00, time = 9.27s.
# Batch 64 of 100: Hypervolume = 120.00, time = 8.23s.
# Batch 65 of 100: Hypervolume = 120.00, time = 10.18s.
# Batch 66 of 100: Hypervolume = 120.00, time = 8.41s.
# Batch 67 of 100: Hypervolume = 120.00, time = 9.22s.
# Batch 68 of 100: Hypervolume = 120.00, time = 10.68s.
# Batch 69 of 100: Hypervolume = 120.00, time = 6.80s.
# Batch 70 of 100: Hypervolume = 120.00, time = 11.32s.
# Batch 71 of 100: Hypervolume = 120.00, time = 9.80s.
# Batch 72 of 100: Hypervolume = 120.00, time = 14.04s.
# Batch 73 of 100: Hypervolume = 120.00, time = 9.54s.
# Batch 74 of 100: Hypervolume = 120.00, time = 13.78s.
# Batch 75 of 100: Hypervolume = 120.00, time = 10.18s.
# Batch 76 of 100: Hypervolume = 120.00, time = 6.78s.
# Batch 77 of 100: Hypervolume = 120.00, time = 8.99s.
# Batch 78 of 100: Hypervolume = 120.00, time = 9.10s.
# Batch 79 of 100: Hypervolume = 120.00, time = 13.45s.
# Batch 80 of 100: Hypervolume = 120.00, time = 10.61s.
# Batch 81 of 100: Hypervolume = 120.00, time = 11.60s.
# Batch 82 of 100: Hypervolume = 120.00, time = 9.13s.
# Batch 83 of 100: Hypervolume = 120.00, time = 19.81s.
# Batch 84 of 100: Hypervolume = 120.00, time = 10.60s.
# Batch 85 of 100: Hypervolume = 120.00, time = 8.05s.
# Batch 86 of 100: Hypervolume = 120.00, time = 11.31s.
# Batch 87 of 100: Hypervolume = 120.00, time = 9.98s.
# Batch 88 of 100: Hypervolume = 120.00, time = 11.97s.
# Batch 89 of 100: Hypervolume = 120.00, time = 14.73s.
# Batch 90 of 100: Hypervolume = 120.00, time = 11.55s.
# Batch 91 of 100: Hypervolume = 120.00, time = 12.63s.
# Batch 92 of 100: Hypervolume = 120.00, time = 13.59s.
# Batch 93 of 100: Hypervolume = 120.00, time = 11.47s.
# Batch 94 of 100: Hypervolume = 120.00, time = 16.62s.
# Batch 95 of 100: Hypervolume = 120.00, time = 29.74s.
# Batch 96 of 100: Hypervolume = 120.00, time = 13.14s.
# Batch 97 of 100: Hypervolume = 120.00, time = 16.70s.
# Batch 98 of 100: Hypervolume = 120.00, time = 17.90s.
# Batch 99 of 100: Hypervolume = 120.00, time = 17.10s.
# Batch 100 of 100: Hypervolume = 120.00, time = 11.11s.
# Time taken in total: 953.92s.
# Optimizing with NSGA-III
# Time taken in total: 1.17s.

# %%
savetxt("ZDT2_hvs_nsga3_100by8.csv", hvs_nsga3, delimiter=',')
savetxt("ZDT2_hvs_qnehvi_100by8.csv", hvs_qnehvi, delimiter=',')

savetxt("ZDT2_train_qnehvi_100by8.csv", np.array(train_qnehvi).reshape(-1), delimiter=',')
savetxt("ZDT2_train_nsga3_100by8.csv", np.array(train_nsga3).reshape(-1), delimiter=',')

# %%
N_BATCH = 100
BATCH_SIZE = 8

hvs_nsga3 = loadtxt("ZDT2_hvs_nsga3_100by8.csv", delimiter=',')
hvs_qnehvi = loadtxt("ZDT2_hvs_qnehvi_100by8.csv", delimiter=',')

train_qnehvi = loadtxt("ZDT2_train_qnehvi_100by8.csv", delimiter=',')
train_nsga3 = loadtxt("ZDT2_train_nsga3_100by8.csv",  delimiter=',')

train_qnehvi = np.array(train_qnehvi).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)    
train_nsga3 = np.array(train_nsga3).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)

cm = plt.cm.get_cmap('inferno')

fig, ax = plt.subplots(ncols = 2, figsize = (14,5))

algos = ['MOEA U-NSGA-III', 'MOBO qNEHVI']

batch_number = torch.cat([torch.zeros(2*(problem.n_var+1)),
                          torch.arange(1, N_BATCH+1).repeat(BATCH_SIZE, 1).t().reshape(-1)
                         ]).numpy()

for i, train in enumerate((train_nsga3, train_qnehvi)):

    ax[i].scatter(pareto[:,0],
                  pareto[:,1], 
                  c="r", s=3, marker=".", alpha=0.8)
    
    ax[i].scatter(-train[...,problem.n_var:problem.n_var+problem.n_obj][:,0],
                  -train[...,problem.n_var:problem.n_var+problem.n_obj][:,1],
                 c=batch_number, cmap=cm, s=3, alpha=0.8)

    ax[i].set_title(f"ZDT2 (d={dimensions}), {algos[i]} ({N_BATCH} x {BATCH_SIZE})", fontsize=14)
    ax[i].set_xlabel('f1')
    
    ax[i].set_xlim(-0.05, 1.05)
    ax[i].set_ylim(-0.2, 9.0)

ax[0].set_ylabel('f2')

ax[0].text(-0.025, 0.1, f"HV = {hvs_nsga3[-1]:.7f}", fontsize=14)
ax[1].text(-0.025, 0.1, f"HV = {hvs_qnehvi[-1]:.7f}", fontsize=14)


#plt.setp(ax, xlim=ax[1].get_xlim(), ylim=ax[1].get_ylim())

fig.tight_layout()

norm = plt.Normalize(batch_number.min(), batch_number.max())
sm =  ScalarMappable(norm=norm, cmap=cm)
sm.set_array([])
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.01, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.ax.set_title("Iteration", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Iteration')

# %%
fig.savefig('trajectory_ZDT2.pdf')

# %%
ref_point = torch.tensor([11,11], **tkwargs)
verbose = True
noise = 0.00
problem = Problem_ZDT3

problem1 = get_problem("zdt3")
pareto = problem1.pareto_front()

trial = 1

N_BATCH = 100
BATCH_SIZE = 8

initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                    N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                    random_state=trial, noise=noise, verbose=verbose)

hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                 N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                 random_state=trial, noise=noise, verbose=False)

savetxt("ZDT3_hvs_nsga3_100by8.csv", hvs_nsga3, delimiter=',')
savetxt("ZDT3_hvs_qnehvi_100by8.csv", hvs_qnehvi, delimiter=',')

savetxt("ZDT3_train_qnehvi_100by8.csv", np.array(train_qnehvi).reshape(-1), delimiter=',')
savetxt("ZDT3_train_nsga3_100by8.csv", np.array(train_nsga3).reshape(-1), delimiter=',')
# Out:
# Optimizing with qNEHVI
# Batch  1 of 100: Hypervolume = 114.03, time = 6.32s.
# Batch  2 of 100: Hypervolume = 115.58, time = 6.76s.
# Batch  3 of 100: Hypervolume = 115.84, time = 7.58s.
# Batch  4 of 100: Hypervolume = 116.18, time = 9.44s.
# Batch  5 of 100: Hypervolume = 116.71, time = 9.96s.
# Batch  6 of 100: Hypervolume = 117.72, time = 10.24s.
# Batch  7 of 100: Hypervolume = 120.22, time = 11.55s.
# Batch  8 of 100: Hypervolume = 121.21, time = 11.27s.
# Batch  9 of 100: Hypervolume = 121.22, time = 10.39s.
# Batch 10 of 100: Hypervolume = 121.31, time = 10.53s.
# Batch 11 of 100: Hypervolume = 121.35, time = 10.02s.
# Batch 12 of 100: Hypervolume = 121.36, time = 11.17s.
# Batch 13 of 100: Hypervolume = 121.36, time = 10.77s.
# Batch 14 of 100: Hypervolume = 121.36, time = 8.80s.
# Batch 15 of 100: Hypervolume = 121.36, time = 11.36s.
# Batch 16 of 100: Hypervolume = 121.36, time = 11.07s.
# Batch 17 of 100: Hypervolume = 121.36, time = 13.33s.
# Batch 18 of 100: Hypervolume = 121.36, time = 13.13s.
# Batch 19 of 100: Hypervolume = 121.37, time = 14.22s.
# Batch 20 of 100: Hypervolume = 121.38, time = 12.22s.
# Batch 21 of 100: Hypervolume = 121.38, time = 10.62s.
# Batch 22 of 100: Hypervolume = 121.38, time = 8.70s.
# Batch 23 of 100: Hypervolume = 121.38, time = 10.75s.
# Batch 24 of 100: Hypervolume = 121.38, time = 14.77s.
# Batch 25 of 100: Hypervolume = 121.38, time = 13.63s.
# Batch 26 of 100: Hypervolume = 121.38, time = 9.55s.
# Batch 27 of 100: Hypervolume = 121.39, time = 8.37s.
# Batch 28 of 100: Hypervolume = 121.39, time = 3.66s.
# Batch 29 of 100: Hypervolume = 121.39, time = 13.39s.
# Batch 30 of 100: Hypervolume = 121.39, time = 6.37s.
# Batch 31 of 100: Hypervolume = 121.39, time = 13.02s.
# Batch 32 of 100: Hypervolume = 121.39, time = 11.94s.
# Batch 33 of 100: Hypervolume = 121.39, time = 17.13s.
# Batch 34 of 100: Hypervolume = 121.39, time = 9.16s.
# Batch 35 of 100: Hypervolume = 121.39, time = 12.15s.
# Batch 36 of 100: Hypervolume = 121.39, time = 13.76s.
# Batch 37 of 100: Hypervolume = 121.39, time = 9.91s.
# Batch 38 of 100: Hypervolume = 121.39, time = 4.44s.
# Batch 39 of 100: Hypervolume = 121.39, time = 9.75s.
# Batch 40 of 100: Hypervolume = 121.39, time = 4.41s.
# Batch 41 of 100: Hypervolume = 121.39, time = 10.13s.
# Batch 42 of 100: Hypervolume = 121.39, time = 7.00s.
# Batch 43 of 100: Hypervolume = 121.39, time = 8.36s.
# Batch 44 of 100: Hypervolume = 121.39, time = 8.36s.
# Batch 45 of 100: Hypervolume = 121.39, time = 5.35s.
# Batch 46 of 100: Hypervolume = 121.39, time = 5.01s.
# Batch 47 of 100: Hypervolume = 121.39, time = 8.45s.
# Batch 48 of 100: Hypervolume = 121.39, time = 8.01s.
# Batch 49 of 100: Hypervolume = 121.39, time = 8.22s.
# Batch 50 of 100: Hypervolume = 121.39, time = 10.60s.
# Batch 51 of 100: Hypervolume = 121.39, time = 7.98s.
# Batch 52 of 100: Hypervolume = 121.39, time = 8.38s.
# Batch 53 of 100: Hypervolume = 121.39, time = 18.95s.
# Batch 54 of 100: Hypervolume = 121.39, time = 8.26s.
# Batch 55 of 100: Hypervolume = 121.39, time = 9.58s.
# Batch 56 of 100: Hypervolume = 121.39, time = 11.15s.
# Batch 57 of 100: Hypervolume = 121.39, time = 9.49s.
# Batch 58 of 100: Hypervolume = 121.39, time = 10.15s.
# Batch 59 of 100: Hypervolume = 121.39, time = 7.45s.
# Batch 60 of 100: Hypervolume = 121.39, time = 10.06s.
# Batch 61 of 100: Hypervolume = 121.39, time = 15.25s.
# Batch 62 of 100: Hypervolume = 121.39, time = 13.14s.
# Batch 63 of 100: Hypervolume = 121.39, time = 8.62s.
# Batch 64 of 100: Hypervolume = 121.39, time = 11.12s.
# Batch 65 of 100: Hypervolume = 121.39, time = 12.17s.
# Batch 66 of 100: Hypervolume = 121.39, time = 10.95s.
# Batch 67 of 100: Hypervolume = 121.39, time = 19.65s.
# Batch 68 of 100: Hypervolume = 121.39, time = 10.77s.
# Batch 69 of 100: Hypervolume = 121.39, time = 12.04s.
# Batch 70 of 100: Hypervolume = 121.39, time = 9.31s.
# Batch 71 of 100: Hypervolume = 121.39, time = 12.84s.
# Batch 72 of 100: Hypervolume = 121.39, time = 13.90s.
# Batch 73 of 100: Hypervolume = 121.39, time = 16.85s.
# Batch 74 of 100: Hypervolume = 121.39, time = 18.02s.
# Batch 75 of 100: Hypervolume = 121.39, time = 10.26s.
# Batch 76 of 100: Hypervolume = 121.39, time = 16.47s.
# Batch 77 of 100: Hypervolume = 121.39, time = 16.93s.
# Batch 78 of 100: Hypervolume = 121.39, time = 17.55s.
# Batch 79 of 100: Hypervolume = 121.39, time = 15.56s.
# Batch 80 of 100: Hypervolume = 121.39, time = 29.79s.
# Batch 81 of 100: Hypervolume = 121.39, time = 16.85s.
# Batch 82 of 100: Hypervolume = 121.39, time = 19.30s.
# Batch 83 of 100: Hypervolume = 121.39, time = 13.54s.
# Batch 84 of 100: Hypervolume = 121.39, time = 15.62s.
# Batch 85 of 100: Hypervolume = 121.39, time = 17.32s.
# Batch 86 of 100: Hypervolume = 121.39, time = 16.57s.
# Batch 87 of 100: Hypervolume = 121.39, time = 21.63s.
# Batch 88 of 100: Hypervolume = 121.39, time = 26.78s.
# Batch 89 of 100: Hypervolume = 121.39, time = 19.59s.
# Batch 90 of 100: Hypervolume = 121.39, time = 11.54s.
# Batch 91 of 100: Hypervolume = 121.39, time = 25.52s.
# Batch 92 of 100: Hypervolume = 121.39, time = 22.23s.
# Batch 93 of 100: Hypervolume = 121.39, time = 21.01s.
# Batch 94 of 100: Hypervolume = 121.39, time = 13.53s.
# Batch 95 of 100: Hypervolume = 121.39, time = 20.70s.
# Batch 96 of 100: Hypervolume = 121.39, time = 18.72s.
# Batch 97 of 100: Hypervolume = 121.39, time = 23.11s.
# Batch 98 of 100: Hypervolume = 121.39, time = 35.71s.
# Batch 99 of 100: Hypervolume = 121.39, time = 29.43s.
# Batch 100 of 100: Hypervolume = 121.39, time = 42.60s.
# Time taken in total: 1319.34s.
# Optimizing with NSGA-III
# Time taken in total: 1.17s.

# %%
N_BATCH = 100
BATCH_SIZE = 8

hvs_nsga3 = loadtxt("ZDT3_hvs_nsga3_100by8.csv", delimiter=',')
hvs_qnehvi = loadtxt("ZDT3_hvs_qnehvi_100by8.csv", delimiter=',')

train_qnehvi = loadtxt("ZDT3_train_qnehvi_100by8.csv", delimiter=',')
train_nsga3 = loadtxt("ZDT3_train_nsga3_100by8.csv",  delimiter=',')

train_qnehvi = np.array(train_qnehvi).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)    
train_nsga3 = np.array(train_nsga3).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2)

problem1 = get_problem("zdt3")
pareto = problem1.pareto_front()

cm = plt.cm.get_cmap('inferno')

fig, ax = plt.subplots(ncols = 2, figsize = (14,5))

algos = ['MOEA U-NSGA-III', 'MOBO qNEHVI']

batch_number = torch.cat([torch.zeros(2*(problem.n_var+1)),
                          torch.arange(1, N_BATCH+1).repeat(BATCH_SIZE, 1).t().reshape(-1)
                         ]).numpy()

for i, train in enumerate((train_nsga3, train_qnehvi)):

    ax[i].scatter(pareto[:,0],
                  pareto[:,1], 
                  c="r", s=3, marker=".", alpha=0.8)
    
    ax[i].scatter(-train[...,problem.n_var:problem.n_var+problem.n_obj][:,0],
                  -train[...,problem.n_var:problem.n_var+problem.n_obj][:,1],
                 c=batch_number, cmap=cm, s=3, alpha=0.8)

    ax[i].set_title(f"ZDT3 (d={dimensions}), {algos[i]} ({N_BATCH} x {BATCH_SIZE})", fontsize=14)
    ax[i].set_xlabel('f1')
    
    ax[i].set_xlim(-0.05, 1.05)
    ax[i].set_ylim(-1.0, 1.1)

ax[0].set_ylabel('f2')

ax[0].text(-0.025, 0.1, f"HV = {hvs_nsga3[-1]:.7f}", fontsize=14)
ax[1].text(-0.025, 0.1, f"HV = {hvs_qnehvi[-1]:.7f}", fontsize=14)


#plt.setp(ax, xlim=ax[1].get_xlim(), ylim=ax[1].get_ylim())

fig.tight_layout()

norm = plt.Normalize(batch_number.min(), batch_number.max())
sm =  ScalarMappable(norm=norm, cmap=cm)
sm.set_array([])
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.01, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.ax.set_title("Iteration", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Iteration')

# %%
fig.savefig('trajectory_ZDT3.pdf')

# %%
ref_point = torch.tensor([1.2,1.2], **tkwargs)
verbose = True
noise = 0.00
problem = Problem_MW7

problem1 = get_problem("mw7")
pareto = problem1.pareto_front()

trial = 1

N_BATCH = 100
BATCH_SIZE = 8

initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

hvs_qnehvi, train_qnehvi = optimize_qnehvi(problem, ref_point, initial_x,
                                                    N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                    random_state=trial, noise=noise, verbose=verbose)

hvs_nsga3, train_nsga3 = optimize_nsga3(problem, ref_point, initial_x,
                                                 N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                 random_state=trial, noise=noise, verbose=False)

savetxt("MW7_hvs_nsga3_100by8.csv", hvs_nsga3, delimiter=',')
savetxt("MW7_hvs_qnehvi_100by8.csv", hvs_qnehvi, delimiter=',')

savetxt("MW7_train_qnehvi_100by8.csv", np.array(train_qnehvi).reshape(-1), delimiter=',')
savetxt("MW7_train_nsga3_100by8.csv", np.array(train_nsga3).reshape(-1), delimiter=',')
# Out:
# Optimizing with qNEHVI
# Batch  1 of 100: Hypervolume = 0.00, time = 1.22s.
# Batch  2 of 100: Hypervolume = 0.00, time = 4.44s.
# Batch  3 of 100: Hypervolume = 0.21, time = 15.63s.
# Batch  4 of 100: Hypervolume = 0.21, time = 16.39s.
# Batch  5 of 100: Hypervolume = 0.21, time = 13.68s.
# Batch  6 of 100: Hypervolume = 0.22, time = 14.34s.
# Batch  7 of 100: Hypervolume = 0.22, time = 14.87s.
# Batch  8 of 100: Hypervolume = 0.22, time = 14.96s.
# Batch  9 of 100: Hypervolume = 0.22, time = 11.81s.
# Batch 10 of 100: Hypervolume = 0.22, time = 12.89s.
# Batch 11 of 100: Hypervolume = 0.22, time = 13.60s.
# Batch 12 of 100: Hypervolume = 0.22, time = 13.60s.
# Batch 13 of 100: Hypervolume = 0.22, time = 12.64s.
# Batch 14 of 100: Hypervolume = 0.22, time = 11.89s.
# Batch 15 of 100: Hypervolume = 0.22, time = 15.74s.
# Batch 16 of 100: Hypervolume = 0.22, time = 2.09s.
# Batch 17 of 100: Hypervolume = 0.22, time = 12.41s.
# Batch 18 of 100: Hypervolume = 0.22, time = 2.26s.
# Batch 19 of 100: Hypervolume = 0.30, time = 6.42s.
# Batch 20 of 100: Hypervolume = 0.30, time = 14.04s.
# Batch 21 of 100: Hypervolume = 0.30, time = 14.61s.
# Batch 22 of 100: Hypervolume = 0.30, time = 2.43s.
# Batch 23 of 100: Hypervolume = 0.30, time = 9.18s.
# Batch 24 of 100: Hypervolume = 0.32, time = 14.62s.
# Batch 25 of 100: Hypervolume = 0.36, time = 13.88s.
# Batch 26 of 100: Hypervolume = 0.36, time = 18.81s.
# Batch 27 of 100: Hypervolume = 0.36, time = 8.87s.
# Batch 28 of 100: Hypervolume = 0.36, time = 6.30s.
# Batch 29 of 100: Hypervolume = 0.36, time = 5.08s.
# Batch 30 of 100: Hypervolume = 0.36, time = 5.43s.
# Batch 31 of 100: Hypervolume = 0.36, time = 4.68s.
# Batch 32 of 100: Hypervolume = 0.36, time = 5.40s.
# Batch 33 of 100: Hypervolume = 0.36, time = 22.11s.
# Batch 34 of 100: Hypervolume = 0.36, time = 17.76s.
# Batch 35 of 100: Hypervolume = 0.36, time = 5.42s.
# Batch 36 of 100: Hypervolume = 0.36, time = 5.28s.
# Batch 37 of 100: Hypervolume = 0.36, time = 5.47s.
# Batch 38 of 100: Hypervolume = 0.36, time = 16.95s.
# Batch 39 of 100: Hypervolume = 0.36, time = 5.52s.
# Batch 40 of 100: Hypervolume = 0.36, time = 15.01s.
# Batch 41 of 100: Hypervolume = 0.36, time = 7.19s.
# Batch 42 of 100: Hypervolume = 0.36, time = 5.47s.
# Batch 43 of 100: Hypervolume = 0.36, time = 21.18s.
# Batch 44 of 100: Hypervolume = 0.36, time = 7.18s.
# Batch 45 of 100: Hypervolume = 0.37, time = 8.16s.
# Batch 46 of 100: Hypervolume = 0.37, time = 5.67s.
# Batch 47 of 100: Hypervolume = 0.37, time = 9.09s.
# Batch 48 of 100: Hypervolume = 0.37, time = 9.88s.
# Batch 49 of 100: Hypervolume = 0.37, time = 8.67s.
# Batch 50 of 100: Hypervolume = 0.37, time = 10.02s.
# Batch 51 of 100: Hypervolume = 0.37, time = 12.01s.
# Batch 52 of 100: Hypervolume = 0.37, time = 14.67s.
# Batch 53 of 100: Hypervolume = 0.37, time = 20.25s.
# Batch 54 of 100: Hypervolume = 0.37, time = 23.51s.
# Batch 55 of 100: Hypervolume = 0.37, time = 12.49s.
# Batch 56 of 100: Hypervolume = 0.37, time = 13.16s.
# Batch 57 of 100: Hypervolume = 0.37, time = 12.09s.
# Batch 58 of 100: Hypervolume = 0.37, time = 23.43s.
# Batch 59 of 100: Hypervolume = 0.37, time = 17.48s.
# Batch 60 of 100: Hypervolume = 0.37, time = 14.67s.
# Batch 61 of 100: Hypervolume = 0.37, time = 9.82s.
# Batch 62 of 100: Hypervolume = 0.37, time = 12.75s.
# Batch 63 of 100: Hypervolume = 0.37, time = 14.43s.
# Batch 64 of 100: Hypervolume = 0.37, time = 17.36s.
# Batch 65 of 100: Hypervolume = 0.37, time = 15.81s.
# Batch 66 of 100: Hypervolume = 0.37, time = 13.93s.
# Batch 67 of 100: Hypervolume = 0.37, time = 21.89s.
# Batch 68 of 100: Hypervolume = 0.37, time = 40.63s.
# Batch 69 of 100: Hypervolume = 0.37, time = 19.47s.
# Batch 70 of 100: Hypervolume = 0.37, time = 14.89s.
# Batch 71 of 100: Hypervolume = 0.37, time = 22.65s.
# Batch 72 of 100: Hypervolume = 0.37, time = 23.89s.
# Batch 73 of 100: Hypervolume = 0.37, time = 22.34s.
# Batch 74 of 100: Hypervolume = 0.37, time = 16.38s.
# Batch 75 of 100: Hypervolume = 0.37, time = 18.66s.
# Batch 76 of 100: Hypervolume = 0.37, time = 28.88s.
# Batch 77 of 100: Hypervolume = 0.37, time = 19.99s.
# Batch 78 of 100: Hypervolume = 0.37, time = 19.79s.
# Batch 79 of 100: Hypervolume = 0.37, time = 25.76s.
# Batch 80 of 100: Hypervolume = 0.37, time = 24.17s.
# Batch 81 of 100: Hypervolume = 0.37, time = 24.32s.
# Batch 82 of 100: Hypervolume = 0.37, time = 20.43s.
# Batch 83 of 100: Hypervolume = 0.37, time = 32.38s.
# Batch 84 of 100: Hypervolume = 0.37, time = 24.25s.
# Batch 85 of 100: Hypervolume = 0.37, time = 31.10s.
# Batch 86 of 100: Hypervolume = 0.39, time = 40.37s.
# Batch 87 of 100: Hypervolume = 0.39, time = 37.16s.
# Batch 88 of 100: Hypervolume = 0.39, time = 29.41s.
# Batch 89 of 100: Hypervolume = 0.39, time = 42.18s.
# Batch 90 of 100: Hypervolume = 0.39, time = 34.14s.
# Batch 91 of 100: Hypervolume = 0.39, time = 28.50s.
# Batch 92 of 100: Hypervolume = 0.39, time = 26.58s.
# Batch 93 of 100: Hypervolume = 0.39, time = 38.13s.
# Batch 94 of 100: Hypervolume = 0.39, time = 44.11s.
# Batch 95 of 100: Hypervolume = 0.39, time = 41.19s.
# Batch 96 of 100: Hypervolume = 0.39, time = 44.45s.
# Batch 97 of 100: Hypervolume = 0.39, time = 37.13s.
# Batch 98 of 100: Hypervolume = 0.39, time = 45.66s.
# Batch 99 of 100: Hypervolume = 0.39, time = 38.38s.
# Batch 100 of 100: Hypervolume = 0.39, time = 63.51s.
# Time taken in total: 1811.28s.
# Optimizing with NSGA-III
# Time taken in total: 1.60s.
# DONE!

# %%
N_BATCH = 100
BATCH_SIZE = 8

hvs_nsga3 = loadtxt("MW7_hvs_nsga3_100by8.csv", delimiter=',')
hvs_qnehvi = loadtxt("MW7_hvs_qnehvi_100by8.csv", delimiter=',')

train_qnehvi = loadtxt("MW7_train_qnehvi_100by8.csv", delimiter=',')
train_nsga3 = loadtxt("MW7_train_nsga3_100by8.csv",  delimiter=',')

train_qnehvi = np.array(train_qnehvi).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2+2)    
train_nsga3 = np.array(train_nsga3).reshape((N_BATCH*BATCH_SIZE)+2*(dimensions+1), dimensions+2+2)

cm = plt.cm.get_cmap('inferno')

fig, ax = plt.subplots(ncols = 2, figsize = (14,5))

algos = ['MOEA U-NSGA-III', 'MOBO qNEHVI']

batch_number = torch.cat([torch.zeros(2*(problem.n_var+1)),
                          torch.arange(1, N_BATCH+1).repeat(BATCH_SIZE, 1).t().reshape(-1)
                         ]).numpy()

for i, train in enumerate((train_nsga3, train_qnehvi)):

    ax[i].scatter(pareto[:,0],
                  pareto[:,1], 
                  c="r", s=3, marker=".", alpha=0.8)
    
    ax[i].add_patch(plt.Circle((0, 0), 1, color='b', fill=False, alpha=0.5))

    
    ax[i].scatter(-train[...,problem.n_var:problem.n_var+problem.n_obj][:,0],
                  -train[...,problem.n_var:problem.n_var+problem.n_obj][:,1],
                 c=batch_number, cmap=cm, s=5, alpha=0.8)
    

    ax[i].set_title(f"MW7 (d={dimensions}), {algos[i]} ({N_BATCH} x {BATCH_SIZE})", fontsize=14)
    ax[i].set_xlabel('f1')
    
    ax[i].set_xlim(-0, 3)
    ax[i].set_ylim(-0, 3)

ax[0].set_ylabel('f2')

ax[0].text(1.25, 0.2, f"HV = {hvs_nsga3[-1]:.7f}", fontsize=14)
ax[1].text(1.25, 0.2, f"HV = {hvs_qnehvi[-1]:.7f}", fontsize=14)

#plt.setp(ax, xlim=ax[1].get_xlim(), ylim=ax[1].get_ylim())

fig.tight_layout()

norm = plt.Normalize(batch_number.min(), batch_number.max())
sm =  ScalarMappable(norm=norm, cmap=cm)
sm.set_array([])
fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.01, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.ax.set_title("Iteration", fontsize=11)
# Out:
# Text(0.5, 1.0, 'Iteration')

# %%
fig.savefig('trajectory_MW7.pdf')
