# %%
# basic dependencies

import numpy as np
from numpy import loadtxt
from numpy import savetxt

import pandas as pd
import math
import time

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

###########

# torch dependencies
import torch

tkwargs = {"dtype": torch.double, # set as double to minimize zero error for cholesky decomposition error
           "device": torch.device("cuda:0" if torch.cuda.is_available() else "cpu")} # set tensors to GPU, if multiple GPUs please set cuda:x properly

torch.set_printoptions(precision=3)

###########

# botorch dependencies
import botorch

# data related
from botorch.utils.sampling import draw_sobol_samples
from botorch.utils.transforms import unnormalize, normalize

# surrogate model specific
from botorch.models.gp_regression import SingleTaskGP, FixedNoiseGP
from botorch.models.model_list_gp_regression import ModelListGP
from botorch.models.transforms.outcome import Standardize
from gpytorch.mlls.sum_marginal_log_likelihood import SumMarginalLogLikelihood
from botorch import fit_gpytorch_model

# qNEHVI specific
from botorch.optim.optimize import optimize_acqf
from botorch.acquisition.multi_objective.objective import IdentityMCMultiOutputObjective
from botorch.acquisition.multi_objective.monte_carlo import qNoisyExpectedHypervolumeImprovement

# utilities
from botorch.sampling.samplers import SobolQMCNormalSampler
from botorch.utils.multi_objective.pareto import is_non_dominated
from botorch.utils.multi_objective.hypervolume import Hypervolume
from botorch.utils.multi_objective.hypervolume import infer_reference_point
from typing import Optional
from torch import Tensor
from botorch.exceptions import BadInitialCandidatesWarning

import warnings

warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

###########

# pymoo dependencies
import pymoo

from pymoo.factory import get_problem
from pymoo.core.problem import ElementwiseProblem

from pymoo.algorithms.moo.nsga3 import NSGA3
from pymoo.algorithms.moo.unsga3 import UNSGA3
from pymoo.algorithms.moo.ctaea import CTAEA
from pymoo.factory import get_sampling, get_crossover, get_mutation, get_reference_directions, get_termination
from pymoo.optimize import minimize

from pymoo.core.problem import Problem
from pymoo.util.termination.no_termination import NoTermination
from pymoo.core.evaluator import set_cv
from pymoo.factory import get_performance_indicator


###########

# plotting dependencies
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# this is for the colorbar, you can change the cmap if you prefer other colour schemes
from matplotlib.cm import ScalarMappable
cm = plt.cm.get_cmap('viridis')

# function to return the std dev across runs
def ci(y, N_TRIALS):
    return 1.96 * y.std(axis=0) / np.sqrt(N_TRIALS)

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, Matern, WhiteKernel
from sklearn.preprocessing import MinMaxScaler

# %%
def optimize_qnehvi(problem, ref_point, initial_x, # must haves
                    N_BATCH, BATCH_SIZE, 
                    random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with qNEHVI")

    t0 = time.time()

    # some initializing 
    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj, train_con = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    train_con_noisy = train_con + noise*torch.randn_like(train_con)
    
    ##########
    
    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, standard_bounds)
    
    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
        
    ##########    
    
    def create_idxr(i):
        def idxr(Z):
            return Z[..., i]

        return idxr

    def create_idxrs():
        return [create_idxr(i=i) for i in range(problem.n_obj, problem.n_obj+problem.n_constr)]
    
    # original location for an extra HV check wrt to initial samples
    
    ########## ########## ########## start of iteration loop


    # training loop for N_BATCH iterations
    for iteration in range(1, N_BATCH + 1):    

        t3 = time.time()
                
        # fit the surrogate model
        fit_gpytorch_model(mll)    
                
        ##########
            
        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            constraints=create_idxrs(), # constraint on last n_constr col
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on
        
        ##########
        
        # propose candidates given defined qNEHVI acq func given model and latest observed training data
        new_x, _ = optimize_acqf(
                        acq_function=acq_func,
                        bounds=standard_bounds, # since train_x was normalized
                        q=BATCH_SIZE, # no of candidates to propose in parallel
                        num_restarts=2, # no of restarts if q candidates fail to show improvement
                        raw_samples=128,  # pool of samples to choose the starting points from
                        options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                        )

        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj, new_con = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)
        new_con_noisy = new_con + noise*torch.randn_like(new_con)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        train_con_noisy = torch.cat([train_con_noisy, new_con_noisy])
        
        ##########
        
        # computing HV of current candidate list
        is_feas = (train_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = train_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0
        
        hvs.append(volume)
        
        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, standard_bounds) # dont forget to renormalize!
        train_y = torch.cat([train_obj_noisy, train_con_noisy], dim=-1) # model takes noisy observations

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)
        
        ##########
        
        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")
            
        del new_x, new_obj, new_con, new_obj_noisy, new_con_noisy, train_x_gp, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial     
        
        ########## ########## ########## end of iteration loop

    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")       
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

def optimize_nsga3(problem, ref_point, initial_x, # must haves
                   N_BATCH, pop_size,
                   ref_num=10, # as a rule of thumb, pop_size>ref_num,
                   noise=0, random_state=np.random.randint(0, 1000000, (1,)).item(), verbose=False):
    
    print("Optimizing with NSGA-III")
    
    t0 = time.time()    
    
    # some initializing
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    
    noise=noise

    # define a pymoo problem class based on the torch class
    class PymooProblem(ElementwiseProblem):

        def __init__(self):
            super().__init__(n_var=problem.n_var,
                             n_obj=problem.n_obj,
                             n_constr=problem.n_constr,
                             xl=problem.bounds[0].cpu().numpy(),
                             xu=problem.bounds[1].cpu().numpy())

        def _evaluate(self, X, out, *args, **kwargs):
            # base input/output from torch class
            train_x = torch.tensor(X.tolist(), **tkwargs).unsqueeze(dim=0)
            
            # take the noisy observations for algo
            train_obj, train_con = problem.evaluate(train_x)
            train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
            train_con_noisy = train_con + noise*torch.randn_like(train_con)

            # output the noisy observations instead
            out["F"] = -train_obj_noisy.cpu().numpy() # flip since botorch assumes maximisation vs pymoo minimization
            out["G"] = train_con_noisy.cpu().numpy()
            
    ##########        

    pymooproblem = PymooProblem()

    # create the reference directions to be used for the optimization
    ref_dirs = get_reference_directions("energy", problem.n_obj, ref_num, seed=random_state)
    
    # initial sampling
    sampling = initial_x.cpu().numpy()
    
    # create the algorithm object
    algorithm = UNSGA3(pop_size=pop_size,
                      ref_dirs=ref_dirs,
                      sampling=sampling
                     )

    # execute the optimization, take N_BATCH+1 since 1st iteration is just the initial sampling
    res = minimize(pymooproblem, algorithm, seed=random_state, termination=('n_gen', N_BATCH+1),
                   verbose=verbose, save_history=True)
    
    ##########
    
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")

    ##########
        
    # convert population data into tensor form
    # initial data
    train_x = torch.tensor(res.history[0].pop.get("X").tolist(), **tkwargs)
    train_obj, train_con = problem.evaluate(train_x) 
    # population at each iteration
    for i in range(1,N_BATCH+1): # don't forget we did +1 for total iterations
        new_x = torch.tensor(res.history[i].pop.get("X").tolist(), **tkwargs)
        new_obj, new_con = problem.evaluate(new_x)
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_con = torch.cat([train_con, new_con])

    ##########
        
    # calculate hypervolume based on checks, done on noiseless train_obj and train_con
    iterdict = {}
    a = 0
    b = initial_x.shape[0]
    for i in range(0, N_BATCH+1):

        iterdict[i] = (a, b)
        # a stays at zero
        b+=pop_size
    
    for i in range(0,N_BATCH):
        hvs_obj = train_obj[iterdict[i][0]:iterdict[i][1]]
        hvs_con = train_con[iterdict[i][0]:iterdict[i][1]]

        is_feas = (hvs_con <= 0).all(dim=-1) # check whether points fit ALL (.all) constraint criteria
        feas_train_obj = hvs_obj[is_feas] # take only points that fit the 1st check
        if feas_train_obj.shape[0] > 0:
            pareto_mask = is_non_dominated(feas_train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
            pareto_y = feas_train_obj[pareto_mask] # take only points that fit the 2nd check
            volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        else:
            volume = 0.0
        
        hvs.append(volume)
        
    print("DONE!\n")
        
    return hvs, torch.hstack([train_x, train_obj, train_con]).cpu().numpy()

def optimize_qnehvi_noconstr(problem, ref_point, initial_x, # must haves
                    N_BATCH, BATCH_SIZE, 
                    random_state=torch.randint(1000000, (1,)).item(), noise=0, verbose=False): # change noise here!
    
    print("Optimizing with qNEHVI")

    t0 = time.time()

    # some initializing 
    torch.manual_seed(random_state) # gives a consistent seed based on the trial number
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    # generate initial training data for that run
    train_x = initial_x
    train_obj = problem.evaluate(train_x)

    # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
    train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)
    
    ##########
    
    # normalize inputs to [0,1] first before feeding into model
    standard_bounds = torch.zeros(2, problem.n_var, **tkwargs)
    standard_bounds[1] = 1
    train_x_gp = normalize(train_x, standard_bounds)
    
    # form the output train_y data by concentenating ground truth train_obj with its feasibility value on the rightmost
    # this is necessary since the surrogate GpyTorch model needs to model BOTH obj and con for predicted candidates
    train_y = train_obj_noisy

    # define and train surrogate models for objective and constraint
    models = []
    for i in range(train_y.shape[-1]):
        models.append(SingleTaskGP(train_x_gp, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
    model = ModelListGP(*models)
    mll = SumMarginalLogLikelihood(model.likelihood, model)
        
    ##########    
    
    # original location for an extra HV check wrt to initial samples
    
    ########## ########## ########## start of iteration loop


    # training loop for N_BATCH iterations
    for iteration in range(1, N_BATCH + 1):    

        t3 = time.time()
                
        # fit the surrogate model
        fit_gpytorch_model(mll)    
                
        ##########
            
        # define the acqusition function for EIC if feas_weighting is false
        acq_func = qNoisyExpectedHypervolumeImprovement(
            model=model,
            ref_point=-ref_point, # for computing HV, must flip for BoTorch
            X_baseline=train_x, # feed total list of train_x for this current iteration
            sampler=SobolQMCNormalSampler(num_samples=128),  # determines how candidates are randomly proposed before selection
            objective=IdentityMCMultiOutputObjective(outcomes=np.arange(problem.n_obj).tolist()), # optimize first n_obj col 
            prune_baseline=True, cache_pending=True)  # options for improving qNEHVI, keep these on
        
        ##########
        
        # propose candidates given defined qNEHVI acq func given model and latest observed training data
        new_x, _ = optimize_acqf(
                        acq_function=acq_func,
                        bounds=standard_bounds, # since train_x was normalized
                        q=BATCH_SIZE, # no of candidates to propose in parallel
                        num_restarts=2, # no of restarts if q candidates fail to show improvement
                        raw_samples=128,  # pool of samples to choose the starting points from
                        options={"batch_limit": 5, "maxiter": 200}, # default arguments, not too sure about this yet
                        )

        # unormalize our training inputs back to original problem bounds
        new_x =  unnormalize(new_x.detach(), bounds=problem.bounds)

        # feed new proposed observations into objective func to get its new ground truth
        new_obj = problem.evaluate(new_x)

        # add noise, by default noise=0, so train_noisy = train, noise factor determines amt of std dev to add
        new_obj_noisy = new_obj + noise*torch.randn_like(new_obj)

        # update training points by concatenating the new values into their respective tensors
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        train_obj_noisy = torch.cat([train_obj_noisy, new_obj_noisy])
        
        ##########
        
        # computing HV of current candidate list
        pareto_mask = is_non_dominated(train_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
        pareto_y = train_obj[pareto_mask] # take only points that fit the 2nd check
        volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
        
        hvs.append(volume)
        
        ##########

        # update the surrogate models for next iteration
        train_x_gp = normalize(train_x, standard_bounds) # dont forget to renormalize!
        train_y = train_obj_noisy

        models = []
        for i in range(train_y.shape[-1]):
            models.append(SingleTaskGP(train_x, train_y[..., i : i + 1], outcome_transform=Standardize(m=1)))
        model = ModelListGP(*models)
        mll = SumMarginalLogLikelihood(model.likelihood, model)
        
        ##########
        
        t4 = time.time()
        if verbose:
            print(
                    f"Batch {iteration:>2} of {N_BATCH}: Hypervolume = "
                    f"{hvs[-1]:>4.2f}, "
                    f"time = {t4-t3:>4.2f}s.\n"
                    , end="")
            
        del new_x, new_obj, new_obj_noisy, train_x_gp, train_y
        torch.cuda.empty_cache() # clear some memory here between each run/trial     
        
        ########## ########## ########## end of iteration loop

    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")       
    
    # returns the HV score across iterations, total training set as an array
    return hvs, torch.hstack([train_x, train_obj]).cpu().numpy()

def optimize_nsga3_noconstr(problem, ref_point,  initial_x, # must haves
                            N_BATCH, pop_size,
                            ref_num=10, # as a rule of thumb, pop_size>ref_num,
                            noise=0, random_state=np.random.randint(0, 1000000, (1,)).item(), verbose=False):
    
    print("Optimizing with NSGA-III")
    
    t0 = time.time()    
    
    # some initializing
    hv=Hypervolume(ref_point=-ref_point) # sets the hv based on problem, flip since BoTorch takes maximisation
    hvs = [] # create a blank array to append the scores at each batch/iteration for that run
    
    ##########
    
    noise=noise

    # define a pymoo problem class based on the torch class
    class PymooProblem(ElementwiseProblem):

        def __init__(self):
            super().__init__(n_var=problem.n_var,
                             n_obj=problem.n_obj,
                             xl=problem.bounds[0].cpu().numpy(),
                             xu=problem.bounds[1].cpu().numpy())

        def _evaluate(self, X, out, *args, **kwargs):
            # base input/output from torch class
            train_x = torch.tensor(X.tolist(), **tkwargs).unsqueeze(dim=0)
            
            # take the noisy observations for algo
            train_obj = problem.evaluate(train_x)
            train_obj_noisy = train_obj + noise*torch.randn_like(train_obj)

            # output the noisy observations instead
            out["F"] = -train_obj_noisy.cpu().numpy() # flip since botorch assumes maximisation vs pymoo minimization
            
    ##########        

    pymooproblem = PymooProblem()

    # create the reference directions to be used for the optimization
    ref_dirs = get_reference_directions("energy", problem.n_obj, ref_num, seed=random_state)
    
    # initial sampling
    sampling = initial_x.cpu().numpy()
    
    # create the algorithm object
    algorithm = UNSGA3(pop_size=pop_size,
                      ref_dirs=ref_dirs,
                      sampling=sampling
                     )

    # execute the optimization, take N_BATCH+1 since 1st iteration is just the initial sampling
    res = minimize(pymooproblem, algorithm, seed=random_state, termination=('n_gen', N_BATCH+1),
                   verbose=verbose, save_history=True)
    
    ##########
    
    t1 = time.time()
    print(f"Time taken in total: {t1-t0:>4.2f}s.")
    
    ##########
    
    # convert population data into tensor form
    # initial data
    train_x = torch.tensor(res.history[0].pop.get("X").tolist(), **tkwargs)
    train_obj = problem.evaluate(train_x) 
    # population at each iteration
    for i in range(1,N_BATCH+1): # don't forget we did +1 for total iterations
        new_x = torch.tensor(res.history[i].pop.get("X").tolist(), **tkwargs)
        new_obj = problem.evaluate(new_x)
        train_x = torch.cat([train_x, new_x])
        train_obj = torch.cat([train_obj, new_obj])
        
    ##########
    
    # calculate hypervolume based on checks, done on noiseless train_obj and train_con
    iterdict = {}
    a = 0
    b = initial_x.shape[0]
    for i in range(0, N_BATCH+1):

        iterdict[i] = (a, b)
        # a stays at zero
        b+=pop_size
    
    for i in range(0,N_BATCH):
        hvs_obj = train_obj[iterdict[i][0]:iterdict[i][1]]

        # computing HV of current candidate list
        pareto_mask = is_non_dominated(hvs_obj) # check for 2nd criteria: non-dominated, meaning new pareto optimal
        pareto_y = hvs_obj[pareto_mask] # take only points that fit the 2nd check
        volume = hv.compute(pareto_y) # compute change in HV with new pareto optimal wrt to original ref point
                
        hvs.append(volume)   
        
    ##########
     
    return hvs, torch.hstack([train_x, train_obj]).cpu().numpy()

# %%
dimensions = 8

from botorch.test_functions.multi_objective import ZDT1

ZDT1base = ZDT1(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT1(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT1base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import ZDT2

ZDT2base = ZDT2(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT2(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT2base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import ZDT3

ZDT3base = ZDT3(dim=dimensions, negate=True).to(**tkwargs)

class Problem_ZDT3(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1 # inequality constraints only!
        
    bounds = torch.vstack([torch.zeros(dimensions, **tkwargs),torch.ones(dimensions, **tkwargs)])
    
    def evaluate(X):        
    
        output = ZDT3base(X)
        
        # for 1 constraint, take c1.unsqueeze(dim=-1)
        # for >1 constraint, take torch.stack([c1, c2....], dim=-1)
        
        return output
    
from botorch.test_functions.multi_objective import MW7

MW7base = MW7(dim=dimensions, negate=True).to(**tkwargs)

class Problem_MW7(torch.nn.Module):
    n_var = dimensions
    n_obj = 2
    n_constr = 1
    
    bounds = MW7base.bounds    
    
    def evaluate(X):       
        output = MW7base(X)
        slack = -MW7base.evaluate_slack(X)
       
        return output, slack

# %%
ref_point = torch.tensor([11,11], **tkwargs)

N_TRIALS = 10
verbose = True
N_BATCH = 24
BATCH_SIZE = 8

hvs_qnehvi_all0 = []
hvs_qnehvi_all1 = []
hvs_qnehvi_all2 = []
hvs_qnehvi_all3 = []

hvs_nsga3_all0 = []
hvs_nsga3_all1 = []
hvs_nsga3_all2 = []
hvs_nsga3_all3 = []

problem = Problem_ZDT1
problemname = 'ZDT1'

# main loop for each trial/run, random_state will be trial number
for trial in range(1, 10 + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} for problem {problem} with d = {dimensions}\n", end="")

    # initialize with a 2*(d+1) sample set

    initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

    ###############    
    
    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.01, verbose=verbose)
    hvs_qnehvi_all0.append(hvs_qnehvi)
        
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.025, verbose=verbose)
    hvs_qnehvi_all1.append(hvs_qnehvi)

    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.05, verbose=verbose)
    hvs_qnehvi_all2.append(hvs_qnehvi)
    
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.1, verbose=verbose)
    hvs_qnehvi_all3.append(hvs_qnehvi)
    
    ###############    

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.01, verbose=False)
    hvs_nsga3_all0.append(hvs_nsga3) 
    
    ###############

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.025, verbose=False)
    hvs_nsga3_all1.append(hvs_nsga3) 
    
    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.05, verbose=False)
    hvs_nsga3_all2.append(hvs_nsga3) 

    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.1, verbose=False)
    hvs_nsga3_all3.append(hvs_nsga3) 
    
    ###############

savetxt(f"{problemname}_hvs_qnehvi_noise1.csv", hvs_qnehvi_all0, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise2.csv", hvs_qnehvi_all1, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise3.csv", hvs_qnehvi_all2, delimiter=',')    
savetxt(f"{problemname}_hvs_qnehvi_noise4.csv", hvs_qnehvi_all3, delimiter=',')    

savetxt(f"{problemname}_hvs_nsga3_noise1.csv", hvs_nsga3_all0, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all1, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all2, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise4.csv", hvs_nsga3_all3, delimiter=',')
    
print("ALL DONE!")
# Out:
# Trial  1 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# C:\Users\user\anaconda3\lib\site-packages\botorch\fit.py:143: UserWarning: Specified kernel cache directory could not be created! This disables kernel caching. Specified directory is C:\Users\user\AppData\Local\Temp/torch/kernels. This warning will appear only once per process. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cuda\jit_utils.cpp:860.)
#   warnings.warn(w.message, w.category)
# C:\Users\user\anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1741: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\BatchLinearAlgebra.cpp:1672.)
#   Linv = torch.triangular_solve(Eye, L, upper=False).solution
# Batch  1 of 96: Hypervolume = 91.65, time = 4.06s.
# Batch  2 of 96: Hypervolume = 93.47, time = 2.92s.
# Batch  3 of 96: Hypervolume = 96.74, time = 2.49s.
# Batch  4 of 96: Hypervolume = 100.75, time = 2.96s.
# Batch  5 of 96: Hypervolume = 105.68, time = 2.28s.
# Batch  6 of 96: Hypervolume = 109.28, time = 2.53s.
# Batch  7 of 96: Hypervolume = 112.30, time = 3.96s.
# Batch  8 of 96: Hypervolume = 115.22, time = 2.82s.
# Batch  9 of 96: Hypervolume = 116.20, time = 2.10s.
# Batch 10 of 96: Hypervolume = 116.66, time = 1.68s.
# Batch 11 of 96: Hypervolume = 116.68, time = 1.90s.
# Batch 12 of 96: Hypervolume = 116.69, time = 2.79s.
# Batch 13 of 96: Hypervolume = 116.69, time = 3.28s.
# Batch 14 of 96: Hypervolume = 116.69, time = 3.97s.
# Batch 15 of 96: Hypervolume = 116.73, time = 3.28s.
# Batch 16 of 96: Hypervolume = 116.73, time = 4.43s.
# Batch 17 of 96: Hypervolume = 118.70, time = 5.30s.
# Batch 18 of 96: Hypervolume = 118.90, time = 2.90s.
# Batch 19 of 96: Hypervolume = 118.95, time = 1.97s.
# Batch 20 of 96: Hypervolume = 118.95, time = 1.82s.
# Batch 21 of 96: Hypervolume = 118.95, time = 3.80s.
# Batch 22 of 96: Hypervolume = 118.95, time = 2.93s.
# Batch 23 of 96: Hypervolume = 118.95, time = 3.91s.
# Batch 24 of 96: Hypervolume = 118.95, time = 2.48s.
# Batch 25 of 96: Hypervolume = 118.95, time = 4.61s.
# Batch 26 of 96: Hypervolume = 118.95, time = 4.37s.
# Batch 27 of 96: Hypervolume = 118.95, time = 4.50s.
# Batch 28 of 96: Hypervolume = 118.95, time = 3.03s.
# Batch 29 of 96: Hypervolume = 118.95, time = 3.40s.
# Batch 30 of 96: Hypervolume = 118.95, time = 2.46s.
# Batch 31 of 96: Hypervolume = 118.95, time = 3.86s.
# Batch 32 of 96: Hypervolume = 118.95, time = 2.40s.
# Batch 33 of 96: Hypervolume = 118.95, time = 2.85s.
# Batch 34 of 96: Hypervolume = 118.95, time = 3.22s.
# Batch 35 of 96: Hypervolume = 118.95, time = 2.29s.
# Batch 36 of 96: Hypervolume = 118.95, time = 2.20s.
# Batch 37 of 96: Hypervolume = 118.95, time = 2.67s.
# Batch 38 of 96: Hypervolume = 118.95, time = 2.68s.
# Batch 39 of 96: Hypervolume = 118.95, time = 2.87s.
# Batch 40 of 96: Hypervolume = 118.95, time = 3.59s.
# Batch 41 of 96: Hypervolume = 118.95, time = 3.12s.
# Batch 42 of 96: Hypervolume = 118.95, time = 3.21s.
# Batch 43 of 96: Hypervolume = 118.95, time = 3.76s.
# Batch 44 of 96: Hypervolume = 118.95, time = 4.45s.
# Batch 45 of 96: Hypervolume = 118.95, time = 2.52s.
# Batch 46 of 96: Hypervolume = 118.95, time = 3.95s.
# Batch 47 of 96: Hypervolume = 118.95, time = 3.02s.
# Batch 48 of 96: Hypervolume = 118.95, time = 2.79s.
# Batch 49 of 96: Hypervolume = 118.95, time = 4.06s.
# Batch 50 of 96: Hypervolume = 118.95, time = 3.59s.
# Batch 51 of 96: Hypervolume = 118.95, time = 2.56s.
# Batch 52 of 96: Hypervolume = 118.95, time = 2.62s.
# Batch 53 of 96: Hypervolume = 118.95, time = 2.88s.
# Batch 54 of 96: Hypervolume = 118.95, time = 3.14s.
# Batch 55 of 96: Hypervolume = 118.95, time = 3.99s.
# Batch 56 of 96: Hypervolume = 118.95, time = 2.98s.
# Batch 57 of 96: Hypervolume = 118.95, time = 2.51s.
# Batch 58 of 96: Hypervolume = 118.95, time = 2.85s.
# Batch 59 of 96: Hypervolume = 118.95, time = 3.58s.
# Batch 60 of 96: Hypervolume = 118.95, time = 2.86s.
# Batch 61 of 96: Hypervolume = 118.95, time = 2.83s.
# Batch 62 of 96: Hypervolume = 118.95, time = 2.03s.
# Batch 63 of 96: Hypervolume = 118.95, time = 1.53s.
# Batch 64 of 96: Hypervolume = 118.95, time = 2.76s.
# Batch 65 of 96: Hypervolume = 118.95, time = 1.85s.
# Batch 66 of 96: Hypervolume = 118.95, time = 2.13s.
# Batch 67 of 96: Hypervolume = 118.95, time = 1.75s.
# Batch 68 of 96: Hypervolume = 118.95, time = 2.97s.
# Batch 69 of 96: Hypervolume = 118.95, time = 1.66s.
# Batch 70 of 96: Hypervolume = 118.95, time = 2.82s.
# Batch 71 of 96: Hypervolume = 118.95, time = 2.05s.
# Batch 72 of 96: Hypervolume = 118.95, time = 3.13s.
# Batch 73 of 96: Hypervolume = 118.95, time = 2.91s.
# Batch 74 of 96: Hypervolume = 118.95, time = 1.86s.
# Batch 75 of 96: Hypervolume = 118.95, time = 1.40s.
# Batch 76 of 96: Hypervolume = 118.95, time = 2.27s.
# Batch 77 of 96: Hypervolume = 118.95, time = 1.83s.
# Batch 78 of 96: Hypervolume = 118.95, time = 1.55s.
# Batch 79 of 96: Hypervolume = 118.95, time = 1.69s.
# Batch 80 of 96: Hypervolume = 118.95, time = 2.61s.
# Batch 81 of 96: Hypervolume = 118.95, time = 1.40s.
# Batch 82 of 96: Hypervolume = 118.95, time = 2.06s.
# Batch 83 of 96: Hypervolume = 118.95, time = 1.29s.
# Batch 84 of 96: Hypervolume = 118.95, time = 1.52s.
# Batch 85 of 96: Hypervolume = 118.95, time = 2.12s.
# Batch 86 of 96: Hypervolume = 118.95, time = 2.22s.
# Batch 87 of 96: Hypervolume = 118.95, time = 2.87s.
# Batch 88 of 96: Hypervolume = 118.95, time = 1.49s.
# Batch 89 of 96: Hypervolume = 118.95, time = 2.56s.
# Batch 90 of 96: Hypervolume = 118.95, time = 1.64s.
# Batch 91 of 96: Hypervolume = 118.95, time = 2.74s.
# Batch 92 of 96: Hypervolume = 118.95, time = 2.13s.
# Batch 93 of 96: Hypervolume = 118.95, time = 2.36s.
# Batch 94 of 96: Hypervolume = 118.95, time = 1.26s.
# Batch 95 of 96: Hypervolume = 118.95, time = 1.87s.
# Batch 96 of 96: Hypervolume = 118.95, time = 2.04s.
# Time taken in total: 263.29s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 92.56, time = 1.94s.
# Batch  2 of 48: Hypervolume = 98.04, time = 1.94s.
# Batch  3 of 48: Hypervolume = 102.81, time = 4.06s.
# Batch  4 of 48: Hypervolume = 107.62, time = 3.93s.
# Batch  5 of 48: Hypervolume = 113.30, time = 4.10s.
# Batch  6 of 48: Hypervolume = 117.56, time = 4.12s.
# Batch  7 of 48: Hypervolume = 117.56, time = 2.18s.
# Batch  8 of 48: Hypervolume = 117.66, time = 2.55s.
# Batch  9 of 48: Hypervolume = 117.66, time = 4.75s.
# Batch 10 of 48: Hypervolume = 117.66, time = 3.44s.
# Batch 11 of 48: Hypervolume = 117.66, time = 4.31s.
# Batch 12 of 48: Hypervolume = 118.10, time = 4.85s.
# Batch 13 of 48: Hypervolume = 118.10, time = 4.61s.
# Batch 14 of 48: Hypervolume = 118.10, time = 4.62s.
# Batch 15 of 48: Hypervolume = 118.10, time = 4.98s.
# Batch 16 of 48: Hypervolume = 118.10, time = 4.79s.
# Batch 17 of 48: Hypervolume = 118.23, time = 3.24s.
# Batch 18 of 48: Hypervolume = 118.23, time = 4.71s.
# Batch 19 of 48: Hypervolume = 118.23, time = 4.63s.
# Batch 20 of 48: Hypervolume = 118.23, time = 4.50s.
# Batch 21 of 48: Hypervolume = 118.23, time = 5.01s.
# Batch 22 of 48: Hypervolume = 118.23, time = 4.90s.
# Batch 23 of 48: Hypervolume = 118.23, time = 4.14s.
# Batch 24 of 48: Hypervolume = 118.23, time = 4.98s.
# Batch 25 of 48: Hypervolume = 118.23, time = 2.52s.
# Batch 26 of 48: Hypervolume = 118.23, time = 4.49s.
# Batch 27 of 48: Hypervolume = 118.23, time = 3.79s.
# Batch 28 of 48: Hypervolume = 118.23, time = 2.78s.
# Batch 29 of 48: Hypervolume = 118.23, time = 4.79s.
# Batch 30 of 48: Hypervolume = 118.23, time = 3.35s.
# Batch 31 of 48: Hypervolume = 118.23, time = 5.28s.
# Batch 32 of 48: Hypervolume = 118.23, time = 4.99s.
# Batch 33 of 48: Hypervolume = 118.23, time = 3.06s.
# Batch 34 of 48: Hypervolume = 118.23, time = 5.49s.
# Batch 35 of 48: Hypervolume = 118.23, time = 4.24s.
# Batch 36 of 48: Hypervolume = 118.23, time = 2.56s.
# Batch 37 of 48: Hypervolume = 118.23, time = 1.89s.
# Batch 38 of 48: Hypervolume = 118.23, time = 2.11s.
# Batch 39 of 48: Hypervolume = 118.23, time = 2.98s.
# Batch 40 of 48: Hypervolume = 118.23, time = 5.98s.
# Batch 41 of 48: Hypervolume = 118.23, time = 2.66s.
# Batch 42 of 48: Hypervolume = 118.23, time = 3.19s.
# Batch 43 of 48: Hypervolume = 118.23, time = 5.18s.
# Batch 44 of 48: Hypervolume = 118.23, time = 2.09s.
# Batch 45 of 48: Hypervolume = 118.23, time = 5.62s.
# Batch 46 of 48: Hypervolume = 118.23, time = 2.97s.
# Batch 47 of 48: Hypervolume = 118.23, time = 4.75s.
# Batch 48 of 48: Hypervolume = 118.23, time = 2.27s.
# Time taken in total: 186.38s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 93.52, time = 6.26s.
# Batch  2 of 24: Hypervolume = 101.06, time = 6.08s.
# Batch  3 of 24: Hypervolume = 108.53, time = 6.62s.
# Batch  4 of 24: Hypervolume = 116.64, time = 6.41s.
# Batch  5 of 24: Hypervolume = 120.15, time = 6.37s.
# Batch  6 of 24: Hypervolume = 120.15, time = 6.61s.
# Batch  7 of 24: Hypervolume = 120.15, time = 8.12s.
# Batch  8 of 24: Hypervolume = 120.33, time = 7.79s.
# Batch  9 of 24: Hypervolume = 120.33, time = 7.73s.
# Batch 10 of 24: Hypervolume = 120.33, time = 8.45s.
# Batch 11 of 24: Hypervolume = 120.49, time = 9.22s.
# Batch 12 of 24: Hypervolume = 120.49, time = 4.68s.
# Batch 13 of 24: Hypervolume = 120.49, time = 8.92s.
# Batch 14 of 24: Hypervolume = 120.49, time = 8.90s.
# Batch 15 of 24: Hypervolume = 120.49, time = 9.50s.
# Batch 16 of 24: Hypervolume = 120.49, time = 9.48s.
# Batch 17 of 24: Hypervolume = 120.49, time = 8.24s.
# Batch 18 of 24: Hypervolume = 120.49, time = 8.68s.
# Batch 19 of 24: Hypervolume = 120.49, time = 8.56s.
# Batch 20 of 24: Hypervolume = 120.49, time = 5.87s.
# Batch 21 of 24: Hypervolume = 120.49, time = 9.62s.
# Batch 22 of 24: Hypervolume = 120.49, time = 7.84s.
# Batch 23 of 24: Hypervolume = 120.49, time = 10.66s.
# Batch 24 of 24: Hypervolume = 120.49, time = 6.52s.
# Time taken in total: 187.19s.
# Optimizing with NSGA-III
# Time taken in total: 0.78s.
# Optimizing with NSGA-III
# Time taken in total: 0.72s.
# Optimizing with NSGA-III
# Time taken in total: 0.77s.
# Optimizing with NSGA-III
# Time taken in total: 0.76s.
#
# Trial  2 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 97.78, time = 2.45s.
# Batch  2 of 96: Hypervolume = 97.79, time = 1.59s.
# Batch  3 of 96: Hypervolume = 99.98, time = 2.35s.
# Batch  4 of 96: Hypervolume = 105.09, time = 2.01s.
# Batch  5 of 96: Hypervolume = 109.20, time = 2.16s.
# Batch  6 of 96: Hypervolume = 111.80, time = 2.25s.
# Batch  7 of 96: Hypervolume = 115.03, time = 2.38s.
# Batch  8 of 96: Hypervolume = 117.94, time = 2.10s.
# Batch  9 of 96: Hypervolume = 118.56, time = 1.32s.
# Batch 10 of 96: Hypervolume = 118.74, time = 1.83s.
# Batch 11 of 96: Hypervolume = 118.97, time = 1.98s.
# Batch 12 of 96: Hypervolume = 119.21, time = 1.78s.
# Batch 13 of 96: Hypervolume = 119.61, time = 2.70s.
# Batch 14 of 96: Hypervolume = 119.82, time = 2.99s.
# Batch 15 of 96: Hypervolume = 119.82, time = 1.78s.
# Batch 16 of 96: Hypervolume = 119.82, time = 3.45s.
# Batch 17 of 96: Hypervolume = 119.82, time = 2.80s.
# Batch 18 of 96: Hypervolume = 119.82, time = 3.93s.
# Batch 19 of 96: Hypervolume = 119.82, time = 2.28s.
# Batch 20 of 96: Hypervolume = 119.82, time = 3.20s.
# Batch 21 of 96: Hypervolume = 120.34, time = 2.39s.
# Batch 22 of 96: Hypervolume = 120.34, time = 3.96s.
# Batch 23 of 96: Hypervolume = 120.34, time = 4.21s.
# Batch 24 of 96: Hypervolume = 120.34, time = 2.51s.
# Batch 25 of 96: Hypervolume = 120.34, time = 2.89s.
# Batch 26 of 96: Hypervolume = 120.34, time = 3.18s.
# Batch 27 of 96: Hypervolume = 120.34, time = 3.02s.
# Batch 28 of 96: Hypervolume = 120.34, time = 4.17s.
# Batch 29 of 96: Hypervolume = 120.34, time = 2.65s.
# Batch 30 of 96: Hypervolume = 120.34, time = 3.76s.
# Batch 31 of 96: Hypervolume = 120.34, time = 5.03s.
# Batch 32 of 96: Hypervolume = 120.34, time = 4.06s.
# Batch 33 of 96: Hypervolume = 120.34, time = 3.79s.
# Batch 34 of 96: Hypervolume = 120.34, time = 2.25s.
# Batch 35 of 96: Hypervolume = 120.34, time = 3.21s.
# Batch 36 of 96: Hypervolume = 120.34, time = 3.10s.
# Batch 37 of 96: Hypervolume = 120.34, time = 3.96s.
# Batch 38 of 96: Hypervolume = 120.34, time = 2.91s.
# Batch 39 of 96: Hypervolume = 120.34, time = 4.03s.
# Batch 40 of 96: Hypervolume = 120.34, time = 2.80s.
# Batch 41 of 96: Hypervolume = 120.34, time = 3.97s.
# Batch 42 of 96: Hypervolume = 120.34, time = 2.97s.
# Batch 43 of 96: Hypervolume = 120.34, time = 3.60s.
# Batch 44 of 96: Hypervolume = 120.34, time = 3.54s.
# Batch 45 of 96: Hypervolume = 120.34, time = 2.93s.
# Batch 46 of 96: Hypervolume = 120.34, time = 3.50s.
# Batch 47 of 96: Hypervolume = 120.34, time = 4.23s.
# Batch 48 of 96: Hypervolume = 120.34, time = 3.39s.
# Batch 49 of 96: Hypervolume = 120.34, time = 3.54s.
# Batch 50 of 96: Hypervolume = 120.34, time = 1.66s.
# Batch 51 of 96: Hypervolume = 120.34, time = 2.60s.
# Batch 52 of 96: Hypervolume = 120.34, time = 2.28s.
# Batch 53 of 96: Hypervolume = 120.34, time = 3.89s.
# Batch 54 of 96: Hypervolume = 120.34, time = 3.07s.
# Batch 55 of 96: Hypervolume = 120.34, time = 2.90s.
# Batch 56 of 96: Hypervolume = 120.34, time = 3.30s.
# Batch 57 of 96: Hypervolume = 120.34, time = 5.13s.
# Batch 58 of 96: Hypervolume = 120.34, time = 3.50s.
# Batch 59 of 96: Hypervolume = 120.42, time = 3.87s.
# Batch 60 of 96: Hypervolume = 120.42, time = 3.73s.
# Batch 61 of 96: Hypervolume = 120.42, time = 4.37s.
# Batch 62 of 96: Hypervolume = 120.42, time = 2.30s.
# Batch 63 of 96: Hypervolume = 120.42, time = 1.52s.
# Batch 64 of 96: Hypervolume = 120.42, time = 2.73s.
# Batch 65 of 96: Hypervolume = 120.42, time = 1.69s.
# Batch 66 of 96: Hypervolume = 120.42, time = 2.04s.
# Batch 67 of 96: Hypervolume = 120.42, time = 3.83s.
# Batch 68 of 96: Hypervolume = 120.42, time = 2.59s.
# Batch 69 of 96: Hypervolume = 120.42, time = 1.76s.
# Batch 70 of 96: Hypervolume = 120.42, time = 2.58s.
# Batch 71 of 96: Hypervolume = 120.42, time = 1.28s.
# Batch 72 of 96: Hypervolume = 120.42, time = 2.15s.
# Batch 73 of 96: Hypervolume = 120.42, time = 1.58s.
# Batch 74 of 96: Hypervolume = 120.42, time = 1.38s.
# Batch 75 of 96: Hypervolume = 120.42, time = 4.54s.
# Batch 76 of 96: Hypervolume = 120.42, time = 1.68s.
# Batch 77 of 96: Hypervolume = 120.42, time = 2.00s.
# Batch 78 of 96: Hypervolume = 120.42, time = 2.52s.
# Batch 79 of 96: Hypervolume = 120.42, time = 3.50s.
# Batch 80 of 96: Hypervolume = 120.42, time = 1.92s.
# Batch 81 of 96: Hypervolume = 120.42, time = 2.25s.
# Batch 82 of 96: Hypervolume = 120.42, time = 2.26s.
# Batch 83 of 96: Hypervolume = 120.42, time = 1.30s.
# Batch 84 of 96: Hypervolume = 120.42, time = 2.81s.
# Batch 85 of 96: Hypervolume = 120.42, time = 1.45s.
# Batch 86 of 96: Hypervolume = 120.42, time = 2.42s.
# Batch 87 of 96: Hypervolume = 120.42, time = 1.56s.
# Batch 88 of 96: Hypervolume = 120.42, time = 2.68s.
# Batch 89 of 96: Hypervolume = 120.42, time = 1.69s.
# Batch 90 of 96: Hypervolume = 120.42, time = 2.45s.
# Batch 91 of 96: Hypervolume = 120.42, time = 2.43s.
# Batch 92 of 96: Hypervolume = 120.42, time = 1.92s.
# Batch 93 of 96: Hypervolume = 120.42, time = 2.63s.
# Batch 94 of 96: Hypervolume = 120.42, time = 3.43s.
# Batch 95 of 96: Hypervolume = 120.42, time = 3.35s.
# Batch 96 of 96: Hypervolume = 120.42, time = 2.97s.
# Time taken in total: 268.42s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 99.15, time = 3.77s.
# Batch  2 of 48: Hypervolume = 103.21, time = 2.35s.
# Batch  3 of 48: Hypervolume = 107.70, time = 2.59s.
# Batch  4 of 48: Hypervolume = 113.05, time = 3.49s.
# Batch  5 of 48: Hypervolume = 116.00, time = 4.42s.
# Batch  6 of 48: Hypervolume = 116.29, time = 4.93s.
# Batch  7 of 48: Hypervolume = 119.19, time = 3.73s.
# Batch  8 of 48: Hypervolume = 119.78, time = 4.29s.
# Batch  9 of 48: Hypervolume = 119.87, time = 3.34s.
# Batch 10 of 48: Hypervolume = 119.87, time = 4.43s.
# Batch 11 of 48: Hypervolume = 119.87, time = 4.07s.
# Batch 12 of 48: Hypervolume = 119.87, time = 3.38s.
# Batch 13 of 48: Hypervolume = 119.87, time = 4.57s.
# Batch 14 of 48: Hypervolume = 119.87, time = 4.31s.
# Batch 15 of 48: Hypervolume = 119.87, time = 4.18s.
# Batch 16 of 48: Hypervolume = 119.87, time = 3.43s.
# Batch 17 of 48: Hypervolume = 119.87, time = 4.32s.
# Batch 18 of 48: Hypervolume = 119.87, time = 3.83s.
# Batch 19 of 48: Hypervolume = 119.87, time = 4.17s.
# Batch 20 of 48: Hypervolume = 119.87, time = 4.36s.
# Batch 21 of 48: Hypervolume = 119.87, time = 4.47s.
# Batch 22 of 48: Hypervolume = 119.87, time = 4.29s.
# Batch 23 of 48: Hypervolume = 119.87, time = 4.35s.
# Batch 24 of 48: Hypervolume = 119.87, time = 2.46s.
# Batch 25 of 48: Hypervolume = 119.87, time = 5.19s.
# Batch 26 of 48: Hypervolume = 119.87, time = 4.96s.
# Batch 27 of 48: Hypervolume = 119.87, time = 3.70s.
# Batch 28 of 48: Hypervolume = 119.87, time = 4.39s.
# Batch 29 of 48: Hypervolume = 119.87, time = 3.31s.
# Batch 30 of 48: Hypervolume = 119.87, time = 4.21s.
# Batch 31 of 48: Hypervolume = 119.87, time = 2.70s.
# Batch 32 of 48: Hypervolume = 119.87, time = 4.48s.
# Batch 33 of 48: Hypervolume = 119.87, time = 3.73s.
# Batch 34 of 48: Hypervolume = 119.87, time = 4.04s.
# Batch 35 of 48: Hypervolume = 119.87, time = 5.02s.
# Batch 36 of 48: Hypervolume = 119.87, time = 5.73s.
# Batch 37 of 48: Hypervolume = 119.87, time = 2.74s.
# Batch 38 of 48: Hypervolume = 119.87, time = 4.72s.
# Batch 39 of 48: Hypervolume = 119.87, time = 5.20s.
# Batch 40 of 48: Hypervolume = 119.87, time = 1.29s.
# Batch 41 of 48: Hypervolume = 119.87, time = 3.87s.
# Batch 42 of 48: Hypervolume = 119.87, time = 5.57s.
# Batch 43 of 48: Hypervolume = 119.87, time = 1.58s.
# Batch 44 of 48: Hypervolume = 119.87, time = 4.97s.
# Batch 45 of 48: Hypervolume = 119.87, time = 2.46s.
# Batch 46 of 48: Hypervolume = 119.87, time = 4.93s.
# Batch 47 of 48: Hypervolume = 119.87, time = 6.72s.
# Batch 48 of 48: Hypervolume = 119.87, time = 2.91s.
# Time taken in total: 191.97s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 99.75, time = 5.80s.
# Batch  2 of 24: Hypervolume = 106.99, time = 4.81s.
# Batch  3 of 24: Hypervolume = 113.82, time = 6.60s.
# Batch  4 of 24: Hypervolume = 118.47, time = 6.46s.
# Batch  5 of 24: Hypervolume = 119.06, time = 6.69s.
# Batch  6 of 24: Hypervolume = 119.07, time = 6.79s.
# Batch  7 of 24: Hypervolume = 119.07, time = 7.33s.
# Batch  8 of 24: Hypervolume = 119.07, time = 6.47s.
# Batch  9 of 24: Hypervolume = 119.07, time = 6.71s.
# Batch 10 of 24: Hypervolume = 119.07, time = 3.90s.
# Batch 11 of 24: Hypervolume = 119.07, time = 8.62s.
# Batch 12 of 24: Hypervolume = 119.07, time = 7.91s.
# Batch 13 of 24: Hypervolume = 119.07, time = 8.95s.
# Batch 14 of 24: Hypervolume = 119.07, time = 8.79s.
# Batch 15 of 24: Hypervolume = 119.07, time = 7.99s.
# Batch 16 of 24: Hypervolume = 119.07, time = 8.63s.
# Batch 17 of 24: Hypervolume = 119.07, time = 10.44s.
# Batch 18 of 24: Hypervolume = 119.07, time = 7.23s.
# Batch 19 of 24: Hypervolume = 119.07, time = 8.79s.
# Batch 20 of 24: Hypervolume = 119.07, time = 9.54s.
# Batch 21 of 24: Hypervolume = 119.07, time = 8.81s.
# Batch 22 of 24: Hypervolume = 119.07, time = 9.43s.
# Batch 23 of 24: Hypervolume = 119.07, time = 9.48s.
# Batch 24 of 24: Hypervolume = 119.07, time = 10.41s.
# Time taken in total: 186.62s.
# Optimizing with NSGA-III
# Time taken in total: 0.73s.
# Optimizing with NSGA-III
# Time taken in total: 0.70s.
# Optimizing with NSGA-III
# Time taken in total: 0.74s.
# Optimizing with NSGA-III
# Time taken in total: 0.74s.
#
# Trial  3 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 98.13, time = 2.49s.
# Batch  2 of 96: Hypervolume = 99.75, time = 1.75s.
# Batch  3 of 96: Hypervolume = 99.77, time = 2.27s.
# Batch  4 of 96: Hypervolume = 102.86, time = 2.65s.
# Batch  5 of 96: Hypervolume = 106.57, time = 3.67s.
# Batch  6 of 96: Hypervolume = 110.36, time = 4.45s.
# Batch  7 of 96: Hypervolume = 113.29, time = 2.54s.
# Batch  8 of 96: Hypervolume = 115.44, time = 2.37s.
# Batch  9 of 96: Hypervolume = 116.20, time = 2.04s.
# Batch 10 of 96: Hypervolume = 116.31, time = 2.26s.
# Batch 11 of 96: Hypervolume = 116.31, time = 1.79s.
# Batch 12 of 96: Hypervolume = 116.31, time = 1.71s.
# Batch 13 of 96: Hypervolume = 116.31, time = 2.09s.
# Batch 14 of 96: Hypervolume = 116.31, time = 2.98s.
# Batch 15 of 96: Hypervolume = 116.31, time = 3.95s.
# Batch 16 of 96: Hypervolume = 116.31, time = 1.97s.
# Batch 17 of 96: Hypervolume = 116.44, time = 3.12s.
# Batch 18 of 96: Hypervolume = 116.44, time = 2.17s.
# Batch 19 of 96: Hypervolume = 116.44, time = 2.90s.
# Batch 20 of 96: Hypervolume = 119.91, time = 3.34s.
# Batch 21 of 96: Hypervolume = 119.91, time = 3.32s.
# Batch 22 of 96: Hypervolume = 119.91, time = 3.61s.
# Batch 23 of 96: Hypervolume = 119.91, time = 4.92s.
# Batch 24 of 96: Hypervolume = 119.91, time = 4.31s.
# Batch 25 of 96: Hypervolume = 119.91, time = 3.92s.
# Batch 26 of 96: Hypervolume = 119.91, time = 2.77s.
# Batch 27 of 96: Hypervolume = 119.91, time = 1.96s.
# Batch 28 of 96: Hypervolume = 119.91, time = 2.99s.
# Batch 29 of 96: Hypervolume = 119.91, time = 4.22s.
# Batch 30 of 96: Hypervolume = 119.91, time = 2.39s.
# Batch 31 of 96: Hypervolume = 119.91, time = 3.96s.
# Batch 32 of 96: Hypervolume = 119.91, time = 4.25s.
# Batch 33 of 96: Hypervolume = 119.91, time = 2.23s.
# Batch 34 of 96: Hypervolume = 119.91, time = 2.80s.
# Batch 35 of 96: Hypervolume = 119.91, time = 4.14s.
# Batch 36 of 96: Hypervolume = 119.91, time = 4.48s.
# Batch 37 of 96: Hypervolume = 119.91, time = 3.03s.
# Batch 38 of 96: Hypervolume = 119.91, time = 3.59s.
# Batch 39 of 96: Hypervolume = 119.91, time = 3.27s.
# Batch 40 of 96: Hypervolume = 119.91, time = 3.65s.
# Batch 41 of 96: Hypervolume = 119.91, time = 4.08s.
# Batch 42 of 96: Hypervolume = 119.91, time = 3.21s.
# Batch 43 of 96: Hypervolume = 119.91, time = 4.42s.
# Batch 44 of 96: Hypervolume = 119.91, time = 2.41s.
# Batch 45 of 96: Hypervolume = 119.91, time = 3.47s.
# Batch 46 of 96: Hypervolume = 119.91, time = 3.28s.
# Batch 47 of 96: Hypervolume = 119.91, time = 2.44s.
# Batch 48 of 96: Hypervolume = 119.91, time = 2.64s.
# Batch 49 of 96: Hypervolume = 119.91, time = 4.19s.
# Batch 50 of 96: Hypervolume = 119.91, time = 3.78s.
# Batch 51 of 96: Hypervolume = 119.91, time = 2.46s.
# Batch 52 of 96: Hypervolume = 119.91, time = 1.83s.
# Batch 53 of 96: Hypervolume = 119.91, time = 1.55s.
# Batch 54 of 96: Hypervolume = 119.91, time = 1.85s.
# Batch 55 of 96: Hypervolume = 119.91, time = 3.26s.
# Batch 56 of 96: Hypervolume = 119.91, time = 4.60s.
# Batch 57 of 96: Hypervolume = 119.91, time = 3.10s.
# Batch 58 of 96: Hypervolume = 119.91, time = 2.37s.
# Batch 59 of 96: Hypervolume = 119.91, time = 3.53s.
# Batch 60 of 96: Hypervolume = 119.91, time = 2.46s.
# Batch 61 of 96: Hypervolume = 119.91, time = 2.04s.
# Batch 62 of 96: Hypervolume = 119.91, time = 3.31s.
# Batch 63 of 96: Hypervolume = 119.91, time = 3.71s.
# Batch 64 of 96: Hypervolume = 119.91, time = 2.67s.
# Batch 65 of 96: Hypervolume = 119.91, time = 3.16s.
# Batch 66 of 96: Hypervolume = 119.91, time = 4.30s.
# Batch 67 of 96: Hypervolume = 119.91, time = 1.97s.
# Batch 68 of 96: Hypervolume = 119.91, time = 3.62s.
# Batch 69 of 96: Hypervolume = 119.91, time = 2.11s.
# Batch 70 of 96: Hypervolume = 119.91, time = 1.80s.
# Batch 71 of 96: Hypervolume = 119.91, time = 1.85s.
# Batch 72 of 96: Hypervolume = 119.91, time = 1.90s.
# Batch 73 of 96: Hypervolume = 119.91, time = 1.85s.
# Batch 74 of 96: Hypervolume = 119.91, time = 1.86s.
# Batch 75 of 96: Hypervolume = 119.91, time = 1.83s.
# Batch 76 of 96: Hypervolume = 119.91, time = 1.55s.
# Batch 77 of 96: Hypervolume = 119.91, time = 2.38s.
# Batch 78 of 96: Hypervolume = 119.91, time = 2.50s.
# Batch 79 of 96: Hypervolume = 119.91, time = 2.20s.
# Batch 80 of 96: Hypervolume = 119.91, time = 2.87s.
# Batch 81 of 96: Hypervolume = 119.91, time = 2.48s.
# Batch 82 of 96: Hypervolume = 119.91, time = 2.14s.
# Batch 83 of 96: Hypervolume = 119.91, time = 1.84s.
# Batch 84 of 96: Hypervolume = 119.91, time = 3.35s.
# Batch 85 of 96: Hypervolume = 119.91, time = 1.45s.
# Batch 86 of 96: Hypervolume = 119.91, time = 1.97s.
# Batch 87 of 96: Hypervolume = 119.91, time = 1.97s.
# Batch 88 of 96: Hypervolume = 119.91, time = 1.32s.
# Batch 89 of 96: Hypervolume = 119.91, time = 2.64s.
# Batch 90 of 96: Hypervolume = 119.91, time = 1.75s.
# Batch 91 of 96: Hypervolume = 119.91, time = 2.25s.
# Batch 92 of 96: Hypervolume = 119.91, time = 2.13s.
# Batch 93 of 96: Hypervolume = 119.91, time = 1.49s.
# Batch 94 of 96: Hypervolume = 119.91, time = 2.26s.
# Batch 95 of 96: Hypervolume = 119.91, time = 2.27s.
# Batch 96 of 96: Hypervolume = 119.91, time = 2.20s.
# Time taken in total: 266.32s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 98.12, time = 2.88s.
# Batch  2 of 48: Hypervolume = 100.20, time = 3.41s.
# Batch  3 of 48: Hypervolume = 103.20, time = 4.41s.
# Batch  4 of 48: Hypervolume = 108.21, time = 4.77s.
# Batch  5 of 48: Hypervolume = 115.44, time = 3.88s.
# Batch  6 of 48: Hypervolume = 115.79, time = 4.48s.
# Batch  7 of 48: Hypervolume = 115.79, time = 3.15s.
# Batch  8 of 48: Hypervolume = 115.79, time = 2.89s.
# Batch  9 of 48: Hypervolume = 119.28, time = 4.41s.
# Batch 10 of 48: Hypervolume = 119.28, time = 3.48s.
# Batch 11 of 48: Hypervolume = 119.28, time = 4.73s.
# Batch 12 of 48: Hypervolume = 119.49, time = 4.98s.
# Batch 13 of 48: Hypervolume = 119.49, time = 4.07s.
# Batch 14 of 48: Hypervolume = 119.49, time = 3.42s.
# Batch 15 of 48: Hypervolume = 119.49, time = 3.95s.
# Batch 16 of 48: Hypervolume = 119.49, time = 3.66s.
# Batch 17 of 48: Hypervolume = 119.49, time = 3.23s.
# Batch 18 of 48: Hypervolume = 119.49, time = 4.19s.
# Batch 19 of 48: Hypervolume = 119.49, time = 3.41s.
# Batch 20 of 48: Hypervolume = 119.49, time = 5.15s.
# Batch 21 of 48: Hypervolume = 119.49, time = 4.74s.
# Batch 22 of 48: Hypervolume = 119.49, time = 5.21s.
# Batch 23 of 48: Hypervolume = 119.49, time = 5.08s.
# Batch 24 of 48: Hypervolume = 119.49, time = 4.87s.
# Batch 25 of 48: Hypervolume = 119.49, time = 3.68s.
# Batch 26 of 48: Hypervolume = 119.49, time = 5.57s.
# Batch 27 of 48: Hypervolume = 119.49, time = 3.55s.
# Batch 28 of 48: Hypervolume = 119.49, time = 5.53s.
# Batch 29 of 48: Hypervolume = 119.49, time = 5.05s.
# Batch 30 of 48: Hypervolume = 119.49, time = 3.69s.
# Batch 31 of 48: Hypervolume = 119.49, time = 4.95s.
# Batch 32 of 48: Hypervolume = 119.49, time = 2.68s.
# Batch 33 of 48: Hypervolume = 119.49, time = 1.82s.
# Batch 34 of 48: Hypervolume = 119.49, time = 5.08s.
# Batch 35 of 48: Hypervolume = 119.49, time = 3.67s.
# Batch 36 of 48: Hypervolume = 119.49, time = 4.56s.
# Batch 37 of 48: Hypervolume = 119.49, time = 3.83s.
# Batch 38 of 48: Hypervolume = 119.49, time = 2.45s.
# Batch 39 of 48: Hypervolume = 119.49, time = 2.80s.
# Batch 40 of 48: Hypervolume = 119.49, time = 3.12s.
# Batch 41 of 48: Hypervolume = 119.49, time = 3.35s.
# Batch 42 of 48: Hypervolume = 119.49, time = 4.13s.
# Batch 43 of 48: Hypervolume = 119.49, time = 4.94s.
# Batch 44 of 48: Hypervolume = 119.49, time = 2.09s.
# Batch 45 of 48: Hypervolume = 119.49, time = 3.34s.
# Batch 46 of 48: Hypervolume = 119.49, time = 1.83s.
# Batch 47 of 48: Hypervolume = 119.66, time = 3.47s.
# Batch 48 of 48: Hypervolume = 119.66, time = 1.76s.
# Time taken in total: 185.40s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 99.08, time = 4.33s.
# Batch  2 of 24: Hypervolume = 104.30, time = 7.14s.
# Batch  3 of 24: Hypervolume = 110.19, time = 6.76s.
# Batch  4 of 24: Hypervolume = 118.97, time = 6.39s.
# Batch  5 of 24: Hypervolume = 119.06, time = 6.31s.
# Batch  6 of 24: Hypervolume = 119.06, time = 6.40s.
# Batch  7 of 24: Hypervolume = 119.06, time = 7.49s.
# Batch  8 of 24: Hypervolume = 119.06, time = 3.03s.
# Batch  9 of 24: Hypervolume = 119.06, time = 6.64s.
# Batch 10 of 24: Hypervolume = 119.06, time = 8.25s.
# Batch 11 of 24: Hypervolume = 119.06, time = 8.16s.
# Batch 12 of 24: Hypervolume = 119.06, time = 7.99s.
# Batch 13 of 24: Hypervolume = 119.15, time = 8.21s.
# Batch 14 of 24: Hypervolume = 119.15, time = 6.73s.
# Batch 15 of 24: Hypervolume = 119.15, time = 9.05s.
# Batch 16 of 24: Hypervolume = 119.15, time = 8.53s.
# Batch 17 of 24: Hypervolume = 119.15, time = 11.92s.
# Batch 18 of 24: Hypervolume = 119.15, time = 10.44s.
# Batch 19 of 24: Hypervolume = 119.15, time = 13.84s.
# Batch 20 of 24: Hypervolume = 119.15, time = 8.55s.
# Batch 21 of 24: Hypervolume = 119.15, time = 9.52s.
# Batch 22 of 24: Hypervolume = 119.15, time = 11.10s.
# Batch 23 of 24: Hypervolume = 119.15, time = 6.66s.
# Batch 24 of 24: Hypervolume = 119.15, time = 8.10s.
# Time taken in total: 191.57s.
# Optimizing with NSGA-III
# Time taken in total: 0.74s.
# Optimizing with NSGA-III
# Time taken in total: 0.71s.
# Optimizing with NSGA-III
# Time taken in total: 0.75s.
# Optimizing with NSGA-III
# Time taken in total: 0.76s.
#
# Trial  4 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 99.14, time = 2.31s.
# Batch  2 of 96: Hypervolume = 100.70, time = 1.57s.
# Batch  3 of 96: Hypervolume = 101.58, time = 1.69s.
# Batch  4 of 96: Hypervolume = 102.68, time = 2.62s.
# Batch  5 of 96: Hypervolume = 105.89, time = 2.02s.
# Batch  6 of 96: Hypervolume = 109.63, time = 2.37s.
# Batch  7 of 96: Hypervolume = 113.17, time = 2.83s.
# Batch  8 of 96: Hypervolume = 116.61, time = 3.64s.
# Batch  9 of 96: Hypervolume = 117.41, time = 2.94s.
# Batch 10 of 96: Hypervolume = 118.40, time = 1.48s.
# Batch 11 of 96: Hypervolume = 118.62, time = 2.13s.
# Batch 12 of 96: Hypervolume = 118.62, time = 4.38s.
# Batch 13 of 96: Hypervolume = 120.03, time = 3.70s.
# Batch 14 of 96: Hypervolume = 120.03, time = 1.89s.
# Batch 15 of 96: Hypervolume = 120.03, time = 2.54s.
# Batch 16 of 96: Hypervolume = 120.03, time = 2.73s.
# Batch 17 of 96: Hypervolume = 120.03, time = 1.67s.
# Batch 18 of 96: Hypervolume = 120.03, time = 2.16s.
# Batch 19 of 96: Hypervolume = 120.03, time = 3.22s.
# Batch 20 of 96: Hypervolume = 120.03, time = 3.92s.
# Batch 21 of 96: Hypervolume = 120.03, time = 2.29s.
# Batch 22 of 96: Hypervolume = 120.03, time = 3.95s.
# Batch 23 of 96: Hypervolume = 120.03, time = 2.07s.
# Batch 24 of 96: Hypervolume = 120.03, time = 2.65s.
# Batch 25 of 96: Hypervolume = 120.03, time = 2.43s.
# Batch 26 of 96: Hypervolume = 120.03, time = 4.53s.
# Batch 27 of 96: Hypervolume = 120.03, time = 2.34s.
# Batch 28 of 96: Hypervolume = 120.03, time = 3.31s.
# Batch 29 of 96: Hypervolume = 120.03, time = 2.80s.
# Batch 30 of 96: Hypervolume = 120.03, time = 3.94s.
# Batch 31 of 96: Hypervolume = 120.03, time = 3.81s.
# Batch 32 of 96: Hypervolume = 120.03, time = 2.62s.
# Batch 33 of 96: Hypervolume = 120.03, time = 3.74s.
# Batch 34 of 96: Hypervolume = 120.03, time = 4.10s.
# Batch 35 of 96: Hypervolume = 120.03, time = 2.94s.
# Batch 36 of 96: Hypervolume = 120.03, time = 3.14s.
# Batch 37 of 96: Hypervolume = 120.03, time = 2.91s.
# Batch 38 of 96: Hypervolume = 120.03, time = 2.50s.
# Batch 39 of 96: Hypervolume = 120.03, time = 2.22s.
# Batch 40 of 96: Hypervolume = 120.03, time = 3.29s.
# Batch 41 of 96: Hypervolume = 120.03, time = 2.56s.
# Batch 42 of 96: Hypervolume = 120.03, time = 2.86s.
# Batch 43 of 96: Hypervolume = 120.03, time = 3.68s.
# Batch 44 of 96: Hypervolume = 120.03, time = 4.82s.
# Batch 45 of 96: Hypervolume = 120.03, time = 4.64s.
# Batch 46 of 96: Hypervolume = 120.03, time = 2.62s.
# Batch 47 of 96: Hypervolume = 120.03, time = 3.34s.
# Batch 48 of 96: Hypervolume = 120.03, time = 2.74s.
# Batch 49 of 96: Hypervolume = 120.03, time = 4.69s.
# Batch 50 of 96: Hypervolume = 120.03, time = 2.13s.
# Batch 51 of 96: Hypervolume = 120.13, time = 4.36s.
# Batch 52 of 96: Hypervolume = 120.13, time = 2.24s.
# Batch 53 of 96: Hypervolume = 120.13, time = 3.93s.
# Batch 54 of 96: Hypervolume = 120.13, time = 4.35s.
# Batch 55 of 96: Hypervolume = 120.13, time = 3.39s.
# Batch 56 of 96: Hypervolume = 120.13, time = 3.65s.
# Batch 57 of 96: Hypervolume = 120.13, time = 2.70s.
# Batch 58 of 96: Hypervolume = 120.13, time = 3.04s.
# Batch 59 of 96: Hypervolume = 120.13, time = 3.44s.
# Batch 60 of 96: Hypervolume = 120.13, time = 2.87s.
# Batch 61 of 96: Hypervolume = 120.13, time = 2.44s.
# Batch 62 of 96: Hypervolume = 120.13, time = 4.84s.
# Batch 63 of 96: Hypervolume = 120.13, time = 3.09s.
# Batch 64 of 96: Hypervolume = 120.13, time = 3.28s.
# Batch 65 of 96: Hypervolume = 120.13, time = 2.05s.
# Batch 66 of 96: Hypervolume = 120.13, time = 4.50s.
# Batch 67 of 96: Hypervolume = 120.13, time = 2.84s.
# Batch 68 of 96: Hypervolume = 120.13, time = 2.99s.
# Batch 69 of 96: Hypervolume = 120.13, time = 3.26s.
# Batch 70 of 96: Hypervolume = 120.13, time = 3.22s.
# Batch 71 of 96: Hypervolume = 120.13, time = 2.23s.
# Batch 72 of 96: Hypervolume = 120.13, time = 2.16s.
# Batch 73 of 96: Hypervolume = 120.13, time = 4.56s.
# Batch 74 of 96: Hypervolume = 120.13, time = 2.72s.
# Batch 75 of 96: Hypervolume = 120.13, time = 2.98s.
# Batch 76 of 96: Hypervolume = 120.13, time = 2.09s.
# Batch 77 of 96: Hypervolume = 120.13, time = 2.67s.
# Batch 78 of 96: Hypervolume = 120.13, time = 2.43s.
# Batch 79 of 96: Hypervolume = 120.13, time = 2.31s.
# Batch 80 of 96: Hypervolume = 120.13, time = 2.30s.
# Batch 81 of 96: Hypervolume = 120.13, time = 3.89s.
# Batch 82 of 96: Hypervolume = 120.13, time = 1.79s.
# Batch 83 of 96: Hypervolume = 120.13, time = 2.19s.
# Batch 84 of 96: Hypervolume = 120.13, time = 1.86s.
# Batch 85 of 96: Hypervolume = 120.13, time = 2.05s.
# Batch 86 of 96: Hypervolume = 120.13, time = 2.78s.
# Batch 87 of 96: Hypervolume = 120.13, time = 1.44s.
# Batch 88 of 96: Hypervolume = 120.13, time = 3.17s.
# Batch 89 of 96: Hypervolume = 120.13, time = 3.06s.
# Batch 90 of 96: Hypervolume = 120.13, time = 2.09s.
# Batch 91 of 96: Hypervolume = 120.13, time = 1.47s.
# Batch 92 of 96: Hypervolume = 120.13, time = 2.07s.
# Batch 93 of 96: Hypervolume = 120.13, time = 2.40s.
# Batch 94 of 96: Hypervolume = 120.13, time = 1.68s.
# Batch 95 of 96: Hypervolume = 120.13, time = 2.05s.
# Batch 96 of 96: Hypervolume = 120.13, time = 2.34s.
# Time taken in total: 276.76s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 99.50, time = 3.57s.
# Batch  2 of 48: Hypervolume = 100.81, time = 4.42s.
# Batch  3 of 48: Hypervolume = 105.63, time = 4.66s.
# Batch  4 of 48: Hypervolume = 110.22, time = 4.89s.
# Batch  5 of 48: Hypervolume = 115.60, time = 5.14s.
# Batch  6 of 48: Hypervolume = 116.12, time = 4.75s.
# Batch  7 of 48: Hypervolume = 116.12, time = 3.60s.
# Batch  8 of 48: Hypervolume = 116.12, time = 4.37s.
# Batch  9 of 48: Hypervolume = 118.91, time = 4.75s.
# Batch 10 of 48: Hypervolume = 118.91, time = 4.78s.
# Batch 11 of 48: Hypervolume = 119.15, time = 5.39s.
# Batch 12 of 48: Hypervolume = 119.43, time = 4.88s.
# Batch 13 of 48: Hypervolume = 119.43, time = 4.67s.
# Batch 14 of 48: Hypervolume = 119.43, time = 4.66s.
# Batch 15 of 48: Hypervolume = 119.43, time = 3.03s.
# Batch 16 of 48: Hypervolume = 119.43, time = 4.25s.
# Batch 17 of 48: Hypervolume = 119.43, time = 4.72s.
# Batch 18 of 48: Hypervolume = 119.43, time = 3.65s.
# Batch 19 of 48: Hypervolume = 119.43, time = 4.65s.
# Batch 20 of 48: Hypervolume = 119.43, time = 5.03s.
# Batch 21 of 48: Hypervolume = 119.43, time = 3.38s.
# Batch 22 of 48: Hypervolume = 119.43, time = 4.36s.
# Batch 23 of 48: Hypervolume = 119.43, time = 2.63s.
# Batch 24 of 48: Hypervolume = 119.43, time = 5.68s.
# Batch 25 of 48: Hypervolume = 119.43, time = 3.95s.
# Batch 26 of 48: Hypervolume = 119.43, time = 4.87s.
# Batch 27 of 48: Hypervolume = 119.43, time = 4.22s.
# Batch 28 of 48: Hypervolume = 119.43, time = 4.82s.
# Batch 29 of 48: Hypervolume = 119.43, time = 4.85s.
# Batch 30 of 48: Hypervolume = 119.43, time = 4.93s.
# Batch 31 of 48: Hypervolume = 119.43, time = 4.49s.
# Batch 32 of 48: Hypervolume = 119.43, time = 3.57s.
# Batch 33 of 48: Hypervolume = 119.43, time = 4.12s.
# Batch 34 of 48: Hypervolume = 119.50, time = 5.43s.
# Batch 35 of 48: Hypervolume = 119.50, time = 2.64s.
# Batch 36 of 48: Hypervolume = 119.50, time = 4.71s.
# Batch 37 of 48: Hypervolume = 119.50, time = 3.98s.
# Batch 38 of 48: Hypervolume = 119.50, time = 2.51s.
# Batch 39 of 48: Hypervolume = 119.50, time = 1.35s.
# Batch 40 of 48: Hypervolume = 119.50, time = 2.61s.
# Batch 41 of 48: Hypervolume = 119.50, time = 2.85s.
# Batch 42 of 48: Hypervolume = 119.50, time = 4.47s.
# Batch 43 of 48: Hypervolume = 119.50, time = 3.63s.
# Batch 44 of 48: Hypervolume = 119.50, time = 1.83s.
# Batch 45 of 48: Hypervolume = 119.50, time = 7.40s.
# Batch 46 of 48: Hypervolume = 119.50, time = 2.99s.
# Batch 47 of 48: Hypervolume = 119.50, time = 2.00s.
# Batch 48 of 48: Hypervolume = 119.50, time = 3.96s.
# Time taken in total: 198.12s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 102.27, time = 6.13s.
# Batch  2 of 24: Hypervolume = 106.54, time = 6.45s.
# Batch  3 of 24: Hypervolume = 111.90, time = 6.72s.
# Batch  4 of 24: Hypervolume = 116.94, time = 7.04s.
# Batch  5 of 24: Hypervolume = 117.60, time = 6.36s.
# Batch  6 of 24: Hypervolume = 117.60, time = 7.12s.
# Batch  7 of 24: Hypervolume = 117.60, time = 7.33s.
# Batch  8 of 24: Hypervolume = 117.60, time = 6.90s.
# Batch  9 of 24: Hypervolume = 117.60, time = 8.05s.
# Batch 10 of 24: Hypervolume = 117.60, time = 8.26s.
# Batch 11 of 24: Hypervolume = 117.60, time = 8.11s.
# Batch 12 of 24: Hypervolume = 117.60, time = 7.84s.
# Batch 13 of 24: Hypervolume = 117.60, time = 8.20s.
# Batch 14 of 24: Hypervolume = 117.60, time = 8.69s.
# Batch 15 of 24: Hypervolume = 117.60, time = 9.45s.
# Batch 16 of 24: Hypervolume = 117.60, time = 8.93s.
# Batch 17 of 24: Hypervolume = 117.60, time = 8.55s.
# Batch 18 of 24: Hypervolume = 117.60, time = 8.87s.
# Batch 19 of 24: Hypervolume = 117.60, time = 10.24s.
# Batch 20 of 24: Hypervolume = 117.60, time = 11.10s.
# Batch 21 of 24: Hypervolume = 117.60, time = 8.87s.
# Batch 22 of 24: Hypervolume = 117.60, time = 10.46s.
# Batch 23 of 24: Hypervolume = 117.60, time = 8.77s.
# Batch 24 of 24: Hypervolume = 117.60, time = 5.15s.
# Time taken in total: 193.61s.
# Optimizing with NSGA-III
# Time taken in total: 0.71s.
# Optimizing with NSGA-III
# Time taken in total: 0.72s.
# Optimizing with NSGA-III
# Time taken in total: 0.86s.
# Optimizing with NSGA-III
# Time taken in total: 1.11s.
#
# Trial  5 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 91.61, time = 1.15s.
# Batch  2 of 96: Hypervolume = 94.32, time = 1.90s.
# Batch  3 of 96: Hypervolume = 95.97, time = 1.78s.
# Batch  4 of 96: Hypervolume = 99.87, time = 2.39s.
# Batch  5 of 96: Hypervolume = 104.81, time = 1.92s.
# Batch  6 of 96: Hypervolume = 108.88, time = 2.38s.
# Batch  7 of 96: Hypervolume = 113.17, time = 2.58s.
# Batch  8 of 96: Hypervolume = 117.04, time = 3.48s.
# Batch  9 of 96: Hypervolume = 117.71, time = 2.18s.
# Batch 10 of 96: Hypervolume = 117.99, time = 2.38s.
# Batch 11 of 96: Hypervolume = 118.04, time = 2.96s.
# Batch 12 of 96: Hypervolume = 118.04, time = 2.61s.
# Batch 13 of 96: Hypervolume = 118.24, time = 2.42s.
# Batch 14 of 96: Hypervolume = 118.24, time = 1.85s.
# Batch 15 of 96: Hypervolume = 118.24, time = 2.87s.
# Batch 16 of 96: Hypervolume = 118.46, time = 1.41s.
# Batch 17 of 96: Hypervolume = 118.46, time = 1.97s.
# Batch 18 of 96: Hypervolume = 118.46, time = 3.29s.
# Batch 19 of 96: Hypervolume = 118.46, time = 4.21s.
# Batch 20 of 96: Hypervolume = 118.46, time = 2.93s.
# Batch 21 of 96: Hypervolume = 118.46, time = 3.10s.
# Batch 22 of 96: Hypervolume = 118.46, time = 2.90s.
# Batch 23 of 96: Hypervolume = 118.46, time = 4.22s.
# Batch 24 of 96: Hypervolume = 118.46, time = 2.19s.
# Batch 25 of 96: Hypervolume = 118.46, time = 4.23s.
# Batch 26 of 96: Hypervolume = 118.46, time = 3.23s.
# Batch 27 of 96: Hypervolume = 118.46, time = 1.84s.
# Batch 28 of 96: Hypervolume = 118.46, time = 2.50s.
# Batch 29 of 96: Hypervolume = 118.46, time = 2.76s.
# Batch 30 of 96: Hypervolume = 118.46, time = 1.95s.
# Batch 31 of 96: Hypervolume = 118.46, time = 4.37s.
# Batch 32 of 96: Hypervolume = 118.46, time = 4.33s.
# Batch 33 of 96: Hypervolume = 118.46, time = 3.94s.
# Batch 34 of 96: Hypervolume = 118.46, time = 1.98s.
# Batch 35 of 96: Hypervolume = 118.46, time = 2.23s.
# Batch 36 of 96: Hypervolume = 118.46, time = 4.24s.
# Batch 37 of 96: Hypervolume = 118.46, time = 2.75s.
# Batch 38 of 96: Hypervolume = 118.46, time = 3.32s.
# Batch 39 of 96: Hypervolume = 118.46, time = 4.22s.
# Batch 40 of 96: Hypervolume = 118.46, time = 3.55s.
# Batch 41 of 96: Hypervolume = 118.46, time = 2.44s.
# Batch 42 of 96: Hypervolume = 118.46, time = 2.69s.
# Batch 43 of 96: Hypervolume = 118.46, time = 2.75s.
# Batch 44 of 96: Hypervolume = 118.46, time = 3.95s.
# Batch 45 of 96: Hypervolume = 118.46, time = 2.43s.
# Batch 46 of 96: Hypervolume = 118.46, time = 2.81s.
# Batch 47 of 96: Hypervolume = 118.46, time = 3.91s.
# Batch 48 of 96: Hypervolume = 118.46, time = 3.48s.
# Batch 49 of 96: Hypervolume = 118.46, time = 2.38s.
# Batch 50 of 96: Hypervolume = 118.46, time = 2.81s.
# Batch 51 of 96: Hypervolume = 118.46, time = 3.48s.
# Batch 52 of 96: Hypervolume = 118.46, time = 4.65s.
# Batch 53 of 96: Hypervolume = 118.46, time = 2.37s.
# Batch 54 of 96: Hypervolume = 118.46, time = 3.31s.
# Batch 55 of 96: Hypervolume = 118.46, time = 2.37s.
# Batch 56 of 96: Hypervolume = 118.46, time = 3.04s.
# Batch 57 of 96: Hypervolume = 118.46, time = 4.12s.
# Batch 58 of 96: Hypervolume = 118.46, time = 2.68s.
# Batch 59 of 96: Hypervolume = 118.46, time = 2.89s.
# Batch 60 of 96: Hypervolume = 118.46, time = 2.54s.
# Batch 61 of 96: Hypervolume = 118.46, time = 2.84s.
# Batch 62 of 96: Hypervolume = 118.46, time = 2.49s.
# Batch 63 of 96: Hypervolume = 118.46, time = 2.93s.
# Batch 64 of 96: Hypervolume = 118.46, time = 2.94s.
# Batch 65 of 96: Hypervolume = 118.46, time = 3.69s.
# Batch 66 of 96: Hypervolume = 118.46, time = 3.64s.
# Batch 67 of 96: Hypervolume = 118.46, time = 3.10s.
# Batch 68 of 96: Hypervolume = 118.46, time = 2.46s.
# Batch 69 of 96: Hypervolume = 118.46, time = 2.94s.
# Batch 70 of 96: Hypervolume = 118.46, time = 3.51s.
# Batch 71 of 96: Hypervolume = 118.46, time = 2.11s.
# Batch 72 of 96: Hypervolume = 118.46, time = 2.67s.
# Batch 73 of 96: Hypervolume = 118.46, time = 2.03s.
# Batch 74 of 96: Hypervolume = 118.46, time = 2.17s.
# Batch 75 of 96: Hypervolume = 118.46, time = 1.74s.
# Batch 76 of 96: Hypervolume = 118.46, time = 2.54s.
# Batch 77 of 96: Hypervolume = 118.46, time = 1.99s.
# Batch 78 of 96: Hypervolume = 118.46, time = 2.02s.
# Batch 79 of 96: Hypervolume = 118.46, time = 2.27s.
# Batch 80 of 96: Hypervolume = 118.46, time = 2.16s.
# Batch 81 of 96: Hypervolume = 118.46, time = 2.67s.
# Batch 82 of 96: Hypervolume = 118.46, time = 1.71s.
# Batch 83 of 96: Hypervolume = 118.46, time = 1.62s.
# Batch 84 of 96: Hypervolume = 118.46, time = 2.16s.
# Batch 85 of 96: Hypervolume = 118.46, time = 2.12s.
# Batch 86 of 96: Hypervolume = 118.46, time = 2.74s.
# Batch 87 of 96: Hypervolume = 118.46, time = 2.80s.
# Batch 88 of 96: Hypervolume = 118.46, time = 3.78s.
# Batch 89 of 96: Hypervolume = 118.46, time = 1.51s.
# Batch 90 of 96: Hypervolume = 118.46, time = 2.35s.
# Batch 91 of 96: Hypervolume = 118.46, time = 2.75s.
# Batch 92 of 96: Hypervolume = 118.46, time = 1.67s.
# Batch 93 of 96: Hypervolume = 118.46, time = 2.92s.
# Batch 94 of 96: Hypervolume = 118.46, time = 1.87s.
# Batch 95 of 96: Hypervolume = 118.46, time = 2.55s.
# Batch 96 of 96: Hypervolume = 118.46, time = 2.09s.
# Time taken in total: 263.22s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 92.11, time = 1.36s.
# Batch  2 of 48: Hypervolume = 95.46, time = 2.37s.
# Batch  3 of 48: Hypervolume = 101.16, time = 2.58s.
# Batch  4 of 48: Hypervolume = 106.99, time = 4.30s.
# Batch  5 of 48: Hypervolume = 112.84, time = 3.96s.
# Batch  6 of 48: Hypervolume = 113.19, time = 1.32s.
# Batch  7 of 48: Hypervolume = 118.39, time = 4.15s.
# Batch  8 of 48: Hypervolume = 119.02, time = 4.19s.
# Batch  9 of 48: Hypervolume = 119.27, time = 3.93s.
# Batch 10 of 48: Hypervolume = 119.27, time = 2.34s.
# Batch 11 of 48: Hypervolume = 119.27, time = 4.64s.
# Batch 12 of 48: Hypervolume = 119.27, time = 4.90s.
# Batch 13 of 48: Hypervolume = 119.27, time = 2.79s.
# Batch 14 of 48: Hypervolume = 119.27, time = 4.66s.
# Batch 15 of 48: Hypervolume = 119.27, time = 3.24s.
# Batch 16 of 48: Hypervolume = 119.27, time = 2.56s.
# Batch 17 of 48: Hypervolume = 119.27, time = 5.14s.
# Batch 18 of 48: Hypervolume = 119.27, time = 4.30s.
# Batch 19 of 48: Hypervolume = 119.27, time = 4.48s.
# Batch 20 of 48: Hypervolume = 119.27, time = 4.89s.
# Batch 21 of 48: Hypervolume = 119.27, time = 4.48s.
# Batch 22 of 48: Hypervolume = 119.27, time = 2.82s.
# Batch 23 of 48: Hypervolume = 119.27, time = 4.65s.
# Batch 24 of 48: Hypervolume = 119.27, time = 5.08s.
# Batch 25 of 48: Hypervolume = 119.27, time = 3.53s.
# Batch 26 of 48: Hypervolume = 119.27, time = 5.33s.
# Batch 27 of 48: Hypervolume = 119.27, time = 4.79s.
# Batch 28 of 48: Hypervolume = 119.27, time = 4.21s.
# Batch 29 of 48: Hypervolume = 119.27, time = 2.74s.
# Batch 30 of 48: Hypervolume = 119.27, time = 4.52s.
# Batch 31 of 48: Hypervolume = 119.27, time = 5.11s.
# Batch 32 of 48: Hypervolume = 119.27, time = 4.09s.
# Batch 33 of 48: Hypervolume = 119.27, time = 3.27s.
# Batch 34 of 48: Hypervolume = 119.27, time = 5.82s.
# Batch 35 of 48: Hypervolume = 119.27, time = 5.29s.
# Batch 36 of 48: Hypervolume = 119.27, time = 6.26s.
# Batch 37 of 48: Hypervolume = 119.27, time = 5.86s.
# Batch 38 of 48: Hypervolume = 119.27, time = 4.95s.
# Batch 39 of 48: Hypervolume = 119.27, time = 5.24s.
# Batch 40 of 48: Hypervolume = 119.27, time = 3.79s.
# Batch 41 of 48: Hypervolume = 119.27, time = 1.75s.
# Batch 42 of 48: Hypervolume = 119.27, time = 5.01s.
# Batch 43 of 48: Hypervolume = 119.27, time = 6.86s.
# Batch 44 of 48: Hypervolume = 119.27, time = 6.10s.
# Batch 45 of 48: Hypervolume = 119.27, time = 2.85s.
# Batch 46 of 48: Hypervolume = 119.27, time = 6.00s.
# Batch 47 of 48: Hypervolume = 119.27, time = 2.84s.
# Batch 48 of 48: Hypervolume = 119.27, time = 3.00s.
# Time taken in total: 198.33s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 93.28, time = 5.82s.
# Batch  2 of 24: Hypervolume = 102.80, time = 6.41s.
# Batch  3 of 24: Hypervolume = 110.08, time = 7.66s.
# Batch  4 of 24: Hypervolume = 117.83, time = 6.10s.
# Batch  5 of 24: Hypervolume = 117.83, time = 5.15s.
# Batch  6 of 24: Hypervolume = 117.83, time = 6.88s.
# Batch  7 of 24: Hypervolume = 117.83, time = 7.01s.
# Batch  8 of 24: Hypervolume = 117.83, time = 7.52s.
# Batch  9 of 24: Hypervolume = 117.83, time = 7.11s.
# Batch 10 of 24: Hypervolume = 118.02, time = 8.12s.
# Batch 11 of 24: Hypervolume = 118.02, time = 8.43s.
# Batch 12 of 24: Hypervolume = 118.02, time = 8.72s.
# Batch 13 of 24: Hypervolume = 118.02, time = 10.24s.
# Batch 14 of 24: Hypervolume = 118.02, time = 9.41s.
# Batch 15 of 24: Hypervolume = 118.02, time = 10.36s.
# Batch 16 of 24: Hypervolume = 118.02, time = 10.58s.
# Batch 17 of 24: Hypervolume = 118.02, time = 8.63s.
# Batch 18 of 24: Hypervolume = 118.02, time = 10.25s.
# Batch 19 of 24: Hypervolume = 118.02, time = 9.77s.
# Batch 20 of 24: Hypervolume = 118.02, time = 9.59s.
# Batch 21 of 24: Hypervolume = 118.02, time = 9.62s.
# Batch 22 of 24: Hypervolume = 118.02, time = 9.69s.
# Batch 23 of 24: Hypervolume = 118.02, time = 8.99s.
# Batch 24 of 24: Hypervolume = 118.02, time = 10.20s.
# Time taken in total: 202.28s.
# Optimizing with NSGA-III
# Time taken in total: 0.80s.
# Optimizing with NSGA-III
# Time taken in total: 0.76s.
# Optimizing with NSGA-III
# Time taken in total: 0.76s.
# Optimizing with NSGA-III
# Time taken in total: 0.85s.
#
# Trial  6 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 102.31, time = 2.83s.
# Batch  2 of 96: Hypervolume = 104.23, time = 3.83s.
# Batch  3 of 96: Hypervolume = 106.61, time = 2.36s.
# Batch  4 of 96: Hypervolume = 107.79, time = 2.64s.
# Batch  5 of 96: Hypervolume = 110.92, time = 3.58s.
# Batch  6 of 96: Hypervolume = 114.10, time = 2.24s.
# Batch  7 of 96: Hypervolume = 117.39, time = 4.03s.
# Batch  8 of 96: Hypervolume = 117.67, time = 2.56s.
# Batch  9 of 96: Hypervolume = 117.69, time = 1.79s.
# Batch 10 of 96: Hypervolume = 118.27, time = 3.00s.
# Batch 11 of 96: Hypervolume = 118.27, time = 2.13s.
# Batch 12 of 96: Hypervolume = 118.27, time = 2.74s.
# Batch 13 of 96: Hypervolume = 118.27, time = 1.84s.
# Batch 14 of 96: Hypervolume = 118.27, time = 1.94s.
# Batch 15 of 96: Hypervolume = 118.27, time = 1.65s.
# Batch 16 of 96: Hypervolume = 118.67, time = 2.55s.
# Batch 17 of 96: Hypervolume = 118.77, time = 2.01s.
# Batch 18 of 96: Hypervolume = 118.77, time = 1.95s.
# Batch 19 of 96: Hypervolume = 118.77, time = 2.94s.
# ...
# Batch 45 of 96: Hypervolume = 120.04, time = 3.22s.
# Batch 46 of 96: Hypervolume = 120.04, time = 3.34s.
# Batch 47 of 96: Hypervolume = 120.04, time = 4.05s.
# Batch 48 of 96: Hypervolume = 120.04, time = 3.93s.
# Batch 49 of 96: Hypervolume = 120.04, time = 2.39s.
# Batch 50 of 96: Hypervolume = 120.04, time = 3.47s.
# Batch 51 of 96: Hypervolume = 120.04, time = 4.36s.
# Batch 52 of 96: Hypervolume = 120.04, time = 3.33s.
# Batch 53 of 96: Hypervolume = 120.04, time = 3.27s.
# Batch 54 of 96: Hypervolume = 120.04, time = 4.14s.
# Batch 55 of 96: Hypervolume = 120.04, time = 2.60s.
# Batch 56 of 96: Hypervolume = 120.04, time = 2.80s.
# Batch 57 of 96: Hypervolume = 120.04, time = 2.73s.
# Batch 58 of 96: Hypervolume = 120.04, time = 3.10s.
# Batch 59 of 96: Hypervolume = 120.04, time = 2.97s.
# Batch 60 of 96: Hypervolume = 120.04, time = 2.85s.
# Batch 61 of 96: Hypervolume = 120.04, time = 3.63s.
# Batch 62 of 96: Hypervolume = 120.04, time = 3.49s.
# Batch 63 of 96: Hypervolume = 120.04, time = 2.14s.
# Batch 64 of 96: Hypervolume = 120.04, time = 2.03s.
# Batch 65 of 96: Hypervolume = 120.04, time = 2.40s.
# Batch 66 of 96: Hypervolume = 120.04, time = 2.54s.
# Batch 67 of 96: Hypervolume = 120.04, time = 2.10s.
# Batch 68 of 96: Hypervolume = 120.04, time = 3.33s.
# Batch 69 of 96: Hypervolume = 120.04, time = 1.06s.
# Batch 70 of 96: Hypervolume = 120.04, time = 1.92s.
# Batch 71 of 96: Hypervolume = 120.04, time = 1.80s.
# Batch 72 of 96: Hypervolume = 120.04, time = 1.96s.
# Batch 73 of 96: Hypervolume = 120.04, time = 3.29s.
# Batch 74 of 96: Hypervolume = 120.04, time = 1.99s.
# Batch 75 of 96: Hypervolume = 120.04, time = 2.10s.
# Batch 76 of 96: Hypervolume = 120.04, time = 2.32s.
# Batch 77 of 96: Hypervolume = 120.04, time = 2.53s.
# Batch 78 of 96: Hypervolume = 120.04, time = 2.72s.
# Batch 79 of 96: Hypervolume = 120.04, time = 1.69s.
# Batch 80 of 96: Hypervolume = 120.04, time = 1.76s.
# Batch 81 of 96: Hypervolume = 120.04, time = 2.73s.
# Batch 82 of 96: Hypervolume = 120.04, time = 2.09s.
# Batch 83 of 96: Hypervolume = 120.04, time = 1.59s.
# Batch 84 of 96: Hypervolume = 120.04, time = 2.01s.
# Batch 85 of 96: Hypervolume = 120.04, time = 2.52s.
# Batch 86 of 96: Hypervolume = 120.04, time = 2.77s.
# Batch 87 of 96: Hypervolume = 120.04, time = 2.85s.
# Batch 88 of 96: Hypervolume = 120.04, time = 2.05s.
# Batch 89 of 96: Hypervolume = 120.04, time = 2.15s.
# Batch 90 of 96: Hypervolume = 120.04, time = 2.33s.
# Batch 91 of 96: Hypervolume = 120.04, time = 4.99s.
# Batch 92 of 96: Hypervolume = 120.04, time = 1.73s.
# Batch 93 of 96: Hypervolume = 120.04, time = 1.99s.
# Batch 94 of 96: Hypervolume = 120.04, time = 2.50s.
# Batch 95 of 96: Hypervolume = 120.04, time = 2.25s.
# Batch 96 of 96: Hypervolume = 120.04, time = 2.40s.
# Time taken in total: 287.47s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 103.31, time = 3.15s.
# Batch  2 of 48: Hypervolume = 103.53, time = 4.56s.
# Batch  3 of 48: Hypervolume = 105.35, time = 4.13s.
# Batch  4 of 48: Hypervolume = 110.36, time = 5.01s.
# Batch  5 of 48: Hypervolume = 114.94, time = 5.17s.
# Batch  6 of 48: Hypervolume = 117.88, time = 4.25s.
# Batch  7 of 48: Hypervolume = 118.22, time = 3.07s.
# Batch  8 of 48: Hypervolume = 118.22, time = 4.73s.
# Batch  9 of 48: Hypervolume = 118.22, time = 4.31s.
# Batch 10 of 48: Hypervolume = 118.22, time = 4.43s.
# Batch 11 of 48: Hypervolume = 118.22, time = 4.89s.
# Batch 12 of 48: Hypervolume = 118.22, time = 4.57s.
# Batch 13 of 48: Hypervolume = 118.22, time = 4.89s.
# Batch 14 of 48: Hypervolume = 118.50, time = 4.90s.
# Batch 15 of 48: Hypervolume = 118.50, time = 4.88s.
# Batch 16 of 48: Hypervolume = 118.50, time = 4.60s.
# Batch 17 of 48: Hypervolume = 118.50, time = 5.01s.
# Batch 18 of 48: Hypervolume = 118.82, time = 4.55s.
# Batch 19 of 48: Hypervolume = 118.82, time = 4.74s.
# Batch 20 of 48: Hypervolume = 118.82, time = 4.18s.
# Batch 21 of 48: Hypervolume = 118.82, time = 5.18s.
# Batch 22 of 48: Hypervolume = 118.82, time = 4.73s.
# Batch 23 of 48: Hypervolume = 118.82, time = 4.66s.
# Batch 24 of 48: Hypervolume = 118.82, time = 4.63s.
# Batch 25 of 48: Hypervolume = 118.82, time = 4.64s.
# Batch 26 of 48: Hypervolume = 118.82, time = 5.15s.
# Batch 27 of 48: Hypervolume = 118.82, time = 5.10s.
# Batch 28 of 48: Hypervolume = 118.82, time = 4.40s.
# Batch 29 of 48: Hypervolume = 118.82, time = 4.71s.
# Batch 30 of 48: Hypervolume = 118.82, time = 5.77s.
# Batch 31 of 48: Hypervolume = 118.82, time = 4.94s.
# Batch 32 of 48: Hypervolume = 118.82, time = 5.24s.
# Batch 33 of 48: Hypervolume = 118.82, time = 4.52s.
# Batch 34 of 48: Hypervolume = 118.82, time = 5.29s.
# Batch 35 of 48: Hypervolume = 118.82, time = 2.05s.
# Batch 36 of 48: Hypervolume = 118.82, time = 5.02s.
# Batch 37 of 48: Hypervolume = 118.82, time = 2.40s.
# Batch 38 of 48: Hypervolume = 118.82, time = 2.28s.
# Batch 39 of 48: Hypervolume = 118.82, time = 4.11s.
# Batch 40 of 48: Hypervolume = 118.82, time = 4.03s.
# Batch 41 of 48: Hypervolume = 118.82, time = 4.94s.
# Batch 42 of 48: Hypervolume = 118.82, time = 3.24s.
# Batch 43 of 48: Hypervolume = 118.82, time = 1.94s.
# Batch 44 of 48: Hypervolume = 118.82, time = 2.82s.
# Batch 45 of 48: Hypervolume = 118.82, time = 5.50s.
# Batch 46 of 48: Hypervolume = 118.82, time = 4.65s.
# Batch 47 of 48: Hypervolume = 118.82, time = 2.10s.
# Batch 48 of 48: Hypervolume = 118.82, time = 3.98s.
# Time taken in total: 208.09s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 103.82, time = 5.59s.
# Batch  2 of 24: Hypervolume = 110.40, time = 5.91s.
# Batch  3 of 24: Hypervolume = 115.51, time = 5.66s.
# Batch  4 of 24: Hypervolume = 118.70, time = 5.50s.
# Batch  5 of 24: Hypervolume = 118.70, time = 6.20s.
# Batch  6 of 24: Hypervolume = 118.95, time = 7.20s.
# Batch  7 of 24: Hypervolume = 118.95, time = 7.41s.
# Batch  8 of 24: Hypervolume = 119.01, time = 7.95s.
# Batch  9 of 24: Hypervolume = 119.01, time = 7.84s.
# Batch 10 of 24: Hypervolume = 119.01, time = 8.40s.
# Batch 11 of 24: Hypervolume = 119.01, time = 6.43s.
# Batch 12 of 24: Hypervolume = 119.01, time = 7.75s.
# Batch 13 of 24: Hypervolume = 119.01, time = 7.24s.
# Batch 14 of 24: Hypervolume = 119.01, time = 7.57s.
# Batch 15 of 24: Hypervolume = 119.01, time = 8.31s.
# Batch 16 of 24: Hypervolume = 119.01, time = 8.70s.
# Batch 17 of 24: Hypervolume = 119.01, time = 9.92s.
# Batch 18 of 24: Hypervolume = 119.01, time = 9.01s.
# Batch 19 of 24: Hypervolume = 119.01, time = 6.72s.
# Batch 20 of 24: Hypervolume = 119.01, time = 9.94s.
# Batch 21 of 24: Hypervolume = 119.01, time = 11.41s.
# Batch 22 of 24: Hypervolume = 119.01, time = 11.68s.
# Batch 23 of 24: Hypervolume = 119.01, time = 10.07s.
# Batch 24 of 24: Hypervolume = 119.01, time = 10.84s.
# Time taken in total: 193.28s.
# Optimizing with NSGA-III
# Time taken in total: 0.72s.
# Optimizing with NSGA-III
# Time taken in total: 0.69s.
# Optimizing with NSGA-III
# Time taken in total: 0.82s.
# Optimizing with NSGA-III
# Time taken in total: 0.69s.
#
# Trial 10 of 10 for problem <class '__main__.Problem_ZDT1'> with d = 8
# Optimizing with qNEHVI
# Batch  1 of 96: Hypervolume = 94.09, time = 1.63s.
# Batch  2 of 96: Hypervolume = 95.21, time = 1.35s.
# Batch  3 of 96: Hypervolume = 97.22, time = 1.70s.
# Batch  4 of 96: Hypervolume = 102.37, time = 1.63s.
# Batch  5 of 96: Hypervolume = 105.66, time = 1.62s.
# Batch  6 of 96: Hypervolume = 110.40, time = 1.98s.
# Batch  7 of 96: Hypervolume = 113.62, time = 2.69s.
# Batch  8 of 96: Hypervolume = 117.56, time = 1.94s.
# Batch  9 of 96: Hypervolume = 118.77, time = 1.50s.
# Batch 10 of 96: Hypervolume = 119.04, time = 2.28s.
# Batch 11 of 96: Hypervolume = 119.28, time = 2.44s.
# Batch 12 of 96: Hypervolume = 119.28, time = 2.73s.
# Batch 13 of 96: Hypervolume = 119.28, time = 2.23s.
# Batch 14 of 96: Hypervolume = 119.28, time = 1.82s.
# Batch 15 of 96: Hypervolume = 119.28, time = 1.69s.
# Batch 16 of 96: Hypervolume = 119.28, time = 2.62s.
# Batch 17 of 96: Hypervolume = 119.52, time = 1.79s.
# Batch 18 of 96: Hypervolume = 119.52, time = 2.05s.
# Batch 19 of 96: Hypervolume = 119.52, time = 3.04s.
# Batch 20 of 96: Hypervolume = 119.52, time = 4.81s.
# Batch 21 of 96: Hypervolume = 119.52, time = 3.72s.
# Batch 22 of 96: Hypervolume = 119.52, time = 4.16s.
# Batch 23 of 96: Hypervolume = 119.52, time = 2.89s.
# Batch 24 of 96: Hypervolume = 119.52, time = 2.99s.
# Batch 25 of 96: Hypervolume = 119.52, time = 2.16s.
# Batch 26 of 96: Hypervolume = 119.52, time = 4.46s.
# Batch 27 of 96: Hypervolume = 119.52, time = 3.00s.
# Batch 28 of 96: Hypervolume = 119.52, time = 3.40s.
# Batch 29 of 96: Hypervolume = 119.52, time = 2.99s.
# Batch 30 of 96: Hypervolume = 119.52, time = 4.44s.
# Batch 31 of 96: Hypervolume = 119.52, time = 4.39s.
# Batch 32 of 96: Hypervolume = 119.52, time = 4.77s.
# Batch 33 of 96: Hypervolume = 119.52, time = 5.14s.
# Batch 34 of 96: Hypervolume = 119.52, time = 4.88s.
# Batch 35 of 96: Hypervolume = 119.52, time = 5.21s.
# Batch 36 of 96: Hypervolume = 119.52, time = 3.13s.
# Batch 37 of 96: Hypervolume = 119.52, time = 4.96s.
# Batch 38 of 96: Hypervolume = 119.52, time = 3.05s.
# Batch 39 of 96: Hypervolume = 119.52, time = 3.14s.
# Batch 40 of 96: Hypervolume = 119.52, time = 3.71s.
# Batch 41 of 96: Hypervolume = 119.52, time = 5.46s.
# Batch 42 of 96: Hypervolume = 119.52, time = 2.93s.
# Batch 43 of 96: Hypervolume = 119.52, time = 3.42s.
# Batch 44 of 96: Hypervolume = 119.52, time = 3.72s.
# Batch 45 of 96: Hypervolume = 119.52, time = 4.70s.
# Batch 46 of 96: Hypervolume = 119.52, time = 2.57s.
# Batch 47 of 96: Hypervolume = 119.52, time = 3.45s.
# Batch 48 of 96: Hypervolume = 119.52, time = 3.08s.
# Batch 49 of 96: Hypervolume = 119.52, time = 3.34s.
# Batch 50 of 96: Hypervolume = 119.52, time = 2.88s.
# Batch 51 of 96: Hypervolume = 119.52, time = 4.75s.
# Batch 52 of 96: Hypervolume = 119.52, time = 5.09s.
# Batch 53 of 96: Hypervolume = 119.52, time = 4.62s.
# Batch 54 of 96: Hypervolume = 119.52, time = 3.34s.
# Batch 55 of 96: Hypervolume = 119.52, time = 2.70s.
# Batch 56 of 96: Hypervolume = 119.52, time = 4.09s.
# Batch 57 of 96: Hypervolume = 119.52, time = 3.48s.
# Batch 58 of 96: Hypervolume = 119.52, time = 2.39s.
# Batch 59 of 96: Hypervolume = 119.52, time = 2.95s.
# Batch 60 of 96: Hypervolume = 119.52, time = 3.60s.
# Batch 61 of 96: Hypervolume = 119.52, time = 4.01s.
# Batch 62 of 96: Hypervolume = 119.52, time = 3.15s.
# Batch 63 of 96: Hypervolume = 119.52, time = 3.57s.
# Batch 64 of 96: Hypervolume = 119.52, time = 2.93s.
# Batch 65 of 96: Hypervolume = 119.52, time = 2.48s.
# Batch 66 of 96: Hypervolume = 119.52, time = 3.42s.
# Batch 67 of 96: Hypervolume = 119.52, time = 2.43s.
# Batch 68 of 96: Hypervolume = 119.52, time = 3.02s.
# Batch 69 of 96: Hypervolume = 119.52, time = 3.08s.
# Batch 70 of 96: Hypervolume = 119.52, time = 2.97s.
# Batch 71 of 96: Hypervolume = 119.52, time = 2.94s.
# Batch 72 of 96: Hypervolume = 119.52, time = 2.22s.
# Batch 73 of 96: Hypervolume = 119.52, time = 2.05s.
# Batch 74 of 96: Hypervolume = 119.52, time = 4.88s.
# Batch 75 of 96: Hypervolume = 119.52, time = 2.18s.
# Batch 76 of 96: Hypervolume = 119.52, time = 2.32s.
# Batch 77 of 96: Hypervolume = 119.52, time = 3.30s.
# Batch 78 of 96: Hypervolume = 119.52, time = 4.04s.
# Batch 79 of 96: Hypervolume = 119.52, time = 2.56s.
# Batch 80 of 96: Hypervolume = 119.52, time = 2.34s.
# Batch 81 of 96: Hypervolume = 119.52, time = 2.06s.
# Batch 82 of 96: Hypervolume = 119.52, time = 2.12s.
# Batch 83 of 96: Hypervolume = 119.52, time = 2.34s.
# Batch 84 of 96: Hypervolume = 119.52, time = 3.29s.
# Batch 85 of 96: Hypervolume = 119.52, time = 1.72s.
# Batch 86 of 96: Hypervolume = 119.52, time = 2.02s.
# Batch 87 of 96: Hypervolume = 119.52, time = 3.24s.
# Batch 88 of 96: Hypervolume = 119.52, time = 2.49s.
# Batch 89 of 96: Hypervolume = 119.52, time = 1.91s.
# Batch 90 of 96: Hypervolume = 119.52, time = 2.18s.
# Batch 91 of 96: Hypervolume = 119.52, time = 3.04s.
# Batch 92 of 96: Hypervolume = 119.52, time = 3.67s.
# Batch 93 of 96: Hypervolume = 119.52, time = 2.63s.
# Batch 94 of 96: Hypervolume = 119.52, time = 2.47s.
# Batch 95 of 96: Hypervolume = 119.52, time = 1.96s.
# Batch 96 of 96: Hypervolume = 119.52, time = 3.83s.
# Time taken in total: 293.60s.
# Optimizing with qNEHVI
# Batch  1 of 48: Hypervolume = 93.99, time = 1.96s.
# Batch  2 of 48: Hypervolume = 98.06, time = 2.79s.
# Batch  3 of 48: Hypervolume = 101.89, time = 3.38s.
# Batch  4 of 48: Hypervolume = 109.33, time = 3.60s.
# Batch  5 of 48: Hypervolume = 109.50, time = 5.20s.
# Batch  6 of 48: Hypervolume = 114.96, time = 4.64s.
# Batch  7 of 48: Hypervolume = 118.52, time = 5.11s.
# Batch  8 of 48: Hypervolume = 119.35, time = 5.27s.
# Batch  9 of 48: Hypervolume = 119.48, time = 4.73s.
# Batch 10 of 48: Hypervolume = 119.48, time = 4.90s.
# Batch 11 of 48: Hypervolume = 119.48, time = 4.60s.
# Batch 12 of 48: Hypervolume = 119.48, time = 4.46s.
# Batch 13 of 48: Hypervolume = 119.52, time = 4.29s.
# Batch 14 of 48: Hypervolume = 119.52, time = 2.05s.
# Batch 15 of 48: Hypervolume = 119.52, time = 4.53s.
# Batch 16 of 48: Hypervolume = 119.52, time = 4.71s.
# Batch 17 of 48: Hypervolume = 119.52, time = 4.56s.
# Batch 18 of 48: Hypervolume = 119.52, time = 4.09s.
# Batch 19 of 48: Hypervolume = 119.52, time = 3.65s.
# Batch 20 of 48: Hypervolume = 119.52, time = 4.91s.
# Batch 21 of 48: Hypervolume = 119.52, time = 3.68s.
# Batch 22 of 48: Hypervolume = 119.52, time = 5.17s.
# Batch 23 of 48: Hypervolume = 119.52, time = 4.73s.
# Batch 24 of 48: Hypervolume = 119.52, time = 5.26s.
# Batch 25 of 48: Hypervolume = 119.52, time = 5.15s.
# Batch 26 of 48: Hypervolume = 119.52, time = 4.81s.
# Batch 27 of 48: Hypervolume = 119.52, time = 3.93s.
# Batch 28 of 48: Hypervolume = 119.52, time = 3.86s.
# Batch 29 of 48: Hypervolume = 119.52, time = 5.63s.
# Batch 30 of 48: Hypervolume = 119.52, time = 3.48s.
# Batch 31 of 48: Hypervolume = 119.52, time = 3.58s.
# Batch 32 of 48: Hypervolume = 119.52, time = 3.24s.
# Batch 33 of 48: Hypervolume = 119.52, time = 5.47s.
# Batch 34 of 48: Hypervolume = 119.52, time = 3.10s.
# Batch 35 of 48: Hypervolume = 119.52, time = 2.73s.
# Batch 36 of 48: Hypervolume = 119.52, time = 5.38s.
# Batch 37 of 48: Hypervolume = 119.52, time = 2.31s.
# Batch 38 of 48: Hypervolume = 119.52, time = 4.83s.
# Batch 39 of 48: Hypervolume = 119.52, time = 4.65s.
# Batch 40 of 48: Hypervolume = 119.52, time = 4.82s.
# Batch 41 of 48: Hypervolume = 119.52, time = 3.74s.
# Batch 42 of 48: Hypervolume = 119.52, time = 2.99s.
# Batch 43 of 48: Hypervolume = 119.52, time = 3.53s.
# Batch 44 of 48: Hypervolume = 119.52, time = 4.09s.
# Batch 45 of 48: Hypervolume = 119.52, time = 2.63s.
# Batch 46 of 48: Hypervolume = 119.52, time = 6.20s.
# Batch 47 of 48: Hypervolume = 119.52, time = 2.23s.
# Batch 48 of 48: Hypervolume = 119.52, time = 3.26s.
# Time taken in total: 197.93s.
# Optimizing with qNEHVI
# Batch  1 of 24: Hypervolume = 94.12, time = 2.56s.
# Batch  2 of 24: Hypervolume = 103.31, time = 5.64s.
# Batch  3 of 24: Hypervolume = 113.04, time = 5.94s.
# Batch  4 of 24: Hypervolume = 118.42, time = 6.42s.
# Batch  5 of 24: Hypervolume = 118.70, time = 6.64s.
# Batch  6 of 24: Hypervolume = 118.70, time = 6.44s.
# Batch  7 of 24: Hypervolume = 118.70, time = 7.34s.
# Batch  8 of 24: Hypervolume = 118.70, time = 7.44s.
# Batch  9 of 24: Hypervolume = 118.70, time = 6.53s.
# Batch 10 of 24: Hypervolume = 118.70, time = 8.41s.
# Batch 11 of 24: Hypervolume = 118.70, time = 8.45s.
# Batch 12 of 24: Hypervolume = 118.70, time = 7.98s.
# Batch 13 of 24: Hypervolume = 118.70, time = 9.17s.
# Batch 14 of 24: Hypervolume = 118.70, time = 8.70s.
# Batch 15 of 24: Hypervolume = 118.70, time = 8.25s.
# Batch 16 of 24: Hypervolume = 118.70, time = 6.68s.
# Batch 17 of 24: Hypervolume = 118.70, time = 8.86s.
# Batch 18 of 24: Hypervolume = 118.70, time = 9.42s.
# Batch 19 of 24: Hypervolume = 118.70, time = 9.99s.
# Batch 20 of 24: Hypervolume = 118.70, time = 9.86s.
# Batch 21 of 24: Hypervolume = 118.70, time = 7.43s.
# Batch 22 of 24: Hypervolume = 118.70, time = 9.40s.
# Batch 23 of 24: Hypervolume = 118.70, time = 9.67s.
# Batch 24 of 24: Hypervolume = 118.70, time = 4.54s.
# Time taken in total: 181.81s.
# Optimizing with NSGA-III
# Time taken in total: 0.76s.
# Optimizing with NSGA-III
# Time taken in total: 0.68s.
# Optimizing with NSGA-III
# Time taken in total: 0.73s.
# Optimizing with NSGA-III
# Time taken in total: 0.95s.
# ALL DONE!

# %%
ref_point = torch.tensor([11,11], **tkwargs)

N_TRIALS = 10
verbose = True
N_BATCH = 24
BATCH_SIZE = 8

hvs_qnehvi_all0 = []
hvs_qnehvi_all1 = []
hvs_qnehvi_all2 = []
hvs_qnehvi_all3 = []

hvs_nsga3_all0 = []
hvs_nsga3_all1 = []
hvs_nsga3_all2 = []
hvs_nsga3_all3 = []

problem = Problem_ZDT2
problemname = 'ZDT2'

# main loop for each trial/run, random_state will be trial number
for trial in range(1, 10 + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} for problem {problem} with d = {dimensions}\n", end="")

    # initialize with a 2*(d+1) sample set

    initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

    ###############    
    
    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.01, verbose=verbose)
    hvs_qnehvi_all0.append(hvs_qnehvi)
        
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.025, verbose=verbose)
    hvs_qnehvi_all1.append(hvs_qnehvi)

    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.05, verbose=verbose)
    hvs_qnehvi_all2.append(hvs_qnehvi)
    
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.1, verbose=verbose)
    hvs_qnehvi_all3.append(hvs_qnehvi)
    
    ###############    

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.01, verbose=False)
    hvs_nsga3_all0.append(hvs_nsga3) 
    
    ###############

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.025, verbose=False)
    hvs_nsga3_all1.append(hvs_nsga3) 
    
    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.05, verbose=False)
    hvs_nsga3_all2.append(hvs_nsga3) 

    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.1, verbose=False)
    hvs_nsga3_all3.append(hvs_nsga3) 
    
    ###############

savetxt(f"{problemname}_hvs_qnehvi_noise1.csv", hvs_qnehvi_all0, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise2.csv", hvs_qnehvi_all1, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise3.csv", hvs_qnehvi_all2, delimiter=',')    
savetxt(f"{problemname}_hvs_qnehvi_noise4.csv", hvs_qnehvi_all3, delimiter=',')    

savetxt(f"{problemname}_hvs_nsga3_noise1.csv", hvs_nsga3_all0, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all1, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all2, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise4.csv", hvs_nsga3_all3, delimiter=',')
    
print("ALL DONE!")

# %%
ref_point = torch.tensor([11,11], **tkwargs)

N_TRIALS = 10
verbose = True
N_BATCH = 24
BATCH_SIZE = 8

hvs_qnehvi_all0 = []
hvs_qnehvi_all1 = []
hvs_qnehvi_all2 = []
hvs_qnehvi_all3 = []

hvs_nsga3_all0 = []
hvs_nsga3_all1 = []
hvs_nsga3_all2 = []
hvs_nsga3_all3 = []

problem = Problem_ZDT3
problemname = 'ZDT3'

# main loop for each trial/run, random_state will be trial number
for trial in range(1, 10 + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} for problem {problem} with d = {dimensions}\n", end="")

    # initialize with a 2*(d+1) sample set

    initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

    ###############    
    
    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.01, verbose=verbose)
    hvs_qnehvi_all0.append(hvs_qnehvi)
        
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.025, verbose=verbose)
    hvs_qnehvi_all1.append(hvs_qnehvi)

    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.05, verbose=verbose)
    hvs_qnehvi_all2.append(hvs_qnehvi)
    
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.1, verbose=verbose)
    hvs_qnehvi_all3.append(hvs_qnehvi)
    
    ###############    

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.01, verbose=False)
    hvs_nsga3_all0.append(hvs_nsga3) 
    
    ###############

    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.025, verbose=False)
    hvs_nsga3_all1.append(hvs_nsga3) 
    
    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.05, verbose=False)
    hvs_nsga3_all2.append(hvs_nsga3) 

    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3_noconstr(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.1, verbose=False)
    hvs_nsga3_all3.append(hvs_nsga3) 
    
    ###############

savetxt(f"{problemname}_hvs_qnehvi_noise1.csv", hvs_qnehvi_all0, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise2.csv", hvs_qnehvi_all1, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise3.csv", hvs_qnehvi_all2, delimiter=',')    
savetxt(f"{problemname}_hvs_qnehvi_noise4.csv", hvs_qnehvi_all3, delimiter=',')    

savetxt(f"{problemname}_hvs_nsga3_noise1.csv", hvs_nsga3_all0, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all1, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all2, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise4.csv", hvs_nsga3_all3, delimiter=',')
    
print("ALL DONE!")

# %%
ref_point = torch.tensor([11,11], **tkwargs)

N_TRIALS = 10
verbose = True
N_BATCH = 24
BATCH_SIZE = 8

hvs_qnehvi_all0 = []
hvs_qnehvi_all1 = []
hvs_qnehvi_all2 = []
hvs_qnehvi_all3 = []

hvs_nsga3_all0 = []
hvs_nsga3_all1 = []
hvs_nsga3_all2 = []
hvs_nsga3_all3 = []

problem = Problem_MW7
problemname = 'MW7'

# main loop for each trial/run, random_state will be trial number
for trial in range(1, 10 + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} for problem {problem} with d = {dimensions}\n", end="")

    # initialize with a 2*(d+1) sample set

    initial_x = draw_sobol_samples(bounds=problem.bounds,n=1, q=2*(problem.n_var+1), seed=trial).squeeze(0)

    ###############    
    
    hvs_qnehvi, train_qnehvi = optimize_qnehvi(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.01, verbose=verbose)
    hvs_qnehvi_all0.append(hvs_qnehvi)
        
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.025, verbose=verbose)
    hvs_qnehvi_all1.append(hvs_qnehvi)

    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.05, verbose=verbose)
    hvs_qnehvi_all2.append(hvs_qnehvi)
    
    ###############    

    hvs_qnehvi, train_qnehvi = optimize_qnehvi_noconstr(problem, ref_point, initial_x,
                                                        N_BATCH=N_BATCH, BATCH_SIZE=BATCH_SIZE,
                                                        random_state=trial, noise=0.1, verbose=verbose)
    hvs_qnehvi_all3.append(hvs_qnehvi)
    
    ###############    

    hvs_nsga3, train_nsga3 = optimize_nsga3(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.01, verbose=False)
    hvs_nsga3_all0.append(hvs_nsga3) 
    
    ###############

    hvs_nsga3, train_nsga3 = optimize_nsga3(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.025, verbose=False)
    hvs_nsga3_all1.append(hvs_nsga3) 
    
    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.05, verbose=False)
    hvs_nsga3_all2.append(hvs_nsga3) 

    ###############
    
    hvs_nsga3, train_nsga3 = optimize_nsga3(problem, ref_point, initial_x,
                                                     N_BATCH=N_BATCH, pop_size=BATCH_SIZE, ref_num=BATCH_SIZE,
                                                     random_state=trial, noise=0.1, verbose=False)
    hvs_nsga3_all3.append(hvs_nsga3) 
    
    ###############

savetxt(f"{problemname}_hvs_qnehvi_noise1.csv", hvs_qnehvi_all0, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise2.csv", hvs_qnehvi_all1, delimiter=',')
savetxt(f"{problemname}_hvs_qnehvi_noise3.csv", hvs_qnehvi_all2, delimiter=',')    
savetxt(f"{problemname}_hvs_qnehvi_noise4.csv", hvs_qnehvi_all3, delimiter=',')    

savetxt(f"{problemname}_hvs_nsga3_noise1.csv", hvs_nsga3_all0, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all1, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise2.csv", hvs_nsga3_all2, delimiter=',')
savetxt(f"{problemname}_hvs_nsga3_noise4.csv", hvs_nsga3_all3, delimiter=',')
    
print("ALL DONE!")
